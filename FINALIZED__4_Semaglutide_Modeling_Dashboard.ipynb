# %% [markdown]
# <a href="https://colab.research.google.com/github/braltoids0089/BIOMEDICINE/blob/main/FINALIZED__4_Semaglutide_Modeling_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ## Modeling: Projections and Sensitivity Analysis

# %% [markdown]
# ### 📈 Modeling: Projected Semaglutide Utilization Trends
#
# We model future fills per 1,000 patients (2023–2025) based on historical data (2020–2022).

# %% [markdown]
# **Background:**
#
# Semaglutide, a glucagon-like peptide-1 (GLP-1) receptor agonist, has gained significant attention for its efficacy in managing type 2 diabetes and weight loss. As its clinical use expands, understanding the trends in its utilization and associated costs becomes crucial for healthcare stakeholders, including payers, providers, and policymakers.
#
#
#
#
# **Objectives:**
#
# This project aims to analyze the utilization and cost trends of Semaglutide in the United States using real-world data from the Centers for Medicare & Medicaid Services (CMS). The specific objectives include:
#
#
#
#
# **Quantifying Utilization:** Determine the number of Semaglutide fills and average cost per fill over the past few years (e.g., 2020-2022).
# Normalizing Utilization: Normalize utilization rates based on diabetes prevalence to account for changes in the patient population.
# Projecting Future Trends: Develop a model to project future Semaglutide utilization and cost trends.
# Sensitivity Analysis: Assess the impact of potential variations in key parameters, such as diabetes prevalence and drug cost, on projections.
# Interactive Dashboard: Create an interactive dashboard using Dash-Plotly to facilitate exploration of these trends and sensitivity analyses.
#
#
#
# **Data Sources:**
#
# The primary data source for this project is the CMS Medicare Part D Prescribers – by Provider & Drug dataset. This dataset contains information on prescription claims, including drug name, cost, and claims count, at the national level. Additional data on diabetes prevalence will be obtained from the World Health Organization (WHO) or a suitable alternative source.
#
#
#
#
# **Methods**
#
# Data from the CMS dataset will be extracted, processed, and analyzed using Python and relevant data science libraries (e.g., Pandas, NumPy, Matplotlib). A linear regression model will be used for forecasting future utilization trends. Sensitivity analyses will be conducted by varying key input parameters. An interactive dashboard will be built using Dash-Plotly for dynamic exploration of results.
#
#
#
#
# **Expected Outcomes:**
#
# This project is expected to provide insights into Semaglutide utilization patterns, associated costs, and potential future trends. The sensitivity analyses will highlight the impact of key uncertainties on the projections. The interactive dashboard will empower stakeholders to explore different scenarios and inform decision-making regarding Semaglutide usage and cost management strategies.
#
#
#
#
# **Limitations:**
#
# The analysis is limited by the availability of real-world data. Assumptions made in the projections and sensitivity analyses may introduce uncertainties. However, this project will adhere to rigorous data science principles and provide transparent reporting of any limitations.
#
#
#
#
# **Scope:**
#
# This project focuses on Semaglutide utilization and cost trends at the national level in the United States. Further research could extend the analysis to regional variations or specific patient subpopulations.

# %%
#1
import pandas as pd
import matplotlib.pyplot as plt

# 1. URLs for CY20–CY22 (just update filename for each year)
base_url = (
    "https://data.cms.gov/provider-summary-by-type-of-service/"
    "medicare-part-d-prescribers/medicare-part-d-prescribers-by-provider"
    "?download=true&filename="
)

files = {
    2020: "MUP_DPR_RY25_P04_V10_DY20_NPI.csv",
    2021: "MUP_DPR_RY25_P04_V10_DY21_NPI.csv",
    2022: "MUP_DPR_RY25_P04_V10_DY22_NPI.csv",
}

# 2. Ingest and summarize
records = []
for year, fname in files.items():
    url = base_url + fname
    df = pd.read_csv(url)

    # Print the columns of the dataframe to check for the correct column name
    print(df.columns)

    # ensure numeric, use the correct column name if it's different
    # For example, if the column name is 'total_drug_cost', use it instead:
# Out:
# Index(['<!doctype html><html lang="en"><head><base href=""><title>Centers for Medicare & Medicaid Services Data</title><script type="text/javascript" defer="defer">window.utag_cfg_ovrd={noview:!0}</script><script type="text/javascript" src="//tealium-tags.cms.gov/cms-data/prod/utag.sync.js" defer="defer"></script><script type="text/javascript" defer="defer">!function(e',
#        't', 'a', 's){e="//tealium-tags.cms.gov/cms-data/prod/utag.js"',
#        'a="script"', '(s=(t=document).createElement(a)).src=e',
#        's.type="text/java"+a', 's.async=!0',
#        '(e=t.getElementsByTagName(a)[0]).parentNode.insertBefore(s',
#        'e)}()</script><script async src="https://www.googletagmanager.com/gtag/js?id=G-V4H982QG9P"></script><script>function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[]',
#        'gtag("js"', 'new Date)', 'gtag("config"',
#        'G-V4H982QG9P)</script><meta name="google-site-verification" content="1Zz9H6vs9l-q9fVNIgjKytNZG3NSQHvL500-iQIPJzQ"/><meta charset="utf-8"/><meta name="viewport" content="width=device-width',
#        'initial-scale=1"/><meta name="theme-color" content="#000000"/><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"><link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png"><link rel="manifest" href="/site.webmanifest"><meta name="msapplication-TileColor" content="#da532c"><meta name="theme-color" content="#ffffff"><script defer="defer" src="/static/js/main.c15d125f.js"></script><link href="/static/css/main.c270c9df.css" rel="stylesheet"></head><body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root" role="main"></div></body></html>'],
#       dtype='object')
# Index(['<!doctype html><html lang="en"><head><base href=""><title>Centers for Medicare & Medicaid Services Data</title><script type="text/javascript" defer="defer">window.utag_cfg_ovrd={noview:!0}</script><script type="text/javascript" src="//tealium-tags.cms.gov/cms-data/prod/utag.sync.js" defer="defer"></script><script type="text/javascript" defer="defer">!function(e',
#        't', 'a', 's){e="//tealium-tags.cms.gov/cms-data/prod/utag.js"',
#        'a="script"', '(s=(t=document).createElement(a)).src=e',
#        's.type="text/java"+a', 's.async=!0',
#        '(e=t.getElementsByTagName(a)[0]).parentNode.insertBefore(s',
#        'e)}()</script><script async src="https://www.googletagmanager.com/gtag/js?id=G-V4H982QG9P"></script><script>function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[]',
#        'gtag("js"', 'new Date)', 'gtag("config"',
#        'G-V4H982QG9P)</script><meta name="google-site-verification" content="1Zz9H6vs9l-q9fVNIgjKytNZG3NSQHvL500-iQIPJzQ"/><meta charset="utf-8"/><meta name="viewport" content="width=device-width',
#        'initial-scale=1"/><meta name="theme-color" content="#000000"/><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"><link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png"><link rel="manifest" href="/site.webmanifest"><meta name="msapplication-TileColor" content="#da532c"><meta name="theme-color" content="#ffffff"><script defer="defer" src="/static/js/main.c15d125f.js"></script><link href="/static/css/main.c270c9df.css" rel="stylesheet"></head><body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root" role="main"></div></body></html>'],
#       dtype='object')
# Index(['<!doctype html><html lang="en"><head><base href=""><title>Centers for Medicare & Medicaid Services Data</title><script type="text/javascript" defer="defer">window.utag_cfg_ovrd={noview:!0}</script><script type="text/javascript" src="//tealium-tags.cms.gov/cms-data/prod/utag.sync.js" defer="defer"></script><script type="text/javascript" defer="defer">!function(e',
#        't', 'a', 's){e="//tealium-tags.cms.gov/cms-data/prod/utag.js"',
#        'a="script"', '(s=(t=document).createElement(a)).src=e',
#        's.type="text/java"+a', 's.async=!0',
#        '(e=t.getElementsByTagName(a)[0]).parentNode.insertBefore(s',
#        'e)}()</script><script async src="https://www.googletagmanager.com/gtag/js?id=G-V4H982QG9P"></script><script>function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[]',
#        'gtag("js"', 'new Date)', 'gtag("config"',
#        'G-V4H982QG9P)</script><meta name="google-site-verification" content="1Zz9H6vs9l-q9fVNIgjKytNZG3NSQHvL500-iQIPJzQ"/><meta charset="utf-8"/><meta name="viewport" content="width=device-width',
#        'initial-scale=1"/><meta name="theme-color" content="#000000"/><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"><link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png"><link rel="manifest" href="/site.webmanifest"><meta name="msapplication-TileColor" content="#da532c"><meta name="theme-color" content="#ffffff"><script defer="defer" src="/static/js/main.c15d125f.js"></script><link href="/static/css/main.c270c9df.css" rel="stylesheet"></head><body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root" role="main"></div></body></html>'],
#       dtype='object')

# %%
#2
import pandas as pd

# Use the CMS Data API v1 endpoint (CSV) for the “Part D Prescribers – by Provider & Drug” dataset
BASE_URL = "https://data.cms.gov/data-api/v1/dataset/9552739e-3d05-4c1b-8eff-ecabf391e2e5/data"

years = [2020, 2021, 2022]
data_samples = {}

for year in years:
    url = f"{BASE_URL}?year={year}&format=csv"
    # Load the CSV directly for that calendar year
    df = pd.read_csv(url)

    # Print a few rows and the column list for inspection
    print(f"\n=== Year {year} Sample ===")
    display(df.head(3))
    print("Columns:", df.columns.tolist())

    data_samples[year] = df
# Out:
# === Year 2020 Sample ===
# Empty DataFrame
# Columns: [[{"Prscrbr_NPI":"1003000126", Prscrbr_Last_Org_Name:"Enkeshafi", Prscrbr_First_Name:"Ardalan", Prscrbr_City:"Bethesda", Prscrbr_State_Abrvtn:"MD", Prscrbr_State_FIPS:"24", Prscrbr_Type:"Hospitalist", Prscrbr_Type_Src:"Claim-Specialty", Brnd_Name:"Eliquis", Gnrc_Name:"Apixaban", Tot_Clms:"13", Tot_30day_Fills:"15.3", Tot_Day_Suply:"437", Tot_Drug_Cst:"8828.74", Tot_Benes:"", GE65_Sprsn_Flag:"#", GE65_Tot_Clms:"", GE65_Tot_30day_Fills:"", GE65_Tot_Drug_Cst:"", GE65_Tot_Day_Suply:"", GE65_Bene_Sprsn_Flag:"*", GE65_Tot_Benes:""}, {"Prscrbr_NPI":"1003000126", Prscrbr_Last_Org_Name:"Enkeshafi".1, Prscrbr_First_Name:"Ardalan".1, Prscrbr_City:"Bethesda".1, Prscrbr_State_Abrvtn:"MD".1, Prscrbr_State_FIPS:"24".1, Prscrbr_Type:"Hospitalist".1, Prscrbr_Type_Src:"Claim-Specialty".1, Brnd_Name:"Prednisone", Gnrc_Name:"Prednisone", Tot_Clms:"14", Tot_30day_Fills:"14", Tot_Day_Suply:"153", Tot_Drug_Cst:"54.98", Tot_Benes:"14", GE65_Sprsn_Flag:"#".1, GE65_Tot_Clms:"".1, GE65_Tot_30day_Fills:"".1, GE65_Tot_Drug_Cst:"".1, GE65_Tot_Day_Suply:"".1, GE65_Bene_Sprsn_Flag:"#", GE65_Tot_Benes:""}.1, {"Prscrbr_NPI":"1003000142", Prscrbr_Last_Org_Name:"Khalil", Prscrbr_First_Name:"Rashid", Prscrbr_City:"Toledo", Prscrbr_State_Abrvtn:"OH", Prscrbr_State_FIPS:"39", Prscrbr_Type:"Anesthesiology", Prscrbr_Type_Src:"Claim-Specialty".2, Brnd_Name:"Acetaminophen-Codeine", Gnrc_Name:"Acetaminophen With Codeine", Tot_Clms:"43", Tot_30day_Fills:"43", Tot_Day_Suply:"1020", Tot_Drug_Cst:"491.38", Tot_Benes:"12", GE65_Sprsn_Flag:"#".2, GE65_Tot_Clms:"".2, GE65_Tot_30day_Fills:"".2, GE65_Tot_Drug_Cst:"".2, GE65_Tot_Day_Suply:"".2, GE65_Bene_Sprsn_Flag:"*".1, GE65_Tot_Benes:""}.2, {"Prscrbr_NPI":"1003000142".1, Prscrbr_Last_Org_Name:"Khalil".1, Prscrbr_First_Name:"Rashid".1, Prscrbr_City:"Toledo".1, Prscrbr_State_Abrvtn:"OH".1, Prscrbr_State_FIPS:"39".1, Prscrbr_Type:"Anesthesiology".1, Prscrbr_Type_Src:"Claim-Specialty".3, Brnd_Name:"Amitriptyline Hcl", Gnrc_Name:"Amitriptyline Hcl", Tot_Clms:"35", Tot_30day_Fills:"35", Tot_Day_Suply:"1050", Tot_Drug_Cst:"471.01", Tot_Benes:"15", GE65_Sprsn_Flag:"#".3, GE65_Tot_Clms:"".3, GE65_Tot_30day_Fills:"".3, GE65_Tot_Drug_Cst:"".3, GE65_Tot_Day_Suply:"".3, GE65_Bene_Sprsn_Flag:"*".2, GE65_Tot_Benes:""}.3, {"Prscrbr_NPI":"1003000142".2, Prscrbr_Last_Org_Name:"Khalil".2, Prscrbr_First_Name:"Rashid".2, Prscrbr_City:"Toledo".2, Prscrbr_State_Abrvtn:"OH".2, Prscrbr_State_FIPS:"39".2, Prscrbr_Type:"Anesthesiology".2, Prscrbr_Type_Src:"Claim-Specialty".4, Brnd_Name:"Baclofen", Gnrc_Name:"Baclofen", Tot_Clms:"55", Tot_30day_Fills:"63", ...]
# Index: []
#
# [0 rows x 22023 columns]
# Columns: ['[{"Prscrbr_NPI":"1003000126"', 'Prscrbr_Last_Org_Name:"Enkeshafi"', 'Prscrbr_First_Name:"Ardalan"', 'Prscrbr_City:"Bethesda"', 'Prscrbr_State_Abrvtn:"MD"', 'Prscrbr_State_FIPS:"24"', 'Prscrbr_Type:"Hospitalist"', 'Prscrbr_Type_Src:"Claim-Specialty"', 'Brnd_Name:"Eliquis"', 'Gnrc_Name:"Apixaban"', 'Tot_Clms:"13"', 'Tot_30day_Fills:"15.3"', 'Tot_Day_Suply:"437"', 'Tot_Drug_Cst:"8828.74"', 'Tot_Benes:""', 'GE65_Sprsn_Flag:"#"', 'GE65_Tot_Clms:""', 'GE65_Tot_30day_Fills:""', 'GE65_Tot_Drug_Cst:""', 'GE65_Tot_Day_Suply:""', 'GE65_Bene_Sprsn_Flag:"*"', 'GE65_Tot_Benes:""}', '{"Prscrbr_NPI":"1003000126"', 'Prscrbr_Last_Org_Name:"Enkeshafi".1', 'Prscrbr_First_Name:"Ardalan".1', 'Prscrbr_City:"Bethesda".1', 'Prscrbr_State_Abrvtn:"MD".1', 'Prscrbr_State_FIPS:"24".1', 'Prscrbr_Type:"Hospitalist".1', 'Prscrbr_Type_Src:"Claim-Specialty".1', 'Brnd_Name:"Prednisone"', 'Gnrc_Name:"Prednisone"', 'Tot_Clms:"14"', 'Tot_30day_Fills:"14"', 'Tot_Day_Suply:"153"', 'Tot_Drug_Cst:"54.98"', 'Tot_Benes:"14"', 'GE65_Sprsn_Flag:"#".1', 'GE65_Tot_Clms:"".1', 'GE65_Tot_30day_Fills:"".1', 'GE65_Tot_Drug_Cst:"".1', 'GE65_Tot_Day_Suply:"".1', 'GE65_Bene_Sprsn_Flag:"#"', 'GE65_Tot_Benes:""}.1', '{"Prscrbr_NPI":"1003000142"', 'Prscrbr_Last_Org_Name:"Khalil"', 'Prscrbr_First_Name:"Rashid"', 'Prscrbr_City:"Toledo"', 'Prscrbr_State_Abrvtn:"OH"', 'Prscrbr_State_FIPS:"39"', 'Prscrbr_Type:"Anesthesiology"', 'Prscrbr_Type_Src:"Claim-Specialty".2', 'Brnd_Name:"Acetaminophen-Codeine"', 'Gnrc_Name:"Acetaminophen With Codeine"', 'Tot_Clms:"43"', 'Tot_30day_Fills:"43"', 'Tot_Day_Suply:"1020"', 'Tot_Drug_Cst:"491.38"', 'Tot_Benes:"12"', 'GE65_Sprsn_Flag:"#".2', 'GE65_Tot_Clms:"".2', 'GE65_Tot_30day_Fills:"".2', 'GE65_Tot_Drug_Cst:"".2', 'GE65_Tot_Day_Suply:"".2', 'GE65_Bene_Sprsn_Flag:"*".1', 'GE65_Tot_Benes:""}.2', '{"Prscrbr_NPI":"1003000142".1', 'Prscrbr_Last_Org_Name:"Khalil".1', 'Prscrbr_First_Name:"Rashid".1', 'Prscrbr_City:"Toledo".1', 'Prscrbr_State_Abrvtn:"OH".1', 'Prscrbr_State_FIPS:"39".1', 'Prscrbr_Type:"Anesthesiology".1', 'Prscrbr_Type_Src:"Claim-Specialty".3', 'Brnd_Name:"Amitriptyline Hcl"', 'Gnrc_Name:"Amitriptyline Hcl"', 'Tot_Clms:"35"', 'Tot_30day_Fills:"35"', 'Tot_Day_Suply:"1050"', 'Tot_Drug_Cst:"471.01"', 'Tot_Benes:"15"', 'GE65_Sprsn_Flag:"#".3', 'GE65_Tot_Clms:"".3', 'GE65_Tot_30day_Fills:"".3', 'GE65_Tot_Drug_Cst:"".3', 'GE65_Tot_Day_Suply:"".3', 'GE65_Bene_Sprsn_Flag:"*".2', 'GE65_Tot_Benes:""}.3', '{"Prscrbr_NPI":"1003000142".2', 'Prscrbr_Last_Org_Name:"Khalil".2', 'Prscrbr_First_Name:"Rashid".2', 'Prscrbr_City:"Toledo".2', 'Prscrbr_State_Abrvtn:"OH".2', 'Prscrbr_State_FIPS:"39".2', 'Prscrbr_Type:"Anesthesiology".2', 'Prscrbr_Type_Src:"Claim-Specialty".4', 'Brnd_Name:"Baclofen"', 'Gnrc_Name:"Baclofen"', 'Tot_Clms:"55"', 'Tot_30day_Fills:"63"', 'Tot_Day_Suply:"1890"', 'Tot_Drug_Cst:"796.1"', 'Tot_Benes:"23"', 'GE65_Sprsn_Flag:""', 'GE65_Tot_Clms:"27"', 'GE65_Tot_30day_Fills:"29"', 'GE65_Tot_Drug_Cst:"417.86"', 'GE65_Tot_Day_Suply:"870"', 'GE65_Bene_Sprsn_Flag:"*".3', 'GE65_Tot_Benes:""}.4', '{"Prscrbr_NPI":"1003000142".3', 'Prscrbr_Last_Org_Name:"Khalil".3', 'Prscrbr_First_Name:"Rashid".3', 'Prscrbr_City:"Toledo".3', 'Prscrbr_State_Abrvtn:"OH".3', 'Prscrbr_State_FIPS:"39".3', 'Prscrbr_Type:"Anesthesiology".3', 'Prscrbr_Type_Src:"Claim-Specialty".5', 'Brnd_Name:"Buprenorphine"', 'Gnrc_Name:"Buprenorphine"', 'Tot_Clms:"16"', 'Tot_30day_Fills:"16"', 'Tot_Day_Suply:"448"', 'Tot_Drug_Cst:"6229.05"', 'Tot_Benes:"".1', 'GE65_Sprsn_Flag:"*"', 'GE65_Tot_Clms:"".4', 'GE65_Tot_30day_Fills:"".4', 'GE65_Tot_Drug_Cst:"".4', 'GE65_Tot_Day_Suply:"".4', 'GE65_Bene_Sprsn_Flag:"*".4', 'GE65_Tot_Benes:""}.5', '{"Prscrbr_NPI":"1003000142".4', 'Prscrbr_Last_Org_Name:"Khalil".4', 'Prscrbr_First_Name:"Rashid".4', 'Prscrbr_City:"Toledo".4', 'Prscrbr_State_Abrvtn:"OH".4', 'Prscrbr_State_FIPS:"39".4', 'Prscrbr_Type:"Anesthesiology".4', 'Prscrbr_Type_Src:"Claim-Specialty".6', 'Brnd_Name:"Cyclobenzaprine Hcl"', 'Gnrc_Name:"Cyclobenzaprine Hcl"', 'Tot_Clms:"54"', 'To ...
#
# === Year 2021 Sample ===
# Empty DataFrame
# Columns: [[{"Prscrbr_NPI":"1003000126", Prscrbr_Last_Org_Name:"Enkeshafi", Prscrbr_First_Name:"Ardalan", Prscrbr_City:"Bethesda", Prscrbr_State_Abrvtn:"MD", Prscrbr_State_FIPS:"24", Prscrbr_Type:"Hospitalist", Prscrbr_Type_Src:"Claim-Specialty", Brnd_Name:"Eliquis", Gnrc_Name:"Apixaban", Tot_Clms:"13", Tot_30day_Fills:"15.3", Tot_Day_Suply:"437", Tot_Drug_Cst:"8828.74", Tot_Benes:"", GE65_Sprsn_Flag:"#", GE65_Tot_Clms:"", GE65_Tot_30day_Fills:"", GE65_Tot_Drug_Cst:"", GE65_Tot_Day_Suply:"", GE65_Bene_Sprsn_Flag:"*", GE65_Tot_Benes:""}, {"Prscrbr_NPI":"1003000126", Prscrbr_Last_Org_Name:"Enkeshafi".1, Prscrbr_First_Name:"Ardalan".1, Prscrbr_City:"Bethesda".1, Prscrbr_State_Abrvtn:"MD".1, Prscrbr_State_FIPS:"24".1, Prscrbr_Type:"Hospitalist".1, Prscrbr_Type_Src:"Claim-Specialty".1, Brnd_Name:"Prednisone", Gnrc_Name:"Prednisone", Tot_Clms:"14", Tot_30day_Fills:"14", Tot_Day_Suply:"153", Tot_Drug_Cst:"54.98", Tot_Benes:"14", GE65_Sprsn_Flag:"#".1, GE65_Tot_Clms:"".1, GE65_Tot_30day_Fills:"".1, GE65_Tot_Drug_Cst:"".1, GE65_Tot_Day_Suply:"".1, GE65_Bene_Sprsn_Flag:"#", GE65_Tot_Benes:""}.1, {"Prscrbr_NPI":"1003000142", Prscrbr_Last_Org_Name:"Khalil", Prscrbr_First_Name:"Rashid", Prscrbr_City:"Toledo", Prscrbr_State_Abrvtn:"OH", Prscrbr_State_FIPS:"39", Prscrbr_Type:"Anesthesiology", Prscrbr_Type_Src:"Claim-Specialty".2, Brnd_Name:"Acetaminophen-Codeine", Gnrc_Name:"Acetaminophen With Codeine", Tot_Clms:"43", Tot_30day_Fills:"43", Tot_Day_Suply:"1020", Tot_Drug_Cst:"491.38", Tot_Benes:"12", GE65_Sprsn_Flag:"#".2, GE65_Tot_Clms:"".2, GE65_Tot_30day_Fills:"".2, GE65_Tot_Drug_Cst:"".2, GE65_Tot_Day_Suply:"".2, GE65_Bene_Sprsn_Flag:"*".1, GE65_Tot_Benes:""}.2, {"Prscrbr_NPI":"1003000142".1, Prscrbr_Last_Org_Name:"Khalil".1, Prscrbr_First_Name:"Rashid".1, Prscrbr_City:"Toledo".1, Prscrbr_State_Abrvtn:"OH".1, Prscrbr_State_FIPS:"39".1, Prscrbr_Type:"Anesthesiology".1, Prscrbr_Type_Src:"Claim-Specialty".3, Brnd_Name:"Amitriptyline Hcl", Gnrc_Name:"Amitriptyline Hcl", Tot_Clms:"35", Tot_30day_Fills:"35", Tot_Day_Suply:"1050", Tot_Drug_Cst:"471.01", Tot_Benes:"15", GE65_Sprsn_Flag:"#".3, GE65_Tot_Clms:"".3, GE65_Tot_30day_Fills:"".3, GE65_Tot_Drug_Cst:"".3, GE65_Tot_Day_Suply:"".3, GE65_Bene_Sprsn_Flag:"*".2, GE65_Tot_Benes:""}.3, {"Prscrbr_NPI":"1003000142".2, Prscrbr_Last_Org_Name:"Khalil".2, Prscrbr_First_Name:"Rashid".2, Prscrbr_City:"Toledo".2, Prscrbr_State_Abrvtn:"OH".2, Prscrbr_State_FIPS:"39".2, Prscrbr_Type:"Anesthesiology".2, Prscrbr_Type_Src:"Claim-Specialty".4, Brnd_Name:"Baclofen", Gnrc_Name:"Baclofen", Tot_Clms:"55", Tot_30day_Fills:"63", ...]
# Index: []
#
# [0 rows x 22023 columns]
# Columns: ['[{"Prscrbr_NPI":"1003000126"', 'Prscrbr_Last_Org_Name:"Enkeshafi"', 'Prscrbr_First_Name:"Ardalan"', 'Prscrbr_City:"Bethesda"', 'Prscrbr_State_Abrvtn:"MD"', 'Prscrbr_State_FIPS:"24"', 'Prscrbr_Type:"Hospitalist"', 'Prscrbr_Type_Src:"Claim-Specialty"', 'Brnd_Name:"Eliquis"', 'Gnrc_Name:"Apixaban"', 'Tot_Clms:"13"', 'Tot_30day_Fills:"15.3"', 'Tot_Day_Suply:"437"', 'Tot_Drug_Cst:"8828.74"', 'Tot_Benes:""', 'GE65_Sprsn_Flag:"#"', 'GE65_Tot_Clms:""', 'GE65_Tot_30day_Fills:""', 'GE65_Tot_Drug_Cst:""', 'GE65_Tot_Day_Suply:""', 'GE65_Bene_Sprsn_Flag:"*"', 'GE65_Tot_Benes:""}', '{"Prscrbr_NPI":"1003000126"', 'Prscrbr_Last_Org_Name:"Enkeshafi".1', 'Prscrbr_First_Name:"Ardalan".1', 'Prscrbr_City:"Bethesda".1', 'Prscrbr_State_Abrvtn:"MD".1', 'Prscrbr_State_FIPS:"24".1', 'Prscrbr_Type:"Hospitalist".1', 'Prscrbr_Type_Src:"Claim-Specialty".1', 'Brnd_Name:"Prednisone"', 'Gnrc_Name:"Prednisone"', 'Tot_Clms:"14"', 'Tot_30day_Fills:"14"', 'Tot_Day_Suply:"153"', 'Tot_Drug_Cst:"54.98"', 'Tot_Benes:"14"', 'GE65_Sprsn_Flag:"#".1', 'GE65_Tot_Clms:"".1', 'GE65_Tot_30day_Fills:"".1', 'GE65_Tot_Drug_Cst:"".1', 'GE65_Tot_Day_Suply:"".1', 'GE65_Bene_Sprsn_Flag:"#"', 'GE65_Tot_Benes:""}.1', '{"Prscrbr_NPI":"1003000142"', 'Prscrbr_Last_Org_Name:"Khalil"', 'Prscrbr_First_Name:"Rashid"', 'Prscrbr_City:"Toledo"', 'Prscrbr_State_Abrvtn:"OH"', 'Prscrbr_State_FIPS:"39"', 'Prscrbr_Type:"Anesthesiology"', 'Prscrbr_Type_Src:"Claim-Specialty".2', 'Brnd_Name:"Acetaminophen-Codeine"', 'Gnrc_Name:"Acetaminophen With Codeine"', 'Tot_Clms:"43"', 'Tot_30day_Fills:"43"', 'Tot_Day_Suply:"1020"', 'Tot_Drug_Cst:"491.38"', 'Tot_Benes:"12"', 'GE65_Sprsn_Flag:"#".2', 'GE65_Tot_Clms:"".2', 'GE65_Tot_30day_Fills:"".2', 'GE65_Tot_Drug_Cst:"".2', 'GE65_Tot_Day_Suply:"".2', 'GE65_Bene_Sprsn_Flag:"*".1', 'GE65_Tot_Benes:""}.2', '{"Prscrbr_NPI":"1003000142".1', 'Prscrbr_Last_Org_Name:"Khalil".1', 'Prscrbr_First_Name:"Rashid".1', 'Prscrbr_City:"Toledo".1', 'Prscrbr_State_Abrvtn:"OH".1', 'Prscrbr_State_FIPS:"39".1', 'Prscrbr_Type:"Anesthesiology".1', 'Prscrbr_Type_Src:"Claim-Specialty".3', 'Brnd_Name:"Amitriptyline Hcl"', 'Gnrc_Name:"Amitriptyline Hcl"', 'Tot_Clms:"35"', 'Tot_30day_Fills:"35"', 'Tot_Day_Suply:"1050"', 'Tot_Drug_Cst:"471.01"', 'Tot_Benes:"15"', 'GE65_Sprsn_Flag:"#".3', 'GE65_Tot_Clms:"".3', 'GE65_Tot_30day_Fills:"".3', 'GE65_Tot_Drug_Cst:"".3', 'GE65_Tot_Day_Suply:"".3', 'GE65_Bene_Sprsn_Flag:"*".2', 'GE65_Tot_Benes:""}.3', '{"Prscrbr_NPI":"1003000142".2', 'Prscrbr_Last_Org_Name:"Khalil".2', 'Prscrbr_First_Name:"Rashid".2', 'Prscrbr_City:"Toledo".2', 'Prscrbr_State_Abrvtn:"OH".2', 'Prscrbr_State_FIPS:"39".2', 'Prscrbr_Type:"Anesthesiology".2', 'Prscrbr_Type_Src:"Claim-Specialty".4', 'Brnd_Name:"Baclofen"', 'Gnrc_Name:"Baclofen"', 'Tot_Clms:"55"', 'Tot_30day_Fills:"63"', 'Tot_Day_Suply:"1890"', 'Tot_Drug_Cst:"796.1"', 'Tot_Benes:"23"', 'GE65_Sprsn_Flag:""', 'GE65_Tot_Clms:"27"', 'GE65_Tot_30day_Fills:"29"', 'GE65_Tot_Drug_Cst:"417.86"', 'GE65_Tot_Day_Suply:"870"', 'GE65_Bene_Sprsn_Flag:"*".3', 'GE65_Tot_Benes:""}.4', '{"Prscrbr_NPI":"1003000142".3', 'Prscrbr_Last_Org_Name:"Khalil".3', 'Prscrbr_First_Name:"Rashid".3', 'Prscrbr_City:"Toledo".3', 'Prscrbr_State_Abrvtn:"OH".3', 'Prscrbr_State_FIPS:"39".3', 'Prscrbr_Type:"Anesthesiology".3', 'Prscrbr_Type_Src:"Claim-Specialty".5', 'Brnd_Name:"Buprenorphine"', 'Gnrc_Name:"Buprenorphine"', 'Tot_Clms:"16"', 'Tot_30day_Fills:"16"', 'Tot_Day_Suply:"448"', 'Tot_Drug_Cst:"6229.05"', 'Tot_Benes:"".1', 'GE65_Sprsn_Flag:"*"', 'GE65_Tot_Clms:"".4', 'GE65_Tot_30day_Fills:"".4', 'GE65_Tot_Drug_Cst:"".4', 'GE65_Tot_Day_Suply:"".4', 'GE65_Bene_Sprsn_Flag:"*".4', 'GE65_Tot_Benes:""}.5', '{"Prscrbr_NPI":"1003000142".4', 'Prscrbr_Last_Org_Name:"Khalil".4', 'Prscrbr_First_Name:"Rashid".4', 'Prscrbr_City:"Toledo".4', 'Prscrbr_State_Abrvtn:"OH".4', 'Prscrbr_State_FIPS:"39".4', 'Prscrbr_Type:"Anesthesiology".4', 'Prscrbr_Type_Src:"Claim-Specialty".6', 'Brnd_Name:"Cyclobenzaprine Hcl"', 'Gnrc_Name:"Cyclobenzaprine Hcl"', 'Tot_Clms:"54"', 'To ...
#
# === Year 2022 Sample ===
# Empty DataFrame
# Columns: [[{"Prscrbr_NPI":"1003000126", Prscrbr_Last_Org_Name:"Enkeshafi", Prscrbr_First_Name:"Ardalan", Prscrbr_City:"Bethesda", Prscrbr_State_Abrvtn:"MD", Prscrbr_State_FIPS:"24", Prscrbr_Type:"Hospitalist", Prscrbr_Type_Src:"Claim-Specialty", Brnd_Name:"Eliquis", Gnrc_Name:"Apixaban", Tot_Clms:"13", Tot_30day_Fills:"15.3", Tot_Day_Suply:"437", Tot_Drug_Cst:"8828.74", Tot_Benes:"", GE65_Sprsn_Flag:"#", GE65_Tot_Clms:"", GE65_Tot_30day_Fills:"", GE65_Tot_Drug_Cst:"", GE65_Tot_Day_Suply:"", GE65_Bene_Sprsn_Flag:"*", GE65_Tot_Benes:""}, {"Prscrbr_NPI":"1003000126", Prscrbr_Last_Org_Name:"Enkeshafi".1, Prscrbr_First_Name:"Ardalan".1, Prscrbr_City:"Bethesda".1, Prscrbr_State_Abrvtn:"MD".1, Prscrbr_State_FIPS:"24".1, Prscrbr_Type:"Hospitalist".1, Prscrbr_Type_Src:"Claim-Specialty".1, Brnd_Name:"Prednisone", Gnrc_Name:"Prednisone", Tot_Clms:"14", Tot_30day_Fills:"14", Tot_Day_Suply:"153", Tot_Drug_Cst:"54.98", Tot_Benes:"14", GE65_Sprsn_Flag:"#".1, GE65_Tot_Clms:"".1, GE65_Tot_30day_Fills:"".1, GE65_Tot_Drug_Cst:"".1, GE65_Tot_Day_Suply:"".1, GE65_Bene_Sprsn_Flag:"#", GE65_Tot_Benes:""}.1, {"Prscrbr_NPI":"1003000142", Prscrbr_Last_Org_Name:"Khalil", Prscrbr_First_Name:"Rashid", Prscrbr_City:"Toledo", Prscrbr_State_Abrvtn:"OH", Prscrbr_State_FIPS:"39", Prscrbr_Type:"Anesthesiology", Prscrbr_Type_Src:"Claim-Specialty".2, Brnd_Name:"Acetaminophen-Codeine", Gnrc_Name:"Acetaminophen With Codeine", Tot_Clms:"43", Tot_30day_Fills:"43", Tot_Day_Suply:"1020", Tot_Drug_Cst:"491.38", Tot_Benes:"12", GE65_Sprsn_Flag:"#".2, GE65_Tot_Clms:"".2, GE65_Tot_30day_Fills:"".2, GE65_Tot_Drug_Cst:"".2, GE65_Tot_Day_Suply:"".2, GE65_Bene_Sprsn_Flag:"*".1, GE65_Tot_Benes:""}.2, {"Prscrbr_NPI":"1003000142".1, Prscrbr_Last_Org_Name:"Khalil".1, Prscrbr_First_Name:"Rashid".1, Prscrbr_City:"Toledo".1, Prscrbr_State_Abrvtn:"OH".1, Prscrbr_State_FIPS:"39".1, Prscrbr_Type:"Anesthesiology".1, Prscrbr_Type_Src:"Claim-Specialty".3, Brnd_Name:"Amitriptyline Hcl", Gnrc_Name:"Amitriptyline Hcl", Tot_Clms:"35", Tot_30day_Fills:"35", Tot_Day_Suply:"1050", Tot_Drug_Cst:"471.01", Tot_Benes:"15", GE65_Sprsn_Flag:"#".3, GE65_Tot_Clms:"".3, GE65_Tot_30day_Fills:"".3, GE65_Tot_Drug_Cst:"".3, GE65_Tot_Day_Suply:"".3, GE65_Bene_Sprsn_Flag:"*".2, GE65_Tot_Benes:""}.3, {"Prscrbr_NPI":"1003000142".2, Prscrbr_Last_Org_Name:"Khalil".2, Prscrbr_First_Name:"Rashid".2, Prscrbr_City:"Toledo".2, Prscrbr_State_Abrvtn:"OH".2, Prscrbr_State_FIPS:"39".2, Prscrbr_Type:"Anesthesiology".2, Prscrbr_Type_Src:"Claim-Specialty".4, Brnd_Name:"Baclofen", Gnrc_Name:"Baclofen", Tot_Clms:"55", Tot_30day_Fills:"63", ...]
# Index: []
#
# [0 rows x 22023 columns]
# Columns: ['[{"Prscrbr_NPI":"1003000126"', 'Prscrbr_Last_Org_Name:"Enkeshafi"', 'Prscrbr_First_Name:"Ardalan"', 'Prscrbr_City:"Bethesda"', 'Prscrbr_State_Abrvtn:"MD"', 'Prscrbr_State_FIPS:"24"', 'Prscrbr_Type:"Hospitalist"', 'Prscrbr_Type_Src:"Claim-Specialty"', 'Brnd_Name:"Eliquis"', 'Gnrc_Name:"Apixaban"', 'Tot_Clms:"13"', 'Tot_30day_Fills:"15.3"', 'Tot_Day_Suply:"437"', 'Tot_Drug_Cst:"8828.74"', 'Tot_Benes:""', 'GE65_Sprsn_Flag:"#"', 'GE65_Tot_Clms:""', 'GE65_Tot_30day_Fills:""', 'GE65_Tot_Drug_Cst:""', 'GE65_Tot_Day_Suply:""', 'GE65_Bene_Sprsn_Flag:"*"', 'GE65_Tot_Benes:""}', '{"Prscrbr_NPI":"1003000126"', 'Prscrbr_Last_Org_Name:"Enkeshafi".1', 'Prscrbr_First_Name:"Ardalan".1', 'Prscrbr_City:"Bethesda".1', 'Prscrbr_State_Abrvtn:"MD".1', 'Prscrbr_State_FIPS:"24".1', 'Prscrbr_Type:"Hospitalist".1', 'Prscrbr_Type_Src:"Claim-Specialty".1', 'Brnd_Name:"Prednisone"', 'Gnrc_Name:"Prednisone"', 'Tot_Clms:"14"', 'Tot_30day_Fills:"14"', 'Tot_Day_Suply:"153"', 'Tot_Drug_Cst:"54.98"', 'Tot_Benes:"14"', 'GE65_Sprsn_Flag:"#".1', 'GE65_Tot_Clms:"".1', 'GE65_Tot_30day_Fills:"".1', 'GE65_Tot_Drug_Cst:"".1', 'GE65_Tot_Day_Suply:"".1', 'GE65_Bene_Sprsn_Flag:"#"', 'GE65_Tot_Benes:""}.1', '{"Prscrbr_NPI":"1003000142"', 'Prscrbr_Last_Org_Name:"Khalil"', 'Prscrbr_First_Name:"Rashid"', 'Prscrbr_City:"Toledo"', 'Prscrbr_State_Abrvtn:"OH"', 'Prscrbr_State_FIPS:"39"', 'Prscrbr_Type:"Anesthesiology"', 'Prscrbr_Type_Src:"Claim-Specialty".2', 'Brnd_Name:"Acetaminophen-Codeine"', 'Gnrc_Name:"Acetaminophen With Codeine"', 'Tot_Clms:"43"', 'Tot_30day_Fills:"43"', 'Tot_Day_Suply:"1020"', 'Tot_Drug_Cst:"491.38"', 'Tot_Benes:"12"', 'GE65_Sprsn_Flag:"#".2', 'GE65_Tot_Clms:"".2', 'GE65_Tot_30day_Fills:"".2', 'GE65_Tot_Drug_Cst:"".2', 'GE65_Tot_Day_Suply:"".2', 'GE65_Bene_Sprsn_Flag:"*".1', 'GE65_Tot_Benes:""}.2', '{"Prscrbr_NPI":"1003000142".1', 'Prscrbr_Last_Org_Name:"Khalil".1', 'Prscrbr_First_Name:"Rashid".1', 'Prscrbr_City:"Toledo".1', 'Prscrbr_State_Abrvtn:"OH".1', 'Prscrbr_State_FIPS:"39".1', 'Prscrbr_Type:"Anesthesiology".1', 'Prscrbr_Type_Src:"Claim-Specialty".3', 'Brnd_Name:"Amitriptyline Hcl"', 'Gnrc_Name:"Amitriptyline Hcl"', 'Tot_Clms:"35"', 'Tot_30day_Fills:"35"', 'Tot_Day_Suply:"1050"', 'Tot_Drug_Cst:"471.01"', 'Tot_Benes:"15"', 'GE65_Sprsn_Flag:"#".3', 'GE65_Tot_Clms:"".3', 'GE65_Tot_30day_Fills:"".3', 'GE65_Tot_Drug_Cst:"".3', 'GE65_Tot_Day_Suply:"".3', 'GE65_Bene_Sprsn_Flag:"*".2', 'GE65_Tot_Benes:""}.3', '{"Prscrbr_NPI":"1003000142".2', 'Prscrbr_Last_Org_Name:"Khalil".2', 'Prscrbr_First_Name:"Rashid".2', 'Prscrbr_City:"Toledo".2', 'Prscrbr_State_Abrvtn:"OH".2', 'Prscrbr_State_FIPS:"39".2', 'Prscrbr_Type:"Anesthesiology".2', 'Prscrbr_Type_Src:"Claim-Specialty".4', 'Brnd_Name:"Baclofen"', 'Gnrc_Name:"Baclofen"', 'Tot_Clms:"55"', 'Tot_30day_Fills:"63"', 'Tot_Day_Suply:"1890"', 'Tot_Drug_Cst:"796.1"', 'Tot_Benes:"23"', 'GE65_Sprsn_Flag:""', 'GE65_Tot_Clms:"27"', 'GE65_Tot_30day_Fills:"29"', 'GE65_Tot_Drug_Cst:"417.86"', 'GE65_Tot_Day_Suply:"870"', 'GE65_Bene_Sprsn_Flag:"*".3', 'GE65_Tot_Benes:""}.4', '{"Prscrbr_NPI":"1003000142".3', 'Prscrbr_Last_Org_Name:"Khalil".3', 'Prscrbr_First_Name:"Rashid".3', 'Prscrbr_City:"Toledo".3', 'Prscrbr_State_Abrvtn:"OH".3', 'Prscrbr_State_FIPS:"39".3', 'Prscrbr_Type:"Anesthesiology".3', 'Prscrbr_Type_Src:"Claim-Specialty".5', 'Brnd_Name:"Buprenorphine"', 'Gnrc_Name:"Buprenorphine"', 'Tot_Clms:"16"', 'Tot_30day_Fills:"16"', 'Tot_Day_Suply:"448"', 'Tot_Drug_Cst:"6229.05"', 'Tot_Benes:"".1', 'GE65_Sprsn_Flag:"*"', 'GE65_Tot_Clms:"".4', 'GE65_Tot_30day_Fills:"".4', 'GE65_Tot_Drug_Cst:"".4', 'GE65_Tot_Day_Suply:"".4', 'GE65_Bene_Sprsn_Flag:"*".4', 'GE65_Tot_Benes:""}.5', '{"Prscrbr_NPI":"1003000142".4', 'Prscrbr_Last_Org_Name:"Khalil".4', 'Prscrbr_First_Name:"Rashid".4', 'Prscrbr_City:"Toledo".4', 'Prscrbr_State_Abrvtn:"OH".4', 'Prscrbr_State_FIPS:"39".4', 'Prscrbr_Type:"Anesthesiology".4', 'Prscrbr_Type_Src:"Claim-Specialty".6', 'Brnd_Name:"Cyclobenzaprine Hcl"', 'Gnrc_Name:"Cyclobenzaprine Hcl"', 'Tot_Clms:"54"', 'To ...

# %%
#3
import pandas as pd
import requests
import matplotlib.pyplot as plt

# === CONFIGURATION ===
BASE_URL_CMS = "https://data.cms.gov/data-api/v1/dataset/9552739e-3d05-4c1b-8eff-ecabf391e2e5/data"
years = [2020, 2021, 2022]

# === STEP 0: Detect columns and hardcode correct mappings ===
# Fetch a small sample for column inspection
df_sample = pd.read_csv(f"{BASE_URL_CMS}?year={years[0]}&format=csv", nrows=5)

# Access the correct column names directly (adjust index if needed)
generic_col = df_sample.columns[0]  # Assuming Drug Name is the first column
cost_col = df_sample.columns[1]    # Assuming Total Drug Cost is the second
claims_col = df_sample.columns[2]   # Assuming Total Claims is the third

print(f"\nUsing Columns -> Generic: {generic_col} | Cost: {cost_col} | Claims: {claims_col}")

# === ... (Rest of the code remains the same) ... ===
# Out:
# Using Columns -> Generic: [{"Prscrbr_NPI":"1003000126" | Cost: Prscrbr_Last_Org_Name:"Enkeshafi" | Claims: Prscrbr_First_Name:"Ardalan"

# %%
#4
# === STEP 1: Build semaglutide summary from CMS data ===
records = []
for y in years:
    print(f"\nProcessing Year: {y}...")
    df = pd.read_csv(f"{BASE_URL_CMS}?year={y}&format=csv")

    # Filter for semaglutide (case-insensitive match)
    semag = df[df[generic_col].str.contains("semaglutide", case=False, na=False)]

    total_fills = semag[claims_col].sum()
    total_cost = semag[cost_col].sum()
    avg_cost = total_cost / total_fills if total_fills else 0

    records.append({
        "Year": y,
        "Total Fills": total_fills,
        "Avg Cost per Fill": avg_cost
    })

summary = pd.DataFrame(records).sort_values("Year")
print("\nSummary Table (Semaglutide Utilization & Cost):")
display(summary)
# Out:
# Processing Year: 2020...
#
# Processing Year: 2021...
#
# Processing Year: 2022...
#
# Summary Table (Semaglutide Utilization & Cost):
#    Year  Total Fills  Avg Cost per Fill
# 0  2020            0                  0
# 1  2021            0                  0
# 2  2022            0                  0

# %%
#5
# === STEP 3: Merge CMS data + Mock WHO data and normalize ===
# --- Mock prevalence data (replace with actual WHO data if available) ---
prev_df = pd.DataFrame({
    "Year": [2020, 2021, 2022],
    "Prevalence": [10.5, 10.7, 10.8]  # Example realistic values (you can adjust if needed)
})
# --- End of mock data ---

df_norm = pd.merge(summary, prev_df[['Year', 'Prevalence']], on='Year', how='inner')
df_norm['Fills per 1,000 Patients'] = df_norm['Total Fills'] / (df_norm['Prevalence'] * 1000)

print("\nNormalized Utilization per 1,000 Patients:")
display(df_norm[['Year', 'Total Fills', 'Prevalence', 'Fills per 1,000 Patients']])
# Out:
# Normalized Utilization per 1,000 Patients:
#    Year  Total Fills  Prevalence  Fills per 1,000 Patients
# 0  2020            0        10.5                       0.0
# 1  2021            0        10.7                       0.0
# 2  2022            0        10.8                       0.0

# %%
#6
# === STEP 4: Visualization ===
plt.figure(figsize=(8, 5))
plt.plot(df_norm['Year'], df_norm['Fills per 1,000 Patients'], marker='o', linestyle='-')
plt.title('Semaglutide Fills per 1,000 Diabetic Patients (USA, 2020–2022)')
plt.xlabel('Year')
plt.ylabel('Fills per 1,000 Patients')
plt.grid(True)
plt.show()

#5
# Re-inspect CMS file structure
df_sample = pd.read_csv(f"{BASE_URL_CMS}?year={years[0]}&format=csv", nrows=5)
cols = df_sample.columns.tolist()

print("\n🔎 Columns found in CMS 2020 sample:")
for c in cols:
    print(c)
# Out:
# 🔎 Columns found in CMS 2020 sample:
# [{"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi"
# Prscrbr_First_Name:"Ardalan"
# Prscrbr_City:"Bethesda"
# Prscrbr_State_Abrvtn:"MD"
# Prscrbr_State_FIPS:"24"
# Prscrbr_Type:"Hospitalist"
# Prscrbr_Type_Src:"Claim-Specialty"
# Brnd_Name:"Eliquis"
# Gnrc_Name:"Apixaban"
# Tot_Clms:"13"
# Tot_30day_Fills:"15.3"
# Tot_Day_Suply:"437"
# Tot_Drug_Cst:"8828.74"
# Tot_Benes:""
# GE65_Sprsn_Flag:"#"
# GE65_Tot_Clms:""
# GE65_Tot_30day_Fills:""
# GE65_Tot_Drug_Cst:""
# GE65_Tot_Day_Suply:""
# GE65_Bene_Sprsn_Flag:"*"
# GE65_Tot_Benes:""}
# {"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi".1
# Prscrbr_First_Name:"Ardalan".1
# Prscrbr_City:"Bethesda".1
# Prscrbr_State_Abrvtn:"MD".1
# Prscrbr_State_FIPS:"24".1
# Prscrbr_Type:"Hospitalist".1
# Prscrbr_Type_Src:"Claim-Specialty".1
# Brnd_Name:"Prednisone"
# Gnrc_Name:"Prednisone"
# Tot_Clms:"14"
# Tot_30day_Fills:"14"
# Tot_Day_Suply:"153"
# Tot_Drug_Cst:"54.98"
# Tot_Benes:"14"
# GE65_Sprsn_Flag:"#".1
# GE65_Tot_Clms:"".1
# GE65_Tot_30day_Fills:"".1
# GE65_Tot_Drug_Cst:"".1
# GE65_Tot_Day_Suply:"".1
# GE65_Bene_Sprsn_Flag:"#"
# GE65_Tot_Benes:""}.1
# {"Prscrbr_NPI":"1003000142"
# Prscrbr_Last_Org_Name:"Khalil"
# Prscrbr_First_Name:"Rashid"
# Prscrbr_City:"Toledo"
# Prscrbr_State_Abrvtn:"OH"
# Prscrbr_State_FIPS:"39"
# Prscrbr_Type:"Anesthesiology"
# Prscrbr_Type_Src:"Claim-Specialty".2
# Brnd_Name:"Acetaminophen-Codeine"
# Gnrc_Name:"Acetaminophen With Codeine"
# Tot_Clms:"43"
# Tot_30day_Fills:"43"
# Tot_Day_Suply:"1020"
# Tot_Drug_Cst:"491.38"
# Tot_Benes:"12"
# GE65_Sprsn_Flag:"#".2
# GE65_Tot_Clms:"".2
# GE65_Tot_30day_Fills:"".2
# GE65_Tot_Drug_Cst:"".2
# GE65_Tot_Day_Suply:"".2
# GE65_Bene_Sprsn_Flag:"*".1
# GE65_Tot_Benes:""}.2
# {"Prscrbr_NPI":"1003000142".1
# Prscrbr_Last_Org_Name:"Khalil".1
# Prscrbr_First_Name:"Rashid".1
# Prscrbr_City:"Toledo".1
# Prscrbr_State_Abrvtn:"OH".1
# Prscrbr_State_FIPS:"39".1
# Prscrbr_Type:"Anesthesiology".1
# Prscrbr_Type_Src:"Claim-Specialty".3
# Brnd_Name:"Amitriptyline Hcl"
# Gnrc_Name:"Amitriptyline Hcl"
# Tot_Clms:"35"
# Tot_30day_Fills:"35"
# Tot_Day_Suply:"1050"
# Tot_Drug_Cst:"471.01"
# Tot_Benes:"15"
# GE65_Sprsn_Flag:"#".3
# GE65_Tot_Clms:"".3
# GE65_Tot_30day_Fills:"".3
# GE65_Tot_Drug_Cst:"".3
# GE65_Tot_Day_Suply:"".3
# GE65_Bene_Sprsn_Flag:"*".2
# GE65_Tot_Benes:""}.3
# {"Prscrbr_NPI":"1003000142".2
# Prscrbr_Last_Org_Name:"Khalil".2
# Prscrbr_First_Name:"Rashid".2
# Prscrbr_City:"Toledo".2
# Prscrbr_State_Abrvtn:"OH".2
# Prscrbr_State_FIPS:"39".2
# Prscrbr_Type:"Anesthesiology".2
# Prscrbr_Type_Src:"Claim-Specialty".4
# Brnd_Name:"Baclofen"
# Gnrc_Name:"Baclofen"
# Tot_Clms:"55"
# Tot_30day_Fills:"63"
# Tot_Day_Suply:"1890"
# Tot_Drug_Cst:"796.1"
# Tot_Benes:"23"
# GE65_Sprsn_Flag:""
# GE65_Tot_Clms:"27"
# GE65_Tot_30day_Fills:"29"
# GE65_Tot_Drug_Cst:"417.86"
# GE65_Tot_Day_Suply:"870"
# GE65_Bene_Sprsn_Flag:"*".3
# GE65_Tot_Benes:""}.4
# {"Prscrbr_NPI":"1003000142".3
# Prscrbr_Last_Org_Name:"Khalil".3
# Prscrbr_First_Name:"Rashid".3
# Prscrbr_City:"Toledo".3
# Prscrbr_State_Abrvtn:"OH".3
# Prscrbr_State_FIPS:"39".3
# Prscrbr_Type:"Anesthesiology".3
# Prscrbr_Type_Src:"Claim-Specialty".5
# Brnd_Name:"Buprenorphine"
# Gnrc_Name:"Buprenorphine"
# Tot_Clms:"16"
# Tot_30day_Fills:"16"
# Tot_Day_Suply:"448"
# Tot_Drug_Cst:"6229.05"
# Tot_Benes:"".1
# GE65_Sprsn_Flag:"*"
# GE65_Tot_Clms:"".4
# GE65_Tot_30day_Fills:"".4
# GE65_Tot_Drug_Cst:"".4
# GE65_Tot_Day_Suply:"".4
# GE65_Bene_Sprsn_Flag:"*".4
# GE65_Tot_Benes:""}.5
# {"Prscrbr_NPI":"1003000142".4
# Prscrbr_Last_Org_Name:"Khalil".4
# Prscrbr_First_Name:"Rashid".4
# Prscrbr_City:"Toledo".4
# Prscrbr_State_Abrvtn:"OH".4
# Prscrbr_State_FIPS:"39".4
# Prscrbr_Type:"Anesthesiology".4
# Prscrbr_Type_Src:"Claim-Specialty".6
# Brnd_Name:"Cyclobenzaprine Hcl"
# Gnrc_Name:"Cyclobenzaprine Hcl"
# Tot_Clms:"54"
# Tot_30day_Fills:"56"
# Tot_Day_Suply:"1645"
# Tot_Drug_Cst:"572.47"
# Tot_Benes:"30"
# GE65_Sprsn_Flag:"".1
# GE65_Tot_Clms:"16"
# GE65_Tot_30day_Fills:"16"
# GE65_Tot_Drug_Cst:"217.6"
# GE65_Tot_Day_Suply:"455"
# GE65_Bene_Sprsn_Flag:""
# GE65_Tot_Benes:"11"}
# {"Prscrbr_NPI":"1003000142".5
# Prscrbr_Last_Org_Name:"Khalil".5
# Prscrbr_First_Name:"Rashid".5
# Prscrbr_City:"Toledo".5
# Prscrbr_State_Abrvtn:"OH".5
# Prscrbr_State_FIPS:"39".5
# Prscrbr_Type:"Anesthesiology".5
# Prscrbr_Type_Src:"Claim-Specialty".7
# Brnd_Name:"Dantrolene Sodium"
# Gnrc_Name:"Dantrolene Sodium"
# Tot_Clms:"14".1
# Tot_30day_Fills:"14".1
# Tot_Day_Suply:"221"
# Tot_Drug_Cst:"236.09"
# Tot_Benes:"13"
# GE65_Sprsn_Flag:"*".1
# GE65_Tot_Clms:"".5
# GE65_Tot_30day_Fills:"".5
# GE65_Tot_Drug_Cst:"".5
# GE65_Tot_Day_Suply:"".5
# GE65_Bene_Sprsn_Flag:"*".5
# GE65_Tot_Benes:""}.6
# {"Prscrbr_NPI":"1003000142".6
# Prscrbr_Last_Org_Name:"Khalil".6
# Prscrbr_First_Name:"Rashid".6
# Prscrbr_City:"Toledo".6
# Prscrbr_State_Abrvtn:"OH".6
# Prscrbr_State_FIPS:"39".6
# Prscrbr_Type:"Anesthesiology".6
# Prscrbr_Type_Src:"Claim-Specialty".8
# Brnd_Name:"Diclofenac Sodium"
# Gnrc_Name:"Diclofenac Sodium"
# Tot_Clms:"82"
# Tot_30day_Fills:"82"
# Tot_Day_Suply:"1629"
# Tot_Drug_Cst:"2423.34"
# Tot_Benes:"42"
# GE65_Sprsn_Flag:"".2
# GE65_Tot_Clms:"42"
# GE65_Tot_30day_Fills:"42"
# GE65_Tot_Drug_Cst:"1374.84"
# GE65_Tot_Day_Suply:"753"
# GE65_Bene_Sprsn_Flag:"".1
# GE65_Tot_Benes:"24"}
# {"Prscrbr_NPI":"1003000142".7
# Prscrbr_Last_Org_Name:"Khalil".7
# Prscrbr_First_Name:"Rashid".7
# Prscrbr_City:"Toledo".7
# Prscrbr_State_Abrvtn:"OH".7
# Prscrbr_State_FIPS:"39".7
# Prscrbr_Type:"Anesthesiology".7
# Prscrbr_Type_Src:"Claim-Specialty".9
# Brnd_Name:"Duloxetine Hcl"
# Gnrc_Name:"Duloxetine Hcl"
# Tot_Clms:"27"
# Tot_30day_Fills:"31"
# Tot_Day_Suply:"930"
# Tot_Drug_Cst:"337.43"
# Tot_Benes:"14".1
# GE65_Sprsn_Flag:"".3
# GE65_Tot_Clms:"11"
# GE65_Tot_30day_Fills:"13"
# GE65_Tot_Drug_Cst:"159.01"
# GE65_Tot_Day_Suply:"390"
# GE65_Bene_Sprsn_Flag:"*".6
# GE65_Tot_Benes:""}.7
# {"Prscrbr_NPI":"1003000142".8
# Prscrbr_Last_Org_Name:"Khalil".8
# Prscrbr_First_Name:"Rashid".8
# Prscrbr_City:"Toledo".8
# Prscrbr_State_Abrvtn:"OH".8
# Prscrbr_State_FIPS:"39".8
# Prscrbr_Type:"Anesthesiology".8
# Prscrbr_Type_Src:"Claim-Specialty".10
# Brnd_Name:"Gabapentin"
# Gnrc_Name:"Gabapentin"
# Tot_Clms:"281"
# Tot_30day_Fills:"345"
# Tot_Day_Suply:"10315"
# Tot_Drug_Cst:"5713.75"
# Tot_Benes:"125"
# GE65_Sprsn_Flag:"".4
# GE65_Tot_Clms:"167"
# GE65_Tot_30day_Fills:"209"
# GE65_Tot_Drug_Cst:"3585.65"
# GE65_Tot_Day_Suply:"6255"
# GE65_Bene_Sprsn_Flag:"".2
# GE65_Tot_Benes:"73"}
# {"Prscrbr_NPI":"1003000142".9
# Prscrbr_Last_Org_Name:"Khalil".9
# Prscrbr_First_Name:"Rashid".9
# Prscrbr_City:"Toledo".9
# Prscrbr_State_Abrvtn:"OH".9
# Prscrbr_State_FIPS:"39".9
# Prscrbr_Type:"Anesthesiology".9
# Prscrbr_Type_Src:"Claim-Specialty".11
# Brnd_Name:"Hydrocodone-Acetaminophen"
# Gnrc_Name:"Hydrocodone\/Acetaminophen"
# Tot_Clms:"355"
# Tot_30day_Fills:"355.5"
# Tot_Day_Suply:"9511"
# Tot_Drug_Cst:"7202.47"
# Tot_Benes:"171"
# GE65_Sprsn_Flag:"".5
# GE65_Tot_Clms:"214"
# GE65_Tot_30day_Fills:"214"
# GE65_Tot_Drug_Cst:"4543.33"
# GE65_Tot_Day_Suply:"5669"
# GE65_Bene_Sprsn_Flag:"".3
# GE65_Tot_Benes:"110"}
# {"Prscrbr_NPI":"1003000142".10
# Prscrbr_Last_Org_Name:"Khalil".10
# Prscrbr_First_Name:"Rashid".10
# Prscrbr_City:"Toledo".10
# Prscrbr_State_Abrvtn:"OH".10
# Prscrbr_State_FIPS:"39".10
# Prscrbr_Type:"Anesthesiology".10
# Prscrbr_Type_Src:"Claim-Specialty".12
# Brnd_Name:"Lidocaine"
# Gnrc_Name:"Lidocaine"
# Tot_Clms:"20"
# Tot_30day_Fills:"20"
# Tot_Day_Suply:"525"
# Tot_Drug_Cst:"2146.83"
# Tot_Benes:"12".1
# GE65_Sprsn_Flag:"#".4
# GE65_Tot_Clms:"".6
# GE65_Tot_30day_Fills:"".6
# GE65_Tot_Drug_Cst:"".6
# GE65_Tot_Day_Suply:"".6
# GE65_Bene_Sprsn_Flag:"*".7
# GE65_Tot_Benes:""}.8
# {"Prscrbr_NPI":"1003000142".11
# Prscrbr_Last_Org_Name:"Khalil".11
# Prscrbr_First_Name:"Rashid".11
# Prscrbr_City:"Toledo".11
# Prscrbr_State_Abrvtn:"OH".11
# Prscrbr_State_FIPS:"39".11
# Prscrbr_Type:"Anesthesiology".11
# Prscrbr_Type_Src:"Claim-Specialty".13
# Brnd_Name:"Meloxicam"
# Gnrc_Name:"Meloxicam"
# Tot_Clms:"57"
# Tot_30day_Fills:"65"
# Tot_Day_Suply:"1948"
# Tot_Drug_Cst:"230.35"
# Tot_Benes:"25"
# GE65_Sprsn_Flag:"".6
# GE65_Tot_Clms:"19"
# GE65_Tot_30day_Fills:"21"
# GE65_Tot_Drug_Cst:"68.52"
# GE65_Tot_Day_Suply:"630"
# GE65_Bene_Sprsn_Flag:"*".8
# GE65_Tot_Benes:""}.9
# {"Prscrbr_NPI":"1003000142".12
# Prscrbr_Last_Org_Name:"Khalil".12
# Prscrbr_First_Name:"Rashid".12
# Prscrbr_City:"Toledo".12
# Prscrbr_State_Abrvtn:"OH".12
# Prscrbr_State_FIPS:"39".12
# Prscrbr_Type:"Anesthesiology".12
# Prscrbr_Type_Src:"Claim-Specialty".14
# Brnd_Name:"Methocarbamol"
# Gnrc_Name:"Methocarbamol"
# Tot_Clms:"14".2
# Tot_30day_Fills:"14".2
# Tot_Day_Suply:"375"
# Tot_Drug_Cst:"231.58"
# Tot_Benes:"".2
# GE65_Sprsn_Flag:"*".2
# GE65_Tot_Clms:"".7
# GE65_Tot_30day_Fills:"".7
# GE65_Tot_Drug_Cst:"".7
# GE65_Tot_Day_Suply:"".7
# GE65_Bene_Sprsn_Flag:"*".9
# GE65_Tot_Benes:""}.10
# {"Prscrbr_NPI":"1003000142".13
# Prscrbr_Last_Org_Name:"Khalil".13
# Prscrbr_First_Name:"Rashid".13
# Prscrbr_City:"Toledo".13
# Prscrbr_State_Abrvtn:"OH".13
# Prscrbr_State_FIPS:"39".13
# Prscrbr_Type:"Anesthesiology".13
# Prscrbr_Type_Src:"Claim-Specialty".15
# Brnd_Name:"Morphine Sulfate Er"
# Gnrc_Name:"Morphine Sulfate"
# Tot_Clms:"35".1
# Tot_30day_Fills:"35".1
# Tot_Day_Suply:"1050".1
# Tot_Drug_Cst:"633.8"
# Tot_Benes:"13".1
# GE65_Sprsn_Flag:"#".5
# GE65_Tot_Clms:"".8
# GE65_Tot_30day_Fills:"".8
# GE65_Tot_Drug_Cst:"".8
# GE65_Tot_Day_Suply:"".8
# GE65_Bene_Sprsn_Flag:"*".10
# GE65_Tot_Benes:""}.11
# {"Prscrbr_NPI":"1003000142".14
# Prscrbr_Last_Org_Name:"Khalil".14
# Prscrbr_First_Name:"Rashid".14
# Prscrbr_City:"Toledo".14
# Prscrbr_State_Abrvtn:"OH".14
# Prscrbr_State_FIPS:"39".14
# Prscrbr_Type:"Anesthesiology".14
# Prscrbr_Type_Src:"Claim-Specialty".16
# Brnd_Name:"Movantik"
# Gnrc_Name:"Naloxegol Oxalate"
# Tot_Clms:"21"
# Tot_30day_Fills:"29"
# Tot_Day_Suply:"844"
# Tot_Drug_Cst:"11694.14"
# Tot_Benes:"13".2
# GE65_Sprsn_Flag:"#".6
# GE65_Tot_Clms:"".9
# GE65_Tot_30day_Fills:"".9
# GE65_Tot_Drug_Cst:"".9
# GE65_Tot_Day_Suply:"".9
# GE65_Bene_Sprsn_Flag:"*".11
# GE65_Tot_Benes:""}.12
# {"Prscrbr_NPI":"1003000142".15
# Prscrbr_Last_Org_Name:"Khalil".15
# Prscrbr_First_Name:"Rashid".15
# Prscrbr_City:"Toledo".15
# Prscrbr_State_Abrvtn:"OH".15
# Prscrbr_State_FIPS:"39".15
# Prscrbr_Type:"Anesthesiology".15
# Prscrbr_Type_Src:"Claim-Specialty".17
# Brnd_Name:"Oxycodone Hcl"
# Gnrc_Name:"Oxycodone Hcl"
# Tot_Clms:"84"
# Tot_30day_Fills:"84"
# Tot_Day_Suply:"2439"
# Tot_Drug_Cst:"1269.35"
# Tot_Benes:"39"
# GE65_Sprsn_Flag:"".7
# GE65_Tot_Clms:"62"
# GE65_Tot_30day_Fills:"62"
# GE65_Tot_Drug_Cst:"983.14"
# GE65_Tot_Day_Suply:"1795"
# GE65_Bene_Sprsn_Flag:"".4
# GE65_Tot_Benes:"27"}
# {"Prscrbr_NPI":"1003000142".16
# Prscrbr_Last_Org_Name:"Khalil".16
# Prscrbr_First_Name:"Rashid".16
# Prscrbr_City:"Toledo".16
# Prscrbr_State_Abrvtn:"OH".16
# Prscrbr_State_FIPS:"39".16
# Prscrbr_Type:"Anesthesiology".16
# Prscrbr_Type_Src:"Claim-Specialty".18
# Brnd_Name:"Oxycodone-Acetaminophen"
# Gnrc_Name:"Oxycodone Hcl\/Acetaminophen"
# Tot_Clms:"194"
# Tot_30day_Fills:"194"
# Tot_Day_Suply:"5644"
# Tot_Drug_Cst:"5029.88"
# Tot_Benes:"94"
# GE65_Sprsn_Flag:"".8
# GE65_Tot_Clms:"94"
# GE65_Tot_30day_Fills:"94"
# GE65_Tot_Drug_Cst:"2155.06"
# GE65_Tot_Day_Suply:"2727"
# GE65_Bene_Sprsn_Flag:"".5
# GE65_Tot_Benes:"48"}
# {"Prscrbr_NPI":"1003000142".17
# Prscrbr_Last_Org_Name:"Khalil".17
# Prscrbr_First_Name:"Rashid".17
# Prscrbr_City:"Toledo".17
# Prscrbr_State_Abrvtn:"OH".17
# Prscrbr_State_FIPS:"39".17
# Prscrbr_Type:"Anesthesiology".17
# Prscrbr_Type_Src:"Claim-Specialty".19
# Brnd_Name:"Pregabalin"
# Gnrc_Name:"Pregabalin"
# Tot_Clms:"143"
# Tot_30day_Fills:"153"
# Tot_Day_Suply:"4425"
# Tot_Drug_Cst:"6575.8"
# Tot_Benes:"58"
# GE65_Sprsn_Flag:"".9
# GE65_Tot_Clms:"61"
# GE65_Tot_30day_Fills:"65"
# GE65_Tot_Drug_Cst:"2168.07"
# GE65_Tot_Day_Suply:"1819"
# GE65_Bene_Sprsn_Flag:"".6
# GE65_Tot_Benes:"27"}.1
# {"Prscrbr_NPI":"1003000142".18
# Prscrbr_Last_Org_Name:"Khalil".18
# Prscrbr_First_Name:"Rashid".18
# Prscrbr_City:"Toledo".18
# Prscrbr_State_Abrvtn:"OH".18
# Prscrbr_State_FIPS:"39".18
# Prscrbr_Type:"Anesthesiology".18
# Prscrbr_Type_Src:"Claim-Specialty".20
# Brnd_Name:"Tizanidine Hcl"
# Gnrc_Name:"Tizanidine Hcl"
# Tot_Clms:"126"
# Tot_30day_Fills:"140"
# Tot_Day_Suply:"4064"
# Tot_Drug_Cst:"1426.75"
# Tot_Benes:"66"
# GE65_Sprsn_Flag:"".10
# GE65_Tot_Clms:"51"
# GE65_Tot_30day_Fills:"51"
# GE65_Tot_Drug_Cst:"515.26"
# GE65_Tot_Day_Suply:"1449"
# GE65_Bene_Sprsn_Flag:"".7
# GE65_Tot_Benes:"29"}
# {"Prscrbr_NPI":"1003000142".19
# Prscrbr_Last_Org_Name:"Khalil".19
# Prscrbr_First_Name:"Rashid".19
# Prscrbr_City:"Toledo".19
# Prscrbr_State_Abrvtn:"OH".19
# Prscrbr_State_FIPS:"39".19
# Prscrbr_Type:"Anesthesiology".19
# Prscrbr_Type_Src:"Claim-Specialty".21
# Brnd_Name:"Topiramate"
# Gnrc_Name:"Topiramate"
# Tot_Clms:"16".1
# Tot_30day_Fills:"22"
# Tot_Day_Suply:"660"
# Tot_Drug_Cst:"199.68"
# Tot_Benes:"".3
# GE65_Sprsn_Flag:"*".3
# GE65_Tot_Clms:"".10
# GE65_Tot_30day_Fills:"".10
# GE65_Tot_Drug_Cst:"".10
# GE65_Tot_Day_Suply:"".10
# GE65_Bene_Sprsn_Flag:"*".12
# GE65_Tot_Benes:""}.13
# {"Prscrbr_NPI":"1003000142".20
# Prscrbr_Last_Org_Name:"Khalil".20
# Prscrbr_First_Name:"Rashid".20
# Prscrbr_City:"Toledo".20
# Prscrbr_State_Abrvtn:"OH".20
# Prscrbr_State_FIPS:"39".20
# Prscrbr_Type:"Anesthesiology".20
# Prscrbr_Type_Src:"Claim-Specialty".22
# Brnd_Name:"Tramadol Hcl"
# Gnrc_Name:"Tramadol Hcl"
# Tot_Clms:"97"
# Tot_30day_Fills:"97"
# Tot_Day_Suply:"2550"
# Tot_Drug_Cst:"529"
# Tot_Benes:"41"
# GE65_Sprsn_Flag:"".11
# GE65_Tot_Clms:"68"
# GE65_Tot_30day_Fills:"68"
# GE65_Tot_Drug_Cst:"344.88"
# GE65_Tot_Day_Suply:"1756"
# GE65_Bene_Sprsn_Flag:"".8
# GE65_Tot_Benes:"29"}.1
# {"Prscrbr_NPI":"1003000167"
# Prscrbr_Last_Org_Name:"Escobar"
# Prscrbr_First_Name:"Julio"
# Prscrbr_City:"Dayton"
# Prscrbr_State_Abrvtn:"NV"
# Prscrbr_State_FIPS:"32"
# Prscrbr_Type:"Dentist"
# Prscrbr_Type_Src:"NPPES-Specialty"
# Brnd_Name:"Amoxicillin"
# Gnrc_Name:"Amoxicillin"
# Tot_Clms:"51"
# Tot_30day_Fills:"51"
# Tot_Day_Suply:"308"
# Tot_Drug_Cst:"152.04"
# Tot_Benes:"43"
# GE65_Sprsn_Flag:"#".7
# GE65_Tot_Clms:"".11
# GE65_Tot_30day_Fills:"".11
# GE65_Tot_Drug_Cst:"".11
# GE65_Tot_Day_Suply:"".11
# GE65_Bene_Sprsn_Flag:"#".1
# GE65_Tot_Benes:""}.14
# {"Prscrbr_NPI":"1003000167".1
# Prscrbr_Last_Org_Name:"Escobar".1
# Prscrbr_First_Name:"Julio".1
# Prscrbr_City:"Dayton".1
# Prscrbr_State_Abrvtn:"NV".1
# Prscrbr_State_FIPS:"32".1
# Prscrbr_Type:"Dentist".1
# Prscrbr_Type_Src:"NPPES-Specialty".1
# Brnd_Name:"Dexamethasone"
# Gnrc_Name:"Dexamethasone"
# Tot_Clms:"20".1
# Tot_30day_Fills:"20".1
# Tot_Day_Suply:"20"
# Tot_Drug_Cst:"38.04"
# Tot_Benes:"17"
# GE65_Sprsn_Flag:"#".8
# GE65_Tot_Clms:"".12
# GE65_Tot_30day_Fills:"".12
# GE65_Tot_Drug_Cst:"".12
# GE65_Tot_Day_Suply:"".12
# GE65_Bene_Sprsn_Flag:"#".2
# GE65_Tot_Benes:""}.15
# {"Prscrbr_NPI":"1003000423"
# Prscrbr_Last_Org_Name:"Velotta"
# Prscrbr_First_Name:"Jennifer"
# Prscrbr_City:"Cleveland"
# Prscrbr_State_Abrvtn:"OH".21
# Prscrbr_State_FIPS:"39".21
# Prscrbr_Type:"Obstetrics \u0026 Gynecology"
# Prscrbr_Type_Src:"Claim-Specialty".23
# Brnd_Name:"Clotrimazole-Betamethasone"
# Gnrc_Name:"Clotrimazole\/Betamethasone Dip"
# Tot_Clms:"19"
# Tot_30day_Fills:"19"
# Tot_Day_Suply:"249"
# Tot_Drug_Cst:"250.55"
# Tot_Benes:"".4
# GE65_Sprsn_Flag:"#".9
# GE65_Tot_Clms:"".13
# GE65_Tot_30day_Fills:"".13
# GE65_Tot_Drug_Cst:"".13
# GE65_Tot_Day_Suply:"".13
# GE65_Bene_Sprsn_Flag:"*".13
# GE65_Tot_Benes:""}.16
# {"Prscrbr_NPI":"1003000423".1
# Prscrbr_Last_Org_Name:"Velotta".1
# Prscrbr_First_Name:"Jennifer".1
# Prscrbr_City:"Cleveland".1
# Prscrbr_State_Abrvtn:"OH".22
# Prscrbr_State_FIPS:"39".22
# Prscrbr_Type:"Obstetrics \u0026 Gynecology".1
# Prscrbr_Type_Src:"Claim-Specialty".24
# Brnd_Name:"Estradiol"
# Gnrc_Name:"Estradiol"
# Tot_Clms:"39"
# Tot_30day_Fills:"112.4"
# Tot_Day_Suply:"3359"
# Tot_Drug_Cst:"5419.72"
# Tot_Benes:"19"
# GE65_Sprsn_Flag:"#".10
# GE65_Tot_Clms:"".14
# GE65_Tot_30day_Fills:"".14
# GE65_Tot_Drug_Cst:"".14
# GE65_Tot_Day_Suply:"".14
# GE65_Bene_Sprsn_Flag:"#".3
# GE65_Tot_Benes:""}.17
# {"Prscrbr_NPI":"1003000480"
# Prscrbr_Last_Org_Name:"Rothchild"
# Prscrbr_First_Name:"Kevin"
# Prscrbr_City:"Aurora"
# Prscrbr_State_Abrvtn:"CO"
# Prscrbr_State_FIPS:"08"
# Prscrbr_Type:"General Surgery"
# Prscrbr_Type_Src:"Claim-Specialty".25
# Brnd_Name:"Omeprazole"
# Gnrc_Name:"Omeprazole"
# Tot_Clms:"16".2
# Tot_30day_Fills:"18.1"
# Tot_Day_Suply:"543"
# Tot_Drug_Cst:"384.12"
# Tot_Benes:"".5
# GE65_Sprsn_Flag:"*".4
# GE65_Tot_Clms:"".15
# GE65_Tot_30day_Fills:"".15
# GE65_Tot_Drug_Cst:"".15
# GE65_Tot_Day_Suply:"".15
# GE65_Bene_Sprsn_Flag:"*".14
# GE65_Tot_Benes:""}.18
# {"Prscrbr_NPI":"1003000480".1
# Prscrbr_Last_Org_Name:"Rothchild".1
# Prscrbr_First_Name:"Kevin".1
# Prscrbr_City:"Aurora".1
# Prscrbr_State_Abrvtn:"CO".1
# Prscrbr_State_FIPS:"08".1
# Prscrbr_Type:"General Surgery".1
# Prscrbr_Type_Src:"Claim-Specialty".26
# Brnd_Name:"Oxycodone Hcl".1
# Gnrc_Name:"Oxycodone Hcl".1
# Tot_Clms:"12"
# Tot_30day_Fills:"12"
# Tot_Day_Suply:"40"
# Tot_Drug_Cst:"25.58"
# Tot_Benes:"12".2
# GE65_Sprsn_Flag:"*".5
# GE65_Tot_Clms:"".16
# GE65_Tot_30day_Fills:"".16
# GE65_Tot_Drug_Cst:"".16
# GE65_Tot_Day_Suply:"".16
# GE65_Bene_Sprsn_Flag:"*".15
# GE65_Tot_Benes:""}.19
# {"Prscrbr_NPI":"1003000530"
# Prscrbr_Last_Org_Name:"Semonche"
# Prscrbr_First_Name:"Amanda"
# Prscrbr_City:"Quakertown"
# Prscrbr_State_Abrvtn:"PA"
# Prscrbr_State_FIPS:"42"
# Prscrbr_Type:"Internal Medicine"
# Prscrbr_Type_Src:"Claim-Specialty".27
# Brnd_Name:"Advair Diskus"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol"
# Tot_Clms:"18"
# Tot_30day_Fills:"25"
# Tot_Day_Suply:"750"
# Tot_Drug_Cst:"8222.59"
# Tot_Benes:"".6
# GE65_Sprsn_Flag:"".12
# GE65_Tot_Clms:"18"
# GE65_Tot_30day_Fills:"25"
# GE65_Tot_Drug_Cst:"8222.59"
# GE65_Tot_Day_Suply:"750"
# GE65_Bene_Sprsn_Flag:"*".16
# GE65_Tot_Benes:""}.20
# {"Prscrbr_NPI":"1003000530".1
# Prscrbr_Last_Org_Name:"Semonche".1
# Prscrbr_First_Name:"Amanda".1
# Prscrbr_City:"Quakertown".1
# Prscrbr_State_Abrvtn:"PA".1
# Prscrbr_State_FIPS:"42".1
# Prscrbr_Type:"Internal Medicine".1
# Prscrbr_Type_Src:"Claim-Specialty".28
# Brnd_Name:"Albuterol Sulfate Hfa"
# Gnrc_Name:"Albuterol Sulfate"
# Tot_Clms:"54".1
# Tot_30day_Fills:"59.9"
# Tot_Day_Suply:"1385"
# Tot_Drug_Cst:"1900.5"
# Tot_Benes:"24"
# GE65_Sprsn_Flag:"#".11
# GE65_Tot_Clms:"".17
# GE65_Tot_30day_Fills:"".17
# GE65_Tot_Drug_Cst:"".17
# GE65_Tot_Day_Suply:"".17
# GE65_Bene_Sprsn_Flag:"#".4
# GE65_Tot_Benes:""}.21
# {"Prscrbr_NPI":"1003000530".2
# Prscrbr_Last_Org_Name:"Semonche".2
# Prscrbr_First_Name:"Amanda".2
# Prscrbr_City:"Quakertown".2
# Prscrbr_State_Abrvtn:"PA".2
# Prscrbr_State_FIPS:"42".2
# Prscrbr_Type:"Internal Medicine".2
# Prscrbr_Type_Src:"Claim-Specialty".29
# Brnd_Name:"Alendronate Sodium"
# Gnrc_Name:"Alendronate Sodium"
# Tot_Clms:"68"
# Tot_30day_Fills:"155.1"
# Tot_Day_Suply:"4611"
# Tot_Drug_Cst:"876.77"
# Tot_Benes:"17".1
# GE65_Sprsn_Flag:"".13
# GE65_Tot_Clms:"68".1
# GE65_Tot_30day_Fills:"155.1"
# GE65_Tot_Drug_Cst:"876.77"
# GE65_Tot_Day_Suply:"4611"
# GE65_Bene_Sprsn_Flag:"".9
# GE65_Tot_Benes:"17"}
# {"Prscrbr_NPI":"1003000530".3
# Prscrbr_Last_Org_Name:"Semonche".3
# Prscrbr_First_Name:"Amanda".3
# Prscrbr_City:"Quakertown".3
# Prscrbr_State_Abrvtn:"PA".3
# Prscrbr_State_FIPS:"42".3
# Prscrbr_Type:"Internal Medicine".3
# Prscrbr_Type_Src:"Claim-Specialty".30
# Brnd_Name:"Alfuzosin Hcl Er"
# Gnrc_Name:"Alfuzosin Hcl"
# Tot_Clms:"13".1
# Tot_30day_Fills:"13"
# Tot_Day_Suply:"390"
# Tot_Drug_Cst:"121.14"
# Tot_Benes:"".7
# GE65_Sprsn_Flag:"".14
# GE65_Tot_Clms:"13"
# GE65_Tot_30day_Fills:"13".1
# GE65_Tot_Drug_Cst:"121.14"
# GE65_Tot_Day_Suply:"390".1
# GE65_Bene_Sprsn_Flag:"*".17
# GE65_Tot_Benes:""}.22
# {"Prscrbr_NPI":"1003000530".4
# Prscrbr_Last_Org_Name:"Semonche".4
# Prscrbr_First_Name:"Amanda".4
# Prscrbr_City:"Quakertown".4
# Prscrbr_State_Abrvtn:"PA".4
# Prscrbr_State_FIPS:"42".4
# Prscrbr_Type:"Internal Medicine".4
# Prscrbr_Type_Src:"Claim-Specialty".31
# Brnd_Name:"Allopurinol"
# Gnrc_Name:"Allopurinol"
# Tot_Clms:"57".1
# Tot_30day_Fills:"155"
# Tot_Day_Suply:"4650"
# Tot_Drug_Cst:"927.53"
# Tot_Benes:"14".2
# GE65_Sprsn_Flag:"".15
# GE65_Tot_Clms:"57"
# GE65_Tot_30day_Fills:"155"
# GE65_Tot_Drug_Cst:"927.53"
# GE65_Tot_Day_Suply:"4650"
# GE65_Bene_Sprsn_Flag:"".10
# GE65_Tot_Benes:"14"}
# {"Prscrbr_NPI":"1003000530".5
# Prscrbr_Last_Org_Name:"Semonche".5
# Prscrbr_First_Name:"Amanda".5
# Prscrbr_City:"Quakertown".5
# Prscrbr_State_Abrvtn:"PA".5
# Prscrbr_State_FIPS:"42".5
# Prscrbr_Type:"Internal Medicine".5
# Prscrbr_Type_Src:"Claim-Specialty".32
# Brnd_Name:"Alprazolam"
# Gnrc_Name:"Alprazolam"
# Tot_Clms:"31"
# Tot_30day_Fills:"54"
# Tot_Day_Suply:"1590"
# Tot_Drug_Cst:"194.85"
# Tot_Benes:"11"
# GE65_Sprsn_Flag:"#".12
# GE65_Tot_Clms:"".18
# GE65_Tot_30day_Fills:"".18
# GE65_Tot_Drug_Cst:"".18
# GE65_Tot_Day_Suply:"".18
# GE65_Bene_Sprsn_Flag:"*".18
# GE65_Tot_Benes:""}.23
# {"Prscrbr_NPI":"1003000530".6
# Prscrbr_Last_Org_Name:"Semonche".6
# Prscrbr_First_Name:"Amanda".6
# Prscrbr_City:"Quakertown".6
# Prscrbr_State_Abrvtn:"PA".6
# Prscrbr_State_FIPS:"42".6
# Prscrbr_Type:"Internal Medicine".6
# Prscrbr_Type_Src:"Claim-Specialty".33
# Brnd_Name:"Amiodarone Hcl"
# Gnrc_Name:"Amiodarone Hcl"
# Tot_Clms:"12".1
# Tot_30day_Fills:"12".1
# Tot_Day_Suply:"360"
# Tot_Drug_Cst:"122.76"
# Tot_Benes:"".8
# GE65_Sprsn_Flag:"".16
# GE65_Tot_Clms:"12"
# GE65_Tot_30day_Fills:"12"
# GE65_Tot_Drug_Cst:"122.76"
# GE65_Tot_Day_Suply:"360"
# GE65_Bene_Sprsn_Flag:"*".19
# GE65_Tot_Benes:""}.24
# {"Prscrbr_NPI":"1003000530".7
# Prscrbr_Last_Org_Name:"Semonche".7
# Prscrbr_First_Name:"Amanda".7
# Prscrbr_City:"Quakertown".7
# Prscrbr_State_Abrvtn:"PA".7
# Prscrbr_State_FIPS:"42".7
# Prscrbr_Type:"Internal Medicine".7
# Prscrbr_Type_Src:"Claim-Specialty".34
# Brnd_Name:"Amlodipine Besylate"
# Gnrc_Name:"Amlodipine Besylate"
# Tot_Clms:"419"
# Tot_30day_Fills:"976.7"
# Tot_Day_Suply:"29238"
# Tot_Drug_Cst:"3238.1"
# Tot_Benes:"101"
# GE65_Sprsn_Flag:"".17
# GE65_Tot_Clms:"403"
# GE65_Tot_30day_Fills:"956.5"
# GE65_Tot_Drug_Cst:"3171.72"
# GE65_Tot_Day_Suply:"28664"
# GE65_Bene_Sprsn_Flag:"#".5
# GE65_Tot_Benes:""}.25
# {"Prscrbr_NPI":"1003000530".8
# Prscrbr_Last_Org_Name:"Semonche".8
# Prscrbr_First_Name:"Amanda".8
# Prscrbr_City:"Quakertown".8
# Prscrbr_State_Abrvtn:"PA".8
# Prscrbr_State_FIPS:"42".8
# Prscrbr_Type:"Internal Medicine".8
# Prscrbr_Type_Src:"Claim-Specialty".35
# Brnd_Name:"Amoxicillin-Clavulanate Potass"
# Gnrc_Name:"Amoxicillin\/Potassium Clav"
# Tot_Clms:"29"
# Tot_30day_Fills:"29".1
# Tot_Day_Suply:"204"
# Tot_Drug_Cst:"299.35"
# Tot_Benes:"28"
# GE65_Sprsn_Flag:"#".13
# GE65_Tot_Clms:"".19
# GE65_Tot_30day_Fills:"".19
# GE65_Tot_Drug_Cst:"".19
# GE65_Tot_Day_Suply:"".19
# GE65_Bene_Sprsn_Flag:"#".6
# GE65_Tot_Benes:""}.26
# {"Prscrbr_NPI":"1003000530".9
# Prscrbr_Last_Org_Name:"Semonche".9
# Prscrbr_First_Name:"Amanda".9
# Prscrbr_City:"Quakertown".9
# Prscrbr_State_Abrvtn:"PA".9
# Prscrbr_State_FIPS:"42".9
# Prscrbr_Type:"Internal Medicine".9
# Prscrbr_Type_Src:"Claim-Specialty".36
# Brnd_Name:"Aripiprazole"
# Gnrc_Name:"Aripiprazole"
# Tot_Clms:"24"
# Tot_30day_Fills:"36"
# Tot_Day_Suply:"1080"
# Tot_Drug_Cst:"1879.6"
# Tot_Benes:"".9
# GE65_Sprsn_Flag:"#".14
# GE65_Tot_Clms:"".20
# GE65_Tot_30day_Fills:"".20
# GE65_Tot_Drug_Cst:"".20
# GE65_Tot_Day_Suply:"".20
# GE65_Bene_Sprsn_Flag:"*".20
# GE65_Tot_Benes:""}.27
# {"Prscrbr_NPI":"1003000530".10
# Prscrbr_Last_Org_Name:"Semonche".10
# Prscrbr_First_Name:"Amanda".10
# Prscrbr_City:"Quakertown".10
# Prscrbr_State_Abrvtn:"PA".10
# Prscrbr_State_FIPS:"42".10
# Prscrbr_Type:"Internal Medicine".10
# Prscrbr_Type_Src:"Claim-Specialty".37
# Brnd_Name:"Atenolol"
# Gnrc_Name:"Atenolol"
# Tot_Clms:"26"
# Tot_30day_Fills:"78"
# Tot_Day_Suply:"2340"
# Tot_Drug_Cst:"142.77"
# Tot_Benes:"".10
# GE65_Sprsn_Flag:"".18
# GE65_Tot_Clms:"26"
# GE65_Tot_30day_Fills:"78"
# GE65_Tot_Drug_Cst:"142.77"
# GE65_Tot_Day_Suply:"2340"
# GE65_Bene_Sprsn_Flag:"*".21
# GE65_Tot_Benes:""}.28
# {"Prscrbr_NPI":"1003000530".11
# Prscrbr_Last_Org_Name:"Semonche".11
# Prscrbr_First_Name:"Amanda".11
# Prscrbr_City:"Quakertown".11
# Prscrbr_State_Abrvtn:"PA".11
# Prscrbr_State_FIPS:"42".11
# Prscrbr_Type:"Internal Medicine".11
# Prscrbr_Type_Src:"Claim-Specialty".38
# Brnd_Name:"Atorvastatin Calcium"
# Gnrc_Name:"Atorvastatin Calcium"
# Tot_Clms:"470"
# Tot_30day_Fills:"1154.7"
# Tot_Day_Suply:"34590"
# Tot_Drug_Cst:"5690.05"
# Tot_Benes:"112"
# GE65_Sprsn_Flag:"".19
# GE65_Tot_Clms:"453"
# GE65_Tot_30day_Fills:"1117.7"
# GE65_Tot_Drug_Cst:"5225.24"
# GE65_Tot_Day_Suply:"33480"
# GE65_Bene_Sprsn_Flag:"#".7
# GE65_Tot_Benes:""}.29
# {"Prscrbr_NPI":"1003000530".12
# Prscrbr_Last_Org_Name:"Semonche".12
# Prscrbr_First_Name:"Amanda".12
# Prscrbr_City:"Quakertown".12
# Prscrbr_State_Abrvtn:"PA".12
# Prscrbr_State_FIPS:"42".12
# Prscrbr_Type:"Internal Medicine".12
# Prscrbr_Type_Src:"Claim-Specialty".39
# Brnd_Name:"Benazepril Hcl"
# Gnrc_Name:"Benazepril Hcl"
# Tot_Clms:"13".2
# Tot_30day_Fills:"37"
# Tot_Day_Suply:"1110"
# Tot_Drug_Cst:"282.77"
# Tot_Benes:"".11
# GE65_Sprsn_Flag:"".20
# GE65_Tot_Clms:"13".1
# GE65_Tot_30day_Fills:"37"
# GE65_Tot_Drug_Cst:"282.77"
# GE65_Tot_Day_Suply:"1110"
# GE65_Bene_Sprsn_Flag:"*".22
# GE65_Tot_Benes:""}.30
# {"Prscrbr_NPI":"1003000530".13
# Prscrbr_Last_Org_Name:"Semonche".13
# Prscrbr_First_Name:"Amanda".13
# Prscrbr_City:"Quakertown".13
# Prscrbr_State_Abrvtn:"PA".13
# Prscrbr_State_FIPS:"42".13
# Prscrbr_Type:"Internal Medicine".13
# Prscrbr_Type_Src:"Claim-Specialty".40
# Brnd_Name:"Bupropion Hcl Sr"
# Gnrc_Name:"Bupropion Hcl"
# Tot_Clms:"25"
# Tot_30day_Fills:"33.5"
# Tot_Day_Suply:"1005"
# Tot_Drug_Cst:"258.44"
# Tot_Benes:"".12
# GE65_Sprsn_Flag:"".21
# GE65_Tot_Clms:"25"
# GE65_Tot_30day_Fills:"33.5"
# GE65_Tot_Drug_Cst:"258.44"
# GE65_Tot_Day_Suply:"1005"
# GE65_Bene_Sprsn_Flag:"*".23
# GE65_Tot_Benes:""}.31
# {"Prscrbr_NPI":"1003000530".14
# Prscrbr_Last_Org_Name:"Semonche".14
# Prscrbr_First_Name:"Amanda".14
# Prscrbr_City:"Quakertown".14
# Prscrbr_State_Abrvtn:"PA".14
# Prscrbr_State_FIPS:"42".14
# Prscrbr_Type:"Internal Medicine".14
# Prscrbr_Type_Src:"Claim-Specialty".41
# Brnd_Name:"Bupropion Xl"
# Gnrc_Name:"Bupropion Hcl".1
# Tot_Clms:"85"
# Tot_30day_Fills:"191"
# Tot_Day_Suply:"5714"
# Tot_Drug_Cst:"2770.34"
# Tot_Benes:"18"
# GE65_Sprsn_Flag:"".22
# GE65_Tot_Clms:"71"
# GE65_Tot_30day_Fills:"159"
# GE65_Tot_Drug_Cst:"2514.77"
# GE65_Tot_Day_Suply:"4770"
# GE65_Bene_Sprsn_Flag:"#".8
# GE65_Tot_Benes:""}.32
# {"Prscrbr_NPI":"1003000530".15
# Prscrbr_Last_Org_Name:"Semonche".15
# Prscrbr_First_Name:"Amanda".15
# Prscrbr_City:"Quakertown".15
# Prscrbr_State_Abrvtn:"PA".15
# Prscrbr_State_FIPS:"42".15
# Prscrbr_Type:"Internal Medicine".15
# Prscrbr_Type_Src:"Claim-Specialty".42
# Brnd_Name:"Buspirone Hcl"
# Gnrc_Name:"Buspirone Hcl"
# Tot_Clms:"13".3
# Tot_30day_Fills:"31".1
# Tot_Day_Suply:"930".1
# Tot_Drug_Cst:"82.61"
# Tot_Benes:"".13
# GE65_Sprsn_Flag:"".23
# GE65_Tot_Clms:"13".2
# GE65_Tot_30day_Fills:"31"
# GE65_Tot_Drug_Cst:"82.61"
# GE65_Tot_Day_Suply:"930"
# GE65_Bene_Sprsn_Flag:"*".24
# GE65_Tot_Benes:""}.33
# {"Prscrbr_NPI":"1003000530".16
# Prscrbr_Last_Org_Name:"Semonche".16
# Prscrbr_First_Name:"Amanda".16
# Prscrbr_City:"Quakertown".16
# Prscrbr_State_Abrvtn:"PA".16
# Prscrbr_State_FIPS:"42".16
# Prscrbr_Type:"Internal Medicine".16
# Prscrbr_Type_Src:"Claim-Specialty".43
# Brnd_Name:"Butalbital-Acetaminophen-Caffe"
# Gnrc_Name:"Butalb\/Acetaminophen\/Caffeine"
# Tot_Clms:"14".3
# Tot_30day_Fills:"15"
# Tot_Day_Suply:"450"
# Tot_Drug_Cst:"463.9"
# Tot_Benes:"".14
# GE65_Sprsn_Flag:"".24
# GE65_Tot_Clms:"14"
# GE65_Tot_30day_Fills:"15"
# GE65_Tot_Drug_Cst:"463.9"
# GE65_Tot_Day_Suply:"450"
# GE65_Bene_Sprsn_Flag:"*".25
# GE65_Tot_Benes:""}.34
# {"Prscrbr_NPI":"1003000530".17
# Prscrbr_Last_Org_Name:"Semonche".17
# Prscrbr_First_Name:"Amanda".17
# Prscrbr_City:"Quakertown".17
# Prscrbr_State_Abrvtn:"PA".17
# Prscrbr_State_FIPS:"42".17
# Prscrbr_Type:"Internal Medicine".17
# Prscrbr_Type_Src:"Claim-Specialty".44
# Brnd_Name:"Calcitriol"
# Gnrc_Name:"Calcitriol"
# Tot_Clms:"12".2
# Tot_30day_Fills:"12.2"
# Tot_Day_Suply:"365"
# Tot_Drug_Cst:"328.47"
# Tot_Benes:"".15
# GE65_Sprsn_Flag:"".25
# GE65_Tot_Clms:"0"
# GE65_Tot_30day_Fills:"0"
# GE65_Tot_Drug_Cst:"0"
# GE65_Tot_Day_Suply:"0"
# GE65_Bene_Sprsn_Flag:"#".9
# GE65_Tot_Benes:""}.35
# {"Prscrbr_NPI":"1003000530".18
# Prscrbr_Last_Org_Name:"Semonche".18
# Prscrbr_First_Name:"Amanda".18
# Prscrbr_City:"Quakertown".18
# Prscrbr_State_Abrvtn:"PA".18
# Prscrbr_State_FIPS:"42".18
# Prscrbr_Type:"Internal Medicine".18
# Prscrbr_Type_Src:"Claim-Specialty".45
# Brnd_Name:"Carvedilol"
# Gnrc_Name:"Carvedilol"
# Tot_Clms:"23"
# Tot_30day_Fills:"60"
# Tot_Day_Suply:"1800"
# Tot_Drug_Cst:"391.49"
# Tot_Benes:"".16
# GE65_Sprsn_Flag:"#".15
# GE65_Tot_Clms:"".21
# GE65_Tot_30day_Fills:"".21
# GE65_Tot_Drug_Cst:"".21
# GE65_Tot_Day_Suply:"".21
# GE65_Bene_Sprsn_Flag:"*".26
# GE65_Tot_Benes:""}.36
# {"Prscrbr_NPI":"1003000530".19
# Prscrbr_Last_Org_Name:"Semonche".19
# Prscrbr_First_Name:"Amanda".19
# Prscrbr_City:"Quakertown".19
# Prscrbr_State_Abrvtn:"PA".19
# Prscrbr_State_FIPS:"42".19
# Prscrbr_Type:"Internal Medicine".19
# Prscrbr_Type_Src:"Claim-Specialty".46
# Brnd_Name:"Cephalexin"
# Gnrc_Name:"Cephalexin"
# Tot_Clms:"12".3
# Tot_30day_Fills:"12".2
# Tot_Day_Suply:"110"
# Tot_Drug_Cst:"43.42"
# Tot_Benes:"12".3
# GE65_Sprsn_Flag:"#".16
# GE65_Tot_Clms:"".22
# GE65_Tot_30day_Fills:"".22
# GE65_Tot_Drug_Cst:"".22
# GE65_Tot_Day_Suply:"".22
# GE65_Bene_Sprsn_Flag:"#".10
# GE65_Tot_Benes:""}.37
# {"Prscrbr_NPI":"1003000530".20
# Prscrbr_Last_Org_Name:"Semonche".20
# Prscrbr_First_Name:"Amanda".20
# Prscrbr_City:"Quakertown".20
# Prscrbr_State_Abrvtn:"PA".20
# Prscrbr_State_FIPS:"42".20
# Prscrbr_Type:"Internal Medicine".20
# Prscrbr_Type_Src:"Claim-Specialty".47
# Brnd_Name:"Chlorhexidine Gluconate"
# Gnrc_Name:"Chlorhexidine Gluconate"
# Tot_Clms:"20".2
# Tot_30day_Fills:"20".2
# Tot_Day_Suply:"345"
# Tot_Drug_Cst:"116.2"
# Tot_Benes:"".17
# GE65_Sprsn_Flag:"".26
# GE65_Tot_Clms:"0".1
# GE65_Tot_30day_Fills:"0".1
# GE65_Tot_Drug_Cst:"0".1
# GE65_Tot_Day_Suply:"0".1
# GE65_Bene_Sprsn_Flag:"#".11
# GE65_Tot_Benes:""}.38
# {"Prscrbr_NPI":"1003000530".21
# Prscrbr_Last_Org_Name:"Semonche".21
# Prscrbr_First_Name:"Amanda".21
# Prscrbr_City:"Quakertown".21
# Prscrbr_State_Abrvtn:"PA".21
# Prscrbr_State_FIPS:"42".21
# Prscrbr_Type:"Internal Medicine".21
# Prscrbr_Type_Src:"Claim-Specialty".48
# Brnd_Name:"Citalopram Hbr"
# Gnrc_Name:"Citalopram Hydrobromide"
# Tot_Clms:"39".1
# Tot_30day_Fills:"81"
# Tot_Day_Suply:"2430"
# Tot_Drug_Cst:"228.34"
# Tot_Benes:"".18
# GE65_Sprsn_Flag:"".27
# GE65_Tot_Clms:"39"
# GE65_Tot_30day_Fills:"81"
# GE65_Tot_Drug_Cst:"228.34"
# GE65_Tot_Day_Suply:"2430"
# GE65_Bene_Sprsn_Flag:"*".27
# GE65_Tot_Benes:""}.39
# {"Prscrbr_NPI":"1003000530".22
# Prscrbr_Last_Org_Name:"Semonche".22
# Prscrbr_First_Name:"Amanda".22
# Prscrbr_City:"Quakertown".22
# Prscrbr_State_Abrvtn:"PA".22
# Prscrbr_State_FIPS:"42".22
# Prscrbr_Type:"Internal Medicine".22
# Prscrbr_Type_Src:"Claim-Specialty".49
# Brnd_Name:"Clonazepam"
# Gnrc_Name:"Clonazepam"
# Tot_Clms:"35".2
# Tot_30day_Fills:"45"
# Tot_Day_Suply:"1341"
# Tot_Drug_Cst:"386.75"
# Tot_Benes:"".19
# GE65_Sprsn_Flag:"".28
# GE65_Tot_Clms:"22"
# GE65_Tot_30day_Fills:"32"
# GE65_Tot_Drug_Cst:"258.27"
# GE65_Tot_Day_Suply:"951"
# GE65_Bene_Sprsn_Flag:"*".28
# GE65_Tot_Benes:""}.40
# {"Prscrbr_NPI":"1003000530".23
# Prscrbr_Last_Org_Name:"Semonche".23
# Prscrbr_First_Name:"Amanda".23
# Prscrbr_City:"Quakertown".23
# Prscrbr_State_Abrvtn:"PA".23
# Prscrbr_State_FIPS:"42".23
# Prscrbr_Type:"Internal Medicine".23
# Prscrbr_Type_Src:"Claim-Specialty".50
# Brnd_Name:"Clonidine Hcl"
# Gnrc_Name:"Clonidine Hcl"
# Tot_Clms:"13".4
# Tot_30day_Fills:"27.6"
# Tot_Day_Suply:"827"
# Tot_Drug_Cst:"48.65"
# Tot_Benes:"".20
# GE65_Sprsn_Flag:"".29
# GE65_Tot_Clms:"13".3
# GE65_Tot_30day_Fills:"27.6"
# GE65_Tot_Drug_Cst:"48.65"
# GE65_Tot_Day_Suply:"827"
# GE65_Bene_Sprsn_Flag:"*".29
# GE65_Tot_Benes:""}.41
# {"Prscrbr_NPI":"1003000530".24
# Prscrbr_Last_Org_Name:"Semonche".24
# Prscrbr_First_Name:"Amanda".24
# Prscrbr_City:"Quakertown".24
# Prscrbr_State_Abrvtn:"PA".24
# Prscrbr_State_FIPS:"42".24
# Prscrbr_Type:"Internal Medicine".24
# Prscrbr_Type_Src:"Claim-Specialty".51
# Brnd_Name:"Clopidogrel"
# Gnrc_Name:"Clopidogrel Bisulfate"
# Tot_Clms:"85".1
# Tot_30day_Fills:"188"
# Tot_Day_Suply:"5630"
# Tot_Drug_Cst:"1640.22"
# Tot_Benes:"19".1
# GE65_Sprsn_Flag:"".30
# GE65_Tot_Clms:"85"
# GE65_Tot_30day_Fills:"188"
# GE65_Tot_Drug_Cst:"1640.22"
# GE65_Tot_Day_Suply:"5630"
# GE65_Bene_Sprsn_Flag:"".11
# GE65_Tot_Benes:"19"}
# {"Prscrbr_NPI":"1003000530".25
# Prscrbr_Last_Org_Name:"Semonche".25
# Prscrbr_First_Name:"Amanda".25
# Prscrbr_City:"Quakertown".25
# Prscrbr_State_Abrvtn:"PA".25
# Prscrbr_State_FIPS:"42".25
# Prscrbr_Type:"Internal Medicine".25
# Prscrbr_Type_Src:"Claim-Specialty".52
# Brnd_Name:"Cyclobenzaprine Hcl".1
# Gnrc_Name:"Cyclobenzaprine Hcl".1
# Tot_Clms:"11"
# Tot_30day_Fills:"11"
# Tot_Day_Suply:"110".1
# Tot_Drug_Cst:"41.17"
# Tot_Benes:"".21
# GE65_Sprsn_Flag:"*".6
# GE65_Tot_Clms:"".23
# GE65_Tot_30day_Fills:"".23
# GE65_Tot_Drug_Cst:"".23
# GE65_Tot_Day_Suply:"".23
# GE65_Bene_Sprsn_Flag:"*".30
# GE65_Tot_Benes:""}.42
# {"Prscrbr_NPI":"1003000530".26
# Prscrbr_Last_Org_Name:"Semonche".26
# Prscrbr_First_Name:"Amanda".26
# Prscrbr_City:"Quakertown".26
# Prscrbr_State_Abrvtn:"PA".26
# Prscrbr_State_FIPS:"42".26
# Prscrbr_Type:"Internal Medicine".26
# Prscrbr_Type_Src:"Claim-Specialty".53
# Brnd_Name:"Dexlansoprazole Dr"
# Gnrc_Name:"Dexlansoprazole"
# Tot_Clms:"13".5
# Tot_30day_Fills:"24"
# Tot_Day_Suply:"720"
# Tot_Drug_Cst:"5600.13"
# Tot_Benes:"".22
# GE65_Sprsn_Flag:"".31
# GE65_Tot_Clms:"13".4
# GE65_Tot_30day_Fills:"24"
# GE65_Tot_Drug_Cst:"5600.13"
# GE65_Tot_Day_Suply:"720"
# GE65_Bene_Sprsn_Flag:"*".31
# GE65_Tot_Benes:""}.43
# {"Prscrbr_NPI":"1003000530".27
# Prscrbr_Last_Org_Name:"Semonche".27
# Prscrbr_First_Name:"Amanda".27
# Prscrbr_City:"Quakertown".27
# Prscrbr_State_Abrvtn:"PA".27
# Prscrbr_State_FIPS:"42".27
# Prscrbr_Type:"Internal Medicine".27
# Prscrbr_Type_Src:"Claim-Specialty".54
# Brnd_Name:"Diazepam"
# Gnrc_Name:"Diazepam"
# Tot_Clms:"16".3
# Tot_30day_Fills:"16".1
# Tot_Day_Suply:"199"
# Tot_Drug_Cst:"41.64"
# Tot_Benes:"".23
# GE65_Sprsn_Flag:"*".7
# GE65_Tot_Clms:"".24
# GE65_Tot_30day_Fills:"".24
# GE65_Tot_Drug_Cst:"".24
# GE65_Tot_Day_Suply:"".24
# GE65_Bene_Sprsn_Flag:"*".32
# GE65_Tot_Benes:""}.44
# {"Prscrbr_NPI":"1003000530".28
# Prscrbr_Last_Org_Name:"Semonche".28
# Prscrbr_First_Name:"Amanda".28
# Prscrbr_City:"Quakertown".28
# Prscrbr_State_Abrvtn:"PA".28
# Prscrbr_State_FIPS:"42".28
# Prscrbr_Type:"Internal Medicine".28
# Prscrbr_Type_Src:"Claim-Specialty".55
# Brnd_Name:"Diclofenac Sodium".1
# Gnrc_Name:"Diclofenac Sodium".1
# Tot_Clms:"14".4
# Tot_30day_Fills:"14".3
# Tot_Day_Suply:"260"
# Tot_Drug_Cst:"307.2"
# Tot_Benes:"".24
# GE65_Sprsn_Flag:"#".17
# GE65_Tot_Clms:"".25
# GE65_Tot_30day_Fills:"".25
# GE65_Tot_Drug_Cst:"".25
# GE65_Tot_Day_Suply:"".25
# GE65_Bene_Sprsn_Flag:"*".33
# GE65_Tot_Benes:""}.45
# {"Prscrbr_NPI":"1003000530".29
# Prscrbr_Last_Org_Name:"Semonche".29
# Prscrbr_First_Name:"Amanda".29
# Prscrbr_City:"Quakertown".29
# Prscrbr_State_Abrvtn:"PA".29
# Prscrbr_State_FIPS:"42".29
# Prscrbr_Type:"Internal Medicine".29
# Prscrbr_Type_Src:"Claim-Specialty".56
# Brnd_Name:"Diltiazem 24hr Er (Cd)"
# Gnrc_Name:"Diltiazem Hcl"
# Tot_Clms:"14".5
# Tot_30day_Fills:"14".4
# Tot_Day_Suply:"420"
# Tot_Drug_Cst:"232.74"
# Tot_Benes:"".25
# GE65_Sprsn_Flag:"".32
# GE65_Tot_Clms:"14".1
# GE65_Tot_30day_Fills:"14"
# GE65_Tot_Drug_Cst:"232.74"
# GE65_Tot_Day_Suply:"420"
# GE65_Bene_Sprsn_Flag:"*".34
# GE65_Tot_Benes:""}.46
# {"Prscrbr_NPI":"1003000530".30
# Prscrbr_Last_Org_Name:"Semonche".30
# Prscrbr_First_Name:"Amanda".30
# Prscrbr_City:"Quakertown".30
# Prscrbr_State_Abrvtn:"PA".30
# Prscrbr_State_FIPS:"42".30
# Prscrbr_Type:"Internal Medicine".30
# Prscrbr_Type_Src:"Claim-Specialty".57
# Brnd_Name:"Dofetilide"
# Gnrc_Name:"Dofetilide"
# Tot_Clms:"14".6
# Tot_30day_Fills:"14".5
# Tot_Day_Suply:"409"
# Tot_Drug_Cst:"312.85"
# Tot_Benes:"".26
# GE65_Sprsn_Flag:"".33
# GE65_Tot_Clms:"14".2
# GE65_Tot_30day_Fills:"14".1
# GE65_Tot_Drug_Cst:"312.85"
# GE65_Tot_Day_Suply:"409"
# GE65_Bene_Sprsn_Flag:"*".35
# GE65_Tot_Benes:""}.47
# {"Prscrbr_NPI":"1003000530".31
# Prscrbr_Last_Org_Name:"Semonche".31
# Prscrbr_First_Name:"Amanda".31
# Prscrbr_City:"Quakertown".31
# Prscrbr_State_Abrvtn:"PA".31
# Prscrbr_State_FIPS:"42".31
# Prscrbr_Type:"Internal Medicine".31
# Prscrbr_Type_Src:"Claim-Specialty".58
# Brnd_Name:"Donepezil Hcl"
# Gnrc_Name:"Donepezil Hcl"
# Tot_Clms:"20".3
# Tot_30day_Fills:"30"
# Tot_Day_Suply:"900"
# Tot_Drug_Cst:"289.85"
# Tot_Benes:"".27
# GE65_Sprsn_Flag:"".34
# GE65_Tot_Clms:"20"
# GE65_Tot_30day_Fills:"30"
# GE65_Tot_Drug_Cst:"289.85"
# GE65_Tot_Day_Suply:"900"
# GE65_Bene_Sprsn_Flag:"*".36
# GE65_Tot_Benes:""}.48
# {"Prscrbr_NPI":"1003000530".32
# Prscrbr_Last_Org_Name:"Semonche".32
# Prscrbr_First_Name:"Amanda".32
# Prscrbr_City:"Quakertown".32
# Prscrbr_State_Abrvtn:"PA".32
# Prscrbr_State_FIPS:"42".32
# Prscrbr_Type:"Internal Medicine".32
# Prscrbr_Type_Src:"Claim-Specialty".59
# Brnd_Name:"Doxazosin Mesylate"
# Gnrc_Name:"Doxazosin Mesylate"
# Tot_Clms:"15"
# Tot_30day_Fills:"35.8"
# Tot_Day_Suply:"1050".2
# Tot_Drug_Cst:"386.22"
# Tot_Benes:"".28
# GE65_Sprsn_Flag:"".35
# GE65_Tot_Clms:"15"
# GE65_Tot_30day_Fills:"35.8"
# GE65_Tot_Drug_Cst:"386.22"
# GE65_Tot_Day_Suply:"1050"
# GE65_Bene_Sprsn_Flag:"*".37
# GE65_Tot_Benes:""}.49
# {"Prscrbr_NPI":"1003000530".33
# Prscrbr_Last_Org_Name:"Semonche".33
# Prscrbr_First_Name:"Amanda".33
# Prscrbr_City:"Quakertown".33
# Prscrbr_State_Abrvtn:"PA".33
# Prscrbr_State_FIPS:"42".33
# Prscrbr_Type:"Internal Medicine".33
# Prscrbr_Type_Src:"Claim-Specialty".60
# Brnd_Name:"Doxycycline Hyclate"
# Gnrc_Name:"Doxycycline Hyclate"
# Tot_Clms:"30"
# Tot_30day_Fills:"30".1
# Tot_Day_Suply:"251"
# Tot_Drug_Cst:"319.64"
# Tot_Benes:"28".1
# GE65_Sprsn_Flag:"".36
# GE65_Tot_Clms:"30"
# GE65_Tot_30day_Fills:"30".1
# GE65_Tot_Drug_Cst:"319.64"
# GE65_Tot_Day_Suply:"251"
# GE65_Bene_Sprsn_Flag:"".12
# GE65_Tot_Benes:"28"}
# {"Prscrbr_NPI":"1003000530".34
# Prscrbr_Last_Org_Name:"Semonche".34
# Prscrbr_First_Name:"Amanda".34
# Prscrbr_City:"Quakertown".34
# Prscrbr_State_Abrvtn:"PA".34
# Prscrbr_State_FIPS:"42".34
# Prscrbr_Type:"Internal Medicine".34
# Prscrbr_Type_Src:"Claim-Specialty".61
# Brnd_Name:"Duloxetine Hcl".1
# Gnrc_Name:"Duloxetine Hcl".1
# Tot_Clms:"69"
# Tot_30day_Fills:"113"
# Tot_Day_Suply:"3382"
# Tot_Drug_Cst:"3664.57"
# Tot_Benes:"11".1
# GE65_Sprsn_Flag:"".37
# GE65_Tot_Clms:"55"
# GE65_Tot_30day_Fills:"89"
# GE65_Tot_Drug_Cst:"3243.56"
# GE65_Tot_Day_Suply:"2662"
# GE65_Bene_Sprsn_Flag:"*".38
# GE65_Tot_Benes:""}.50
# {"Prscrbr_NPI":"1003000530".35
# Prscrbr_Last_Org_Name:"Semonche".35
# Prscrbr_First_Name:"Amanda".35
# Prscrbr_City:"Quakertown".35
# Prscrbr_State_Abrvtn:"PA".35
# Prscrbr_State_FIPS:"42".35
# Prscrbr_Type:"Internal Medicine".35
# Prscrbr_Type_Src:"Claim-Specialty".62
# Brnd_Name:"Eliquis".1
# Gnrc_Name:"Apixaban".1
# Tot_Clms:"113"
# Tot_30day_Fills:"167"
# Tot_Day_Suply:"4999"
# Tot_Drug_Cst:"92087.78"
# Tot_Benes:"20"
# GE65_Sprsn_Flag:"".38
# GE65_Tot_Clms:"113"
# GE65_Tot_30day_Fills:"167"
# GE65_Tot_Drug_Cst:"92087.78"
# GE65_Tot_Day_Suply:"4999"
# GE65_Bene_Sprsn_Flag:"".13
# GE65_Tot_Benes:"20"}
# {"Prscrbr_NPI":"1003000530".36
# Prscrbr_Last_Org_Name:"Semonche".36
# Prscrbr_First_Name:"Amanda".36
# Prscrbr_City:"Quakertown".36
# Prscrbr_State_Abrvtn:"PA".36
# Prscrbr_State_FIPS:"42".36
# Prscrbr_Type:"Internal Medicine".36
# Prscrbr_Type_Src:"Claim-Specialty".63
# Brnd_Name:"Escitalopram Oxalate"
# Gnrc_Name:"Escitalopram Oxalate"
# Tot_Clms:"75"
# Tot_30day_Fills:"168"
# Tot_Day_Suply:"5015"
# Tot_Drug_Cst:"967.02"
# Tot_Benes:"19".2
# GE65_Sprsn_Flag:"#".18
# GE65_Tot_Clms:"".26
# GE65_Tot_30day_Fills:"".26
# GE65_Tot_Drug_Cst:"".26
# GE65_Tot_Day_Suply:"".26
# GE65_Bene_Sprsn_Flag:"#".12
# GE65_Tot_Benes:""}.51
# {"Prscrbr_NPI":"1003000530".37
# Prscrbr_Last_Org_Name:"Semonche".37
# Prscrbr_First_Name:"Amanda".37
# Prscrbr_City:"Quakertown".37
# Prscrbr_State_Abrvtn:"PA".37
# Prscrbr_State_FIPS:"42".37
# Prscrbr_Type:"Internal Medicine".37
# Prscrbr_Type_Src:"Claim-Specialty".64
# Brnd_Name:"Ezetimibe"
# Gnrc_Name:"Ezetimibe"
# Tot_Clms:"13".6
# Tot_30day_Fills:"39"
# Tot_Day_Suply:"1170"
# Tot_Drug_Cst:"272.15"
# Tot_Benes:"".29
# GE65_Sprsn_Flag:"".39
# GE65_Tot_Clms:"13".5
# GE65_Tot_30day_Fills:"39"
# GE65_Tot_Drug_Cst:"272.15"
# GE65_Tot_Day_Suply:"1170"
# GE65_Bene_Sprsn_Flag:"*".39
# GE65_Tot_Benes:""}.52
# {"Prscrbr_NPI":"1003000530".38
# Prscrbr_Last_Org_Name:"Semonche".38
# Prscrbr_First_Name:"Amanda".38
# Prscrbr_City:"Quakertown".38
# Prscrbr_State_Abrvtn:"PA".38
# Prscrbr_State_FIPS:"42".38
# Prscrbr_Type:"Internal Medicine".38
# Prscrbr_Type_Src:"Claim-Specialty".65
# Brnd_Name:"Famotidine"
# Gnrc_Name:"Famotidine"
# Tot_Clms:"143".1
# Tot_30day_Fills:"293.5"
# Tot_Day_Suply:"8770"
# Tot_Drug_Cst:"1813.81"
# Tot_Benes:"42".1
# GE65_Sprsn_Flag:"#".19
# GE65_Tot_Clms:"".27
# GE65_Tot_30day_Fills:"".27
# GE65_Tot_Drug_Cst:"".27
# GE65_Tot_Day_Suply:"".27
# GE65_Bene_Sprsn_Flag:"#".13
# GE65_Tot_Benes:""}.53
# {"Prscrbr_NPI":"1003000530".39
# Prscrbr_Last_Org_Name:"Semonche".39
# Prscrbr_First_Name:"Amanda".39
# Prscrbr_City:"Quakertown".39
# Prscrbr_State_Abrvtn:"PA".39
# Prscrbr_State_FIPS:"42".39
# Prscrbr_Type:"Internal Medicine".39
# Prscrbr_Type_Src:"Claim-Specialty".66
# Brnd_Name:"Febuxostat"
# Gnrc_Name:"Febuxostat"
# Tot_Clms:"12".4
# Tot_30day_Fills:"12".3
# Tot_Day_Suply:"360".1
# Tot_Drug_Cst:"2867.88"
# Tot_Benes:"".30
# GE65_Sprsn_Flag:"".40
# GE65_Tot_Clms:"12".1
# GE65_Tot_30day_Fills:"12".1
# GE65_Tot_Drug_Cst:"2867.88"
# GE65_Tot_Day_Suply:"360".1
# GE65_Bene_Sprsn_Flag:"*".40
# GE65_Tot_Benes:""}.54
# {"Prscrbr_NPI":"1003000530".40
# Prscrbr_Last_Org_Name:"Semonche".40
# Prscrbr_First_Name:"Amanda".40
# Prscrbr_City:"Quakertown".40
# Prscrbr_State_Abrvtn:"PA".40
# Prscrbr_State_FIPS:"42".40
# Prscrbr_Type:"Internal Medicine".40
# Prscrbr_Type_Src:"Claim-Specialty".67
# Brnd_Name:"Fenofibrate"
# Gnrc_Name:"Fenofibrate"
# Tot_Clms:"12".5
# Tot_30day_Fills:"32"
# Tot_Day_Suply:"960"
# Tot_Drug_Cst:"400.88"
# Tot_Benes:"".31
# GE65_Sprsn_Flag:"*".8
# GE65_Tot_Clms:"".28
# GE65_Tot_30day_Fills:"".28
# GE65_Tot_Drug_Cst:"".28
# GE65_Tot_Day_Suply:"".28
# GE65_Bene_Sprsn_Flag:"*".41
# GE65_Tot_Benes:""}.55
# {"Prscrbr_NPI":"1003000530".41
# Prscrbr_Last_Org_Name:"Semonche".41
# Prscrbr_First_Name:"Amanda".41
# Prscrbr_City:"Quakertown".41
# Prscrbr_State_Abrvtn:"PA".41
# Prscrbr_State_FIPS:"42".41
# Prscrbr_Type:"Internal Medicine".41
# Prscrbr_Type_Src:"Claim-Specialty".68
# Brnd_Name:"Finasteride"
# Gnrc_Name:"Finasteride"
# Tot_Clms:"31".1
# Tot_30day_Fills:"79"
# Tot_Day_Suply:"2370"
# Tot_Drug_Cst:"628.74"
# Tot_Benes:"".32
# GE65_Sprsn_Flag:"".41
# GE65_Tot_Clms:"31"
# GE65_Tot_30day_Fills:"79"
# GE65_Tot_Drug_Cst:"628.74"
# GE65_Tot_Day_Suply:"2370"
# GE65_Bene_Sprsn_Flag:"*".42
# GE65_Tot_Benes:""}.56
# {"Prscrbr_NPI":"1003000530".42
# Prscrbr_Last_Org_Name:"Semonche".42
# Prscrbr_First_Name:"Amanda".42
# Prscrbr_City:"Quakertown".42
# Prscrbr_State_Abrvtn:"PA".42
# Prscrbr_State_FIPS:"42".42
# Prscrbr_Type:"Internal Medicine".42
# Prscrbr_Type_Src:"Claim-Specialty".69
# Brnd_Name:"Fluticasone Propionate"
# Gnrc_Name:"Fluticasone Propionate"
# Tot_Clms:"59"
# Tot_30day_Fills:"108"
# Tot_Day_Suply:"3240"
# Tot_Drug_Cst:"709.42"
# Tot_Benes:"23".1
# GE65_Sprsn_Flag:"#".20
# GE65_Tot_Clms:"".29
# GE65_Tot_30day_Fills:"".29
# GE65_Tot_Drug_Cst:"".29
# GE65_Tot_Day_Suply:"".29
# GE65_Bene_Sprsn_Flag:"#".14
# GE65_Tot_Benes:""}.57
# {"Prscrbr_NPI":"1003000530".43
# Prscrbr_Last_Org_Name:"Semonche".43
# Prscrbr_First_Name:"Amanda".43
# Prscrbr_City:"Quakertown".43
# Prscrbr_State_Abrvtn:"PA".43
# Prscrbr_State_FIPS:"42".43
# Prscrbr_Type:"Internal Medicine".43
# Prscrbr_Type_Src:"Claim-Specialty".70
# Brnd_Name:"Fluticasone-Salmeterol"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol".1
# Tot_Clms:"16".4
# Tot_30day_Fills:"24".1
# Tot_Day_Suply:"720".1
# Tot_Drug_Cst:"3464.46"
# Tot_Benes:"".33
# GE65_Sprsn_Flag:"#".21
# GE65_Tot_Clms:"".30
# GE65_Tot_30day_Fills:"".30
# GE65_Tot_Drug_Cst:"".30
# GE65_Tot_Day_Suply:"".30
# GE65_Bene_Sprsn_Flag:"*".43
# GE65_Tot_Benes:""}.58
# {"Prscrbr_NPI":"1003000530".44
# Prscrbr_Last_Org_Name:"Semonche".44
# Prscrbr_First_Name:"Amanda".44
# Prscrbr_City:"Quakertown".44
# Prscrbr_State_Abrvtn:"PA".44
# Prscrbr_State_FIPS:"42".44
# Prscrbr_Type:"Internal Medicine".44
# Prscrbr_Type_Src:"Claim-Specialty".71
# Brnd_Name:"Fosinopril Sodium"
# Gnrc_Name:"Fosinopril Sodium"
# Tot_Clms:"23".1
# Tot_30day_Fills:"33"
# Tot_Day_Suply:"990"
# Tot_Drug_Cst:"487.11"
# Tot_Benes:"".34
# GE65_Sprsn_Flag:"".42
# GE65_Tot_Clms:"23"
# GE65_Tot_30day_Fills:"33"
# GE65_Tot_Drug_Cst:"487.11"
# GE65_Tot_Day_Suply:"990"
# GE65_Bene_Sprsn_Flag:"*".44
# GE65_Tot_Benes:""}.59
# {"Prscrbr_NPI":"1003000530".45
# Prscrbr_Last_Org_Name:"Semonche".45
# Prscrbr_First_Name:"Amanda".45
# Prscrbr_City:"Quakertown".45
# Prscrbr_State_Abrvtn:"PA".45
# Prscrbr_State_FIPS:"42".45
# Prscrbr_Type:"Internal Medicine".45
# Prscrbr_Type_Src:"Claim-Specialty".72
# Brnd_Name:"Furosemide"
# Gnrc_Name:"Furosemide"
# Tot_Clms:"74"
# Tot_30day_Fills:"137"
# Tot_Day_Suply:"4054"
# Tot_Drug_Cst:"516.89"
# Tot_Benes:"23".2
# GE65_Sprsn_Flag:"#".22
# GE65_Tot_Clms:"".31
# GE65_Tot_30day_Fills:"".31
# GE65_Tot_Drug_Cst:"".31
# GE65_Tot_Day_Suply:"".31
# GE65_Bene_Sprsn_Flag:"#".15
# GE65_Tot_Benes:""}.60
# {"Prscrbr_NPI":"1003000530".46
# Prscrbr_Last_Org_Name:"Semonche".46
# Prscrbr_First_Name:"Amanda".46
# Prscrbr_City:"Quakertown".46
# Prscrbr_State_Abrvtn:"PA".46
# Prscrbr_State_FIPS:"42".46
# Prscrbr_Type:"Internal Medicine".46
# Prscrbr_Type_Src:"Claim-Specialty".73
# Brnd_Name:"Gabapentin".1
# Gnrc_Name:"Gabapentin".1
# Tot_Clms:"223"
# Tot_30day_Fills:"382"
# Tot_Day_Suply:"11391"
# Tot_Drug_Cst:"3411.56"
# Tot_Benes:"53"
# GE65_Sprsn_Flag:"".43
# GE65_Tot_Clms:"203"
# GE65_Tot_30day_Fills:"358"
# GE65_Tot_Drug_Cst:"3230.61"
# GE65_Tot_Day_Suply:"10677"
# GE65_Bene_Sprsn_Flag:"#".16
# GE65_Tot_Benes:""}.61
# {"Prscrbr_NPI":"1003000530".47
# Prscrbr_Last_Org_Name:"Semonche".47
# Prscrbr_First_Name:"Amanda".47
# Prscrbr_City:"Quakertown".47
# Prscrbr_State_Abrvtn:"PA".47
# Prscrbr_State_FIPS:"42".47
# Prscrbr_Type:"Internal Medicine".47
# Prscrbr_Type_Src:"Claim-Specialty".74
# Brnd_Name:"Gemfibrozil"
# Gnrc_Name:"Gemfibrozil"
# Tot_Clms:"11".1
# Tot_30day_Fills:"11".1
# Tot_Day_Suply:"330"
# Tot_Drug_Cst:"99"
# Tot_Benes:"".35
# GE65_Sprsn_Flag:"".44
# GE65_Tot_Clms:"11".1
# GE65_Tot_30day_Fills:"11"
# GE65_Tot_Drug_Cst:"99"
# GE65_Tot_Day_Suply:"330"
# GE65_Bene_Sprsn_Flag:"*".45
# GE65_Tot_Benes:""}.62
# {"Prscrbr_NPI":"1003000530".48
# Prscrbr_Last_Org_Name:"Semonche".48
# Prscrbr_First_Name:"Amanda".48
# Prscrbr_City:"Quakertown".48
# Prscrbr_State_Abrvtn:"PA".48
# Prscrbr_State_FIPS:"42".48
# Prscrbr_Type:"Internal Medicine".48
# Prscrbr_Type_Src:"Claim-Specialty".75
# Brnd_Name:"Glipizide"
# Gnrc_Name:"Glipizide"
# Tot_Clms:"82".1
# Tot_30day_Fills:"191.1"
# Tot_Day_Suply:"5694"
# Tot_Drug_Cst:"958.43"
# Tot_Benes:"18".1
# GE65_Sprsn_Flag:"".45
# GE65_Tot_Clms:"82"
# GE65_Tot_30day_Fills:"191.1"
# GE65_Tot_Drug_Cst:"958.43"
# GE65_Tot_Day_Suply:"5694"
# GE65_Bene_Sprsn_Flag:"".14
# GE65_Tot_Benes:"18"}
# {"Prscrbr_NPI":"1003000530".49
# Prscrbr_Last_Org_Name:"Semonche".49
# Prscrbr_First_Name:"Amanda".49
# Prscrbr_City:"Quakertown".49
# Prscrbr_State_Abrvtn:"PA".49
# Prscrbr_State_FIPS:"42".49
# Prscrbr_Type:"Internal Medicine".49
# Prscrbr_Type_Src:"Claim-Specialty".76
# Brnd_Name:"Glycopyrrolate"
# Gnrc_Name:"Glycopyrrolate"
# Tot_Clms:"14".7
# Tot_30day_Fills:"16.2"
# Tot_Day_Suply:"485"
# Tot_Drug_Cst:"908.42"
# Tot_Benes:"".36
# GE65_Sprsn_Flag:"*".9
# GE65_Tot_Clms:"".32
# GE65_Tot_30day_Fills:"".32
# GE65_Tot_Drug_Cst:"".32
# GE65_Tot_Day_Suply:"".32
# GE65_Bene_Sprsn_Flag:"*".46
# GE65_Tot_Benes:""}.63
# {"Prscrbr_NPI":"1003000530".50
# Prscrbr_Last_Org_Name:"Semonche".50
# Prscrbr_First_Name:"Amanda".50
# Prscrbr_City:"Quakertown".50
# Prscrbr_State_Abrvtn:"PA".50
# Prscrbr_State_FIPS:"42".50
# Prscrbr_Type:"Internal Medicine".50
# Prscrbr_Type_Src:"Claim-Specialty".77
# Brnd_Name:"Hydrochlorothiazide"
# Gnrc_Name:"Hydrochlorothiazide"
# Tot_Clms:"188"
# Tot_30day_Fills:"456"
# Tot_Day_Suply:"13668"
# Tot_Drug_Cst:"712.76"
# Tot_Benes:"44"
# GE65_Sprsn_Flag:"#".23
# GE65_Tot_Clms:"".33
# GE65_Tot_30day_Fills:"".33
# GE65_Tot_Drug_Cst:"".33
# GE65_Tot_Day_Suply:"".33
# GE65_Bene_Sprsn_Flag:"#".17
# GE65_Tot_Benes:""}.64
# {"Prscrbr_NPI":"1003000530".51
# Prscrbr_Last_Org_Name:"Semonche".51
# Prscrbr_First_Name:"Amanda".51
# Prscrbr_City:"Quakertown".51
# Prscrbr_State_Abrvtn:"PA".51
# Prscrbr_State_FIPS:"42".51
# Prscrbr_Type:"Internal Medicine".51
# Prscrbr_Type_Src:"Claim-Specialty".78
# Brnd_Name:"Hydrocodone-Acetaminophen".1
# Gnrc_Name:"Hydrocodone\/Acetaminophen".1
# Tot_Clms:"21".1
# Tot_30day_Fills:"21"
# Tot_Day_Suply:"306"
# Tot_Drug_Cst:"463.91"
# Tot_Benes:"".37
# GE65_Sprsn_Flag:"".46
# GE65_Tot_Clms:"21"
# GE65_Tot_30day_Fills:"21".1
# GE65_Tot_Drug_Cst:"463.91"
# GE65_Tot_Day_Suply:"306"
# GE65_Bene_Sprsn_Flag:"*".47
# GE65_Tot_Benes:""}.65
# {"Prscrbr_NPI":"1003000530".52
# Prscrbr_Last_Org_Name:"Semonche".52
# Prscrbr_First_Name:"Amanda".52
# Prscrbr_City:"Quakertown".52
# Prscrbr_State_Abrvtn:"PA".52
# Prscrbr_State_FIPS:"42".52
# Prscrbr_Type:"Internal Medicine".52
# Prscrbr_Type_Src:"Claim-Specialty".79
# Brnd_Name:"Irbesartan"
# Gnrc_Name:"Irbesartan"
# Tot_Clms:"19".1
# Tot_30day_Fills:"33".1
# Tot_Day_Suply:"964"
# Tot_Drug_Cst:"852.51"
# Tot_Benes:"".38
# GE65_Sprsn_Flag:"*".10
# GE65_Tot_Clms:"".34
# GE65_Tot_30day_Fills:"".34
# GE65_Tot_Drug_Cst:"".34
# GE65_Tot_Day_Suply:"".34
# GE65_Bene_Sprsn_Flag:"*".48
# GE65_Tot_Benes:""}.66
# {"Prscrbr_NPI":"1003000530".53
# Prscrbr_Last_Org_Name:"Semonche".53
# Prscrbr_First_Name:"Amanda".53
# Prscrbr_City:"Quakertown".53
# Prscrbr_State_Abrvtn:"PA".53
# Prscrbr_State_FIPS:"42".53
# Prscrbr_Type:"Internal Medicine".53
# Prscrbr_Type_Src:"Claim-Specialty".80
# Brnd_Name:"Isosorbide Mononitrate Er"
# Gnrc_Name:"Isosorbide Mononitrate"
# Tot_Clms:"23".2
# Tot_30day_Fills:"47"
# Tot_Day_Suply:"1410"
# Tot_Drug_Cst:"529.15"
# Tot_Benes:"".39
# GE65_Sprsn_Flag:"#".24
# GE65_Tot_Clms:"".35
# GE65_Tot_30day_Fills:"".35
# GE65_Tot_Drug_Cst:"".35
# GE65_Tot_Day_Suply:"".35
# GE65_Bene_Sprsn_Flag:"*".49
# GE65_Tot_Benes:""}.67
# {"Prscrbr_NPI":"1003000530".54
# Prscrbr_Last_Org_Name:"Semonche".54
# Prscrbr_First_Name:"Amanda".54
# Prscrbr_City:"Quakertown".54
# Prscrbr_State_Abrvtn:"PA".54
# Prscrbr_State_FIPS:"42".54
# Prscrbr_Type:"Internal Medicine".54
# Prscrbr_Type_Src:"Claim-Specialty".81
# Brnd_Name:"Januvia"
# Gnrc_Name:"Sitagliptin Phosphate"
# Tot_Clms:"27".1
# Tot_30day_Fills:"49"
# Tot_Day_Suply:"1470"
# Tot_Drug_Cst:"27971.54"
# Tot_Benes:"".40
# GE65_Sprsn_Flag:"".47
# GE65_Tot_Clms:"27".1
# GE65_Tot_30day_Fills:"49"
# GE65_Tot_Drug_Cst:"27971.54"
# GE65_Tot_Day_Suply:"1470"
# GE65_Bene_Sprsn_Flag:"*".50
# GE65_Tot_Benes:""}.68
# ...
# Tot_Benes:"41".5
# GE65_Sprsn_Flag:"".553
# GE65_Tot_Clms:"106".2
# GE65_Tot_30day_Fills:"226".1
# GE65_Tot_Drug_Cst:"2465.7"
# GE65_Tot_Day_Suply:"6780"
# GE65_Bene_Sprsn_Flag:"".146
# GE65_Tot_Benes:"30"}.1
# {"Prscrbr_NPI":"1003004201".48
# Prscrbr_Last_Org_Name:"Philbrick".48
# Prscrbr_First_Name:"Natalie".48
# Prscrbr_City:"Corpus Christi".48
# Prscrbr_State_Abrvtn:"TX".96
# Prscrbr_State_FIPS:"48".96
# Prscrbr_Type:"Internal Medicine".170
# Prscrbr_Type_Src:"Claim-Specialty".758
# Brnd_Name:"Glimepiride".2
# Gnrc_Name:"Glimepiride".2
# Tot_Clms:"11".54
# Tot_30day_Fills:"31".7
# Tot_Day_Suply:"911"
# Tot_Drug_Cst:"72.72"
# Tot_Benes:"".497
# GE65_Sprsn_Flag:"".554
# GE65_Tot_Clms:"11".26
# GE65_Tot_30day_Fills:"31".3
# GE65_Tot_Drug_Cst:"72.72"
# GE65_Tot_Day_Suply:"911"
# GE65_Bene_Sprsn_Flag:"*".531
# GE65_Tot_Benes:""}.827
# {"Prscrbr_NPI":"1003004201".49
# Prscrbr_Last_Org_Name:"Philbrick".49
# Prscrbr_First_Name:"Natalie".49
# Prscrbr_City:"Corpus Christi".49
# Prscrbr_State_Abrvtn:"TX".97
# Prscrbr_State_FIPS:"48".97
# Prscrbr_Type:"Internal Medicine".171
# Prscrbr_Type_Src:"Claim-Specialty".759
# Brnd_Name:"Glipizide".4
# Gnrc_Name:"Glipizide".8
# Tot_Clms:"12".45
# Tot_30day_Fills:"35".12
# Tot_Day_Suply:"1050".8
# Tot_Drug_Cst:"69.59".1
# Tot_Benes:"".498
# GE65_Sprsn_Flag:"".555
# GE65_Tot_Clms:"12".24
# GE65_Tot_30day_Fills:"35".5
# GE65_Tot_Drug_Cst:"69.59".1
# GE65_Tot_Day_Suply:"1050".5
# GE65_Bene_Sprsn_Flag:"*".532
# GE65_Tot_Benes:""}.828
# {"Prscrbr_NPI":"1003004201".50
# Prscrbr_Last_Org_Name:"Philbrick".50
# Prscrbr_First_Name:"Natalie".50
# Prscrbr_City:"Corpus Christi".50
# Prscrbr_State_Abrvtn:"TX".98
# Prscrbr_State_FIPS:"48".98
# Prscrbr_Type:"Internal Medicine".172
# Prscrbr_Type_Src:"Claim-Specialty".760
# Brnd_Name:"Hydrochlorothiazide".7
# Gnrc_Name:"Hydrochlorothiazide".7
# Tot_Clms:"88".4
# Tot_30day_Fills:"198.7"
# Tot_Day_Suply:"5943"
# Tot_Drug_Cst:"308.78"
# Tot_Benes:"21".17
# GE65_Sprsn_Flag:"".556
# GE65_Tot_Clms:"76".1
# GE65_Tot_30day_Fills:"164"
# GE65_Tot_Drug_Cst:"245.72"
# GE65_Tot_Day_Suply:"4903"
# GE65_Bene_Sprsn_Flag:"#".296
# GE65_Tot_Benes:""}.829
# {"Prscrbr_NPI":"1003004201".51
# Prscrbr_Last_Org_Name:"Philbrick".51
# Prscrbr_First_Name:"Natalie".51
# Prscrbr_City:"Corpus Christi".51
# Prscrbr_State_Abrvtn:"TX".99
# Prscrbr_State_FIPS:"48".99
# Prscrbr_Type:"Internal Medicine".173
# Prscrbr_Type_Src:"Claim-Specialty".761
# Brnd_Name:"Hydrocodone-Acetaminophen".12
# Gnrc_Name:"Hydrocodone\/Acetaminophen".12
# Tot_Clms:"75".2
# Tot_30day_Fills:"75".3
# Tot_Day_Suply:"1902"
# Tot_Drug_Cst:"1984.27"
# Tot_Benes:"24".11
# GE65_Sprsn_Flag:"".557
# GE65_Tot_Clms:"51".2
# GE65_Tot_30day_Fills:"51".5
# GE65_Tot_Drug_Cst:"1443.05"
# GE65_Tot_Day_Suply:"1317"
# GE65_Bene_Sprsn_Flag:"#".297
# GE65_Tot_Benes:""}.830
# {"Prscrbr_NPI":"1003004201".52
# Prscrbr_Last_Org_Name:"Philbrick".52
# Prscrbr_First_Name:"Natalie".52
# Prscrbr_City:"Corpus Christi".52
# Prscrbr_State_Abrvtn:"TX".100
# Prscrbr_State_FIPS:"48".100
# Prscrbr_Type:"Internal Medicine".174
# Prscrbr_Type_Src:"Claim-Specialty".762
# Brnd_Name:"Ibuprofen".5
# Gnrc_Name:"Ibuprofen".5
# Tot_Clms:"23".20
# Tot_30day_Fills:"23".9
# Tot_Day_Suply:"645"
# Tot_Drug_Cst:"239.22"
# Tot_Benes:"".499
# GE65_Sprsn_Flag:"*".100
# GE65_Tot_Clms:"".420
# GE65_Tot_30day_Fills:"".420
# GE65_Tot_Drug_Cst:"".420
# GE65_Tot_Day_Suply:"".420
# GE65_Bene_Sprsn_Flag:"*".533
# GE65_Tot_Benes:""}.831
# {"Prscrbr_NPI":"1003004201".53
# Prscrbr_Last_Org_Name:"Philbrick".53
# Prscrbr_First_Name:"Natalie".53
# Prscrbr_City:"Corpus Christi".53
# Prscrbr_State_Abrvtn:"TX".101
# Prscrbr_State_FIPS:"48".101
# Prscrbr_Type:"Internal Medicine".175
# Prscrbr_Type_Src:"Claim-Specialty".763
# Brnd_Name:"Irbesartan".3
# Gnrc_Name:"Irbesartan".3
# Tot_Clms:"33".12
# Tot_30day_Fills:"81".2
# Tot_Day_Suply:"2409"
# Tot_Drug_Cst:"601.43"
# Tot_Benes:"".500
# GE65_Sprsn_Flag:"".558
# GE65_Tot_Clms:"33".5
# GE65_Tot_30day_Fills:"81".1
# GE65_Tot_Drug_Cst:"601.43"
# GE65_Tot_Day_Suply:"2409"
# GE65_Bene_Sprsn_Flag:"*".534
# GE65_Tot_Benes:""}.832
# {"Prscrbr_NPI":"1003004201".54
# Prscrbr_Last_Org_Name:"Philbrick".54
# Prscrbr_First_Name:"Natalie".54
# Prscrbr_City:"Corpus Christi".54
# Prscrbr_State_Abrvtn:"TX".102
# Prscrbr_State_FIPS:"48".102
# Prscrbr_Type:"Internal Medicine".176
# Prscrbr_Type_Src:"Claim-Specialty".764
# Brnd_Name:"Janumet".2
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".3
# Tot_Clms:"11".55
# Tot_30day_Fills:"34.3".1
# Tot_Day_Suply:"1030"
# Tot_Drug_Cst:"15945.71"
# Tot_Benes:"".501
# GE65_Sprsn_Flag:"*".101
# GE65_Tot_Clms:"".421
# GE65_Tot_30day_Fills:"".421
# GE65_Tot_Drug_Cst:"".421
# GE65_Tot_Day_Suply:"".421
# GE65_Bene_Sprsn_Flag:"*".535
# GE65_Tot_Benes:""}.833
# {"Prscrbr_NPI":"1003004201".55
# Prscrbr_Last_Org_Name:"Philbrick".55
# Prscrbr_First_Name:"Natalie".55
# Prscrbr_City:"Corpus Christi".55
# Prscrbr_State_Abrvtn:"TX".103
# Prscrbr_State_FIPS:"48".103
# Prscrbr_Type:"Internal Medicine".177
# Prscrbr_Type_Src:"Claim-Specialty".765
# Brnd_Name:"Janumet Xr".1
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".4
# Tot_Clms:"16".31
# Tot_30day_Fills:"26".10
# Tot_Day_Suply:"780".4
# Tot_Drug_Cst:"14576.22"
# Tot_Benes:"".502
# GE65_Sprsn_Flag:"".559
# GE65_Tot_Clms:"16".17
# GE65_Tot_30day_Fills:"26".4
# GE65_Tot_Drug_Cst:"14576.22"
# GE65_Tot_Day_Suply:"780".1
# GE65_Bene_Sprsn_Flag:"*".536
# GE65_Tot_Benes:""}.834
# {"Prscrbr_NPI":"1003004201".56
# Prscrbr_Last_Org_Name:"Philbrick".56
# Prscrbr_First_Name:"Natalie".56
# Prscrbr_City:"Corpus Christi".56
# Prscrbr_State_Abrvtn:"TX".104
# Prscrbr_State_FIPS:"48".104
# Prscrbr_Type:"Internal Medicine".178
# Prscrbr_Type_Src:"Claim-Specialty".766
# Brnd_Name:"Januvia".5
# Gnrc_Name:"Sitagliptin Phosphate".5
# Tot_Clms:"47".7
# Tot_30day_Fills:"102.7"
# Tot_Day_Suply:"3080"
# Tot_Drug_Cst:"57151.67"
# Tot_Benes:"".503
# GE65_Sprsn_Flag:"".560
# GE65_Tot_Clms:"33".6
# GE65_Tot_30day_Fills:"61".4
# GE65_Tot_Drug_Cst:"32794.59"
# GE65_Tot_Day_Suply:"1830".3
# GE65_Bene_Sprsn_Flag:"*".537
# GE65_Tot_Benes:""}.835
# {"Prscrbr_NPI":"1003004201".57
# Prscrbr_Last_Org_Name:"Philbrick".57
# Prscrbr_First_Name:"Natalie".57
# Prscrbr_City:"Corpus Christi".57
# Prscrbr_State_Abrvtn:"TX".105
# Prscrbr_State_FIPS:"48".105
# Prscrbr_Type:"Internal Medicine".179
# Prscrbr_Type_Src:"Claim-Specialty".767
# Brnd_Name:"Jardiance".5
# Gnrc_Name:"Empagliflozin".5
# Tot_Clms:"36".10
# Tot_30day_Fills:"48".7
# Tot_Day_Suply:"1440".5
# Tot_Drug_Cst:"30810.62"
# Tot_Benes:"".504
# GE65_Sprsn_Flag:"".561
# GE65_Tot_Clms:"16".18
# GE65_Tot_30day_Fills:"28".4
# GE65_Tot_Drug_Cst:"17814.66"
# GE65_Tot_Day_Suply:"840".4
# GE65_Bene_Sprsn_Flag:"*".538
# GE65_Tot_Benes:""}.836
# {"Prscrbr_NPI":"1003004201".58
# Prscrbr_Last_Org_Name:"Philbrick".58
# Prscrbr_First_Name:"Natalie".58
# Prscrbr_City:"Corpus Christi".58
# Prscrbr_State_Abrvtn:"TX".106
# Prscrbr_State_FIPS:"48".106
# Prscrbr_Type:"Internal Medicine".180
# Prscrbr_Type_Src:"Claim-Specialty".768
# Brnd_Name:"Lantus Solostar".4
# Gnrc_Name:"Insulin Glargine.7
# hum.Rec.Anlog".7
# Tot_Clms:"30".15
# Tot_30day_Fills:"42.6"
# Tot_Day_Suply:"1200".4
# Tot_Drug_Cst:"14025.7"
# Tot_Benes:"".505
# GE65_Sprsn_Flag:"*".102
# GE65_Tot_Clms:"".422
# GE65_Tot_30day_Fills:"".422
# GE65_Tot_Drug_Cst:"".422
# GE65_Tot_Day_Suply:"".422
# GE65_Bene_Sprsn_Flag:"*".539
# GE65_Tot_Benes:""}.837
# {"Prscrbr_NPI":"1003004201".59
# Prscrbr_Last_Org_Name:"Philbrick".59
# Prscrbr_First_Name:"Natalie".59
# Prscrbr_City:"Corpus Christi".59
# Prscrbr_State_Abrvtn:"TX".107
# Prscrbr_State_FIPS:"48".107
# Prscrbr_Type:"Internal Medicine".181
# Prscrbr_Type_Src:"Claim-Specialty".769
# Brnd_Name:"Levemir Flexpen"
# Gnrc_Name:"Insulin Detemir"
# Tot_Clms:"18".24
# Tot_30day_Fills:"40.7".1
# Tot_Day_Suply:"1216"
# Tot_Drug_Cst:"14820.64"
# Tot_Benes:"".506
# GE65_Sprsn_Flag:"#".320
# GE65_Tot_Clms:"".423
# GE65_Tot_30day_Fills:"".423
# GE65_Tot_Drug_Cst:"".423
# GE65_Tot_Day_Suply:"".423
# GE65_Bene_Sprsn_Flag:"*".540
# GE65_Tot_Benes:""}.838
# {"Prscrbr_NPI":"1003004201".60
# Prscrbr_Last_Org_Name:"Philbrick".60
# Prscrbr_First_Name:"Natalie".60
# Prscrbr_City:"Corpus Christi".60
# Prscrbr_State_Abrvtn:"TX".108
# Prscrbr_State_FIPS:"48".108
# Prscrbr_Type:"Internal Medicine".182
# Prscrbr_Type_Src:"Claim-Specialty".770
# Brnd_Name:"Levothyroxine Sodium".7
# Gnrc_Name:"Levothyroxine Sodium".13
# Tot_Clms:"329"
# Tot_30day_Fills:"878.8"
# Tot_Day_Suply:"26336"
# Tot_Drug_Cst:"5172.2"
# Tot_Benes:"87".1
# GE65_Sprsn_Flag:"".562
# GE65_Tot_Clms:"296"
# GE65_Tot_30day_Fills:"792.8"
# GE65_Tot_Drug_Cst:"4565.09"
# GE65_Tot_Day_Suply:"23768"
# GE65_Bene_Sprsn_Flag:"#".298
# GE65_Tot_Benes:""}.839
# {"Prscrbr_NPI":"1003004201".61
# Prscrbr_Last_Org_Name:"Philbrick".61
# Prscrbr_First_Name:"Natalie".61
# Prscrbr_City:"Corpus Christi".61
# Prscrbr_State_Abrvtn:"TX".109
# Prscrbr_State_FIPS:"48".109
# Prscrbr_Type:"Internal Medicine".183
# Prscrbr_Type_Src:"Claim-Specialty".771
# Brnd_Name:"Lisinopril".9
# Gnrc_Name:"Lisinopril".9
# Tot_Clms:"191".1
# Tot_30day_Fills:"567.6"
# Tot_Day_Suply:"17030"
# Tot_Drug_Cst:"1067.95"
# Tot_Benes:"57".1
# GE65_Sprsn_Flag:"".563
# GE65_Tot_Clms:"168".1
# GE65_Tot_30day_Fills:"498.6"
# GE65_Tot_Drug_Cst:"935.82"
# GE65_Tot_Day_Suply:"14960"
# GE65_Bene_Sprsn_Flag:"#".299
# GE65_Tot_Benes:""}.840
# {"Prscrbr_NPI":"1003004201".62
# Prscrbr_Last_Org_Name:"Philbrick".62
# Prscrbr_First_Name:"Natalie".62
# Prscrbr_City:"Corpus Christi".62
# Prscrbr_State_Abrvtn:"TX".110
# Prscrbr_State_FIPS:"48".110
# Prscrbr_Type:"Internal Medicine".184
# Prscrbr_Type_Src:"Claim-Specialty".772
# Brnd_Name:"Lisinopril-Hydrochlorothiazide".3
# Gnrc_Name:"Lisinopril\/Hydrochlorothiazide".3
# Tot_Clms:"31".8
# Tot_30day_Fills:"86.3"
# Tot_Day_Suply:"2556"
# Tot_Drug_Cst:"358.53"
# Tot_Benes:"".507
# GE65_Sprsn_Flag:"#".321
# GE65_Tot_Clms:"".424
# GE65_Tot_30day_Fills:"".424
# GE65_Tot_Drug_Cst:"".424
# GE65_Tot_Day_Suply:"".424
# GE65_Bene_Sprsn_Flag:"*".541
# GE65_Tot_Benes:""}.841
# {"Prscrbr_NPI":"1003004201".63
# Prscrbr_Last_Org_Name:"Philbrick".63
# Prscrbr_First_Name:"Natalie".63
# Prscrbr_City:"Corpus Christi".63
# Prscrbr_State_Abrvtn:"TX".111
# Prscrbr_State_FIPS:"48".111
# Prscrbr_Type:"Internal Medicine".185
# Prscrbr_Type_Src:"Claim-Specialty".773
# Brnd_Name:"Lorazepam".4
# Gnrc_Name:"Lorazepam".4
# Tot_Clms:"17".23
# Tot_30day_Fills:"17".14
# Tot_Day_Suply:"467"
# Tot_Drug_Cst:"68.44"
# Tot_Benes:"".508
# GE65_Sprsn_Flag:"#".322
# GE65_Tot_Clms:"".425
# GE65_Tot_30day_Fills:"".425
# GE65_Tot_Drug_Cst:"".425
# GE65_Tot_Day_Suply:"".425
# GE65_Bene_Sprsn_Flag:"*".542
# GE65_Tot_Benes:""}.842
# {"Prscrbr_NPI":"1003004201".64
# Prscrbr_Last_Org_Name:"Philbrick".64
# Prscrbr_First_Name:"Natalie".64
# Prscrbr_City:"Corpus Christi".64
# Prscrbr_State_Abrvtn:"TX".112
# Prscrbr_State_FIPS:"48".112
# Prscrbr_Type:"Internal Medicine".186
# Prscrbr_Type_Src:"Claim-Specialty".774
# Brnd_Name:"Losartan Potassium".8
# Gnrc_Name:"Losartan Potassium".8
# Tot_Clms:"198"
# Tot_30day_Fills:"489"
# Tot_Day_Suply:"14661"
# Tot_Drug_Cst:"2739.62"
# Tot_Benes:"54".1
# GE65_Sprsn_Flag:"#".323
# GE65_Tot_Clms:"".426
# GE65_Tot_30day_Fills:"".426
# GE65_Tot_Drug_Cst:"".426
# GE65_Tot_Day_Suply:"".426
# GE65_Bene_Sprsn_Flag:"#".300
# GE65_Tot_Benes:""}.843
# {"Prscrbr_NPI":"1003004201".65
# Prscrbr_Last_Org_Name:"Philbrick".65
# Prscrbr_First_Name:"Natalie".65
# Prscrbr_City:"Corpus Christi".65
# Prscrbr_State_Abrvtn:"TX".113
# Prscrbr_State_FIPS:"48".113
# Prscrbr_Type:"Internal Medicine".187
# Prscrbr_Type_Src:"Claim-Specialty".775
# Brnd_Name:"Losartan-Hydrochlorothiazide".3
# Gnrc_Name:"Losartan\/Hydrochlorothiazide".3
# Tot_Clms:"77"
# Tot_30day_Fills:"218.3"
# Tot_Day_Suply:"6550"
# Tot_Drug_Cst:"1248.85"
# Tot_Benes:"23".11
# GE65_Sprsn_Flag:"#".324
# GE65_Tot_Clms:"".427
# GE65_Tot_30day_Fills:"".427
# GE65_Tot_Drug_Cst:"".427
# GE65_Tot_Day_Suply:"".427
# GE65_Bene_Sprsn_Flag:"#".301
# GE65_Tot_Benes:""}.844
# {"Prscrbr_NPI":"1003004201".66
# Prscrbr_Last_Org_Name:"Philbrick".66
# Prscrbr_First_Name:"Natalie".66
# Prscrbr_City:"Corpus Christi".66
# Prscrbr_State_Abrvtn:"TX".114
# Prscrbr_State_FIPS:"48".114
# Prscrbr_Type:"Internal Medicine".188
# Prscrbr_Type_Src:"Claim-Specialty".776
# Brnd_Name:"Meloxicam".10
# Gnrc_Name:"Meloxicam".10
# Tot_Clms:"295".1
# Tot_30day_Fills:"662.6"
# Tot_Day_Suply:"19839"
# Tot_Drug_Cst:"1681.33"
# Tot_Benes:"87".2
# GE65_Sprsn_Flag:"".564
# GE65_Tot_Clms:"250"
# GE65_Tot_30day_Fills:"558"
# GE65_Tot_Drug_Cst:"1493.45"
# GE65_Tot_Day_Suply:"16724"
# GE65_Bene_Sprsn_Flag:"".147
# GE65_Tot_Benes:"72"}
# {"Prscrbr_NPI":"1003004201".67
# Prscrbr_Last_Org_Name:"Philbrick".67
# Prscrbr_First_Name:"Natalie".67
# Prscrbr_City:"Corpus Christi".67
# Prscrbr_State_Abrvtn:"TX".115
# Prscrbr_State_FIPS:"48".115
# Prscrbr_Type:"Internal Medicine".189
# Prscrbr_Type_Src:"Claim-Specialty".777
# Brnd_Name:"Memantine Hcl Er"
# Gnrc_Name:"Memantine Hcl".3
# Tot_Clms:"11".56
# Tot_30day_Fills:"17".15
# Tot_Day_Suply:"510".6
# Tot_Drug_Cst:"685.59"
# Tot_Benes:"".509
# GE65_Sprsn_Flag:"".565
# GE65_Tot_Clms:"11".27
# GE65_Tot_30day_Fills:"17".5
# GE65_Tot_Drug_Cst:"685.59"
# GE65_Tot_Day_Suply:"510".2
# GE65_Bene_Sprsn_Flag:"*".543
# GE65_Tot_Benes:""}.845
# {"Prscrbr_NPI":"1003004201".68
# Prscrbr_Last_Org_Name:"Philbrick".68
# Prscrbr_First_Name:"Natalie".68
# Prscrbr_City:"Corpus Christi".68
# Prscrbr_State_Abrvtn:"TX".116
# Prscrbr_State_FIPS:"48".116
# Prscrbr_Type:"Internal Medicine".190
# Prscrbr_Type_Src:"Claim-Specialty".778
# Brnd_Name:"Metformin Hcl".7
# Gnrc_Name:"Metformin Hcl".12
# Tot_Clms:"172"
# Tot_30day_Fills:"477.7"
# Tot_Day_Suply:"14331"
# Tot_Drug_Cst:"1379.45"
# Tot_Benes:"54".2
# GE65_Sprsn_Flag:"".566
# GE65_Tot_Clms:"134"
# GE65_Tot_30day_Fills:"385"
# GE65_Tot_Drug_Cst:"998.73"
# GE65_Tot_Day_Suply:"11551"
# GE65_Bene_Sprsn_Flag:"".148
# GE65_Tot_Benes:"43"}.1
# {"Prscrbr_NPI":"1003004201".69
# Prscrbr_Last_Org_Name:"Philbrick".69
# Prscrbr_First_Name:"Natalie".69
# Prscrbr_City:"Corpus Christi".69
# Prscrbr_State_Abrvtn:"TX".117
# Prscrbr_State_FIPS:"48".117
# Prscrbr_Type:"Internal Medicine".191
# Prscrbr_Type_Src:"Claim-Specialty".779
# Brnd_Name:"Metformin Hcl Er".5
# Gnrc_Name:"Metformin Hcl".13
# Tot_Clms:"36".11
# Tot_30day_Fills:"94".2
# Tot_Day_Suply:"2819"
# Tot_Drug_Cst:"453.51"
# Tot_Benes:"14".23
# GE65_Sprsn_Flag:"#".325
# GE65_Tot_Clms:"".428
# GE65_Tot_30day_Fills:"".428
# GE65_Tot_Drug_Cst:"".428
# GE65_Tot_Day_Suply:"".428
# GE65_Bene_Sprsn_Flag:"#".302
# GE65_Tot_Benes:""}.846
# {"Prscrbr_NPI":"1003004201".70
# Prscrbr_Last_Org_Name:"Philbrick".70
# Prscrbr_First_Name:"Natalie".70
# Prscrbr_City:"Corpus Christi".70
# Prscrbr_State_Abrvtn:"TX".118
# Prscrbr_State_FIPS:"48".118
# Prscrbr_Type:"Internal Medicine".192
# Prscrbr_Type_Src:"Claim-Specialty".780
# Brnd_Name:"Methocarbamol".2
# Gnrc_Name:"Methocarbamol".2
# Tot_Clms:"16".32
# Tot_30day_Fills:"18".11
# Tot_Day_Suply:"520".1
# Tot_Drug_Cst:"110.37"
# Tot_Benes:"".510
# GE65_Sprsn_Flag:"#".326
# GE65_Tot_Clms:"".429
# GE65_Tot_30day_Fills:"".429
# GE65_Tot_Drug_Cst:"".429
# GE65_Tot_Day_Suply:"".429
# GE65_Bene_Sprsn_Flag:"*".544
# GE65_Tot_Benes:""}.847
# {"Prscrbr_NPI":"1003004201".71
# Prscrbr_Last_Org_Name:"Philbrick".71
# Prscrbr_First_Name:"Natalie".71
# Prscrbr_City:"Corpus Christi".71
# Prscrbr_State_Abrvtn:"TX".119
# Prscrbr_State_FIPS:"48".119
# Prscrbr_Type:"Internal Medicine".193
# Prscrbr_Type_Src:"Claim-Specialty".781
# Brnd_Name:"Metoprolol Succinate".8
# Gnrc_Name:"Metoprolol Succinate".8
# Tot_Clms:"65".3
# Tot_30day_Fills:"192.3"
# Tot_Day_Suply:"5770"
# Tot_Drug_Cst:"1332.13"
# Tot_Benes:"20".12
# GE65_Sprsn_Flag:"#".327
# GE65_Tot_Clms:"".430
# GE65_Tot_30day_Fills:"".430
# GE65_Tot_Drug_Cst:"".430
# GE65_Tot_Day_Suply:"".430
# GE65_Bene_Sprsn_Flag:"#".303
# GE65_Tot_Benes:""}.848
# {"Prscrbr_NPI":"1003004201".72
# Prscrbr_Last_Org_Name:"Philbrick".72
# Prscrbr_First_Name:"Natalie".72
# Prscrbr_City:"Corpus Christi".72
# Prscrbr_State_Abrvtn:"TX".120
# Prscrbr_State_FIPS:"48".120
# Prscrbr_Type:"Internal Medicine".194
# Prscrbr_Type_Src:"Claim-Specialty".782
# Brnd_Name:"Metoprolol Tartrate".6
# Gnrc_Name:"Metoprolol Tartrate".6
# Tot_Clms:"60".3
# Tot_30day_Fills:"150.1"
# Tot_Day_Suply:"4492"
# Tot_Drug_Cst:"305.37"
# Tot_Benes:"21".18
# GE65_Sprsn_Flag:"#".328
# GE65_Tot_Clms:"".431
# GE65_Tot_30day_Fills:"".431
# GE65_Tot_Drug_Cst:"".431
# GE65_Tot_Day_Suply:"".431
# GE65_Bene_Sprsn_Flag:"#".304
# GE65_Tot_Benes:""}.849
# {"Prscrbr_NPI":"1003004201".73
# Prscrbr_Last_Org_Name:"Philbrick".73
# Prscrbr_First_Name:"Natalie".73
# Prscrbr_City:"Corpus Christi".73
# Prscrbr_State_Abrvtn:"TX".121
# Prscrbr_State_FIPS:"48".121
# Prscrbr_Type:"Internal Medicine".195
# Prscrbr_Type_Src:"Claim-Specialty".783
# Brnd_Name:"Mirtazapine".4
# Gnrc_Name:"Mirtazapine".4
# Tot_Clms:"11".57
# Tot_30day_Fills:"21.3"
# Tot_Day_Suply:"640"
# Tot_Drug_Cst:"174.68"
# Tot_Benes:"".511
# GE65_Sprsn_Flag:"".567
# GE65_Tot_Clms:"11".28
# GE65_Tot_30day_Fills:"21.3"
# GE65_Tot_Drug_Cst:"174.68"
# GE65_Tot_Day_Suply:"640"
# GE65_Bene_Sprsn_Flag:"*".545
# GE65_Tot_Benes:""}]

# %%
#7
# Re-inspect CMS file structure
df_sample = pd.read_csv(f"{BASE_URL_CMS}?year={years[0]}&format=csv", nrows=5)
cols = df_sample.columns.tolist()

print("\n🔎 Columns found in CMS 2020 sample:")
for c in cols:
    print(c)
# Out:
# 🔎 Columns found in CMS 2020 sample:
# [{"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi"
# Prscrbr_First_Name:"Ardalan"
# Prscrbr_City:"Bethesda"
# Prscrbr_State_Abrvtn:"MD"
# Prscrbr_State_FIPS:"24"
# Prscrbr_Type:"Hospitalist"
# Prscrbr_Type_Src:"Claim-Specialty"
# Brnd_Name:"Eliquis"
# Gnrc_Name:"Apixaban"
# Tot_Clms:"13"
# Tot_30day_Fills:"15.3"
# Tot_Day_Suply:"437"
# Tot_Drug_Cst:"8828.74"
# Tot_Benes:""
# GE65_Sprsn_Flag:"#"
# GE65_Tot_Clms:""
# GE65_Tot_30day_Fills:""
# GE65_Tot_Drug_Cst:""
# GE65_Tot_Day_Suply:""
# GE65_Bene_Sprsn_Flag:"*"
# GE65_Tot_Benes:""}
# {"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi".1
# Prscrbr_First_Name:"Ardalan".1
# Prscrbr_City:"Bethesda".1
# Prscrbr_State_Abrvtn:"MD".1
# Prscrbr_State_FIPS:"24".1
# Prscrbr_Type:"Hospitalist".1
# Prscrbr_Type_Src:"Claim-Specialty".1
# Brnd_Name:"Prednisone"
# Gnrc_Name:"Prednisone"
# Tot_Clms:"14"
# Tot_30day_Fills:"14"
# Tot_Day_Suply:"153"
# Tot_Drug_Cst:"54.98"
# Tot_Benes:"14"
# GE65_Sprsn_Flag:"#".1
# GE65_Tot_Clms:"".1
# GE65_Tot_30day_Fills:"".1
# GE65_Tot_Drug_Cst:"".1
# GE65_Tot_Day_Suply:"".1
# GE65_Bene_Sprsn_Flag:"#"
# GE65_Tot_Benes:""}.1
# {"Prscrbr_NPI":"1003000142"
# Prscrbr_Last_Org_Name:"Khalil"
# Prscrbr_First_Name:"Rashid"
# Prscrbr_City:"Toledo"
# Prscrbr_State_Abrvtn:"OH"
# Prscrbr_State_FIPS:"39"
# Prscrbr_Type:"Anesthesiology"
# Prscrbr_Type_Src:"Claim-Specialty".2
# Brnd_Name:"Acetaminophen-Codeine"
# Gnrc_Name:"Acetaminophen With Codeine"
# Tot_Clms:"43"
# Tot_30day_Fills:"43"
# Tot_Day_Suply:"1020"
# Tot_Drug_Cst:"491.38"
# Tot_Benes:"12"
# GE65_Sprsn_Flag:"#".2
# GE65_Tot_Clms:"".2
# GE65_Tot_30day_Fills:"".2
# GE65_Tot_Drug_Cst:"".2
# GE65_Tot_Day_Suply:"".2
# GE65_Bene_Sprsn_Flag:"*".1
# GE65_Tot_Benes:""}.2
# {"Prscrbr_NPI":"1003000142".1
# Prscrbr_Last_Org_Name:"Khalil".1
# Prscrbr_First_Name:"Rashid".1
# Prscrbr_City:"Toledo".1
# Prscrbr_State_Abrvtn:"OH".1
# Prscrbr_State_FIPS:"39".1
# Prscrbr_Type:"Anesthesiology".1
# Prscrbr_Type_Src:"Claim-Specialty".3
# Brnd_Name:"Amitriptyline Hcl"
# Gnrc_Name:"Amitriptyline Hcl"
# Tot_Clms:"35"
# Tot_30day_Fills:"35"
# Tot_Day_Suply:"1050"
# Tot_Drug_Cst:"471.01"
# Tot_Benes:"15"
# GE65_Sprsn_Flag:"#".3
# GE65_Tot_Clms:"".3
# GE65_Tot_30day_Fills:"".3
# GE65_Tot_Drug_Cst:"".3
# GE65_Tot_Day_Suply:"".3
# GE65_Bene_Sprsn_Flag:"*".2
# GE65_Tot_Benes:""}.3
# {"Prscrbr_NPI":"1003000142".2
# Prscrbr_Last_Org_Name:"Khalil".2
# Prscrbr_First_Name:"Rashid".2
# Prscrbr_City:"Toledo".2
# Prscrbr_State_Abrvtn:"OH".2
# Prscrbr_State_FIPS:"39".2
# Prscrbr_Type:"Anesthesiology".2
# Prscrbr_Type_Src:"Claim-Specialty".4
# Brnd_Name:"Baclofen"
# Gnrc_Name:"Baclofen"
# Tot_Clms:"55"
# Tot_30day_Fills:"63"
# Tot_Day_Suply:"1890"
# Tot_Drug_Cst:"796.1"
# Tot_Benes:"23"
# GE65_Sprsn_Flag:""
# GE65_Tot_Clms:"27"
# GE65_Tot_30day_Fills:"29"
# GE65_Tot_Drug_Cst:"417.86"
# GE65_Tot_Day_Suply:"870"
# GE65_Bene_Sprsn_Flag:"*".3
# GE65_Tot_Benes:""}.4
# {"Prscrbr_NPI":"1003000142".3
# Prscrbr_Last_Org_Name:"Khalil".3
# Prscrbr_First_Name:"Rashid".3
# Prscrbr_City:"Toledo".3
# Prscrbr_State_Abrvtn:"OH".3
# Prscrbr_State_FIPS:"39".3
# Prscrbr_Type:"Anesthesiology".3
# Prscrbr_Type_Src:"Claim-Specialty".5
# Brnd_Name:"Buprenorphine"
# Gnrc_Name:"Buprenorphine"
# Tot_Clms:"16"
# Tot_30day_Fills:"16"
# Tot_Day_Suply:"448"
# Tot_Drug_Cst:"6229.05"
# Tot_Benes:"".1
# GE65_Sprsn_Flag:"*"
# GE65_Tot_Clms:"".4
# GE65_Tot_30day_Fills:"".4
# GE65_Tot_Drug_Cst:"".4
# GE65_Tot_Day_Suply:"".4
# GE65_Bene_Sprsn_Flag:"*".4
# GE65_Tot_Benes:""}.5
# {"Prscrbr_NPI":"1003000142".4
# Prscrbr_Last_Org_Name:"Khalil".4
# Prscrbr_First_Name:"Rashid".4
# Prscrbr_City:"Toledo".4
# Prscrbr_State_Abrvtn:"OH".4
# Prscrbr_State_FIPS:"39".4
# Prscrbr_Type:"Anesthesiology".4
# Prscrbr_Type_Src:"Claim-Specialty".6
# Brnd_Name:"Cyclobenzaprine Hcl"
# Gnrc_Name:"Cyclobenzaprine Hcl"
# Tot_Clms:"54"
# Tot_30day_Fills:"56"
# Tot_Day_Suply:"1645"
# Tot_Drug_Cst:"572.47"
# Tot_Benes:"30"
# GE65_Sprsn_Flag:"".1
# GE65_Tot_Clms:"16"
# GE65_Tot_30day_Fills:"16"
# GE65_Tot_Drug_Cst:"217.6"
# GE65_Tot_Day_Suply:"455"
# GE65_Bene_Sprsn_Flag:""
# GE65_Tot_Benes:"11"}
# {"Prscrbr_NPI":"1003000142".5
# Prscrbr_Last_Org_Name:"Khalil".5
# Prscrbr_First_Name:"Rashid".5
# Prscrbr_City:"Toledo".5
# Prscrbr_State_Abrvtn:"OH".5
# Prscrbr_State_FIPS:"39".5
# Prscrbr_Type:"Anesthesiology".5
# Prscrbr_Type_Src:"Claim-Specialty".7
# Brnd_Name:"Dantrolene Sodium"
# Gnrc_Name:"Dantrolene Sodium"
# Tot_Clms:"14".1
# Tot_30day_Fills:"14".1
# Tot_Day_Suply:"221"
# Tot_Drug_Cst:"236.09"
# Tot_Benes:"13"
# GE65_Sprsn_Flag:"*".1
# GE65_Tot_Clms:"".5
# GE65_Tot_30day_Fills:"".5
# GE65_Tot_Drug_Cst:"".5
# GE65_Tot_Day_Suply:"".5
# GE65_Bene_Sprsn_Flag:"*".5
# GE65_Tot_Benes:""}.6
# {"Prscrbr_NPI":"1003000142".6
# Prscrbr_Last_Org_Name:"Khalil".6
# Prscrbr_First_Name:"Rashid".6
# Prscrbr_City:"Toledo".6
# Prscrbr_State_Abrvtn:"OH".6
# Prscrbr_State_FIPS:"39".6
# Prscrbr_Type:"Anesthesiology".6
# Prscrbr_Type_Src:"Claim-Specialty".8
# Brnd_Name:"Diclofenac Sodium"
# Gnrc_Name:"Diclofenac Sodium"
# Tot_Clms:"82"
# Tot_30day_Fills:"82"
# Tot_Day_Suply:"1629"
# Tot_Drug_Cst:"2423.34"
# Tot_Benes:"42"
# GE65_Sprsn_Flag:"".2
# GE65_Tot_Clms:"42"
# GE65_Tot_30day_Fills:"42"
# GE65_Tot_Drug_Cst:"1374.84"
# GE65_Tot_Day_Suply:"753"
# GE65_Bene_Sprsn_Flag:"".1
# GE65_Tot_Benes:"24"}
# {"Prscrbr_NPI":"1003000142".7
# Prscrbr_Last_Org_Name:"Khalil".7
# Prscrbr_First_Name:"Rashid".7
# Prscrbr_City:"Toledo".7
# Prscrbr_State_Abrvtn:"OH".7
# Prscrbr_State_FIPS:"39".7
# Prscrbr_Type:"Anesthesiology".7
# Prscrbr_Type_Src:"Claim-Specialty".9
# Brnd_Name:"Duloxetine Hcl"
# Gnrc_Name:"Duloxetine Hcl"
# Tot_Clms:"27"
# Tot_30day_Fills:"31"
# Tot_Day_Suply:"930"
# Tot_Drug_Cst:"337.43"
# Tot_Benes:"14".1
# GE65_Sprsn_Flag:"".3
# GE65_Tot_Clms:"11"
# GE65_Tot_30day_Fills:"13"
# GE65_Tot_Drug_Cst:"159.01"
# GE65_Tot_Day_Suply:"390"
# GE65_Bene_Sprsn_Flag:"*".6
# GE65_Tot_Benes:""}.7
# {"Prscrbr_NPI":"1003000142".8
# Prscrbr_Last_Org_Name:"Khalil".8
# Prscrbr_First_Name:"Rashid".8
# Prscrbr_City:"Toledo".8
# Prscrbr_State_Abrvtn:"OH".8
# Prscrbr_State_FIPS:"39".8
# Prscrbr_Type:"Anesthesiology".8
# Prscrbr_Type_Src:"Claim-Specialty".10
# Brnd_Name:"Gabapentin"
# Gnrc_Name:"Gabapentin"
# Tot_Clms:"281"
# Tot_30day_Fills:"345"
# Tot_Day_Suply:"10315"
# Tot_Drug_Cst:"5713.75"
# Tot_Benes:"125"
# GE65_Sprsn_Flag:"".4
# GE65_Tot_Clms:"167"
# GE65_Tot_30day_Fills:"209"
# GE65_Tot_Drug_Cst:"3585.65"
# GE65_Tot_Day_Suply:"6255"
# GE65_Bene_Sprsn_Flag:"".2
# GE65_Tot_Benes:"73"}
# {"Prscrbr_NPI":"1003000142".9
# Prscrbr_Last_Org_Name:"Khalil".9
# Prscrbr_First_Name:"Rashid".9
# Prscrbr_City:"Toledo".9
# Prscrbr_State_Abrvtn:"OH".9
# Prscrbr_State_FIPS:"39".9
# Prscrbr_Type:"Anesthesiology".9
# Prscrbr_Type_Src:"Claim-Specialty".11
# Brnd_Name:"Hydrocodone-Acetaminophen"
# Gnrc_Name:"Hydrocodone\/Acetaminophen"
# Tot_Clms:"355"
# Tot_30day_Fills:"355.5"
# Tot_Day_Suply:"9511"
# Tot_Drug_Cst:"7202.47"
# Tot_Benes:"171"
# GE65_Sprsn_Flag:"".5
# GE65_Tot_Clms:"214"
# GE65_Tot_30day_Fills:"214"
# GE65_Tot_Drug_Cst:"4543.33"
# GE65_Tot_Day_Suply:"5669"
# GE65_Bene_Sprsn_Flag:"".3
# GE65_Tot_Benes:"110"}
# {"Prscrbr_NPI":"1003000142".10
# Prscrbr_Last_Org_Name:"Khalil".10
# Prscrbr_First_Name:"Rashid".10
# Prscrbr_City:"Toledo".10
# Prscrbr_State_Abrvtn:"OH".10
# Prscrbr_State_FIPS:"39".10
# Prscrbr_Type:"Anesthesiology".10
# Prscrbr_Type_Src:"Claim-Specialty".12
# Brnd_Name:"Lidocaine"
# Gnrc_Name:"Lidocaine"
# Tot_Clms:"20"
# Tot_30day_Fills:"20"
# Tot_Day_Suply:"525"
# Tot_Drug_Cst:"2146.83"
# Tot_Benes:"12".1
# GE65_Sprsn_Flag:"#".4
# GE65_Tot_Clms:"".6
# GE65_Tot_30day_Fills:"".6
# GE65_Tot_Drug_Cst:"".6
# GE65_Tot_Day_Suply:"".6
# GE65_Bene_Sprsn_Flag:"*".7
# GE65_Tot_Benes:""}.8
# {"Prscrbr_NPI":"1003000142".11
# Prscrbr_Last_Org_Name:"Khalil".11
# Prscrbr_First_Name:"Rashid".11
# Prscrbr_City:"Toledo".11
# Prscrbr_State_Abrvtn:"OH".11
# Prscrbr_State_FIPS:"39".11
# Prscrbr_Type:"Anesthesiology".11
# Prscrbr_Type_Src:"Claim-Specialty".13
# Brnd_Name:"Meloxicam"
# Gnrc_Name:"Meloxicam"
# Tot_Clms:"57"
# Tot_30day_Fills:"65"
# Tot_Day_Suply:"1948"
# Tot_Drug_Cst:"230.35"
# Tot_Benes:"25"
# GE65_Sprsn_Flag:"".6
# GE65_Tot_Clms:"19"
# GE65_Tot_30day_Fills:"21"
# GE65_Tot_Drug_Cst:"68.52"
# GE65_Tot_Day_Suply:"630"
# GE65_Bene_Sprsn_Flag:"*".8
# GE65_Tot_Benes:""}.9
# {"Prscrbr_NPI":"1003000142".12
# Prscrbr_Last_Org_Name:"Khalil".12
# Prscrbr_First_Name:"Rashid".12
# Prscrbr_City:"Toledo".12
# Prscrbr_State_Abrvtn:"OH".12
# Prscrbr_State_FIPS:"39".12
# Prscrbr_Type:"Anesthesiology".12
# Prscrbr_Type_Src:"Claim-Specialty".14
# Brnd_Name:"Methocarbamol"
# Gnrc_Name:"Methocarbamol"
# Tot_Clms:"14".2
# Tot_30day_Fills:"14".2
# Tot_Day_Suply:"375"
# Tot_Drug_Cst:"231.58"
# Tot_Benes:"".2
# GE65_Sprsn_Flag:"*".2
# GE65_Tot_Clms:"".7
# GE65_Tot_30day_Fills:"".7
# GE65_Tot_Drug_Cst:"".7
# GE65_Tot_Day_Suply:"".7
# GE65_Bene_Sprsn_Flag:"*".9
# GE65_Tot_Benes:""}.10
# {"Prscrbr_NPI":"1003000142".13
# Prscrbr_Last_Org_Name:"Khalil".13
# Prscrbr_First_Name:"Rashid".13
# Prscrbr_City:"Toledo".13
# Prscrbr_State_Abrvtn:"OH".13
# Prscrbr_State_FIPS:"39".13
# Prscrbr_Type:"Anesthesiology".13
# Prscrbr_Type_Src:"Claim-Specialty".15
# Brnd_Name:"Morphine Sulfate Er"
# Gnrc_Name:"Morphine Sulfate"
# Tot_Clms:"35".1
# Tot_30day_Fills:"35".1
# Tot_Day_Suply:"1050".1
# Tot_Drug_Cst:"633.8"
# Tot_Benes:"13".1
# GE65_Sprsn_Flag:"#".5
# GE65_Tot_Clms:"".8
# GE65_Tot_30day_Fills:"".8
# GE65_Tot_Drug_Cst:"".8
# GE65_Tot_Day_Suply:"".8
# GE65_Bene_Sprsn_Flag:"*".10
# GE65_Tot_Benes:""}.11
# {"Prscrbr_NPI":"1003000142".14
# Prscrbr_Last_Org_Name:"Khalil".14
# Prscrbr_First_Name:"Rashid".14
# Prscrbr_City:"Toledo".14
# Prscrbr_State_Abrvtn:"OH".14
# Prscrbr_State_FIPS:"39".14
# Prscrbr_Type:"Anesthesiology".14
# Prscrbr_Type_Src:"Claim-Specialty".16
# Brnd_Name:"Movantik"
# Gnrc_Name:"Naloxegol Oxalate"
# Tot_Clms:"21"
# Tot_30day_Fills:"29"
# Tot_Day_Suply:"844"
# Tot_Drug_Cst:"11694.14"
# Tot_Benes:"13".2
# GE65_Sprsn_Flag:"#".6
# GE65_Tot_Clms:"".9
# GE65_Tot_30day_Fills:"".9
# GE65_Tot_Drug_Cst:"".9
# GE65_Tot_Day_Suply:"".9
# GE65_Bene_Sprsn_Flag:"*".11
# GE65_Tot_Benes:""}.12
# {"Prscrbr_NPI":"1003000142".15
# Prscrbr_Last_Org_Name:"Khalil".15
# Prscrbr_First_Name:"Rashid".15
# Prscrbr_City:"Toledo".15
# Prscrbr_State_Abrvtn:"OH".15
# Prscrbr_State_FIPS:"39".15
# Prscrbr_Type:"Anesthesiology".15
# Prscrbr_Type_Src:"Claim-Specialty".17
# Brnd_Name:"Oxycodone Hcl"
# Gnrc_Name:"Oxycodone Hcl"
# Tot_Clms:"84"
# Tot_30day_Fills:"84"
# Tot_Day_Suply:"2439"
# Tot_Drug_Cst:"1269.35"
# Tot_Benes:"39"
# GE65_Sprsn_Flag:"".7
# GE65_Tot_Clms:"62"
# GE65_Tot_30day_Fills:"62"
# GE65_Tot_Drug_Cst:"983.14"
# GE65_Tot_Day_Suply:"1795"
# GE65_Bene_Sprsn_Flag:"".4
# GE65_Tot_Benes:"27"}
# {"Prscrbr_NPI":"1003000142".16
# Prscrbr_Last_Org_Name:"Khalil".16
# Prscrbr_First_Name:"Rashid".16
# Prscrbr_City:"Toledo".16
# Prscrbr_State_Abrvtn:"OH".16
# Prscrbr_State_FIPS:"39".16
# Prscrbr_Type:"Anesthesiology".16
# Prscrbr_Type_Src:"Claim-Specialty".18
# Brnd_Name:"Oxycodone-Acetaminophen"
# Gnrc_Name:"Oxycodone Hcl\/Acetaminophen"
# Tot_Clms:"194"
# Tot_30day_Fills:"194"
# Tot_Day_Suply:"5644"
# Tot_Drug_Cst:"5029.88"
# Tot_Benes:"94"
# GE65_Sprsn_Flag:"".8
# GE65_Tot_Clms:"94"
# GE65_Tot_30day_Fills:"94"
# GE65_Tot_Drug_Cst:"2155.06"
# GE65_Tot_Day_Suply:"2727"
# GE65_Bene_Sprsn_Flag:"".5
# GE65_Tot_Benes:"48"}
# {"Prscrbr_NPI":"1003000142".17
# Prscrbr_Last_Org_Name:"Khalil".17
# Prscrbr_First_Name:"Rashid".17
# Prscrbr_City:"Toledo".17
# Prscrbr_State_Abrvtn:"OH".17
# Prscrbr_State_FIPS:"39".17
# Prscrbr_Type:"Anesthesiology".17
# Prscrbr_Type_Src:"Claim-Specialty".19
# Brnd_Name:"Pregabalin"
# Gnrc_Name:"Pregabalin"
# Tot_Clms:"143"
# Tot_30day_Fills:"153"
# Tot_Day_Suply:"4425"
# Tot_Drug_Cst:"6575.8"
# Tot_Benes:"58"
# GE65_Sprsn_Flag:"".9
# GE65_Tot_Clms:"61"
# GE65_Tot_30day_Fills:"65"
# GE65_Tot_Drug_Cst:"2168.07"
# GE65_Tot_Day_Suply:"1819"
# GE65_Bene_Sprsn_Flag:"".6
# GE65_Tot_Benes:"27"}.1
# {"Prscrbr_NPI":"1003000142".18
# Prscrbr_Last_Org_Name:"Khalil".18
# Prscrbr_First_Name:"Rashid".18
# Prscrbr_City:"Toledo".18
# Prscrbr_State_Abrvtn:"OH".18
# Prscrbr_State_FIPS:"39".18
# Prscrbr_Type:"Anesthesiology".18
# Prscrbr_Type_Src:"Claim-Specialty".20
# Brnd_Name:"Tizanidine Hcl"
# Gnrc_Name:"Tizanidine Hcl"
# Tot_Clms:"126"
# Tot_30day_Fills:"140"
# Tot_Day_Suply:"4064"
# Tot_Drug_Cst:"1426.75"
# Tot_Benes:"66"
# GE65_Sprsn_Flag:"".10
# GE65_Tot_Clms:"51"
# GE65_Tot_30day_Fills:"51"
# GE65_Tot_Drug_Cst:"515.26"
# GE65_Tot_Day_Suply:"1449"
# GE65_Bene_Sprsn_Flag:"".7
# GE65_Tot_Benes:"29"}
# {"Prscrbr_NPI":"1003000142".19
# Prscrbr_Last_Org_Name:"Khalil".19
# Prscrbr_First_Name:"Rashid".19
# Prscrbr_City:"Toledo".19
# Prscrbr_State_Abrvtn:"OH".19
# Prscrbr_State_FIPS:"39".19
# Prscrbr_Type:"Anesthesiology".19
# Prscrbr_Type_Src:"Claim-Specialty".21
# Brnd_Name:"Topiramate"
# Gnrc_Name:"Topiramate"
# Tot_Clms:"16".1
# Tot_30day_Fills:"22"
# Tot_Day_Suply:"660"
# Tot_Drug_Cst:"199.68"
# Tot_Benes:"".3
# GE65_Sprsn_Flag:"*".3
# GE65_Tot_Clms:"".10
# GE65_Tot_30day_Fills:"".10
# GE65_Tot_Drug_Cst:"".10
# GE65_Tot_Day_Suply:"".10
# GE65_Bene_Sprsn_Flag:"*".12
# GE65_Tot_Benes:""}.13
# {"Prscrbr_NPI":"1003000142".20
# Prscrbr_Last_Org_Name:"Khalil".20
# Prscrbr_First_Name:"Rashid".20
# Prscrbr_City:"Toledo".20
# Prscrbr_State_Abrvtn:"OH".20
# Prscrbr_State_FIPS:"39".20
# Prscrbr_Type:"Anesthesiology".20
# Prscrbr_Type_Src:"Claim-Specialty".22
# Brnd_Name:"Tramadol Hcl"
# Gnrc_Name:"Tramadol Hcl"
# Tot_Clms:"97"
# Tot_30day_Fills:"97"
# Tot_Day_Suply:"2550"
# Tot_Drug_Cst:"529"
# Tot_Benes:"41"
# GE65_Sprsn_Flag:"".11
# GE65_Tot_Clms:"68"
# GE65_Tot_30day_Fills:"68"
# GE65_Tot_Drug_Cst:"344.88"
# GE65_Tot_Day_Suply:"1756"
# GE65_Bene_Sprsn_Flag:"".8
# GE65_Tot_Benes:"29"}.1
# {"Prscrbr_NPI":"1003000167"
# Prscrbr_Last_Org_Name:"Escobar"
# Prscrbr_First_Name:"Julio"
# Prscrbr_City:"Dayton"
# Prscrbr_State_Abrvtn:"NV"
# Prscrbr_State_FIPS:"32"
# Prscrbr_Type:"Dentist"
# Prscrbr_Type_Src:"NPPES-Specialty"
# Brnd_Name:"Amoxicillin"
# Gnrc_Name:"Amoxicillin"
# Tot_Clms:"51"
# Tot_30day_Fills:"51"
# Tot_Day_Suply:"308"
# Tot_Drug_Cst:"152.04"
# Tot_Benes:"43"
# GE65_Sprsn_Flag:"#".7
# GE65_Tot_Clms:"".11
# GE65_Tot_30day_Fills:"".11
# GE65_Tot_Drug_Cst:"".11
# GE65_Tot_Day_Suply:"".11
# GE65_Bene_Sprsn_Flag:"#".1
# GE65_Tot_Benes:""}.14
# {"Prscrbr_NPI":"1003000167".1
# Prscrbr_Last_Org_Name:"Escobar".1
# Prscrbr_First_Name:"Julio".1
# Prscrbr_City:"Dayton".1
# Prscrbr_State_Abrvtn:"NV".1
# Prscrbr_State_FIPS:"32".1
# Prscrbr_Type:"Dentist".1
# Prscrbr_Type_Src:"NPPES-Specialty".1
# Brnd_Name:"Dexamethasone"
# Gnrc_Name:"Dexamethasone"
# Tot_Clms:"20".1
# Tot_30day_Fills:"20".1
# Tot_Day_Suply:"20"
# Tot_Drug_Cst:"38.04"
# Tot_Benes:"17"
# GE65_Sprsn_Flag:"#".8
# GE65_Tot_Clms:"".12
# GE65_Tot_30day_Fills:"".12
# GE65_Tot_Drug_Cst:"".12
# GE65_Tot_Day_Suply:"".12
# GE65_Bene_Sprsn_Flag:"#".2
# GE65_Tot_Benes:""}.15
# {"Prscrbr_NPI":"1003000423"
# Prscrbr_Last_Org_Name:"Velotta"
# Prscrbr_First_Name:"Jennifer"
# Prscrbr_City:"Cleveland"
# Prscrbr_State_Abrvtn:"OH".21
# Prscrbr_State_FIPS:"39".21
# Prscrbr_Type:"Obstetrics \u0026 Gynecology"
# Prscrbr_Type_Src:"Claim-Specialty".23
# Brnd_Name:"Clotrimazole-Betamethasone"
# Gnrc_Name:"Clotrimazole\/Betamethasone Dip"
# Tot_Clms:"19"
# Tot_30day_Fills:"19"
# Tot_Day_Suply:"249"
# Tot_Drug_Cst:"250.55"
# Tot_Benes:"".4
# GE65_Sprsn_Flag:"#".9
# GE65_Tot_Clms:"".13
# GE65_Tot_30day_Fills:"".13
# GE65_Tot_Drug_Cst:"".13
# GE65_Tot_Day_Suply:"".13
# GE65_Bene_Sprsn_Flag:"*".13
# GE65_Tot_Benes:""}.16
# {"Prscrbr_NPI":"1003000423".1
# Prscrbr_Last_Org_Name:"Velotta".1
# Prscrbr_First_Name:"Jennifer".1
# Prscrbr_City:"Cleveland".1
# Prscrbr_State_Abrvtn:"OH".22
# Prscrbr_State_FIPS:"39".22
# Prscrbr_Type:"Obstetrics \u0026 Gynecology".1
# Prscrbr_Type_Src:"Claim-Specialty".24
# Brnd_Name:"Estradiol"
# Gnrc_Name:"Estradiol"
# Tot_Clms:"39"
# Tot_30day_Fills:"112.4"
# Tot_Day_Suply:"3359"
# Tot_Drug_Cst:"5419.72"
# Tot_Benes:"19"
# GE65_Sprsn_Flag:"#".10
# GE65_Tot_Clms:"".14
# GE65_Tot_30day_Fills:"".14
# GE65_Tot_Drug_Cst:"".14
# GE65_Tot_Day_Suply:"".14
# GE65_Bene_Sprsn_Flag:"#".3
# GE65_Tot_Benes:""}.17
# {"Prscrbr_NPI":"1003000480"
# Prscrbr_Last_Org_Name:"Rothchild"
# Prscrbr_First_Name:"Kevin"
# Prscrbr_City:"Aurora"
# Prscrbr_State_Abrvtn:"CO"
# Prscrbr_State_FIPS:"08"
# Prscrbr_Type:"General Surgery"
# Prscrbr_Type_Src:"Claim-Specialty".25
# Brnd_Name:"Omeprazole"
# Gnrc_Name:"Omeprazole"
# Tot_Clms:"16".2
# Tot_30day_Fills:"18.1"
# Tot_Day_Suply:"543"
# Tot_Drug_Cst:"384.12"
# Tot_Benes:"".5
# GE65_Sprsn_Flag:"*".4
# GE65_Tot_Clms:"".15
# GE65_Tot_30day_Fills:"".15
# GE65_Tot_Drug_Cst:"".15
# GE65_Tot_Day_Suply:"".15
# GE65_Bene_Sprsn_Flag:"*".14
# GE65_Tot_Benes:""}.18
# {"Prscrbr_NPI":"1003000480".1
# Prscrbr_Last_Org_Name:"Rothchild".1
# Prscrbr_First_Name:"Kevin".1
# Prscrbr_City:"Aurora".1
# Prscrbr_State_Abrvtn:"CO".1
# Prscrbr_State_FIPS:"08".1
# Prscrbr_Type:"General Surgery".1
# Prscrbr_Type_Src:"Claim-Specialty".26
# Brnd_Name:"Oxycodone Hcl".1
# Gnrc_Name:"Oxycodone Hcl".1
# Tot_Clms:"12"
# Tot_30day_Fills:"12"
# Tot_Day_Suply:"40"
# Tot_Drug_Cst:"25.58"
# Tot_Benes:"12".2
# GE65_Sprsn_Flag:"*".5
# GE65_Tot_Clms:"".16
# GE65_Tot_30day_Fills:"".16
# GE65_Tot_Drug_Cst:"".16
# GE65_Tot_Day_Suply:"".16
# GE65_Bene_Sprsn_Flag:"*".15
# GE65_Tot_Benes:""}.19
# {"Prscrbr_NPI":"1003000530"
# Prscrbr_Last_Org_Name:"Semonche"
# Prscrbr_First_Name:"Amanda"
# Prscrbr_City:"Quakertown"
# Prscrbr_State_Abrvtn:"PA"
# Prscrbr_State_FIPS:"42"
# Prscrbr_Type:"Internal Medicine"
# Prscrbr_Type_Src:"Claim-Specialty".27
# Brnd_Name:"Advair Diskus"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol"
# Tot_Clms:"18"
# Tot_30day_Fills:"25"
# Tot_Day_Suply:"750"
# Tot_Drug_Cst:"8222.59"
# Tot_Benes:"".6
# GE65_Sprsn_Flag:"".12
# GE65_Tot_Clms:"18"
# GE65_Tot_30day_Fills:"25"
# GE65_Tot_Drug_Cst:"8222.59"
# GE65_Tot_Day_Suply:"750"
# GE65_Bene_Sprsn_Flag:"*".16
# GE65_Tot_Benes:""}.20
# {"Prscrbr_NPI":"1003000530".1
# Prscrbr_Last_Org_Name:"Semonche".1
# Prscrbr_First_Name:"Amanda".1
# Prscrbr_City:"Quakertown".1
# Prscrbr_State_Abrvtn:"PA".1
# Prscrbr_State_FIPS:"42".1
# Prscrbr_Type:"Internal Medicine".1
# Prscrbr_Type_Src:"Claim-Specialty".28
# Brnd_Name:"Albuterol Sulfate Hfa"
# Gnrc_Name:"Albuterol Sulfate"
# Tot_Clms:"54".1
# Tot_30day_Fills:"59.9"
# Tot_Day_Suply:"1385"
# Tot_Drug_Cst:"1900.5"
# Tot_Benes:"24"
# GE65_Sprsn_Flag:"#".11
# GE65_Tot_Clms:"".17
# GE65_Tot_30day_Fills:"".17
# GE65_Tot_Drug_Cst:"".17
# GE65_Tot_Day_Suply:"".17
# GE65_Bene_Sprsn_Flag:"#".4
# GE65_Tot_Benes:""}.21
# {"Prscrbr_NPI":"1003000530".2
# Prscrbr_Last_Org_Name:"Semonche".2
# Prscrbr_First_Name:"Amanda".2
# Prscrbr_City:"Quakertown".2
# Prscrbr_State_Abrvtn:"PA".2
# Prscrbr_State_FIPS:"42".2
# Prscrbr_Type:"Internal Medicine".2
# Prscrbr_Type_Src:"Claim-Specialty".29
# Brnd_Name:"Alendronate Sodium"
# Gnrc_Name:"Alendronate Sodium"
# Tot_Clms:"68"
# Tot_30day_Fills:"155.1"
# Tot_Day_Suply:"4611"
# Tot_Drug_Cst:"876.77"
# Tot_Benes:"17".1
# GE65_Sprsn_Flag:"".13
# GE65_Tot_Clms:"68".1
# GE65_Tot_30day_Fills:"155.1"
# GE65_Tot_Drug_Cst:"876.77"
# GE65_Tot_Day_Suply:"4611"
# GE65_Bene_Sprsn_Flag:"".9
# GE65_Tot_Benes:"17"}
# {"Prscrbr_NPI":"1003000530".3
# Prscrbr_Last_Org_Name:"Semonche".3
# Prscrbr_First_Name:"Amanda".3
# Prscrbr_City:"Quakertown".3
# Prscrbr_State_Abrvtn:"PA".3
# Prscrbr_State_FIPS:"42".3
# Prscrbr_Type:"Internal Medicine".3
# Prscrbr_Type_Src:"Claim-Specialty".30
# Brnd_Name:"Alfuzosin Hcl Er"
# Gnrc_Name:"Alfuzosin Hcl"
# Tot_Clms:"13".1
# Tot_30day_Fills:"13"
# Tot_Day_Suply:"390"
# Tot_Drug_Cst:"121.14"
# Tot_Benes:"".7
# GE65_Sprsn_Flag:"".14
# GE65_Tot_Clms:"13"
# GE65_Tot_30day_Fills:"13".1
# GE65_Tot_Drug_Cst:"121.14"
# GE65_Tot_Day_Suply:"390".1
# GE65_Bene_Sprsn_Flag:"*".17
# GE65_Tot_Benes:""}.22
# {"Prscrbr_NPI":"1003000530".4
# Prscrbr_Last_Org_Name:"Semonche".4
# Prscrbr_First_Name:"Amanda".4
# Prscrbr_City:"Quakertown".4
# Prscrbr_State_Abrvtn:"PA".4
# Prscrbr_State_FIPS:"42".4
# Prscrbr_Type:"Internal Medicine".4
# Prscrbr_Type_Src:"Claim-Specialty".31
# Brnd_Name:"Allopurinol"
# Gnrc_Name:"Allopurinol"
# Tot_Clms:"57".1
# Tot_30day_Fills:"155"
# Tot_Day_Suply:"4650"
# Tot_Drug_Cst:"927.53"
# Tot_Benes:"14".2
# GE65_Sprsn_Flag:"".15
# GE65_Tot_Clms:"57"
# GE65_Tot_30day_Fills:"155"
# GE65_Tot_Drug_Cst:"927.53"
# GE65_Tot_Day_Suply:"4650"
# GE65_Bene_Sprsn_Flag:"".10
# GE65_Tot_Benes:"14"}
# {"Prscrbr_NPI":"1003000530".5
# Prscrbr_Last_Org_Name:"Semonche".5
# Prscrbr_First_Name:"Amanda".5
# Prscrbr_City:"Quakertown".5
# Prscrbr_State_Abrvtn:"PA".5
# Prscrbr_State_FIPS:"42".5
# Prscrbr_Type:"Internal Medicine".5
# Prscrbr_Type_Src:"Claim-Specialty".32
# Brnd_Name:"Alprazolam"
# Gnrc_Name:"Alprazolam"
# Tot_Clms:"31"
# Tot_30day_Fills:"54"
# Tot_Day_Suply:"1590"
# Tot_Drug_Cst:"194.85"
# Tot_Benes:"11"
# GE65_Sprsn_Flag:"#".12
# GE65_Tot_Clms:"".18
# GE65_Tot_30day_Fills:"".18
# GE65_Tot_Drug_Cst:"".18
# GE65_Tot_Day_Suply:"".18
# GE65_Bene_Sprsn_Flag:"*".18
# GE65_Tot_Benes:""}.23
# {"Prscrbr_NPI":"1003000530".6
# Prscrbr_Last_Org_Name:"Semonche".6
# Prscrbr_First_Name:"Amanda".6
# Prscrbr_City:"Quakertown".6
# Prscrbr_State_Abrvtn:"PA".6
# Prscrbr_State_FIPS:"42".6
# Prscrbr_Type:"Internal Medicine".6
# Prscrbr_Type_Src:"Claim-Specialty".33
# Brnd_Name:"Amiodarone Hcl"
# Gnrc_Name:"Amiodarone Hcl"
# Tot_Clms:"12".1
# Tot_30day_Fills:"12".1
# Tot_Day_Suply:"360"
# Tot_Drug_Cst:"122.76"
# Tot_Benes:"".8
# GE65_Sprsn_Flag:"".16
# GE65_Tot_Clms:"12"
# GE65_Tot_30day_Fills:"12"
# GE65_Tot_Drug_Cst:"122.76"
# GE65_Tot_Day_Suply:"360"
# GE65_Bene_Sprsn_Flag:"*".19
# GE65_Tot_Benes:""}.24
# {"Prscrbr_NPI":"1003000530".7
# Prscrbr_Last_Org_Name:"Semonche".7
# Prscrbr_First_Name:"Amanda".7
# Prscrbr_City:"Quakertown".7
# Prscrbr_State_Abrvtn:"PA".7
# Prscrbr_State_FIPS:"42".7
# Prscrbr_Type:"Internal Medicine".7
# Prscrbr_Type_Src:"Claim-Specialty".34
# Brnd_Name:"Amlodipine Besylate"
# Gnrc_Name:"Amlodipine Besylate"
# Tot_Clms:"419"
# Tot_30day_Fills:"976.7"
# Tot_Day_Suply:"29238"
# Tot_Drug_Cst:"3238.1"
# Tot_Benes:"101"
# GE65_Sprsn_Flag:"".17
# GE65_Tot_Clms:"403"
# GE65_Tot_30day_Fills:"956.5"
# GE65_Tot_Drug_Cst:"3171.72"
# GE65_Tot_Day_Suply:"28664"
# GE65_Bene_Sprsn_Flag:"#".5
# GE65_Tot_Benes:""}.25
# {"Prscrbr_NPI":"1003000530".8
# Prscrbr_Last_Org_Name:"Semonche".8
# Prscrbr_First_Name:"Amanda".8
# Prscrbr_City:"Quakertown".8
# Prscrbr_State_Abrvtn:"PA".8
# Prscrbr_State_FIPS:"42".8
# Prscrbr_Type:"Internal Medicine".8
# Prscrbr_Type_Src:"Claim-Specialty".35
# Brnd_Name:"Amoxicillin-Clavulanate Potass"
# Gnrc_Name:"Amoxicillin\/Potassium Clav"
# Tot_Clms:"29"
# Tot_30day_Fills:"29".1
# Tot_Day_Suply:"204"
# Tot_Drug_Cst:"299.35"
# Tot_Benes:"28"
# GE65_Sprsn_Flag:"#".13
# GE65_Tot_Clms:"".19
# GE65_Tot_30day_Fills:"".19
# GE65_Tot_Drug_Cst:"".19
# GE65_Tot_Day_Suply:"".19
# GE65_Bene_Sprsn_Flag:"#".6
# GE65_Tot_Benes:""}.26
# {"Prscrbr_NPI":"1003000530".9
# Prscrbr_Last_Org_Name:"Semonche".9
# Prscrbr_First_Name:"Amanda".9
# Prscrbr_City:"Quakertown".9
# Prscrbr_State_Abrvtn:"PA".9
# Prscrbr_State_FIPS:"42".9
# Prscrbr_Type:"Internal Medicine".9
# Prscrbr_Type_Src:"Claim-Specialty".36
# Brnd_Name:"Aripiprazole"
# Gnrc_Name:"Aripiprazole"
# Tot_Clms:"24"
# Tot_30day_Fills:"36"
# Tot_Day_Suply:"1080"
# Tot_Drug_Cst:"1879.6"
# Tot_Benes:"".9
# GE65_Sprsn_Flag:"#".14
# GE65_Tot_Clms:"".20
# GE65_Tot_30day_Fills:"".20
# GE65_Tot_Drug_Cst:"".20
# GE65_Tot_Day_Suply:"".20
# GE65_Bene_Sprsn_Flag:"*".20
# GE65_Tot_Benes:""}.27
# {"Prscrbr_NPI":"1003000530".10
# Prscrbr_Last_Org_Name:"Semonche".10
# Prscrbr_First_Name:"Amanda".10
# Prscrbr_City:"Quakertown".10
# Prscrbr_State_Abrvtn:"PA".10
# Prscrbr_State_FIPS:"42".10
# Prscrbr_Type:"Internal Medicine".10
# Prscrbr_Type_Src:"Claim-Specialty".37
# Brnd_Name:"Atenolol"
# Gnrc_Name:"Atenolol"
# Tot_Clms:"26"
# Tot_30day_Fills:"78"
# Tot_Day_Suply:"2340"
# Tot_Drug_Cst:"142.77"
# Tot_Benes:"".10
# GE65_Sprsn_Flag:"".18
# GE65_Tot_Clms:"26"
# GE65_Tot_30day_Fills:"78"
# GE65_Tot_Drug_Cst:"142.77"
# GE65_Tot_Day_Suply:"2340"
# GE65_Bene_Sprsn_Flag:"*".21
# GE65_Tot_Benes:""}.28
# {"Prscrbr_NPI":"1003000530".11
# Prscrbr_Last_Org_Name:"Semonche".11
# Prscrbr_First_Name:"Amanda".11
# Prscrbr_City:"Quakertown".11
# Prscrbr_State_Abrvtn:"PA".11
# Prscrbr_State_FIPS:"42".11
# Prscrbr_Type:"Internal Medicine".11
# Prscrbr_Type_Src:"Claim-Specialty".38
# Brnd_Name:"Atorvastatin Calcium"
# Gnrc_Name:"Atorvastatin Calcium"
# Tot_Clms:"470"
# Tot_30day_Fills:"1154.7"
# Tot_Day_Suply:"34590"
# Tot_Drug_Cst:"5690.05"
# Tot_Benes:"112"
# GE65_Sprsn_Flag:"".19
# GE65_Tot_Clms:"453"
# GE65_Tot_30day_Fills:"1117.7"
# GE65_Tot_Drug_Cst:"5225.24"
# GE65_Tot_Day_Suply:"33480"
# GE65_Bene_Sprsn_Flag:"#".7
# GE65_Tot_Benes:""}.29
# {"Prscrbr_NPI":"1003000530".12
# Prscrbr_Last_Org_Name:"Semonche".12
# Prscrbr_First_Name:"Amanda".12
# Prscrbr_City:"Quakertown".12
# Prscrbr_State_Abrvtn:"PA".12
# Prscrbr_State_FIPS:"42".12
# Prscrbr_Type:"Internal Medicine".12
# Prscrbr_Type_Src:"Claim-Specialty".39
# Brnd_Name:"Benazepril Hcl"
# Gnrc_Name:"Benazepril Hcl"
# Tot_Clms:"13".2
# Tot_30day_Fills:"37"
# Tot_Day_Suply:"1110"
# Tot_Drug_Cst:"282.77"
# Tot_Benes:"".11
# GE65_Sprsn_Flag:"".20
# GE65_Tot_Clms:"13".1
# GE65_Tot_30day_Fills:"37"
# GE65_Tot_Drug_Cst:"282.77"
# GE65_Tot_Day_Suply:"1110"
# GE65_Bene_Sprsn_Flag:"*".22
# GE65_Tot_Benes:""}.30
# {"Prscrbr_NPI":"1003000530".13
# Prscrbr_Last_Org_Name:"Semonche".13
# Prscrbr_First_Name:"Amanda".13
# Prscrbr_City:"Quakertown".13
# Prscrbr_State_Abrvtn:"PA".13
# Prscrbr_State_FIPS:"42".13
# Prscrbr_Type:"Internal Medicine".13
# Prscrbr_Type_Src:"Claim-Specialty".40
# Brnd_Name:"Bupropion Hcl Sr"
# Gnrc_Name:"Bupropion Hcl"
# Tot_Clms:"25"
# Tot_30day_Fills:"33.5"
# Tot_Day_Suply:"1005"
# Tot_Drug_Cst:"258.44"
# Tot_Benes:"".12
# GE65_Sprsn_Flag:"".21
# GE65_Tot_Clms:"25"
# GE65_Tot_30day_Fills:"33.5"
# GE65_Tot_Drug_Cst:"258.44"
# GE65_Tot_Day_Suply:"1005"
# GE65_Bene_Sprsn_Flag:"*".23
# GE65_Tot_Benes:""}.31
# {"Prscrbr_NPI":"1003000530".14
# Prscrbr_Last_Org_Name:"Semonche".14
# Prscrbr_First_Name:"Amanda".14
# Prscrbr_City:"Quakertown".14
# Prscrbr_State_Abrvtn:"PA".14
# Prscrbr_State_FIPS:"42".14
# Prscrbr_Type:"Internal Medicine".14
# Prscrbr_Type_Src:"Claim-Specialty".41
# Brnd_Name:"Bupropion Xl"
# Gnrc_Name:"Bupropion Hcl".1
# Tot_Clms:"85"
# Tot_30day_Fills:"191"
# Tot_Day_Suply:"5714"
# Tot_Drug_Cst:"2770.34"
# Tot_Benes:"18"
# GE65_Sprsn_Flag:"".22
# GE65_Tot_Clms:"71"
# GE65_Tot_30day_Fills:"159"
# GE65_Tot_Drug_Cst:"2514.77"
# GE65_Tot_Day_Suply:"4770"
# GE65_Bene_Sprsn_Flag:"#".8
# GE65_Tot_Benes:""}.32
# {"Prscrbr_NPI":"1003000530".15
# Prscrbr_Last_Org_Name:"Semonche".15
# Prscrbr_First_Name:"Amanda".15
# Prscrbr_City:"Quakertown".15
# Prscrbr_State_Abrvtn:"PA".15
# Prscrbr_State_FIPS:"42".15
# Prscrbr_Type:"Internal Medicine".15
# Prscrbr_Type_Src:"Claim-Specialty".42
# Brnd_Name:"Buspirone Hcl"
# Gnrc_Name:"Buspirone Hcl"
# Tot_Clms:"13".3
# Tot_30day_Fills:"31".1
# Tot_Day_Suply:"930".1
# Tot_Drug_Cst:"82.61"
# Tot_Benes:"".13
# GE65_Sprsn_Flag:"".23
# GE65_Tot_Clms:"13".2
# GE65_Tot_30day_Fills:"31"
# GE65_Tot_Drug_Cst:"82.61"
# GE65_Tot_Day_Suply:"930"
# GE65_Bene_Sprsn_Flag:"*".24
# GE65_Tot_Benes:""}.33
# {"Prscrbr_NPI":"1003000530".16
# Prscrbr_Last_Org_Name:"Semonche".16
# Prscrbr_First_Name:"Amanda".16
# Prscrbr_City:"Quakertown".16
# Prscrbr_State_Abrvtn:"PA".16
# Prscrbr_State_FIPS:"42".16
# Prscrbr_Type:"Internal Medicine".16
# Prscrbr_Type_Src:"Claim-Specialty".43
# Brnd_Name:"Butalbital-Acetaminophen-Caffe"
# Gnrc_Name:"Butalb\/Acetaminophen\/Caffeine"
# Tot_Clms:"14".3
# Tot_30day_Fills:"15"
# Tot_Day_Suply:"450"
# Tot_Drug_Cst:"463.9"
# Tot_Benes:"".14
# GE65_Sprsn_Flag:"".24
# GE65_Tot_Clms:"14"
# GE65_Tot_30day_Fills:"15"
# GE65_Tot_Drug_Cst:"463.9"
# GE65_Tot_Day_Suply:"450"
# GE65_Bene_Sprsn_Flag:"*".25
# GE65_Tot_Benes:""}.34
# {"Prscrbr_NPI":"1003000530".17
# Prscrbr_Last_Org_Name:"Semonche".17
# Prscrbr_First_Name:"Amanda".17
# Prscrbr_City:"Quakertown".17
# Prscrbr_State_Abrvtn:"PA".17
# Prscrbr_State_FIPS:"42".17
# Prscrbr_Type:"Internal Medicine".17
# Prscrbr_Type_Src:"Claim-Specialty".44
# Brnd_Name:"Calcitriol"
# Gnrc_Name:"Calcitriol"
# Tot_Clms:"12".2
# Tot_30day_Fills:"12.2"
# Tot_Day_Suply:"365"
# Tot_Drug_Cst:"328.47"
# Tot_Benes:"".15
# GE65_Sprsn_Flag:"".25
# GE65_Tot_Clms:"0"
# GE65_Tot_30day_Fills:"0"
# GE65_Tot_Drug_Cst:"0"
# GE65_Tot_Day_Suply:"0"
# GE65_Bene_Sprsn_Flag:"#".9
# GE65_Tot_Benes:""}.35
# {"Prscrbr_NPI":"1003000530".18
# Prscrbr_Last_Org_Name:"Semonche".18
# Prscrbr_First_Name:"Amanda".18
# Prscrbr_City:"Quakertown".18
# Prscrbr_State_Abrvtn:"PA".18
# Prscrbr_State_FIPS:"42".18
# Prscrbr_Type:"Internal Medicine".18
# Prscrbr_Type_Src:"Claim-Specialty".45
# Brnd_Name:"Carvedilol"
# Gnrc_Name:"Carvedilol"
# Tot_Clms:"23"
# Tot_30day_Fills:"60"
# Tot_Day_Suply:"1800"
# Tot_Drug_Cst:"391.49"
# Tot_Benes:"".16
# GE65_Sprsn_Flag:"#".15
# GE65_Tot_Clms:"".21
# GE65_Tot_30day_Fills:"".21
# GE65_Tot_Drug_Cst:"".21
# GE65_Tot_Day_Suply:"".21
# GE65_Bene_Sprsn_Flag:"*".26
# GE65_Tot_Benes:""}.36
# {"Prscrbr_NPI":"1003000530".19
# Prscrbr_Last_Org_Name:"Semonche".19
# Prscrbr_First_Name:"Amanda".19
# Prscrbr_City:"Quakertown".19
# Prscrbr_State_Abrvtn:"PA".19
# Prscrbr_State_FIPS:"42".19
# Prscrbr_Type:"Internal Medicine".19
# Prscrbr_Type_Src:"Claim-Specialty".46
# Brnd_Name:"Cephalexin"
# Gnrc_Name:"Cephalexin"
# Tot_Clms:"12".3
# Tot_30day_Fills:"12".2
# Tot_Day_Suply:"110"
# Tot_Drug_Cst:"43.42"
# Tot_Benes:"12".3
# GE65_Sprsn_Flag:"#".16
# GE65_Tot_Clms:"".22
# GE65_Tot_30day_Fills:"".22
# GE65_Tot_Drug_Cst:"".22
# GE65_Tot_Day_Suply:"".22
# GE65_Bene_Sprsn_Flag:"#".10
# GE65_Tot_Benes:""}.37
# {"Prscrbr_NPI":"1003000530".20
# Prscrbr_Last_Org_Name:"Semonche".20
# Prscrbr_First_Name:"Amanda".20
# Prscrbr_City:"Quakertown".20
# Prscrbr_State_Abrvtn:"PA".20
# Prscrbr_State_FIPS:"42".20
# Prscrbr_Type:"Internal Medicine".20
# Prscrbr_Type_Src:"Claim-Specialty".47
# Brnd_Name:"Chlorhexidine Gluconate"
# Gnrc_Name:"Chlorhexidine Gluconate"
# Tot_Clms:"20".2
# Tot_30day_Fills:"20".2
# Tot_Day_Suply:"345"
# Tot_Drug_Cst:"116.2"
# Tot_Benes:"".17
# GE65_Sprsn_Flag:"".26
# GE65_Tot_Clms:"0".1
# GE65_Tot_30day_Fills:"0".1
# GE65_Tot_Drug_Cst:"0".1
# GE65_Tot_Day_Suply:"0".1
# GE65_Bene_Sprsn_Flag:"#".11
# GE65_Tot_Benes:""}.38
# {"Prscrbr_NPI":"1003000530".21
# Prscrbr_Last_Org_Name:"Semonche".21
# Prscrbr_First_Name:"Amanda".21
# Prscrbr_City:"Quakertown".21
# Prscrbr_State_Abrvtn:"PA".21
# Prscrbr_State_FIPS:"42".21
# Prscrbr_Type:"Internal Medicine".21
# Prscrbr_Type_Src:"Claim-Specialty".48
# Brnd_Name:"Citalopram Hbr"
# Gnrc_Name:"Citalopram Hydrobromide"
# Tot_Clms:"39".1
# Tot_30day_Fills:"81"
# Tot_Day_Suply:"2430"
# Tot_Drug_Cst:"228.34"
# Tot_Benes:"".18
# GE65_Sprsn_Flag:"".27
# GE65_Tot_Clms:"39"
# GE65_Tot_30day_Fills:"81"
# GE65_Tot_Drug_Cst:"228.34"
# GE65_Tot_Day_Suply:"2430"
# GE65_Bene_Sprsn_Flag:"*".27
# GE65_Tot_Benes:""}.39
# {"Prscrbr_NPI":"1003000530".22
# Prscrbr_Last_Org_Name:"Semonche".22
# Prscrbr_First_Name:"Amanda".22
# Prscrbr_City:"Quakertown".22
# Prscrbr_State_Abrvtn:"PA".22
# Prscrbr_State_FIPS:"42".22
# Prscrbr_Type:"Internal Medicine".22
# Prscrbr_Type_Src:"Claim-Specialty".49
# Brnd_Name:"Clonazepam"
# Gnrc_Name:"Clonazepam"
# Tot_Clms:"35".2
# Tot_30day_Fills:"45"
# Tot_Day_Suply:"1341"
# Tot_Drug_Cst:"386.75"
# Tot_Benes:"".19
# GE65_Sprsn_Flag:"".28
# GE65_Tot_Clms:"22"
# GE65_Tot_30day_Fills:"32"
# GE65_Tot_Drug_Cst:"258.27"
# GE65_Tot_Day_Suply:"951"
# GE65_Bene_Sprsn_Flag:"*".28
# GE65_Tot_Benes:""}.40
# {"Prscrbr_NPI":"1003000530".23
# Prscrbr_Last_Org_Name:"Semonche".23
# Prscrbr_First_Name:"Amanda".23
# Prscrbr_City:"Quakertown".23
# Prscrbr_State_Abrvtn:"PA".23
# Prscrbr_State_FIPS:"42".23
# Prscrbr_Type:"Internal Medicine".23
# Prscrbr_Type_Src:"Claim-Specialty".50
# Brnd_Name:"Clonidine Hcl"
# Gnrc_Name:"Clonidine Hcl"
# Tot_Clms:"13".4
# Tot_30day_Fills:"27.6"
# Tot_Day_Suply:"827"
# Tot_Drug_Cst:"48.65"
# Tot_Benes:"".20
# GE65_Sprsn_Flag:"".29
# GE65_Tot_Clms:"13".3
# GE65_Tot_30day_Fills:"27.6"
# GE65_Tot_Drug_Cst:"48.65"
# GE65_Tot_Day_Suply:"827"
# GE65_Bene_Sprsn_Flag:"*".29
# GE65_Tot_Benes:""}.41
# {"Prscrbr_NPI":"1003000530".24
# Prscrbr_Last_Org_Name:"Semonche".24
# Prscrbr_First_Name:"Amanda".24
# Prscrbr_City:"Quakertown".24
# Prscrbr_State_Abrvtn:"PA".24
# Prscrbr_State_FIPS:"42".24
# Prscrbr_Type:"Internal Medicine".24
# Prscrbr_Type_Src:"Claim-Specialty".51
# Brnd_Name:"Clopidogrel"
# Gnrc_Name:"Clopidogrel Bisulfate"
# Tot_Clms:"85".1
# Tot_30day_Fills:"188"
# Tot_Day_Suply:"5630"
# Tot_Drug_Cst:"1640.22"
# Tot_Benes:"19".1
# GE65_Sprsn_Flag:"".30
# GE65_Tot_Clms:"85"
# GE65_Tot_30day_Fills:"188"
# GE65_Tot_Drug_Cst:"1640.22"
# GE65_Tot_Day_Suply:"5630"
# GE65_Bene_Sprsn_Flag:"".11
# GE65_Tot_Benes:"19"}
# {"Prscrbr_NPI":"1003000530".25
# Prscrbr_Last_Org_Name:"Semonche".25
# Prscrbr_First_Name:"Amanda".25
# Prscrbr_City:"Quakertown".25
# Prscrbr_State_Abrvtn:"PA".25
# Prscrbr_State_FIPS:"42".25
# Prscrbr_Type:"Internal Medicine".25
# Prscrbr_Type_Src:"Claim-Specialty".52
# Brnd_Name:"Cyclobenzaprine Hcl".1
# Gnrc_Name:"Cyclobenzaprine Hcl".1
# Tot_Clms:"11"
# Tot_30day_Fills:"11"
# Tot_Day_Suply:"110".1
# Tot_Drug_Cst:"41.17"
# Tot_Benes:"".21
# GE65_Sprsn_Flag:"*".6
# GE65_Tot_Clms:"".23
# GE65_Tot_30day_Fills:"".23
# GE65_Tot_Drug_Cst:"".23
# GE65_Tot_Day_Suply:"".23
# GE65_Bene_Sprsn_Flag:"*".30
# GE65_Tot_Benes:""}.42
# {"Prscrbr_NPI":"1003000530".26
# Prscrbr_Last_Org_Name:"Semonche".26
# Prscrbr_First_Name:"Amanda".26
# Prscrbr_City:"Quakertown".26
# Prscrbr_State_Abrvtn:"PA".26
# Prscrbr_State_FIPS:"42".26
# Prscrbr_Type:"Internal Medicine".26
# Prscrbr_Type_Src:"Claim-Specialty".53
# Brnd_Name:"Dexlansoprazole Dr"
# Gnrc_Name:"Dexlansoprazole"
# Tot_Clms:"13".5
# Tot_30day_Fills:"24"
# Tot_Day_Suply:"720"
# Tot_Drug_Cst:"5600.13"
# Tot_Benes:"".22
# GE65_Sprsn_Flag:"".31
# GE65_Tot_Clms:"13".4
# GE65_Tot_30day_Fills:"24"
# GE65_Tot_Drug_Cst:"5600.13"
# GE65_Tot_Day_Suply:"720"
# GE65_Bene_Sprsn_Flag:"*".31
# GE65_Tot_Benes:""}.43
# {"Prscrbr_NPI":"1003000530".27
# Prscrbr_Last_Org_Name:"Semonche".27
# Prscrbr_First_Name:"Amanda".27
# Prscrbr_City:"Quakertown".27
# Prscrbr_State_Abrvtn:"PA".27
# Prscrbr_State_FIPS:"42".27
# Prscrbr_Type:"Internal Medicine".27
# Prscrbr_Type_Src:"Claim-Specialty".54
# Brnd_Name:"Diazepam"
# Gnrc_Name:"Diazepam"
# Tot_Clms:"16".3
# Tot_30day_Fills:"16".1
# Tot_Day_Suply:"199"
# Tot_Drug_Cst:"41.64"
# Tot_Benes:"".23
# GE65_Sprsn_Flag:"*".7
# GE65_Tot_Clms:"".24
# GE65_Tot_30day_Fills:"".24
# GE65_Tot_Drug_Cst:"".24
# GE65_Tot_Day_Suply:"".24
# GE65_Bene_Sprsn_Flag:"*".32
# GE65_Tot_Benes:""}.44
# {"Prscrbr_NPI":"1003000530".28
# Prscrbr_Last_Org_Name:"Semonche".28
# Prscrbr_First_Name:"Amanda".28
# Prscrbr_City:"Quakertown".28
# Prscrbr_State_Abrvtn:"PA".28
# Prscrbr_State_FIPS:"42".28
# Prscrbr_Type:"Internal Medicine".28
# Prscrbr_Type_Src:"Claim-Specialty".55
# Brnd_Name:"Diclofenac Sodium".1
# Gnrc_Name:"Diclofenac Sodium".1
# Tot_Clms:"14".4
# Tot_30day_Fills:"14".3
# Tot_Day_Suply:"260"
# Tot_Drug_Cst:"307.2"
# Tot_Benes:"".24
# GE65_Sprsn_Flag:"#".17
# GE65_Tot_Clms:"".25
# GE65_Tot_30day_Fills:"".25
# GE65_Tot_Drug_Cst:"".25
# GE65_Tot_Day_Suply:"".25
# GE65_Bene_Sprsn_Flag:"*".33
# GE65_Tot_Benes:""}.45
# {"Prscrbr_NPI":"1003000530".29
# Prscrbr_Last_Org_Name:"Semonche".29
# Prscrbr_First_Name:"Amanda".29
# Prscrbr_City:"Quakertown".29
# Prscrbr_State_Abrvtn:"PA".29
# Prscrbr_State_FIPS:"42".29
# Prscrbr_Type:"Internal Medicine".29
# Prscrbr_Type_Src:"Claim-Specialty".56
# Brnd_Name:"Diltiazem 24hr Er (Cd)"
# Gnrc_Name:"Diltiazem Hcl"
# Tot_Clms:"14".5
# Tot_30day_Fills:"14".4
# Tot_Day_Suply:"420"
# Tot_Drug_Cst:"232.74"
# Tot_Benes:"".25
# GE65_Sprsn_Flag:"".32
# GE65_Tot_Clms:"14".1
# GE65_Tot_30day_Fills:"14"
# GE65_Tot_Drug_Cst:"232.74"
# GE65_Tot_Day_Suply:"420"
# GE65_Bene_Sprsn_Flag:"*".34
# GE65_Tot_Benes:""}.46
# {"Prscrbr_NPI":"1003000530".30
# Prscrbr_Last_Org_Name:"Semonche".30
# Prscrbr_First_Name:"Amanda".30
# Prscrbr_City:"Quakertown".30
# Prscrbr_State_Abrvtn:"PA".30
# Prscrbr_State_FIPS:"42".30
# Prscrbr_Type:"Internal Medicine".30
# Prscrbr_Type_Src:"Claim-Specialty".57
# Brnd_Name:"Dofetilide"
# Gnrc_Name:"Dofetilide"
# Tot_Clms:"14".6
# Tot_30day_Fills:"14".5
# Tot_Day_Suply:"409"
# Tot_Drug_Cst:"312.85"
# Tot_Benes:"".26
# GE65_Sprsn_Flag:"".33
# GE65_Tot_Clms:"14".2
# GE65_Tot_30day_Fills:"14".1
# GE65_Tot_Drug_Cst:"312.85"
# GE65_Tot_Day_Suply:"409"
# GE65_Bene_Sprsn_Flag:"*".35
# GE65_Tot_Benes:""}.47
# {"Prscrbr_NPI":"1003000530".31
# Prscrbr_Last_Org_Name:"Semonche".31
# Prscrbr_First_Name:"Amanda".31
# Prscrbr_City:"Quakertown".31
# Prscrbr_State_Abrvtn:"PA".31
# Prscrbr_State_FIPS:"42".31
# Prscrbr_Type:"Internal Medicine".31
# Prscrbr_Type_Src:"Claim-Specialty".58
# Brnd_Name:"Donepezil Hcl"
# Gnrc_Name:"Donepezil Hcl"
# Tot_Clms:"20".3
# Tot_30day_Fills:"30"
# Tot_Day_Suply:"900"
# Tot_Drug_Cst:"289.85"
# Tot_Benes:"".27
# GE65_Sprsn_Flag:"".34
# GE65_Tot_Clms:"20"
# GE65_Tot_30day_Fills:"30"
# GE65_Tot_Drug_Cst:"289.85"
# GE65_Tot_Day_Suply:"900"
# GE65_Bene_Sprsn_Flag:"*".36
# GE65_Tot_Benes:""}.48
# {"Prscrbr_NPI":"1003000530".32
# Prscrbr_Last_Org_Name:"Semonche".32
# Prscrbr_First_Name:"Amanda".32
# Prscrbr_City:"Quakertown".32
# Prscrbr_State_Abrvtn:"PA".32
# Prscrbr_State_FIPS:"42".32
# Prscrbr_Type:"Internal Medicine".32
# Prscrbr_Type_Src:"Claim-Specialty".59
# Brnd_Name:"Doxazosin Mesylate"
# Gnrc_Name:"Doxazosin Mesylate"
# Tot_Clms:"15"
# Tot_30day_Fills:"35.8"
# Tot_Day_Suply:"1050".2
# Tot_Drug_Cst:"386.22"
# Tot_Benes:"".28
# GE65_Sprsn_Flag:"".35
# GE65_Tot_Clms:"15"
# GE65_Tot_30day_Fills:"35.8"
# GE65_Tot_Drug_Cst:"386.22"
# GE65_Tot_Day_Suply:"1050"
# GE65_Bene_Sprsn_Flag:"*".37
# GE65_Tot_Benes:""}.49
# {"Prscrbr_NPI":"1003000530".33
# Prscrbr_Last_Org_Name:"Semonche".33
# Prscrbr_First_Name:"Amanda".33
# Prscrbr_City:"Quakertown".33
# Prscrbr_State_Abrvtn:"PA".33
# Prscrbr_State_FIPS:"42".33
# Prscrbr_Type:"Internal Medicine".33
# Prscrbr_Type_Src:"Claim-Specialty".60
# Brnd_Name:"Doxycycline Hyclate"
# Gnrc_Name:"Doxycycline Hyclate"
# Tot_Clms:"30"
# Tot_30day_Fills:"30".1
# Tot_Day_Suply:"251"
# Tot_Drug_Cst:"319.64"
# Tot_Benes:"28".1
# GE65_Sprsn_Flag:"".36
# GE65_Tot_Clms:"30"
# GE65_Tot_30day_Fills:"30".1
# GE65_Tot_Drug_Cst:"319.64"
# GE65_Tot_Day_Suply:"251"
# GE65_Bene_Sprsn_Flag:"".12
# GE65_Tot_Benes:"28"}
# {"Prscrbr_NPI":"1003000530".34
# Prscrbr_Last_Org_Name:"Semonche".34
# Prscrbr_First_Name:"Amanda".34
# Prscrbr_City:"Quakertown".34
# Prscrbr_State_Abrvtn:"PA".34
# Prscrbr_State_FIPS:"42".34
# Prscrbr_Type:"Internal Medicine".34
# Prscrbr_Type_Src:"Claim-Specialty".61
# Brnd_Name:"Duloxetine Hcl".1
# Gnrc_Name:"Duloxetine Hcl".1
# Tot_Clms:"69"
# Tot_30day_Fills:"113"
# Tot_Day_Suply:"3382"
# Tot_Drug_Cst:"3664.57"
# Tot_Benes:"11".1
# GE65_Sprsn_Flag:"".37
# GE65_Tot_Clms:"55"
# GE65_Tot_30day_Fills:"89"
# GE65_Tot_Drug_Cst:"3243.56"
# GE65_Tot_Day_Suply:"2662"
# GE65_Bene_Sprsn_Flag:"*".38
# GE65_Tot_Benes:""}.50
# {"Prscrbr_NPI":"1003000530".35
# Prscrbr_Last_Org_Name:"Semonche".35
# Prscrbr_First_Name:"Amanda".35
# Prscrbr_City:"Quakertown".35
# Prscrbr_State_Abrvtn:"PA".35
# Prscrbr_State_FIPS:"42".35
# Prscrbr_Type:"Internal Medicine".35
# Prscrbr_Type_Src:"Claim-Specialty".62
# Brnd_Name:"Eliquis".1
# Gnrc_Name:"Apixaban".1
# Tot_Clms:"113"
# Tot_30day_Fills:"167"
# Tot_Day_Suply:"4999"
# Tot_Drug_Cst:"92087.78"
# Tot_Benes:"20"
# GE65_Sprsn_Flag:"".38
# GE65_Tot_Clms:"113"
# GE65_Tot_30day_Fills:"167"
# GE65_Tot_Drug_Cst:"92087.78"
# GE65_Tot_Day_Suply:"4999"
# GE65_Bene_Sprsn_Flag:"".13
# GE65_Tot_Benes:"20"}
# {"Prscrbr_NPI":"1003000530".36
# Prscrbr_Last_Org_Name:"Semonche".36
# Prscrbr_First_Name:"Amanda".36
# Prscrbr_City:"Quakertown".36
# Prscrbr_State_Abrvtn:"PA".36
# Prscrbr_State_FIPS:"42".36
# Prscrbr_Type:"Internal Medicine".36
# Prscrbr_Type_Src:"Claim-Specialty".63
# Brnd_Name:"Escitalopram Oxalate"
# Gnrc_Name:"Escitalopram Oxalate"
# Tot_Clms:"75"
# Tot_30day_Fills:"168"
# Tot_Day_Suply:"5015"
# Tot_Drug_Cst:"967.02"
# Tot_Benes:"19".2
# GE65_Sprsn_Flag:"#".18
# GE65_Tot_Clms:"".26
# GE65_Tot_30day_Fills:"".26
# GE65_Tot_Drug_Cst:"".26
# GE65_Tot_Day_Suply:"".26
# GE65_Bene_Sprsn_Flag:"#".12
# GE65_Tot_Benes:""}.51
# {"Prscrbr_NPI":"1003000530".37
# Prscrbr_Last_Org_Name:"Semonche".37
# Prscrbr_First_Name:"Amanda".37
# Prscrbr_City:"Quakertown".37
# Prscrbr_State_Abrvtn:"PA".37
# Prscrbr_State_FIPS:"42".37
# Prscrbr_Type:"Internal Medicine".37
# Prscrbr_Type_Src:"Claim-Specialty".64
# Brnd_Name:"Ezetimibe"
# Gnrc_Name:"Ezetimibe"
# Tot_Clms:"13".6
# Tot_30day_Fills:"39"
# Tot_Day_Suply:"1170"
# Tot_Drug_Cst:"272.15"
# Tot_Benes:"".29
# GE65_Sprsn_Flag:"".39
# GE65_Tot_Clms:"13".5
# GE65_Tot_30day_Fills:"39"
# GE65_Tot_Drug_Cst:"272.15"
# GE65_Tot_Day_Suply:"1170"
# GE65_Bene_Sprsn_Flag:"*".39
# GE65_Tot_Benes:""}.52
# {"Prscrbr_NPI":"1003000530".38
# Prscrbr_Last_Org_Name:"Semonche".38
# Prscrbr_First_Name:"Amanda".38
# Prscrbr_City:"Quakertown".38
# Prscrbr_State_Abrvtn:"PA".38
# Prscrbr_State_FIPS:"42".38
# Prscrbr_Type:"Internal Medicine".38
# Prscrbr_Type_Src:"Claim-Specialty".65
# Brnd_Name:"Famotidine"
# Gnrc_Name:"Famotidine"
# Tot_Clms:"143".1
# Tot_30day_Fills:"293.5"
# Tot_Day_Suply:"8770"
# Tot_Drug_Cst:"1813.81"
# Tot_Benes:"42".1
# GE65_Sprsn_Flag:"#".19
# GE65_Tot_Clms:"".27
# GE65_Tot_30day_Fills:"".27
# GE65_Tot_Drug_Cst:"".27
# GE65_Tot_Day_Suply:"".27
# GE65_Bene_Sprsn_Flag:"#".13
# GE65_Tot_Benes:""}.53
# {"Prscrbr_NPI":"1003000530".39
# Prscrbr_Last_Org_Name:"Semonche".39
# Prscrbr_First_Name:"Amanda".39
# Prscrbr_City:"Quakertown".39
# Prscrbr_State_Abrvtn:"PA".39
# Prscrbr_State_FIPS:"42".39
# Prscrbr_Type:"Internal Medicine".39
# Prscrbr_Type_Src:"Claim-Specialty".66
# Brnd_Name:"Febuxostat"
# Gnrc_Name:"Febuxostat"
# Tot_Clms:"12".4
# Tot_30day_Fills:"12".3
# Tot_Day_Suply:"360".1
# Tot_Drug_Cst:"2867.88"
# Tot_Benes:"".30
# GE65_Sprsn_Flag:"".40
# GE65_Tot_Clms:"12".1
# GE65_Tot_30day_Fills:"12".1
# GE65_Tot_Drug_Cst:"2867.88"
# GE65_Tot_Day_Suply:"360".1
# GE65_Bene_Sprsn_Flag:"*".40
# GE65_Tot_Benes:""}.54
# {"Prscrbr_NPI":"1003000530".40
# Prscrbr_Last_Org_Name:"Semonche".40
# Prscrbr_First_Name:"Amanda".40
# Prscrbr_City:"Quakertown".40
# Prscrbr_State_Abrvtn:"PA".40
# Prscrbr_State_FIPS:"42".40
# Prscrbr_Type:"Internal Medicine".40
# Prscrbr_Type_Src:"Claim-Specialty".67
# Brnd_Name:"Fenofibrate"
# Gnrc_Name:"Fenofibrate"
# Tot_Clms:"12".5
# Tot_30day_Fills:"32"
# Tot_Day_Suply:"960"
# Tot_Drug_Cst:"400.88"
# Tot_Benes:"".31
# GE65_Sprsn_Flag:"*".8
# GE65_Tot_Clms:"".28
# GE65_Tot_30day_Fills:"".28
# GE65_Tot_Drug_Cst:"".28
# GE65_Tot_Day_Suply:"".28
# GE65_Bene_Sprsn_Flag:"*".41
# GE65_Tot_Benes:""}.55
# {"Prscrbr_NPI":"1003000530".41
# Prscrbr_Last_Org_Name:"Semonche".41
# Prscrbr_First_Name:"Amanda".41
# Prscrbr_City:"Quakertown".41
# Prscrbr_State_Abrvtn:"PA".41
# Prscrbr_State_FIPS:"42".41
# Prscrbr_Type:"Internal Medicine".41
# Prscrbr_Type_Src:"Claim-Specialty".68
# Brnd_Name:"Finasteride"
# Gnrc_Name:"Finasteride"
# Tot_Clms:"31".1
# Tot_30day_Fills:"79"
# Tot_Day_Suply:"2370"
# Tot_Drug_Cst:"628.74"
# Tot_Benes:"".32
# GE65_Sprsn_Flag:"".41
# GE65_Tot_Clms:"31"
# GE65_Tot_30day_Fills:"79"
# GE65_Tot_Drug_Cst:"628.74"
# GE65_Tot_Day_Suply:"2370"
# GE65_Bene_Sprsn_Flag:"*".42
# GE65_Tot_Benes:""}.56
# {"Prscrbr_NPI":"1003000530".42
# Prscrbr_Last_Org_Name:"Semonche".42
# Prscrbr_First_Name:"Amanda".42
# Prscrbr_City:"Quakertown".42
# Prscrbr_State_Abrvtn:"PA".42
# Prscrbr_State_FIPS:"42".42
# Prscrbr_Type:"Internal Medicine".42
# Prscrbr_Type_Src:"Claim-Specialty".69
# Brnd_Name:"Fluticasone Propionate"
# Gnrc_Name:"Fluticasone Propionate"
# Tot_Clms:"59"
# Tot_30day_Fills:"108"
# Tot_Day_Suply:"3240"
# Tot_Drug_Cst:"709.42"
# Tot_Benes:"23".1
# GE65_Sprsn_Flag:"#".20
# GE65_Tot_Clms:"".29
# GE65_Tot_30day_Fills:"".29
# GE65_Tot_Drug_Cst:"".29
# GE65_Tot_Day_Suply:"".29
# GE65_Bene_Sprsn_Flag:"#".14
# GE65_Tot_Benes:""}.57
# {"Prscrbr_NPI":"1003000530".43
# Prscrbr_Last_Org_Name:"Semonche".43
# Prscrbr_First_Name:"Amanda".43
# Prscrbr_City:"Quakertown".43
# Prscrbr_State_Abrvtn:"PA".43
# Prscrbr_State_FIPS:"42".43
# Prscrbr_Type:"Internal Medicine".43
# Prscrbr_Type_Src:"Claim-Specialty".70
# Brnd_Name:"Fluticasone-Salmeterol"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol".1
# Tot_Clms:"16".4
# Tot_30day_Fills:"24".1
# Tot_Day_Suply:"720".1
# Tot_Drug_Cst:"3464.46"
# Tot_Benes:"".33
# GE65_Sprsn_Flag:"#".21
# GE65_Tot_Clms:"".30
# GE65_Tot_30day_Fills:"".30
# GE65_Tot_Drug_Cst:"".30
# GE65_Tot_Day_Suply:"".30
# GE65_Bene_Sprsn_Flag:"*".43
# GE65_Tot_Benes:""}.58
# {"Prscrbr_NPI":"1003000530".44
# Prscrbr_Last_Org_Name:"Semonche".44
# Prscrbr_First_Name:"Amanda".44
# Prscrbr_City:"Quakertown".44
# Prscrbr_State_Abrvtn:"PA".44
# Prscrbr_State_FIPS:"42".44
# Prscrbr_Type:"Internal Medicine".44
# Prscrbr_Type_Src:"Claim-Specialty".71
# Brnd_Name:"Fosinopril Sodium"
# Gnrc_Name:"Fosinopril Sodium"
# Tot_Clms:"23".1
# Tot_30day_Fills:"33"
# Tot_Day_Suply:"990"
# Tot_Drug_Cst:"487.11"
# Tot_Benes:"".34
# GE65_Sprsn_Flag:"".42
# GE65_Tot_Clms:"23"
# GE65_Tot_30day_Fills:"33"
# GE65_Tot_Drug_Cst:"487.11"
# GE65_Tot_Day_Suply:"990"
# GE65_Bene_Sprsn_Flag:"*".44
# GE65_Tot_Benes:""}.59
# {"Prscrbr_NPI":"1003000530".45
# Prscrbr_Last_Org_Name:"Semonche".45
# Prscrbr_First_Name:"Amanda".45
# Prscrbr_City:"Quakertown".45
# Prscrbr_State_Abrvtn:"PA".45
# Prscrbr_State_FIPS:"42".45
# Prscrbr_Type:"Internal Medicine".45
# Prscrbr_Type_Src:"Claim-Specialty".72
# Brnd_Name:"Furosemide"
# Gnrc_Name:"Furosemide"
# Tot_Clms:"74"
# Tot_30day_Fills:"137"
# Tot_Day_Suply:"4054"
# Tot_Drug_Cst:"516.89"
# Tot_Benes:"23".2
# GE65_Sprsn_Flag:"#".22
# GE65_Tot_Clms:"".31
# GE65_Tot_30day_Fills:"".31
# GE65_Tot_Drug_Cst:"".31
# GE65_Tot_Day_Suply:"".31
# GE65_Bene_Sprsn_Flag:"#".15
# GE65_Tot_Benes:""}.60
# {"Prscrbr_NPI":"1003000530".46
# Prscrbr_Last_Org_Name:"Semonche".46
# Prscrbr_First_Name:"Amanda".46
# Prscrbr_City:"Quakertown".46
# Prscrbr_State_Abrvtn:"PA".46
# Prscrbr_State_FIPS:"42".46
# Prscrbr_Type:"Internal Medicine".46
# Prscrbr_Type_Src:"Claim-Specialty".73
# Brnd_Name:"Gabapentin".1
# Gnrc_Name:"Gabapentin".1
# Tot_Clms:"223"
# Tot_30day_Fills:"382"
# Tot_Day_Suply:"11391"
# Tot_Drug_Cst:"3411.56"
# Tot_Benes:"53"
# GE65_Sprsn_Flag:"".43
# GE65_Tot_Clms:"203"
# GE65_Tot_30day_Fills:"358"
# GE65_Tot_Drug_Cst:"3230.61"
# GE65_Tot_Day_Suply:"10677"
# GE65_Bene_Sprsn_Flag:"#".16
# GE65_Tot_Benes:""}.61
# {"Prscrbr_NPI":"1003000530".47
# Prscrbr_Last_Org_Name:"Semonche".47
# Prscrbr_First_Name:"Amanda".47
# Prscrbr_City:"Quakertown".47
# Prscrbr_State_Abrvtn:"PA".47
# Prscrbr_State_FIPS:"42".47
# Prscrbr_Type:"Internal Medicine".47
# Prscrbr_Type_Src:"Claim-Specialty".74
# Brnd_Name:"Gemfibrozil"
# Gnrc_Name:"Gemfibrozil"
# Tot_Clms:"11".1
# Tot_30day_Fills:"11".1
# Tot_Day_Suply:"330"
# Tot_Drug_Cst:"99"
# Tot_Benes:"".35
# GE65_Sprsn_Flag:"".44
# GE65_Tot_Clms:"11".1
# GE65_Tot_30day_Fills:"11"
# GE65_Tot_Drug_Cst:"99"
# GE65_Tot_Day_Suply:"330"
# GE65_Bene_Sprsn_Flag:"*".45
# GE65_Tot_Benes:""}.62
# {"Prscrbr_NPI":"1003000530".48
# Prscrbr_Last_Org_Name:"Semonche".48
# Prscrbr_First_Name:"Amanda".48
# Prscrbr_City:"Quakertown".48
# Prscrbr_State_Abrvtn:"PA".48
# Prscrbr_State_FIPS:"42".48
# Prscrbr_Type:"Internal Medicine".48
# Prscrbr_Type_Src:"Claim-Specialty".75
# Brnd_Name:"Glipizide"
# Gnrc_Name:"Glipizide"
# Tot_Clms:"82".1
# Tot_30day_Fills:"191.1"
# Tot_Day_Suply:"5694"
# Tot_Drug_Cst:"958.43"
# Tot_Benes:"18".1
# GE65_Sprsn_Flag:"".45
# GE65_Tot_Clms:"82"
# GE65_Tot_30day_Fills:"191.1"
# GE65_Tot_Drug_Cst:"958.43"
# GE65_Tot_Day_Suply:"5694"
# GE65_Bene_Sprsn_Flag:"".14
# GE65_Tot_Benes:"18"}
# {"Prscrbr_NPI":"1003000530".49
# Prscrbr_Last_Org_Name:"Semonche".49
# Prscrbr_First_Name:"Amanda".49
# Prscrbr_City:"Quakertown".49
# Prscrbr_State_Abrvtn:"PA".49
# Prscrbr_State_FIPS:"42".49
# Prscrbr_Type:"Internal Medicine".49
# Prscrbr_Type_Src:"Claim-Specialty".76
# Brnd_Name:"Glycopyrrolate"
# Gnrc_Name:"Glycopyrrolate"
# Tot_Clms:"14".7
# Tot_30day_Fills:"16.2"
# Tot_Day_Suply:"485"
# Tot_Drug_Cst:"908.42"
# Tot_Benes:"".36
# GE65_Sprsn_Flag:"*".9
# GE65_Tot_Clms:"".32
# GE65_Tot_30day_Fills:"".32
# GE65_Tot_Drug_Cst:"".32
# GE65_Tot_Day_Suply:"".32
# GE65_Bene_Sprsn_Flag:"*".46
# GE65_Tot_Benes:""}.63
# {"Prscrbr_NPI":"1003000530".50
# Prscrbr_Last_Org_Name:"Semonche".50
# Prscrbr_First_Name:"Amanda".50
# Prscrbr_City:"Quakertown".50
# Prscrbr_State_Abrvtn:"PA".50
# Prscrbr_State_FIPS:"42".50
# Prscrbr_Type:"Internal Medicine".50
# Prscrbr_Type_Src:"Claim-Specialty".77
# Brnd_Name:"Hydrochlorothiazide"
# Gnrc_Name:"Hydrochlorothiazide"
# Tot_Clms:"188"
# Tot_30day_Fills:"456"
# Tot_Day_Suply:"13668"
# Tot_Drug_Cst:"712.76"
# Tot_Benes:"44"
# GE65_Sprsn_Flag:"#".23
# GE65_Tot_Clms:"".33
# GE65_Tot_30day_Fills:"".33
# GE65_Tot_Drug_Cst:"".33
# GE65_Tot_Day_Suply:"".33
# GE65_Bene_Sprsn_Flag:"#".17
# GE65_Tot_Benes:""}.64
# {"Prscrbr_NPI":"1003000530".51
# Prscrbr_Last_Org_Name:"Semonche".51
# Prscrbr_First_Name:"Amanda".51
# Prscrbr_City:"Quakertown".51
# Prscrbr_State_Abrvtn:"PA".51
# Prscrbr_State_FIPS:"42".51
# Prscrbr_Type:"Internal Medicine".51
# Prscrbr_Type_Src:"Claim-Specialty".78
# Brnd_Name:"Hydrocodone-Acetaminophen".1
# Gnrc_Name:"Hydrocodone\/Acetaminophen".1
# Tot_Clms:"21".1
# Tot_30day_Fills:"21"
# Tot_Day_Suply:"306"
# Tot_Drug_Cst:"463.91"
# Tot_Benes:"".37
# GE65_Sprsn_Flag:"".46
# GE65_Tot_Clms:"21"
# GE65_Tot_30day_Fills:"21".1
# GE65_Tot_Drug_Cst:"463.91"
# GE65_Tot_Day_Suply:"306"
# GE65_Bene_Sprsn_Flag:"*".47
# GE65_Tot_Benes:""}.65
# {"Prscrbr_NPI":"1003000530".52
# Prscrbr_Last_Org_Name:"Semonche".52
# Prscrbr_First_Name:"Amanda".52
# Prscrbr_City:"Quakertown".52
# Prscrbr_State_Abrvtn:"PA".52
# Prscrbr_State_FIPS:"42".52
# Prscrbr_Type:"Internal Medicine".52
# Prscrbr_Type_Src:"Claim-Specialty".79
# Brnd_Name:"Irbesartan"
# Gnrc_Name:"Irbesartan"
# Tot_Clms:"19".1
# Tot_30day_Fills:"33".1
# Tot_Day_Suply:"964"
# Tot_Drug_Cst:"852.51"
# Tot_Benes:"".38
# GE65_Sprsn_Flag:"*".10
# GE65_Tot_Clms:"".34
# GE65_Tot_30day_Fills:"".34
# GE65_Tot_Drug_Cst:"".34
# GE65_Tot_Day_Suply:"".34
# GE65_Bene_Sprsn_Flag:"*".48
# GE65_Tot_Benes:""}.66
# {"Prscrbr_NPI":"1003000530".53
# Prscrbr_Last_Org_Name:"Semonche".53
# Prscrbr_First_Name:"Amanda".53
# Prscrbr_City:"Quakertown".53
# Prscrbr_State_Abrvtn:"PA".53
# Prscrbr_State_FIPS:"42".53
# Prscrbr_Type:"Internal Medicine".53
# Prscrbr_Type_Src:"Claim-Specialty".80
# Brnd_Name:"Isosorbide Mononitrate Er"
# Gnrc_Name:"Isosorbide Mononitrate"
# Tot_Clms:"23".2
# Tot_30day_Fills:"47"
# Tot_Day_Suply:"1410"
# Tot_Drug_Cst:"529.15"
# Tot_Benes:"".39
# GE65_Sprsn_Flag:"#".24
# GE65_Tot_Clms:"".35
# GE65_Tot_30day_Fills:"".35
# GE65_Tot_Drug_Cst:"".35
# GE65_Tot_Day_Suply:"".35
# GE65_Bene_Sprsn_Flag:"*".49
# GE65_Tot_Benes:""}.67
# {"Prscrbr_NPI":"1003000530".54
# Prscrbr_Last_Org_Name:"Semonche".54
# Prscrbr_First_Name:"Amanda".54
# Prscrbr_City:"Quakertown".54
# Prscrbr_State_Abrvtn:"PA".54
# Prscrbr_State_FIPS:"42".54
# Prscrbr_Type:"Internal Medicine".54
# Prscrbr_Type_Src:"Claim-Specialty".81
# Brnd_Name:"Januvia"
# Gnrc_Name:"Sitagliptin Phosphate"
# Tot_Clms:"27".1
# Tot_30day_Fills:"49"
# Tot_Day_Suply:"1470"
# Tot_Drug_Cst:"27971.54"
# Tot_Benes:"".40
# GE65_Sprsn_Flag:"".47
# GE65_Tot_Clms:"27".1
# GE65_Tot_30day_Fills:"49"
# GE65_Tot_Drug_Cst:"27971.54"
# GE65_Tot_Day_Suply:"1470"
# GE65_Bene_Sprsn_Flag:"*".50
# GE65_Tot_Benes:""}.68
# ...
# Tot_Benes:"41".5
# GE65_Sprsn_Flag:"".553
# GE65_Tot_Clms:"106".2
# GE65_Tot_30day_Fills:"226".1
# GE65_Tot_Drug_Cst:"2465.7"
# GE65_Tot_Day_Suply:"6780"
# GE65_Bene_Sprsn_Flag:"".146
# GE65_Tot_Benes:"30"}.1
# {"Prscrbr_NPI":"1003004201".48
# Prscrbr_Last_Org_Name:"Philbrick".48
# Prscrbr_First_Name:"Natalie".48
# Prscrbr_City:"Corpus Christi".48
# Prscrbr_State_Abrvtn:"TX".96
# Prscrbr_State_FIPS:"48".96
# Prscrbr_Type:"Internal Medicine".170
# Prscrbr_Type_Src:"Claim-Specialty".758
# Brnd_Name:"Glimepiride".2
# Gnrc_Name:"Glimepiride".2
# Tot_Clms:"11".54
# Tot_30day_Fills:"31".7
# Tot_Day_Suply:"911"
# Tot_Drug_Cst:"72.72"
# Tot_Benes:"".497
# GE65_Sprsn_Flag:"".554
# GE65_Tot_Clms:"11".26
# GE65_Tot_30day_Fills:"31".3
# GE65_Tot_Drug_Cst:"72.72"
# GE65_Tot_Day_Suply:"911"
# GE65_Bene_Sprsn_Flag:"*".531
# GE65_Tot_Benes:""}.827
# {"Prscrbr_NPI":"1003004201".49
# Prscrbr_Last_Org_Name:"Philbrick".49
# Prscrbr_First_Name:"Natalie".49
# Prscrbr_City:"Corpus Christi".49
# Prscrbr_State_Abrvtn:"TX".97
# Prscrbr_State_FIPS:"48".97
# Prscrbr_Type:"Internal Medicine".171
# Prscrbr_Type_Src:"Claim-Specialty".759
# Brnd_Name:"Glipizide".4
# Gnrc_Name:"Glipizide".8
# Tot_Clms:"12".45
# Tot_30day_Fills:"35".12
# Tot_Day_Suply:"1050".8
# Tot_Drug_Cst:"69.59".1
# Tot_Benes:"".498
# GE65_Sprsn_Flag:"".555
# GE65_Tot_Clms:"12".24
# GE65_Tot_30day_Fills:"35".5
# GE65_Tot_Drug_Cst:"69.59".1
# GE65_Tot_Day_Suply:"1050".5
# GE65_Bene_Sprsn_Flag:"*".532
# GE65_Tot_Benes:""}.828
# {"Prscrbr_NPI":"1003004201".50
# Prscrbr_Last_Org_Name:"Philbrick".50
# Prscrbr_First_Name:"Natalie".50
# Prscrbr_City:"Corpus Christi".50
# Prscrbr_State_Abrvtn:"TX".98
# Prscrbr_State_FIPS:"48".98
# Prscrbr_Type:"Internal Medicine".172
# Prscrbr_Type_Src:"Claim-Specialty".760
# Brnd_Name:"Hydrochlorothiazide".7
# Gnrc_Name:"Hydrochlorothiazide".7
# Tot_Clms:"88".4
# Tot_30day_Fills:"198.7"
# Tot_Day_Suply:"5943"
# Tot_Drug_Cst:"308.78"
# Tot_Benes:"21".17
# GE65_Sprsn_Flag:"".556
# GE65_Tot_Clms:"76".1
# GE65_Tot_30day_Fills:"164"
# GE65_Tot_Drug_Cst:"245.72"
# GE65_Tot_Day_Suply:"4903"
# GE65_Bene_Sprsn_Flag:"#".296
# GE65_Tot_Benes:""}.829
# {"Prscrbr_NPI":"1003004201".51
# Prscrbr_Last_Org_Name:"Philbrick".51
# Prscrbr_First_Name:"Natalie".51
# Prscrbr_City:"Corpus Christi".51
# Prscrbr_State_Abrvtn:"TX".99
# Prscrbr_State_FIPS:"48".99
# Prscrbr_Type:"Internal Medicine".173
# Prscrbr_Type_Src:"Claim-Specialty".761
# Brnd_Name:"Hydrocodone-Acetaminophen".12
# Gnrc_Name:"Hydrocodone\/Acetaminophen".12
# Tot_Clms:"75".2
# Tot_30day_Fills:"75".3
# Tot_Day_Suply:"1902"
# Tot_Drug_Cst:"1984.27"
# Tot_Benes:"24".11
# GE65_Sprsn_Flag:"".557
# GE65_Tot_Clms:"51".2
# GE65_Tot_30day_Fills:"51".5
# GE65_Tot_Drug_Cst:"1443.05"
# GE65_Tot_Day_Suply:"1317"
# GE65_Bene_Sprsn_Flag:"#".297
# GE65_Tot_Benes:""}.830
# {"Prscrbr_NPI":"1003004201".52
# Prscrbr_Last_Org_Name:"Philbrick".52
# Prscrbr_First_Name:"Natalie".52
# Prscrbr_City:"Corpus Christi".52
# Prscrbr_State_Abrvtn:"TX".100
# Prscrbr_State_FIPS:"48".100
# Prscrbr_Type:"Internal Medicine".174
# Prscrbr_Type_Src:"Claim-Specialty".762
# Brnd_Name:"Ibuprofen".5
# Gnrc_Name:"Ibuprofen".5
# Tot_Clms:"23".20
# Tot_30day_Fills:"23".9
# Tot_Day_Suply:"645"
# Tot_Drug_Cst:"239.22"
# Tot_Benes:"".499
# GE65_Sprsn_Flag:"*".100
# GE65_Tot_Clms:"".420
# GE65_Tot_30day_Fills:"".420
# GE65_Tot_Drug_Cst:"".420
# GE65_Tot_Day_Suply:"".420
# GE65_Bene_Sprsn_Flag:"*".533
# GE65_Tot_Benes:""}.831
# {"Prscrbr_NPI":"1003004201".53
# Prscrbr_Last_Org_Name:"Philbrick".53
# Prscrbr_First_Name:"Natalie".53
# Prscrbr_City:"Corpus Christi".53
# Prscrbr_State_Abrvtn:"TX".101
# Prscrbr_State_FIPS:"48".101
# Prscrbr_Type:"Internal Medicine".175
# Prscrbr_Type_Src:"Claim-Specialty".763
# Brnd_Name:"Irbesartan".3
# Gnrc_Name:"Irbesartan".3
# Tot_Clms:"33".12
# Tot_30day_Fills:"81".2
# Tot_Day_Suply:"2409"
# Tot_Drug_Cst:"601.43"
# Tot_Benes:"".500
# GE65_Sprsn_Flag:"".558
# GE65_Tot_Clms:"33".5
# GE65_Tot_30day_Fills:"81".1
# GE65_Tot_Drug_Cst:"601.43"
# GE65_Tot_Day_Suply:"2409"
# GE65_Bene_Sprsn_Flag:"*".534
# GE65_Tot_Benes:""}.832
# {"Prscrbr_NPI":"1003004201".54
# Prscrbr_Last_Org_Name:"Philbrick".54
# Prscrbr_First_Name:"Natalie".54
# Prscrbr_City:"Corpus Christi".54
# Prscrbr_State_Abrvtn:"TX".102
# Prscrbr_State_FIPS:"48".102
# Prscrbr_Type:"Internal Medicine".176
# Prscrbr_Type_Src:"Claim-Specialty".764
# Brnd_Name:"Janumet".2
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".3
# Tot_Clms:"11".55
# Tot_30day_Fills:"34.3".1
# Tot_Day_Suply:"1030"
# Tot_Drug_Cst:"15945.71"
# Tot_Benes:"".501
# GE65_Sprsn_Flag:"*".101
# GE65_Tot_Clms:"".421
# GE65_Tot_30day_Fills:"".421
# GE65_Tot_Drug_Cst:"".421
# GE65_Tot_Day_Suply:"".421
# GE65_Bene_Sprsn_Flag:"*".535
# GE65_Tot_Benes:""}.833
# {"Prscrbr_NPI":"1003004201".55
# Prscrbr_Last_Org_Name:"Philbrick".55
# Prscrbr_First_Name:"Natalie".55
# Prscrbr_City:"Corpus Christi".55
# Prscrbr_State_Abrvtn:"TX".103
# Prscrbr_State_FIPS:"48".103
# Prscrbr_Type:"Internal Medicine".177
# Prscrbr_Type_Src:"Claim-Specialty".765
# Brnd_Name:"Janumet Xr".1
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".4
# Tot_Clms:"16".31
# Tot_30day_Fills:"26".10
# Tot_Day_Suply:"780".4
# Tot_Drug_Cst:"14576.22"
# Tot_Benes:"".502
# GE65_Sprsn_Flag:"".559
# GE65_Tot_Clms:"16".17
# GE65_Tot_30day_Fills:"26".4
# GE65_Tot_Drug_Cst:"14576.22"
# GE65_Tot_Day_Suply:"780".1
# GE65_Bene_Sprsn_Flag:"*".536
# GE65_Tot_Benes:""}.834
# {"Prscrbr_NPI":"1003004201".56
# Prscrbr_Last_Org_Name:"Philbrick".56
# Prscrbr_First_Name:"Natalie".56
# Prscrbr_City:"Corpus Christi".56
# Prscrbr_State_Abrvtn:"TX".104
# Prscrbr_State_FIPS:"48".104
# Prscrbr_Type:"Internal Medicine".178
# Prscrbr_Type_Src:"Claim-Specialty".766
# Brnd_Name:"Januvia".5
# Gnrc_Name:"Sitagliptin Phosphate".5
# Tot_Clms:"47".7
# Tot_30day_Fills:"102.7"
# Tot_Day_Suply:"3080"
# Tot_Drug_Cst:"57151.67"
# Tot_Benes:"".503
# GE65_Sprsn_Flag:"".560
# GE65_Tot_Clms:"33".6
# GE65_Tot_30day_Fills:"61".4
# GE65_Tot_Drug_Cst:"32794.59"
# GE65_Tot_Day_Suply:"1830".3
# GE65_Bene_Sprsn_Flag:"*".537
# GE65_Tot_Benes:""}.835
# {"Prscrbr_NPI":"1003004201".57
# Prscrbr_Last_Org_Name:"Philbrick".57
# Prscrbr_First_Name:"Natalie".57
# Prscrbr_City:"Corpus Christi".57
# Prscrbr_State_Abrvtn:"TX".105
# Prscrbr_State_FIPS:"48".105
# Prscrbr_Type:"Internal Medicine".179
# Prscrbr_Type_Src:"Claim-Specialty".767
# Brnd_Name:"Jardiance".5
# Gnrc_Name:"Empagliflozin".5
# Tot_Clms:"36".10
# Tot_30day_Fills:"48".7
# Tot_Day_Suply:"1440".5
# Tot_Drug_Cst:"30810.62"
# Tot_Benes:"".504
# GE65_Sprsn_Flag:"".561
# GE65_Tot_Clms:"16".18
# GE65_Tot_30day_Fills:"28".4
# GE65_Tot_Drug_Cst:"17814.66"
# GE65_Tot_Day_Suply:"840".4
# GE65_Bene_Sprsn_Flag:"*".538
# GE65_Tot_Benes:""}.836
# {"Prscrbr_NPI":"1003004201".58
# Prscrbr_Last_Org_Name:"Philbrick".58
# Prscrbr_First_Name:"Natalie".58
# Prscrbr_City:"Corpus Christi".58
# Prscrbr_State_Abrvtn:"TX".106
# Prscrbr_State_FIPS:"48".106
# Prscrbr_Type:"Internal Medicine".180
# Prscrbr_Type_Src:"Claim-Specialty".768
# Brnd_Name:"Lantus Solostar".4
# Gnrc_Name:"Insulin Glargine.7
# hum.Rec.Anlog".7
# Tot_Clms:"30".15
# Tot_30day_Fills:"42.6"
# Tot_Day_Suply:"1200".4
# Tot_Drug_Cst:"14025.7"
# Tot_Benes:"".505
# GE65_Sprsn_Flag:"*".102
# GE65_Tot_Clms:"".422
# GE65_Tot_30day_Fills:"".422
# GE65_Tot_Drug_Cst:"".422
# GE65_Tot_Day_Suply:"".422
# GE65_Bene_Sprsn_Flag:"*".539
# GE65_Tot_Benes:""}.837
# {"Prscrbr_NPI":"1003004201".59
# Prscrbr_Last_Org_Name:"Philbrick".59
# Prscrbr_First_Name:"Natalie".59
# Prscrbr_City:"Corpus Christi".59
# Prscrbr_State_Abrvtn:"TX".107
# Prscrbr_State_FIPS:"48".107
# Prscrbr_Type:"Internal Medicine".181
# Prscrbr_Type_Src:"Claim-Specialty".769
# Brnd_Name:"Levemir Flexpen"
# Gnrc_Name:"Insulin Detemir"
# Tot_Clms:"18".24
# Tot_30day_Fills:"40.7".1
# Tot_Day_Suply:"1216"
# Tot_Drug_Cst:"14820.64"
# Tot_Benes:"".506
# GE65_Sprsn_Flag:"#".320
# GE65_Tot_Clms:"".423
# GE65_Tot_30day_Fills:"".423
# GE65_Tot_Drug_Cst:"".423
# GE65_Tot_Day_Suply:"".423
# GE65_Bene_Sprsn_Flag:"*".540
# GE65_Tot_Benes:""}.838
# {"Prscrbr_NPI":"1003004201".60
# Prscrbr_Last_Org_Name:"Philbrick".60
# Prscrbr_First_Name:"Natalie".60
# Prscrbr_City:"Corpus Christi".60
# Prscrbr_State_Abrvtn:"TX".108
# Prscrbr_State_FIPS:"48".108
# Prscrbr_Type:"Internal Medicine".182
# Prscrbr_Type_Src:"Claim-Specialty".770
# Brnd_Name:"Levothyroxine Sodium".7
# Gnrc_Name:"Levothyroxine Sodium".13
# Tot_Clms:"329"
# Tot_30day_Fills:"878.8"
# Tot_Day_Suply:"26336"
# Tot_Drug_Cst:"5172.2"
# Tot_Benes:"87".1
# GE65_Sprsn_Flag:"".562
# GE65_Tot_Clms:"296"
# GE65_Tot_30day_Fills:"792.8"
# GE65_Tot_Drug_Cst:"4565.09"
# GE65_Tot_Day_Suply:"23768"
# GE65_Bene_Sprsn_Flag:"#".298
# GE65_Tot_Benes:""}.839
# {"Prscrbr_NPI":"1003004201".61
# Prscrbr_Last_Org_Name:"Philbrick".61
# Prscrbr_First_Name:"Natalie".61
# Prscrbr_City:"Corpus Christi".61
# Prscrbr_State_Abrvtn:"TX".109
# Prscrbr_State_FIPS:"48".109
# Prscrbr_Type:"Internal Medicine".183
# Prscrbr_Type_Src:"Claim-Specialty".771
# Brnd_Name:"Lisinopril".9
# Gnrc_Name:"Lisinopril".9
# Tot_Clms:"191".1
# Tot_30day_Fills:"567.6"
# Tot_Day_Suply:"17030"
# Tot_Drug_Cst:"1067.95"
# Tot_Benes:"57".1
# GE65_Sprsn_Flag:"".563
# GE65_Tot_Clms:"168".1
# GE65_Tot_30day_Fills:"498.6"
# GE65_Tot_Drug_Cst:"935.82"
# GE65_Tot_Day_Suply:"14960"
# GE65_Bene_Sprsn_Flag:"#".299
# GE65_Tot_Benes:""}.840
# {"Prscrbr_NPI":"1003004201".62
# Prscrbr_Last_Org_Name:"Philbrick".62
# Prscrbr_First_Name:"Natalie".62
# Prscrbr_City:"Corpus Christi".62
# Prscrbr_State_Abrvtn:"TX".110
# Prscrbr_State_FIPS:"48".110
# Prscrbr_Type:"Internal Medicine".184
# Prscrbr_Type_Src:"Claim-Specialty".772
# Brnd_Name:"Lisinopril-Hydrochlorothiazide".3
# Gnrc_Name:"Lisinopril\/Hydrochlorothiazide".3
# Tot_Clms:"31".8
# Tot_30day_Fills:"86.3"
# Tot_Day_Suply:"2556"
# Tot_Drug_Cst:"358.53"
# Tot_Benes:"".507
# GE65_Sprsn_Flag:"#".321
# GE65_Tot_Clms:"".424
# GE65_Tot_30day_Fills:"".424
# GE65_Tot_Drug_Cst:"".424
# GE65_Tot_Day_Suply:"".424
# GE65_Bene_Sprsn_Flag:"*".541
# GE65_Tot_Benes:""}.841
# {"Prscrbr_NPI":"1003004201".63
# Prscrbr_Last_Org_Name:"Philbrick".63
# Prscrbr_First_Name:"Natalie".63
# Prscrbr_City:"Corpus Christi".63
# Prscrbr_State_Abrvtn:"TX".111
# Prscrbr_State_FIPS:"48".111
# Prscrbr_Type:"Internal Medicine".185
# Prscrbr_Type_Src:"Claim-Specialty".773
# Brnd_Name:"Lorazepam".4
# Gnrc_Name:"Lorazepam".4
# Tot_Clms:"17".23
# Tot_30day_Fills:"17".14
# Tot_Day_Suply:"467"
# Tot_Drug_Cst:"68.44"
# Tot_Benes:"".508
# GE65_Sprsn_Flag:"#".322
# GE65_Tot_Clms:"".425
# GE65_Tot_30day_Fills:"".425
# GE65_Tot_Drug_Cst:"".425
# GE65_Tot_Day_Suply:"".425
# GE65_Bene_Sprsn_Flag:"*".542
# GE65_Tot_Benes:""}.842
# {"Prscrbr_NPI":"1003004201".64
# Prscrbr_Last_Org_Name:"Philbrick".64
# Prscrbr_First_Name:"Natalie".64
# Prscrbr_City:"Corpus Christi".64
# Prscrbr_State_Abrvtn:"TX".112
# Prscrbr_State_FIPS:"48".112
# Prscrbr_Type:"Internal Medicine".186
# Prscrbr_Type_Src:"Claim-Specialty".774
# Brnd_Name:"Losartan Potassium".8
# Gnrc_Name:"Losartan Potassium".8
# Tot_Clms:"198"
# Tot_30day_Fills:"489"
# Tot_Day_Suply:"14661"
# Tot_Drug_Cst:"2739.62"
# Tot_Benes:"54".1
# GE65_Sprsn_Flag:"#".323
# GE65_Tot_Clms:"".426
# GE65_Tot_30day_Fills:"".426
# GE65_Tot_Drug_Cst:"".426
# GE65_Tot_Day_Suply:"".426
# GE65_Bene_Sprsn_Flag:"#".300
# GE65_Tot_Benes:""}.843
# {"Prscrbr_NPI":"1003004201".65
# Prscrbr_Last_Org_Name:"Philbrick".65
# Prscrbr_First_Name:"Natalie".65
# Prscrbr_City:"Corpus Christi".65
# Prscrbr_State_Abrvtn:"TX".113
# Prscrbr_State_FIPS:"48".113
# Prscrbr_Type:"Internal Medicine".187
# Prscrbr_Type_Src:"Claim-Specialty".775
# Brnd_Name:"Losartan-Hydrochlorothiazide".3
# Gnrc_Name:"Losartan\/Hydrochlorothiazide".3
# Tot_Clms:"77"
# Tot_30day_Fills:"218.3"
# Tot_Day_Suply:"6550"
# Tot_Drug_Cst:"1248.85"
# Tot_Benes:"23".11
# GE65_Sprsn_Flag:"#".324
# GE65_Tot_Clms:"".427
# GE65_Tot_30day_Fills:"".427
# GE65_Tot_Drug_Cst:"".427
# GE65_Tot_Day_Suply:"".427
# GE65_Bene_Sprsn_Flag:"#".301
# GE65_Tot_Benes:""}.844
# {"Prscrbr_NPI":"1003004201".66
# Prscrbr_Last_Org_Name:"Philbrick".66
# Prscrbr_First_Name:"Natalie".66
# Prscrbr_City:"Corpus Christi".66
# Prscrbr_State_Abrvtn:"TX".114
# Prscrbr_State_FIPS:"48".114
# Prscrbr_Type:"Internal Medicine".188
# Prscrbr_Type_Src:"Claim-Specialty".776
# Brnd_Name:"Meloxicam".10
# Gnrc_Name:"Meloxicam".10
# Tot_Clms:"295".1
# Tot_30day_Fills:"662.6"
# Tot_Day_Suply:"19839"
# Tot_Drug_Cst:"1681.33"
# Tot_Benes:"87".2
# GE65_Sprsn_Flag:"".564
# GE65_Tot_Clms:"250"
# GE65_Tot_30day_Fills:"558"
# GE65_Tot_Drug_Cst:"1493.45"
# GE65_Tot_Day_Suply:"16724"
# GE65_Bene_Sprsn_Flag:"".147
# GE65_Tot_Benes:"72"}
# {"Prscrbr_NPI":"1003004201".67
# Prscrbr_Last_Org_Name:"Philbrick".67
# Prscrbr_First_Name:"Natalie".67
# Prscrbr_City:"Corpus Christi".67
# Prscrbr_State_Abrvtn:"TX".115
# Prscrbr_State_FIPS:"48".115
# Prscrbr_Type:"Internal Medicine".189
# Prscrbr_Type_Src:"Claim-Specialty".777
# Brnd_Name:"Memantine Hcl Er"
# Gnrc_Name:"Memantine Hcl".3
# Tot_Clms:"11".56
# Tot_30day_Fills:"17".15
# Tot_Day_Suply:"510".6
# Tot_Drug_Cst:"685.59"
# Tot_Benes:"".509
# GE65_Sprsn_Flag:"".565
# GE65_Tot_Clms:"11".27
# GE65_Tot_30day_Fills:"17".5
# GE65_Tot_Drug_Cst:"685.59"
# GE65_Tot_Day_Suply:"510".2
# GE65_Bene_Sprsn_Flag:"*".543
# GE65_Tot_Benes:""}.845
# {"Prscrbr_NPI":"1003004201".68
# Prscrbr_Last_Org_Name:"Philbrick".68
# Prscrbr_First_Name:"Natalie".68
# Prscrbr_City:"Corpus Christi".68
# Prscrbr_State_Abrvtn:"TX".116
# Prscrbr_State_FIPS:"48".116
# Prscrbr_Type:"Internal Medicine".190
# Prscrbr_Type_Src:"Claim-Specialty".778
# Brnd_Name:"Metformin Hcl".7
# Gnrc_Name:"Metformin Hcl".12
# Tot_Clms:"172"
# Tot_30day_Fills:"477.7"
# Tot_Day_Suply:"14331"
# Tot_Drug_Cst:"1379.45"
# Tot_Benes:"54".2
# GE65_Sprsn_Flag:"".566
# GE65_Tot_Clms:"134"
# GE65_Tot_30day_Fills:"385"
# GE65_Tot_Drug_Cst:"998.73"
# GE65_Tot_Day_Suply:"11551"
# GE65_Bene_Sprsn_Flag:"".148
# GE65_Tot_Benes:"43"}.1
# {"Prscrbr_NPI":"1003004201".69
# Prscrbr_Last_Org_Name:"Philbrick".69
# Prscrbr_First_Name:"Natalie".69
# Prscrbr_City:"Corpus Christi".69
# Prscrbr_State_Abrvtn:"TX".117
# Prscrbr_State_FIPS:"48".117
# Prscrbr_Type:"Internal Medicine".191
# Prscrbr_Type_Src:"Claim-Specialty".779
# Brnd_Name:"Metformin Hcl Er".5
# Gnrc_Name:"Metformin Hcl".13
# Tot_Clms:"36".11
# Tot_30day_Fills:"94".2
# Tot_Day_Suply:"2819"
# Tot_Drug_Cst:"453.51"
# Tot_Benes:"14".23
# GE65_Sprsn_Flag:"#".325
# GE65_Tot_Clms:"".428
# GE65_Tot_30day_Fills:"".428
# GE65_Tot_Drug_Cst:"".428
# GE65_Tot_Day_Suply:"".428
# GE65_Bene_Sprsn_Flag:"#".302
# GE65_Tot_Benes:""}.846
# {"Prscrbr_NPI":"1003004201".70
# Prscrbr_Last_Org_Name:"Philbrick".70
# Prscrbr_First_Name:"Natalie".70
# Prscrbr_City:"Corpus Christi".70
# Prscrbr_State_Abrvtn:"TX".118
# Prscrbr_State_FIPS:"48".118
# Prscrbr_Type:"Internal Medicine".192
# Prscrbr_Type_Src:"Claim-Specialty".780
# Brnd_Name:"Methocarbamol".2
# Gnrc_Name:"Methocarbamol".2
# Tot_Clms:"16".32
# Tot_30day_Fills:"18".11
# Tot_Day_Suply:"520".1
# Tot_Drug_Cst:"110.37"
# Tot_Benes:"".510
# GE65_Sprsn_Flag:"#".326
# GE65_Tot_Clms:"".429
# GE65_Tot_30day_Fills:"".429
# GE65_Tot_Drug_Cst:"".429
# GE65_Tot_Day_Suply:"".429
# GE65_Bene_Sprsn_Flag:"*".544
# GE65_Tot_Benes:""}.847
# {"Prscrbr_NPI":"1003004201".71
# Prscrbr_Last_Org_Name:"Philbrick".71
# Prscrbr_First_Name:"Natalie".71
# Prscrbr_City:"Corpus Christi".71
# Prscrbr_State_Abrvtn:"TX".119
# Prscrbr_State_FIPS:"48".119
# Prscrbr_Type:"Internal Medicine".193
# Prscrbr_Type_Src:"Claim-Specialty".781
# Brnd_Name:"Metoprolol Succinate".8
# Gnrc_Name:"Metoprolol Succinate".8
# Tot_Clms:"65".3
# Tot_30day_Fills:"192.3"
# Tot_Day_Suply:"5770"
# Tot_Drug_Cst:"1332.13"
# Tot_Benes:"20".12
# GE65_Sprsn_Flag:"#".327
# GE65_Tot_Clms:"".430
# GE65_Tot_30day_Fills:"".430
# GE65_Tot_Drug_Cst:"".430
# GE65_Tot_Day_Suply:"".430
# GE65_Bene_Sprsn_Flag:"#".303
# GE65_Tot_Benes:""}.848
# {"Prscrbr_NPI":"1003004201".72
# Prscrbr_Last_Org_Name:"Philbrick".72
# Prscrbr_First_Name:"Natalie".72
# Prscrbr_City:"Corpus Christi".72
# Prscrbr_State_Abrvtn:"TX".120
# Prscrbr_State_FIPS:"48".120
# Prscrbr_Type:"Internal Medicine".194
# Prscrbr_Type_Src:"Claim-Specialty".782
# Brnd_Name:"Metoprolol Tartrate".6
# Gnrc_Name:"Metoprolol Tartrate".6
# Tot_Clms:"60".3
# Tot_30day_Fills:"150.1"
# Tot_Day_Suply:"4492"
# Tot_Drug_Cst:"305.37"
# Tot_Benes:"21".18
# GE65_Sprsn_Flag:"#".328
# GE65_Tot_Clms:"".431
# GE65_Tot_30day_Fills:"".431
# GE65_Tot_Drug_Cst:"".431
# GE65_Tot_Day_Suply:"".431
# GE65_Bene_Sprsn_Flag:"#".304
# GE65_Tot_Benes:""}.849
# {"Prscrbr_NPI":"1003004201".73
# Prscrbr_Last_Org_Name:"Philbrick".73
# Prscrbr_First_Name:"Natalie".73
# Prscrbr_City:"Corpus Christi".73
# Prscrbr_State_Abrvtn:"TX".121
# Prscrbr_State_FIPS:"48".121
# Prscrbr_Type:"Internal Medicine".195
# Prscrbr_Type_Src:"Claim-Specialty".783
# Brnd_Name:"Mirtazapine".4
# Gnrc_Name:"Mirtazapine".4
# Tot_Clms:"11".57
# Tot_30day_Fills:"21.3"
# Tot_Day_Suply:"640"
# Tot_Drug_Cst:"174.68"
# Tot_Benes:"".511
# GE65_Sprsn_Flag:"".567
# GE65_Tot_Clms:"11".28
# GE65_Tot_30day_Fills:"21.3"
# GE65_Tot_Drug_Cst:"174.68"
# GE65_Tot_Day_Suply:"640"
# GE65_Bene_Sprsn_Flag:"*".545
# GE65_Tot_Benes:""}]

# %%
#8
# Accessing column names from the dataframe
df_sample = pd.read_csv(f"{BASE_URL_CMS}?year={years[0]}&format=csv", nrows=5)
cols = df_sample.columns.tolist()

Drug_Name = cols[0]  # Assuming Drug_Name is the first column
Tot_Drug_Cst = cols[1]  # Assuming Tot_Drug_Cst is the second column
Tot_Clms = cols[2]   # Assuming Tot_Clms is the third column

# Example operations using the column names:
print(f"Drug Name column: {Drug_Name}")
print(f"Total Drug Cost column: {Tot_Drug_Cst}")
print(f"Total Claims column: {Tot_Clms}")
# Out:
# Drug Name column: [{"Prscrbr_NPI":"1003000126"
# Total Drug Cost column: Prscrbr_Last_Org_Name:"Enkeshafi"
# Total Claims column: Prscrbr_First_Name:"Ardalan"

# %%
#9
# Re-inspect CMS file structure
df_sample = pd.read_csv(f"{BASE_URL_CMS}?year={years[0]}&format=csv", nrows=5)
cols = df_sample.columns.tolist()

print("\n🔎 Columns found in CMS 2020 sample:")
for c in cols:
    print(c)

# Accessing column names from the dataframe
Drug_Name = df_sample.columns[0] # Assuming Drug_Name is the first column, adjust index if needed
# Use the correct column name. In this case, it's likely 'Tot_Drug_Cst' is not the correct name
# Replace with the actual name from the printed list or use .get_loc with correct name.
# Assuming the correct name is in the first element of cols list, this is: '[{"Prscrbr_NPI":"100...'
Tot_Drug_Cst = cols[0]
# Update this column if it's also different.
# Again, assuming it's in the second element of cols: 'GE65_Tot_Benes:\"\"}]'
Tot_Clms = cols[1]

# Example operations using the column names:
print(f"Drug Name column: {Drug_Name}")
print(f"Total Drug Cost column: {Tot_Drug_Cst}")
print(f"Total Claims column: {Tot_Clms}")
# Out:
# 🔎 Columns found in CMS 2020 sample:
# [{"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi"
# Prscrbr_First_Name:"Ardalan"
# Prscrbr_City:"Bethesda"
# Prscrbr_State_Abrvtn:"MD"
# Prscrbr_State_FIPS:"24"
# Prscrbr_Type:"Hospitalist"
# Prscrbr_Type_Src:"Claim-Specialty"
# Brnd_Name:"Eliquis"
# Gnrc_Name:"Apixaban"
# Tot_Clms:"13"
# Tot_30day_Fills:"15.3"
# Tot_Day_Suply:"437"
# Tot_Drug_Cst:"8828.74"
# Tot_Benes:""
# GE65_Sprsn_Flag:"#"
# GE65_Tot_Clms:""
# GE65_Tot_30day_Fills:""
# GE65_Tot_Drug_Cst:""
# GE65_Tot_Day_Suply:""
# GE65_Bene_Sprsn_Flag:"*"
# GE65_Tot_Benes:""}
# {"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi".1
# Prscrbr_First_Name:"Ardalan".1
# Prscrbr_City:"Bethesda".1
# Prscrbr_State_Abrvtn:"MD".1
# Prscrbr_State_FIPS:"24".1
# Prscrbr_Type:"Hospitalist".1
# Prscrbr_Type_Src:"Claim-Specialty".1
# Brnd_Name:"Prednisone"
# Gnrc_Name:"Prednisone"
# Tot_Clms:"14"
# Tot_30day_Fills:"14"
# Tot_Day_Suply:"153"
# Tot_Drug_Cst:"54.98"
# Tot_Benes:"14"
# GE65_Sprsn_Flag:"#".1
# GE65_Tot_Clms:"".1
# GE65_Tot_30day_Fills:"".1
# GE65_Tot_Drug_Cst:"".1
# GE65_Tot_Day_Suply:"".1
# GE65_Bene_Sprsn_Flag:"#"
# GE65_Tot_Benes:""}.1
# {"Prscrbr_NPI":"1003000142"
# Prscrbr_Last_Org_Name:"Khalil"
# Prscrbr_First_Name:"Rashid"
# Prscrbr_City:"Toledo"
# Prscrbr_State_Abrvtn:"OH"
# Prscrbr_State_FIPS:"39"
# Prscrbr_Type:"Anesthesiology"
# Prscrbr_Type_Src:"Claim-Specialty".2
# Brnd_Name:"Acetaminophen-Codeine"
# Gnrc_Name:"Acetaminophen With Codeine"
# Tot_Clms:"43"
# Tot_30day_Fills:"43"
# Tot_Day_Suply:"1020"
# Tot_Drug_Cst:"491.38"
# Tot_Benes:"12"
# GE65_Sprsn_Flag:"#".2
# GE65_Tot_Clms:"".2
# GE65_Tot_30day_Fills:"".2
# GE65_Tot_Drug_Cst:"".2
# GE65_Tot_Day_Suply:"".2
# GE65_Bene_Sprsn_Flag:"*".1
# GE65_Tot_Benes:""}.2
# {"Prscrbr_NPI":"1003000142".1
# Prscrbr_Last_Org_Name:"Khalil".1
# Prscrbr_First_Name:"Rashid".1
# Prscrbr_City:"Toledo".1
# Prscrbr_State_Abrvtn:"OH".1
# Prscrbr_State_FIPS:"39".1
# Prscrbr_Type:"Anesthesiology".1
# Prscrbr_Type_Src:"Claim-Specialty".3
# Brnd_Name:"Amitriptyline Hcl"
# Gnrc_Name:"Amitriptyline Hcl"
# Tot_Clms:"35"
# Tot_30day_Fills:"35"
# Tot_Day_Suply:"1050"
# Tot_Drug_Cst:"471.01"
# Tot_Benes:"15"
# GE65_Sprsn_Flag:"#".3
# GE65_Tot_Clms:"".3
# GE65_Tot_30day_Fills:"".3
# GE65_Tot_Drug_Cst:"".3
# GE65_Tot_Day_Suply:"".3
# GE65_Bene_Sprsn_Flag:"*".2
# GE65_Tot_Benes:""}.3
# {"Prscrbr_NPI":"1003000142".2
# Prscrbr_Last_Org_Name:"Khalil".2
# Prscrbr_First_Name:"Rashid".2
# Prscrbr_City:"Toledo".2
# Prscrbr_State_Abrvtn:"OH".2
# Prscrbr_State_FIPS:"39".2
# Prscrbr_Type:"Anesthesiology".2
# Prscrbr_Type_Src:"Claim-Specialty".4
# Brnd_Name:"Baclofen"
# Gnrc_Name:"Baclofen"
# Tot_Clms:"55"
# Tot_30day_Fills:"63"
# Tot_Day_Suply:"1890"
# Tot_Drug_Cst:"796.1"
# Tot_Benes:"23"
# GE65_Sprsn_Flag:""
# GE65_Tot_Clms:"27"
# GE65_Tot_30day_Fills:"29"
# GE65_Tot_Drug_Cst:"417.86"
# GE65_Tot_Day_Suply:"870"
# GE65_Bene_Sprsn_Flag:"*".3
# GE65_Tot_Benes:""}.4
# {"Prscrbr_NPI":"1003000142".3
# Prscrbr_Last_Org_Name:"Khalil".3
# Prscrbr_First_Name:"Rashid".3
# Prscrbr_City:"Toledo".3
# Prscrbr_State_Abrvtn:"OH".3
# Prscrbr_State_FIPS:"39".3
# Prscrbr_Type:"Anesthesiology".3
# Prscrbr_Type_Src:"Claim-Specialty".5
# Brnd_Name:"Buprenorphine"
# Gnrc_Name:"Buprenorphine"
# Tot_Clms:"16"
# Tot_30day_Fills:"16"
# Tot_Day_Suply:"448"
# Tot_Drug_Cst:"6229.05"
# Tot_Benes:"".1
# GE65_Sprsn_Flag:"*"
# GE65_Tot_Clms:"".4
# GE65_Tot_30day_Fills:"".4
# GE65_Tot_Drug_Cst:"".4
# GE65_Tot_Day_Suply:"".4
# GE65_Bene_Sprsn_Flag:"*".4
# GE65_Tot_Benes:""}.5
# {"Prscrbr_NPI":"1003000142".4
# Prscrbr_Last_Org_Name:"Khalil".4
# Prscrbr_First_Name:"Rashid".4
# Prscrbr_City:"Toledo".4
# Prscrbr_State_Abrvtn:"OH".4
# Prscrbr_State_FIPS:"39".4
# Prscrbr_Type:"Anesthesiology".4
# Prscrbr_Type_Src:"Claim-Specialty".6
# Brnd_Name:"Cyclobenzaprine Hcl"
# Gnrc_Name:"Cyclobenzaprine Hcl"
# Tot_Clms:"54"
# Tot_30day_Fills:"56"
# Tot_Day_Suply:"1645"
# Tot_Drug_Cst:"572.47"
# Tot_Benes:"30"
# GE65_Sprsn_Flag:"".1
# GE65_Tot_Clms:"16"
# GE65_Tot_30day_Fills:"16"
# GE65_Tot_Drug_Cst:"217.6"
# GE65_Tot_Day_Suply:"455"
# GE65_Bene_Sprsn_Flag:""
# GE65_Tot_Benes:"11"}
# {"Prscrbr_NPI":"1003000142".5
# Prscrbr_Last_Org_Name:"Khalil".5
# Prscrbr_First_Name:"Rashid".5
# Prscrbr_City:"Toledo".5
# Prscrbr_State_Abrvtn:"OH".5
# Prscrbr_State_FIPS:"39".5
# Prscrbr_Type:"Anesthesiology".5
# Prscrbr_Type_Src:"Claim-Specialty".7
# Brnd_Name:"Dantrolene Sodium"
# Gnrc_Name:"Dantrolene Sodium"
# Tot_Clms:"14".1
# Tot_30day_Fills:"14".1
# Tot_Day_Suply:"221"
# Tot_Drug_Cst:"236.09"
# Tot_Benes:"13"
# GE65_Sprsn_Flag:"*".1
# GE65_Tot_Clms:"".5
# GE65_Tot_30day_Fills:"".5
# GE65_Tot_Drug_Cst:"".5
# GE65_Tot_Day_Suply:"".5
# GE65_Bene_Sprsn_Flag:"*".5
# GE65_Tot_Benes:""}.6
# {"Prscrbr_NPI":"1003000142".6
# Prscrbr_Last_Org_Name:"Khalil".6
# Prscrbr_First_Name:"Rashid".6
# Prscrbr_City:"Toledo".6
# Prscrbr_State_Abrvtn:"OH".6
# Prscrbr_State_FIPS:"39".6
# Prscrbr_Type:"Anesthesiology".6
# Prscrbr_Type_Src:"Claim-Specialty".8
# Brnd_Name:"Diclofenac Sodium"
# Gnrc_Name:"Diclofenac Sodium"
# Tot_Clms:"82"
# Tot_30day_Fills:"82"
# Tot_Day_Suply:"1629"
# Tot_Drug_Cst:"2423.34"
# Tot_Benes:"42"
# GE65_Sprsn_Flag:"".2
# GE65_Tot_Clms:"42"
# GE65_Tot_30day_Fills:"42"
# GE65_Tot_Drug_Cst:"1374.84"
# GE65_Tot_Day_Suply:"753"
# GE65_Bene_Sprsn_Flag:"".1
# GE65_Tot_Benes:"24"}
# {"Prscrbr_NPI":"1003000142".7
# Prscrbr_Last_Org_Name:"Khalil".7
# Prscrbr_First_Name:"Rashid".7
# Prscrbr_City:"Toledo".7
# Prscrbr_State_Abrvtn:"OH".7
# Prscrbr_State_FIPS:"39".7
# Prscrbr_Type:"Anesthesiology".7
# Prscrbr_Type_Src:"Claim-Specialty".9
# Brnd_Name:"Duloxetine Hcl"
# Gnrc_Name:"Duloxetine Hcl"
# Tot_Clms:"27"
# Tot_30day_Fills:"31"
# Tot_Day_Suply:"930"
# Tot_Drug_Cst:"337.43"
# Tot_Benes:"14".1
# GE65_Sprsn_Flag:"".3
# GE65_Tot_Clms:"11"
# GE65_Tot_30day_Fills:"13"
# GE65_Tot_Drug_Cst:"159.01"
# GE65_Tot_Day_Suply:"390"
# GE65_Bene_Sprsn_Flag:"*".6
# GE65_Tot_Benes:""}.7
# {"Prscrbr_NPI":"1003000142".8
# Prscrbr_Last_Org_Name:"Khalil".8
# Prscrbr_First_Name:"Rashid".8
# Prscrbr_City:"Toledo".8
# Prscrbr_State_Abrvtn:"OH".8
# Prscrbr_State_FIPS:"39".8
# Prscrbr_Type:"Anesthesiology".8
# Prscrbr_Type_Src:"Claim-Specialty".10
# Brnd_Name:"Gabapentin"
# Gnrc_Name:"Gabapentin"
# Tot_Clms:"281"
# Tot_30day_Fills:"345"
# Tot_Day_Suply:"10315"
# Tot_Drug_Cst:"5713.75"
# Tot_Benes:"125"
# GE65_Sprsn_Flag:"".4
# GE65_Tot_Clms:"167"
# GE65_Tot_30day_Fills:"209"
# GE65_Tot_Drug_Cst:"3585.65"
# GE65_Tot_Day_Suply:"6255"
# GE65_Bene_Sprsn_Flag:"".2
# GE65_Tot_Benes:"73"}
# {"Prscrbr_NPI":"1003000142".9
# Prscrbr_Last_Org_Name:"Khalil".9
# Prscrbr_First_Name:"Rashid".9
# Prscrbr_City:"Toledo".9
# Prscrbr_State_Abrvtn:"OH".9
# Prscrbr_State_FIPS:"39".9
# Prscrbr_Type:"Anesthesiology".9
# Prscrbr_Type_Src:"Claim-Specialty".11
# Brnd_Name:"Hydrocodone-Acetaminophen"
# Gnrc_Name:"Hydrocodone\/Acetaminophen"
# Tot_Clms:"355"
# Tot_30day_Fills:"355.5"
# Tot_Day_Suply:"9511"
# Tot_Drug_Cst:"7202.47"
# Tot_Benes:"171"
# GE65_Sprsn_Flag:"".5
# GE65_Tot_Clms:"214"
# GE65_Tot_30day_Fills:"214"
# GE65_Tot_Drug_Cst:"4543.33"
# GE65_Tot_Day_Suply:"5669"
# GE65_Bene_Sprsn_Flag:"".3
# GE65_Tot_Benes:"110"}
# {"Prscrbr_NPI":"1003000142".10
# Prscrbr_Last_Org_Name:"Khalil".10
# Prscrbr_First_Name:"Rashid".10
# Prscrbr_City:"Toledo".10
# Prscrbr_State_Abrvtn:"OH".10
# Prscrbr_State_FIPS:"39".10
# Prscrbr_Type:"Anesthesiology".10
# Prscrbr_Type_Src:"Claim-Specialty".12
# Brnd_Name:"Lidocaine"
# Gnrc_Name:"Lidocaine"
# Tot_Clms:"20"
# Tot_30day_Fills:"20"
# Tot_Day_Suply:"525"
# Tot_Drug_Cst:"2146.83"
# Tot_Benes:"12".1
# GE65_Sprsn_Flag:"#".4
# GE65_Tot_Clms:"".6
# GE65_Tot_30day_Fills:"".6
# GE65_Tot_Drug_Cst:"".6
# GE65_Tot_Day_Suply:"".6
# GE65_Bene_Sprsn_Flag:"*".7
# GE65_Tot_Benes:""}.8
# {"Prscrbr_NPI":"1003000142".11
# Prscrbr_Last_Org_Name:"Khalil".11
# Prscrbr_First_Name:"Rashid".11
# Prscrbr_City:"Toledo".11
# Prscrbr_State_Abrvtn:"OH".11
# Prscrbr_State_FIPS:"39".11
# Prscrbr_Type:"Anesthesiology".11
# Prscrbr_Type_Src:"Claim-Specialty".13
# Brnd_Name:"Meloxicam"
# Gnrc_Name:"Meloxicam"
# Tot_Clms:"57"
# Tot_30day_Fills:"65"
# Tot_Day_Suply:"1948"
# Tot_Drug_Cst:"230.35"
# Tot_Benes:"25"
# GE65_Sprsn_Flag:"".6
# GE65_Tot_Clms:"19"
# GE65_Tot_30day_Fills:"21"
# GE65_Tot_Drug_Cst:"68.52"
# GE65_Tot_Day_Suply:"630"
# GE65_Bene_Sprsn_Flag:"*".8
# GE65_Tot_Benes:""}.9
# {"Prscrbr_NPI":"1003000142".12
# Prscrbr_Last_Org_Name:"Khalil".12
# Prscrbr_First_Name:"Rashid".12
# Prscrbr_City:"Toledo".12
# Prscrbr_State_Abrvtn:"OH".12
# Prscrbr_State_FIPS:"39".12
# Prscrbr_Type:"Anesthesiology".12
# Prscrbr_Type_Src:"Claim-Specialty".14
# Brnd_Name:"Methocarbamol"
# Gnrc_Name:"Methocarbamol"
# Tot_Clms:"14".2
# Tot_30day_Fills:"14".2
# Tot_Day_Suply:"375"
# Tot_Drug_Cst:"231.58"
# Tot_Benes:"".2
# GE65_Sprsn_Flag:"*".2
# GE65_Tot_Clms:"".7
# GE65_Tot_30day_Fills:"".7
# GE65_Tot_Drug_Cst:"".7
# GE65_Tot_Day_Suply:"".7
# GE65_Bene_Sprsn_Flag:"*".9
# GE65_Tot_Benes:""}.10
# {"Prscrbr_NPI":"1003000142".13
# Prscrbr_Last_Org_Name:"Khalil".13
# Prscrbr_First_Name:"Rashid".13
# Prscrbr_City:"Toledo".13
# Prscrbr_State_Abrvtn:"OH".13
# Prscrbr_State_FIPS:"39".13
# Prscrbr_Type:"Anesthesiology".13
# Prscrbr_Type_Src:"Claim-Specialty".15
# Brnd_Name:"Morphine Sulfate Er"
# Gnrc_Name:"Morphine Sulfate"
# Tot_Clms:"35".1
# Tot_30day_Fills:"35".1
# Tot_Day_Suply:"1050".1
# Tot_Drug_Cst:"633.8"
# Tot_Benes:"13".1
# GE65_Sprsn_Flag:"#".5
# GE65_Tot_Clms:"".8
# GE65_Tot_30day_Fills:"".8
# GE65_Tot_Drug_Cst:"".8
# GE65_Tot_Day_Suply:"".8
# GE65_Bene_Sprsn_Flag:"*".10
# GE65_Tot_Benes:""}.11
# {"Prscrbr_NPI":"1003000142".14
# Prscrbr_Last_Org_Name:"Khalil".14
# Prscrbr_First_Name:"Rashid".14
# Prscrbr_City:"Toledo".14
# Prscrbr_State_Abrvtn:"OH".14
# Prscrbr_State_FIPS:"39".14
# Prscrbr_Type:"Anesthesiology".14
# Prscrbr_Type_Src:"Claim-Specialty".16
# Brnd_Name:"Movantik"
# Gnrc_Name:"Naloxegol Oxalate"
# Tot_Clms:"21"
# Tot_30day_Fills:"29"
# Tot_Day_Suply:"844"
# Tot_Drug_Cst:"11694.14"
# Tot_Benes:"13".2
# GE65_Sprsn_Flag:"#".6
# GE65_Tot_Clms:"".9
# GE65_Tot_30day_Fills:"".9
# GE65_Tot_Drug_Cst:"".9
# GE65_Tot_Day_Suply:"".9
# GE65_Bene_Sprsn_Flag:"*".11
# GE65_Tot_Benes:""}.12
# {"Prscrbr_NPI":"1003000142".15
# Prscrbr_Last_Org_Name:"Khalil".15
# Prscrbr_First_Name:"Rashid".15
# Prscrbr_City:"Toledo".15
# Prscrbr_State_Abrvtn:"OH".15
# Prscrbr_State_FIPS:"39".15
# Prscrbr_Type:"Anesthesiology".15
# Prscrbr_Type_Src:"Claim-Specialty".17
# Brnd_Name:"Oxycodone Hcl"
# Gnrc_Name:"Oxycodone Hcl"
# Tot_Clms:"84"
# Tot_30day_Fills:"84"
# Tot_Day_Suply:"2439"
# Tot_Drug_Cst:"1269.35"
# Tot_Benes:"39"
# GE65_Sprsn_Flag:"".7
# GE65_Tot_Clms:"62"
# GE65_Tot_30day_Fills:"62"
# GE65_Tot_Drug_Cst:"983.14"
# GE65_Tot_Day_Suply:"1795"
# GE65_Bene_Sprsn_Flag:"".4
# GE65_Tot_Benes:"27"}
# {"Prscrbr_NPI":"1003000142".16
# Prscrbr_Last_Org_Name:"Khalil".16
# Prscrbr_First_Name:"Rashid".16
# Prscrbr_City:"Toledo".16
# Prscrbr_State_Abrvtn:"OH".16
# Prscrbr_State_FIPS:"39".16
# Prscrbr_Type:"Anesthesiology".16
# Prscrbr_Type_Src:"Claim-Specialty".18
# Brnd_Name:"Oxycodone-Acetaminophen"
# Gnrc_Name:"Oxycodone Hcl\/Acetaminophen"
# Tot_Clms:"194"
# Tot_30day_Fills:"194"
# Tot_Day_Suply:"5644"
# Tot_Drug_Cst:"5029.88"
# Tot_Benes:"94"
# GE65_Sprsn_Flag:"".8
# GE65_Tot_Clms:"94"
# GE65_Tot_30day_Fills:"94"
# GE65_Tot_Drug_Cst:"2155.06"
# GE65_Tot_Day_Suply:"2727"
# GE65_Bene_Sprsn_Flag:"".5
# GE65_Tot_Benes:"48"}
# {"Prscrbr_NPI":"1003000142".17
# Prscrbr_Last_Org_Name:"Khalil".17
# Prscrbr_First_Name:"Rashid".17
# Prscrbr_City:"Toledo".17
# Prscrbr_State_Abrvtn:"OH".17
# Prscrbr_State_FIPS:"39".17
# Prscrbr_Type:"Anesthesiology".17
# Prscrbr_Type_Src:"Claim-Specialty".19
# Brnd_Name:"Pregabalin"
# Gnrc_Name:"Pregabalin"
# Tot_Clms:"143"
# Tot_30day_Fills:"153"
# Tot_Day_Suply:"4425"
# Tot_Drug_Cst:"6575.8"
# Tot_Benes:"58"
# GE65_Sprsn_Flag:"".9
# GE65_Tot_Clms:"61"
# GE65_Tot_30day_Fills:"65"
# GE65_Tot_Drug_Cst:"2168.07"
# GE65_Tot_Day_Suply:"1819"
# GE65_Bene_Sprsn_Flag:"".6
# GE65_Tot_Benes:"27"}.1
# {"Prscrbr_NPI":"1003000142".18
# Prscrbr_Last_Org_Name:"Khalil".18
# Prscrbr_First_Name:"Rashid".18
# Prscrbr_City:"Toledo".18
# Prscrbr_State_Abrvtn:"OH".18
# Prscrbr_State_FIPS:"39".18
# Prscrbr_Type:"Anesthesiology".18
# Prscrbr_Type_Src:"Claim-Specialty".20
# Brnd_Name:"Tizanidine Hcl"
# Gnrc_Name:"Tizanidine Hcl"
# Tot_Clms:"126"
# Tot_30day_Fills:"140"
# Tot_Day_Suply:"4064"
# Tot_Drug_Cst:"1426.75"
# Tot_Benes:"66"
# GE65_Sprsn_Flag:"".10
# GE65_Tot_Clms:"51"
# GE65_Tot_30day_Fills:"51"
# GE65_Tot_Drug_Cst:"515.26"
# GE65_Tot_Day_Suply:"1449"
# GE65_Bene_Sprsn_Flag:"".7
# GE65_Tot_Benes:"29"}
# {"Prscrbr_NPI":"1003000142".19
# Prscrbr_Last_Org_Name:"Khalil".19
# Prscrbr_First_Name:"Rashid".19
# Prscrbr_City:"Toledo".19
# Prscrbr_State_Abrvtn:"OH".19
# Prscrbr_State_FIPS:"39".19
# Prscrbr_Type:"Anesthesiology".19
# Prscrbr_Type_Src:"Claim-Specialty".21
# Brnd_Name:"Topiramate"
# Gnrc_Name:"Topiramate"
# Tot_Clms:"16".1
# Tot_30day_Fills:"22"
# Tot_Day_Suply:"660"
# Tot_Drug_Cst:"199.68"
# Tot_Benes:"".3
# GE65_Sprsn_Flag:"*".3
# GE65_Tot_Clms:"".10
# GE65_Tot_30day_Fills:"".10
# GE65_Tot_Drug_Cst:"".10
# GE65_Tot_Day_Suply:"".10
# GE65_Bene_Sprsn_Flag:"*".12
# GE65_Tot_Benes:""}.13
# {"Prscrbr_NPI":"1003000142".20
# Prscrbr_Last_Org_Name:"Khalil".20
# Prscrbr_First_Name:"Rashid".20
# Prscrbr_City:"Toledo".20
# Prscrbr_State_Abrvtn:"OH".20
# Prscrbr_State_FIPS:"39".20
# Prscrbr_Type:"Anesthesiology".20
# Prscrbr_Type_Src:"Claim-Specialty".22
# Brnd_Name:"Tramadol Hcl"
# Gnrc_Name:"Tramadol Hcl"
# Tot_Clms:"97"
# Tot_30day_Fills:"97"
# Tot_Day_Suply:"2550"
# Tot_Drug_Cst:"529"
# Tot_Benes:"41"
# GE65_Sprsn_Flag:"".11
# GE65_Tot_Clms:"68"
# GE65_Tot_30day_Fills:"68"
# GE65_Tot_Drug_Cst:"344.88"
# GE65_Tot_Day_Suply:"1756"
# GE65_Bene_Sprsn_Flag:"".8
# GE65_Tot_Benes:"29"}.1
# {"Prscrbr_NPI":"1003000167"
# Prscrbr_Last_Org_Name:"Escobar"
# Prscrbr_First_Name:"Julio"
# Prscrbr_City:"Dayton"
# Prscrbr_State_Abrvtn:"NV"
# Prscrbr_State_FIPS:"32"
# Prscrbr_Type:"Dentist"
# Prscrbr_Type_Src:"NPPES-Specialty"
# Brnd_Name:"Amoxicillin"
# Gnrc_Name:"Amoxicillin"
# Tot_Clms:"51"
# Tot_30day_Fills:"51"
# Tot_Day_Suply:"308"
# Tot_Drug_Cst:"152.04"
# Tot_Benes:"43"
# GE65_Sprsn_Flag:"#".7
# GE65_Tot_Clms:"".11
# GE65_Tot_30day_Fills:"".11
# GE65_Tot_Drug_Cst:"".11
# GE65_Tot_Day_Suply:"".11
# GE65_Bene_Sprsn_Flag:"#".1
# GE65_Tot_Benes:""}.14
# {"Prscrbr_NPI":"1003000167".1
# Prscrbr_Last_Org_Name:"Escobar".1
# Prscrbr_First_Name:"Julio".1
# Prscrbr_City:"Dayton".1
# Prscrbr_State_Abrvtn:"NV".1
# Prscrbr_State_FIPS:"32".1
# Prscrbr_Type:"Dentist".1
# Prscrbr_Type_Src:"NPPES-Specialty".1
# Brnd_Name:"Dexamethasone"
# Gnrc_Name:"Dexamethasone"
# Tot_Clms:"20".1
# Tot_30day_Fills:"20".1
# Tot_Day_Suply:"20"
# Tot_Drug_Cst:"38.04"
# Tot_Benes:"17"
# GE65_Sprsn_Flag:"#".8
# GE65_Tot_Clms:"".12
# GE65_Tot_30day_Fills:"".12
# GE65_Tot_Drug_Cst:"".12
# GE65_Tot_Day_Suply:"".12
# GE65_Bene_Sprsn_Flag:"#".2
# GE65_Tot_Benes:""}.15
# {"Prscrbr_NPI":"1003000423"
# Prscrbr_Last_Org_Name:"Velotta"
# Prscrbr_First_Name:"Jennifer"
# Prscrbr_City:"Cleveland"
# Prscrbr_State_Abrvtn:"OH".21
# Prscrbr_State_FIPS:"39".21
# Prscrbr_Type:"Obstetrics \u0026 Gynecology"
# Prscrbr_Type_Src:"Claim-Specialty".23
# Brnd_Name:"Clotrimazole-Betamethasone"
# Gnrc_Name:"Clotrimazole\/Betamethasone Dip"
# Tot_Clms:"19"
# Tot_30day_Fills:"19"
# Tot_Day_Suply:"249"
# Tot_Drug_Cst:"250.55"
# Tot_Benes:"".4
# GE65_Sprsn_Flag:"#".9
# GE65_Tot_Clms:"".13
# GE65_Tot_30day_Fills:"".13
# GE65_Tot_Drug_Cst:"".13
# GE65_Tot_Day_Suply:"".13
# GE65_Bene_Sprsn_Flag:"*".13
# GE65_Tot_Benes:""}.16
# {"Prscrbr_NPI":"1003000423".1
# Prscrbr_Last_Org_Name:"Velotta".1
# Prscrbr_First_Name:"Jennifer".1
# Prscrbr_City:"Cleveland".1
# Prscrbr_State_Abrvtn:"OH".22
# Prscrbr_State_FIPS:"39".22
# Prscrbr_Type:"Obstetrics \u0026 Gynecology".1
# Prscrbr_Type_Src:"Claim-Specialty".24
# Brnd_Name:"Estradiol"
# Gnrc_Name:"Estradiol"
# Tot_Clms:"39"
# Tot_30day_Fills:"112.4"
# Tot_Day_Suply:"3359"
# Tot_Drug_Cst:"5419.72"
# Tot_Benes:"19"
# GE65_Sprsn_Flag:"#".10
# GE65_Tot_Clms:"".14
# GE65_Tot_30day_Fills:"".14
# GE65_Tot_Drug_Cst:"".14
# GE65_Tot_Day_Suply:"".14
# GE65_Bene_Sprsn_Flag:"#".3
# GE65_Tot_Benes:""}.17
# {"Prscrbr_NPI":"1003000480"
# Prscrbr_Last_Org_Name:"Rothchild"
# Prscrbr_First_Name:"Kevin"
# Prscrbr_City:"Aurora"
# Prscrbr_State_Abrvtn:"CO"
# Prscrbr_State_FIPS:"08"
# Prscrbr_Type:"General Surgery"
# Prscrbr_Type_Src:"Claim-Specialty".25
# Brnd_Name:"Omeprazole"
# Gnrc_Name:"Omeprazole"
# Tot_Clms:"16".2
# Tot_30day_Fills:"18.1"
# Tot_Day_Suply:"543"
# Tot_Drug_Cst:"384.12"
# Tot_Benes:"".5
# GE65_Sprsn_Flag:"*".4
# GE65_Tot_Clms:"".15
# GE65_Tot_30day_Fills:"".15
# GE65_Tot_Drug_Cst:"".15
# GE65_Tot_Day_Suply:"".15
# GE65_Bene_Sprsn_Flag:"*".14
# GE65_Tot_Benes:""}.18
# {"Prscrbr_NPI":"1003000480".1
# Prscrbr_Last_Org_Name:"Rothchild".1
# Prscrbr_First_Name:"Kevin".1
# Prscrbr_City:"Aurora".1
# Prscrbr_State_Abrvtn:"CO".1
# Prscrbr_State_FIPS:"08".1
# Prscrbr_Type:"General Surgery".1
# Prscrbr_Type_Src:"Claim-Specialty".26
# Brnd_Name:"Oxycodone Hcl".1
# Gnrc_Name:"Oxycodone Hcl".1
# Tot_Clms:"12"
# Tot_30day_Fills:"12"
# Tot_Day_Suply:"40"
# Tot_Drug_Cst:"25.58"
# Tot_Benes:"12".2
# GE65_Sprsn_Flag:"*".5
# GE65_Tot_Clms:"".16
# GE65_Tot_30day_Fills:"".16
# GE65_Tot_Drug_Cst:"".16
# GE65_Tot_Day_Suply:"".16
# GE65_Bene_Sprsn_Flag:"*".15
# GE65_Tot_Benes:""}.19
# {"Prscrbr_NPI":"1003000530"
# Prscrbr_Last_Org_Name:"Semonche"
# Prscrbr_First_Name:"Amanda"
# Prscrbr_City:"Quakertown"
# Prscrbr_State_Abrvtn:"PA"
# Prscrbr_State_FIPS:"42"
# Prscrbr_Type:"Internal Medicine"
# Prscrbr_Type_Src:"Claim-Specialty".27
# Brnd_Name:"Advair Diskus"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol"
# Tot_Clms:"18"
# Tot_30day_Fills:"25"
# Tot_Day_Suply:"750"
# Tot_Drug_Cst:"8222.59"
# Tot_Benes:"".6
# GE65_Sprsn_Flag:"".12
# GE65_Tot_Clms:"18"
# GE65_Tot_30day_Fills:"25"
# GE65_Tot_Drug_Cst:"8222.59"
# GE65_Tot_Day_Suply:"750"
# GE65_Bene_Sprsn_Flag:"*".16
# GE65_Tot_Benes:""}.20
# {"Prscrbr_NPI":"1003000530".1
# Prscrbr_Last_Org_Name:"Semonche".1
# Prscrbr_First_Name:"Amanda".1
# Prscrbr_City:"Quakertown".1
# Prscrbr_State_Abrvtn:"PA".1
# Prscrbr_State_FIPS:"42".1
# Prscrbr_Type:"Internal Medicine".1
# Prscrbr_Type_Src:"Claim-Specialty".28
# Brnd_Name:"Albuterol Sulfate Hfa"
# Gnrc_Name:"Albuterol Sulfate"
# Tot_Clms:"54".1
# Tot_30day_Fills:"59.9"
# Tot_Day_Suply:"1385"
# Tot_Drug_Cst:"1900.5"
# Tot_Benes:"24"
# GE65_Sprsn_Flag:"#".11
# GE65_Tot_Clms:"".17
# GE65_Tot_30day_Fills:"".17
# GE65_Tot_Drug_Cst:"".17
# GE65_Tot_Day_Suply:"".17
# GE65_Bene_Sprsn_Flag:"#".4
# GE65_Tot_Benes:""}.21
# {"Prscrbr_NPI":"1003000530".2
# Prscrbr_Last_Org_Name:"Semonche".2
# Prscrbr_First_Name:"Amanda".2
# Prscrbr_City:"Quakertown".2
# Prscrbr_State_Abrvtn:"PA".2
# Prscrbr_State_FIPS:"42".2
# Prscrbr_Type:"Internal Medicine".2
# Prscrbr_Type_Src:"Claim-Specialty".29
# Brnd_Name:"Alendronate Sodium"
# Gnrc_Name:"Alendronate Sodium"
# Tot_Clms:"68"
# Tot_30day_Fills:"155.1"
# Tot_Day_Suply:"4611"
# Tot_Drug_Cst:"876.77"
# Tot_Benes:"17".1
# GE65_Sprsn_Flag:"".13
# GE65_Tot_Clms:"68".1
# GE65_Tot_30day_Fills:"155.1"
# GE65_Tot_Drug_Cst:"876.77"
# GE65_Tot_Day_Suply:"4611"
# GE65_Bene_Sprsn_Flag:"".9
# GE65_Tot_Benes:"17"}
# {"Prscrbr_NPI":"1003000530".3
# Prscrbr_Last_Org_Name:"Semonche".3
# Prscrbr_First_Name:"Amanda".3
# Prscrbr_City:"Quakertown".3
# Prscrbr_State_Abrvtn:"PA".3
# Prscrbr_State_FIPS:"42".3
# Prscrbr_Type:"Internal Medicine".3
# Prscrbr_Type_Src:"Claim-Specialty".30
# Brnd_Name:"Alfuzosin Hcl Er"
# Gnrc_Name:"Alfuzosin Hcl"
# Tot_Clms:"13".1
# Tot_30day_Fills:"13"
# Tot_Day_Suply:"390"
# Tot_Drug_Cst:"121.14"
# Tot_Benes:"".7
# GE65_Sprsn_Flag:"".14
# GE65_Tot_Clms:"13"
# GE65_Tot_30day_Fills:"13".1
# GE65_Tot_Drug_Cst:"121.14"
# GE65_Tot_Day_Suply:"390".1
# GE65_Bene_Sprsn_Flag:"*".17
# GE65_Tot_Benes:""}.22
# {"Prscrbr_NPI":"1003000530".4
# Prscrbr_Last_Org_Name:"Semonche".4
# Prscrbr_First_Name:"Amanda".4
# Prscrbr_City:"Quakertown".4
# Prscrbr_State_Abrvtn:"PA".4
# Prscrbr_State_FIPS:"42".4
# Prscrbr_Type:"Internal Medicine".4
# Prscrbr_Type_Src:"Claim-Specialty".31
# Brnd_Name:"Allopurinol"
# Gnrc_Name:"Allopurinol"
# Tot_Clms:"57".1
# Tot_30day_Fills:"155"
# Tot_Day_Suply:"4650"
# Tot_Drug_Cst:"927.53"
# Tot_Benes:"14".2
# GE65_Sprsn_Flag:"".15
# GE65_Tot_Clms:"57"
# GE65_Tot_30day_Fills:"155"
# GE65_Tot_Drug_Cst:"927.53"
# GE65_Tot_Day_Suply:"4650"
# GE65_Bene_Sprsn_Flag:"".10
# GE65_Tot_Benes:"14"}
# {"Prscrbr_NPI":"1003000530".5
# Prscrbr_Last_Org_Name:"Semonche".5
# Prscrbr_First_Name:"Amanda".5
# Prscrbr_City:"Quakertown".5
# Prscrbr_State_Abrvtn:"PA".5
# Prscrbr_State_FIPS:"42".5
# Prscrbr_Type:"Internal Medicine".5
# Prscrbr_Type_Src:"Claim-Specialty".32
# Brnd_Name:"Alprazolam"
# Gnrc_Name:"Alprazolam"
# Tot_Clms:"31"
# Tot_30day_Fills:"54"
# Tot_Day_Suply:"1590"
# Tot_Drug_Cst:"194.85"
# Tot_Benes:"11"
# GE65_Sprsn_Flag:"#".12
# GE65_Tot_Clms:"".18
# GE65_Tot_30day_Fills:"".18
# GE65_Tot_Drug_Cst:"".18
# GE65_Tot_Day_Suply:"".18
# GE65_Bene_Sprsn_Flag:"*".18
# GE65_Tot_Benes:""}.23
# {"Prscrbr_NPI":"1003000530".6
# Prscrbr_Last_Org_Name:"Semonche".6
# Prscrbr_First_Name:"Amanda".6
# Prscrbr_City:"Quakertown".6
# Prscrbr_State_Abrvtn:"PA".6
# Prscrbr_State_FIPS:"42".6
# Prscrbr_Type:"Internal Medicine".6
# Prscrbr_Type_Src:"Claim-Specialty".33
# Brnd_Name:"Amiodarone Hcl"
# Gnrc_Name:"Amiodarone Hcl"
# Tot_Clms:"12".1
# Tot_30day_Fills:"12".1
# Tot_Day_Suply:"360"
# Tot_Drug_Cst:"122.76"
# Tot_Benes:"".8
# GE65_Sprsn_Flag:"".16
# GE65_Tot_Clms:"12"
# GE65_Tot_30day_Fills:"12"
# GE65_Tot_Drug_Cst:"122.76"
# GE65_Tot_Day_Suply:"360"
# GE65_Bene_Sprsn_Flag:"*".19
# GE65_Tot_Benes:""}.24
# {"Prscrbr_NPI":"1003000530".7
# Prscrbr_Last_Org_Name:"Semonche".7
# Prscrbr_First_Name:"Amanda".7
# Prscrbr_City:"Quakertown".7
# Prscrbr_State_Abrvtn:"PA".7
# Prscrbr_State_FIPS:"42".7
# Prscrbr_Type:"Internal Medicine".7
# Prscrbr_Type_Src:"Claim-Specialty".34
# Brnd_Name:"Amlodipine Besylate"
# Gnrc_Name:"Amlodipine Besylate"
# Tot_Clms:"419"
# Tot_30day_Fills:"976.7"
# Tot_Day_Suply:"29238"
# Tot_Drug_Cst:"3238.1"
# Tot_Benes:"101"
# GE65_Sprsn_Flag:"".17
# GE65_Tot_Clms:"403"
# GE65_Tot_30day_Fills:"956.5"
# GE65_Tot_Drug_Cst:"3171.72"
# GE65_Tot_Day_Suply:"28664"
# GE65_Bene_Sprsn_Flag:"#".5
# GE65_Tot_Benes:""}.25
# {"Prscrbr_NPI":"1003000530".8
# Prscrbr_Last_Org_Name:"Semonche".8
# Prscrbr_First_Name:"Amanda".8
# Prscrbr_City:"Quakertown".8
# Prscrbr_State_Abrvtn:"PA".8
# Prscrbr_State_FIPS:"42".8
# Prscrbr_Type:"Internal Medicine".8
# Prscrbr_Type_Src:"Claim-Specialty".35
# Brnd_Name:"Amoxicillin-Clavulanate Potass"
# Gnrc_Name:"Amoxicillin\/Potassium Clav"
# Tot_Clms:"29"
# Tot_30day_Fills:"29".1
# Tot_Day_Suply:"204"
# Tot_Drug_Cst:"299.35"
# Tot_Benes:"28"
# GE65_Sprsn_Flag:"#".13
# GE65_Tot_Clms:"".19
# GE65_Tot_30day_Fills:"".19
# GE65_Tot_Drug_Cst:"".19
# GE65_Tot_Day_Suply:"".19
# GE65_Bene_Sprsn_Flag:"#".6
# GE65_Tot_Benes:""}.26
# {"Prscrbr_NPI":"1003000530".9
# Prscrbr_Last_Org_Name:"Semonche".9
# Prscrbr_First_Name:"Amanda".9
# Prscrbr_City:"Quakertown".9
# Prscrbr_State_Abrvtn:"PA".9
# Prscrbr_State_FIPS:"42".9
# Prscrbr_Type:"Internal Medicine".9
# Prscrbr_Type_Src:"Claim-Specialty".36
# Brnd_Name:"Aripiprazole"
# Gnrc_Name:"Aripiprazole"
# Tot_Clms:"24"
# Tot_30day_Fills:"36"
# Tot_Day_Suply:"1080"
# Tot_Drug_Cst:"1879.6"
# Tot_Benes:"".9
# GE65_Sprsn_Flag:"#".14
# GE65_Tot_Clms:"".20
# GE65_Tot_30day_Fills:"".20
# GE65_Tot_Drug_Cst:"".20
# GE65_Tot_Day_Suply:"".20
# GE65_Bene_Sprsn_Flag:"*".20
# GE65_Tot_Benes:""}.27
# {"Prscrbr_NPI":"1003000530".10
# Prscrbr_Last_Org_Name:"Semonche".10
# Prscrbr_First_Name:"Amanda".10
# Prscrbr_City:"Quakertown".10
# Prscrbr_State_Abrvtn:"PA".10
# Prscrbr_State_FIPS:"42".10
# Prscrbr_Type:"Internal Medicine".10
# Prscrbr_Type_Src:"Claim-Specialty".37
# Brnd_Name:"Atenolol"
# Gnrc_Name:"Atenolol"
# Tot_Clms:"26"
# Tot_30day_Fills:"78"
# Tot_Day_Suply:"2340"
# Tot_Drug_Cst:"142.77"
# Tot_Benes:"".10
# GE65_Sprsn_Flag:"".18
# GE65_Tot_Clms:"26"
# GE65_Tot_30day_Fills:"78"
# GE65_Tot_Drug_Cst:"142.77"
# GE65_Tot_Day_Suply:"2340"
# GE65_Bene_Sprsn_Flag:"*".21
# GE65_Tot_Benes:""}.28
# {"Prscrbr_NPI":"1003000530".11
# Prscrbr_Last_Org_Name:"Semonche".11
# Prscrbr_First_Name:"Amanda".11
# Prscrbr_City:"Quakertown".11
# Prscrbr_State_Abrvtn:"PA".11
# Prscrbr_State_FIPS:"42".11
# Prscrbr_Type:"Internal Medicine".11
# Prscrbr_Type_Src:"Claim-Specialty".38
# Brnd_Name:"Atorvastatin Calcium"
# Gnrc_Name:"Atorvastatin Calcium"
# Tot_Clms:"470"
# Tot_30day_Fills:"1154.7"
# Tot_Day_Suply:"34590"
# Tot_Drug_Cst:"5690.05"
# Tot_Benes:"112"
# GE65_Sprsn_Flag:"".19
# GE65_Tot_Clms:"453"
# GE65_Tot_30day_Fills:"1117.7"
# GE65_Tot_Drug_Cst:"5225.24"
# GE65_Tot_Day_Suply:"33480"
# GE65_Bene_Sprsn_Flag:"#".7
# GE65_Tot_Benes:""}.29
# {"Prscrbr_NPI":"1003000530".12
# Prscrbr_Last_Org_Name:"Semonche".12
# Prscrbr_First_Name:"Amanda".12
# Prscrbr_City:"Quakertown".12
# Prscrbr_State_Abrvtn:"PA".12
# Prscrbr_State_FIPS:"42".12
# Prscrbr_Type:"Internal Medicine".12
# Prscrbr_Type_Src:"Claim-Specialty".39
# Brnd_Name:"Benazepril Hcl"
# Gnrc_Name:"Benazepril Hcl"
# Tot_Clms:"13".2
# Tot_30day_Fills:"37"
# Tot_Day_Suply:"1110"
# Tot_Drug_Cst:"282.77"
# Tot_Benes:"".11
# GE65_Sprsn_Flag:"".20
# GE65_Tot_Clms:"13".1
# GE65_Tot_30day_Fills:"37"
# GE65_Tot_Drug_Cst:"282.77"
# GE65_Tot_Day_Suply:"1110"
# GE65_Bene_Sprsn_Flag:"*".22
# GE65_Tot_Benes:""}.30
# {"Prscrbr_NPI":"1003000530".13
# Prscrbr_Last_Org_Name:"Semonche".13
# Prscrbr_First_Name:"Amanda".13
# Prscrbr_City:"Quakertown".13
# Prscrbr_State_Abrvtn:"PA".13
# Prscrbr_State_FIPS:"42".13
# Prscrbr_Type:"Internal Medicine".13
# Prscrbr_Type_Src:"Claim-Specialty".40
# Brnd_Name:"Bupropion Hcl Sr"
# Gnrc_Name:"Bupropion Hcl"
# Tot_Clms:"25"
# Tot_30day_Fills:"33.5"
# Tot_Day_Suply:"1005"
# Tot_Drug_Cst:"258.44"
# Tot_Benes:"".12
# GE65_Sprsn_Flag:"".21
# GE65_Tot_Clms:"25"
# GE65_Tot_30day_Fills:"33.5"
# GE65_Tot_Drug_Cst:"258.44"
# GE65_Tot_Day_Suply:"1005"
# GE65_Bene_Sprsn_Flag:"*".23
# GE65_Tot_Benes:""}.31
# {"Prscrbr_NPI":"1003000530".14
# Prscrbr_Last_Org_Name:"Semonche".14
# Prscrbr_First_Name:"Amanda".14
# Prscrbr_City:"Quakertown".14
# Prscrbr_State_Abrvtn:"PA".14
# Prscrbr_State_FIPS:"42".14
# Prscrbr_Type:"Internal Medicine".14
# Prscrbr_Type_Src:"Claim-Specialty".41
# Brnd_Name:"Bupropion Xl"
# Gnrc_Name:"Bupropion Hcl".1
# Tot_Clms:"85"
# Tot_30day_Fills:"191"
# Tot_Day_Suply:"5714"
# Tot_Drug_Cst:"2770.34"
# Tot_Benes:"18"
# GE65_Sprsn_Flag:"".22
# GE65_Tot_Clms:"71"
# GE65_Tot_30day_Fills:"159"
# GE65_Tot_Drug_Cst:"2514.77"
# GE65_Tot_Day_Suply:"4770"
# GE65_Bene_Sprsn_Flag:"#".8
# GE65_Tot_Benes:""}.32
# {"Prscrbr_NPI":"1003000530".15
# Prscrbr_Last_Org_Name:"Semonche".15
# Prscrbr_First_Name:"Amanda".15
# Prscrbr_City:"Quakertown".15
# Prscrbr_State_Abrvtn:"PA".15
# Prscrbr_State_FIPS:"42".15
# Prscrbr_Type:"Internal Medicine".15
# Prscrbr_Type_Src:"Claim-Specialty".42
# Brnd_Name:"Buspirone Hcl"
# Gnrc_Name:"Buspirone Hcl"
# Tot_Clms:"13".3
# Tot_30day_Fills:"31".1
# Tot_Day_Suply:"930".1
# Tot_Drug_Cst:"82.61"
# Tot_Benes:"".13
# GE65_Sprsn_Flag:"".23
# GE65_Tot_Clms:"13".2
# GE65_Tot_30day_Fills:"31"
# GE65_Tot_Drug_Cst:"82.61"
# GE65_Tot_Day_Suply:"930"
# GE65_Bene_Sprsn_Flag:"*".24
# GE65_Tot_Benes:""}.33
# {"Prscrbr_NPI":"1003000530".16
# Prscrbr_Last_Org_Name:"Semonche".16
# Prscrbr_First_Name:"Amanda".16
# Prscrbr_City:"Quakertown".16
# Prscrbr_State_Abrvtn:"PA".16
# Prscrbr_State_FIPS:"42".16
# Prscrbr_Type:"Internal Medicine".16
# Prscrbr_Type_Src:"Claim-Specialty".43
# Brnd_Name:"Butalbital-Acetaminophen-Caffe"
# Gnrc_Name:"Butalb\/Acetaminophen\/Caffeine"
# Tot_Clms:"14".3
# Tot_30day_Fills:"15"
# Tot_Day_Suply:"450"
# Tot_Drug_Cst:"463.9"
# Tot_Benes:"".14
# GE65_Sprsn_Flag:"".24
# GE65_Tot_Clms:"14"
# GE65_Tot_30day_Fills:"15"
# GE65_Tot_Drug_Cst:"463.9"
# GE65_Tot_Day_Suply:"450"
# GE65_Bene_Sprsn_Flag:"*".25
# GE65_Tot_Benes:""}.34
# {"Prscrbr_NPI":"1003000530".17
# Prscrbr_Last_Org_Name:"Semonche".17
# Prscrbr_First_Name:"Amanda".17
# Prscrbr_City:"Quakertown".17
# Prscrbr_State_Abrvtn:"PA".17
# Prscrbr_State_FIPS:"42".17
# Prscrbr_Type:"Internal Medicine".17
# Prscrbr_Type_Src:"Claim-Specialty".44
# Brnd_Name:"Calcitriol"
# Gnrc_Name:"Calcitriol"
# Tot_Clms:"12".2
# Tot_30day_Fills:"12.2"
# Tot_Day_Suply:"365"
# Tot_Drug_Cst:"328.47"
# Tot_Benes:"".15
# GE65_Sprsn_Flag:"".25
# GE65_Tot_Clms:"0"
# GE65_Tot_30day_Fills:"0"
# GE65_Tot_Drug_Cst:"0"
# GE65_Tot_Day_Suply:"0"
# GE65_Bene_Sprsn_Flag:"#".9
# GE65_Tot_Benes:""}.35
# {"Prscrbr_NPI":"1003000530".18
# Prscrbr_Last_Org_Name:"Semonche".18
# Prscrbr_First_Name:"Amanda".18
# Prscrbr_City:"Quakertown".18
# Prscrbr_State_Abrvtn:"PA".18
# Prscrbr_State_FIPS:"42".18
# Prscrbr_Type:"Internal Medicine".18
# Prscrbr_Type_Src:"Claim-Specialty".45
# Brnd_Name:"Carvedilol"
# Gnrc_Name:"Carvedilol"
# Tot_Clms:"23"
# Tot_30day_Fills:"60"
# Tot_Day_Suply:"1800"
# Tot_Drug_Cst:"391.49"
# Tot_Benes:"".16
# GE65_Sprsn_Flag:"#".15
# GE65_Tot_Clms:"".21
# GE65_Tot_30day_Fills:"".21
# GE65_Tot_Drug_Cst:"".21
# GE65_Tot_Day_Suply:"".21
# GE65_Bene_Sprsn_Flag:"*".26
# GE65_Tot_Benes:""}.36
# {"Prscrbr_NPI":"1003000530".19
# Prscrbr_Last_Org_Name:"Semonche".19
# Prscrbr_First_Name:"Amanda".19
# Prscrbr_City:"Quakertown".19
# Prscrbr_State_Abrvtn:"PA".19
# Prscrbr_State_FIPS:"42".19
# Prscrbr_Type:"Internal Medicine".19
# Prscrbr_Type_Src:"Claim-Specialty".46
# Brnd_Name:"Cephalexin"
# Gnrc_Name:"Cephalexin"
# Tot_Clms:"12".3
# Tot_30day_Fills:"12".2
# Tot_Day_Suply:"110"
# Tot_Drug_Cst:"43.42"
# Tot_Benes:"12".3
# GE65_Sprsn_Flag:"#".16
# GE65_Tot_Clms:"".22
# GE65_Tot_30day_Fills:"".22
# GE65_Tot_Drug_Cst:"".22
# GE65_Tot_Day_Suply:"".22
# GE65_Bene_Sprsn_Flag:"#".10
# GE65_Tot_Benes:""}.37
# {"Prscrbr_NPI":"1003000530".20
# Prscrbr_Last_Org_Name:"Semonche".20
# Prscrbr_First_Name:"Amanda".20
# Prscrbr_City:"Quakertown".20
# Prscrbr_State_Abrvtn:"PA".20
# Prscrbr_State_FIPS:"42".20
# Prscrbr_Type:"Internal Medicine".20
# Prscrbr_Type_Src:"Claim-Specialty".47
# Brnd_Name:"Chlorhexidine Gluconate"
# Gnrc_Name:"Chlorhexidine Gluconate"
# Tot_Clms:"20".2
# Tot_30day_Fills:"20".2
# Tot_Day_Suply:"345"
# Tot_Drug_Cst:"116.2"
# Tot_Benes:"".17
# GE65_Sprsn_Flag:"".26
# GE65_Tot_Clms:"0".1
# GE65_Tot_30day_Fills:"0".1
# GE65_Tot_Drug_Cst:"0".1
# GE65_Tot_Day_Suply:"0".1
# GE65_Bene_Sprsn_Flag:"#".11
# GE65_Tot_Benes:""}.38
# {"Prscrbr_NPI":"1003000530".21
# Prscrbr_Last_Org_Name:"Semonche".21
# Prscrbr_First_Name:"Amanda".21
# Prscrbr_City:"Quakertown".21
# Prscrbr_State_Abrvtn:"PA".21
# Prscrbr_State_FIPS:"42".21
# Prscrbr_Type:"Internal Medicine".21
# Prscrbr_Type_Src:"Claim-Specialty".48
# Brnd_Name:"Citalopram Hbr"
# Gnrc_Name:"Citalopram Hydrobromide"
# Tot_Clms:"39".1
# Tot_30day_Fills:"81"
# Tot_Day_Suply:"2430"
# Tot_Drug_Cst:"228.34"
# Tot_Benes:"".18
# GE65_Sprsn_Flag:"".27
# GE65_Tot_Clms:"39"
# GE65_Tot_30day_Fills:"81"
# GE65_Tot_Drug_Cst:"228.34"
# GE65_Tot_Day_Suply:"2430"
# GE65_Bene_Sprsn_Flag:"*".27
# GE65_Tot_Benes:""}.39
# {"Prscrbr_NPI":"1003000530".22
# Prscrbr_Last_Org_Name:"Semonche".22
# Prscrbr_First_Name:"Amanda".22
# Prscrbr_City:"Quakertown".22
# Prscrbr_State_Abrvtn:"PA".22
# Prscrbr_State_FIPS:"42".22
# Prscrbr_Type:"Internal Medicine".22
# Prscrbr_Type_Src:"Claim-Specialty".49
# Brnd_Name:"Clonazepam"
# Gnrc_Name:"Clonazepam"
# Tot_Clms:"35".2
# Tot_30day_Fills:"45"
# Tot_Day_Suply:"1341"
# Tot_Drug_Cst:"386.75"
# Tot_Benes:"".19
# GE65_Sprsn_Flag:"".28
# GE65_Tot_Clms:"22"
# GE65_Tot_30day_Fills:"32"
# GE65_Tot_Drug_Cst:"258.27"
# GE65_Tot_Day_Suply:"951"
# GE65_Bene_Sprsn_Flag:"*".28
# GE65_Tot_Benes:""}.40
# {"Prscrbr_NPI":"1003000530".23
# Prscrbr_Last_Org_Name:"Semonche".23
# Prscrbr_First_Name:"Amanda".23
# Prscrbr_City:"Quakertown".23
# Prscrbr_State_Abrvtn:"PA".23
# Prscrbr_State_FIPS:"42".23
# Prscrbr_Type:"Internal Medicine".23
# Prscrbr_Type_Src:"Claim-Specialty".50
# Brnd_Name:"Clonidine Hcl"
# Gnrc_Name:"Clonidine Hcl"
# Tot_Clms:"13".4
# Tot_30day_Fills:"27.6"
# Tot_Day_Suply:"827"
# Tot_Drug_Cst:"48.65"
# Tot_Benes:"".20
# GE65_Sprsn_Flag:"".29
# GE65_Tot_Clms:"13".3
# GE65_Tot_30day_Fills:"27.6"
# GE65_Tot_Drug_Cst:"48.65"
# GE65_Tot_Day_Suply:"827"
# GE65_Bene_Sprsn_Flag:"*".29
# GE65_Tot_Benes:""}.41
# {"Prscrbr_NPI":"1003000530".24
# Prscrbr_Last_Org_Name:"Semonche".24
# Prscrbr_First_Name:"Amanda".24
# Prscrbr_City:"Quakertown".24
# Prscrbr_State_Abrvtn:"PA".24
# Prscrbr_State_FIPS:"42".24
# Prscrbr_Type:"Internal Medicine".24
# Prscrbr_Type_Src:"Claim-Specialty".51
# Brnd_Name:"Clopidogrel"
# Gnrc_Name:"Clopidogrel Bisulfate"
# Tot_Clms:"85".1
# Tot_30day_Fills:"188"
# Tot_Day_Suply:"5630"
# Tot_Drug_Cst:"1640.22"
# Tot_Benes:"19".1
# GE65_Sprsn_Flag:"".30
# GE65_Tot_Clms:"85"
# GE65_Tot_30day_Fills:"188"
# GE65_Tot_Drug_Cst:"1640.22"
# GE65_Tot_Day_Suply:"5630"
# GE65_Bene_Sprsn_Flag:"".11
# GE65_Tot_Benes:"19"}
# {"Prscrbr_NPI":"1003000530".25
# Prscrbr_Last_Org_Name:"Semonche".25
# Prscrbr_First_Name:"Amanda".25
# Prscrbr_City:"Quakertown".25
# Prscrbr_State_Abrvtn:"PA".25
# Prscrbr_State_FIPS:"42".25
# Prscrbr_Type:"Internal Medicine".25
# Prscrbr_Type_Src:"Claim-Specialty".52
# Brnd_Name:"Cyclobenzaprine Hcl".1
# Gnrc_Name:"Cyclobenzaprine Hcl".1
# Tot_Clms:"11"
# Tot_30day_Fills:"11"
# Tot_Day_Suply:"110".1
# Tot_Drug_Cst:"41.17"
# Tot_Benes:"".21
# GE65_Sprsn_Flag:"*".6
# GE65_Tot_Clms:"".23
# GE65_Tot_30day_Fills:"".23
# GE65_Tot_Drug_Cst:"".23
# GE65_Tot_Day_Suply:"".23
# GE65_Bene_Sprsn_Flag:"*".30
# GE65_Tot_Benes:""}.42
# {"Prscrbr_NPI":"1003000530".26
# Prscrbr_Last_Org_Name:"Semonche".26
# Prscrbr_First_Name:"Amanda".26
# Prscrbr_City:"Quakertown".26
# Prscrbr_State_Abrvtn:"PA".26
# Prscrbr_State_FIPS:"42".26
# Prscrbr_Type:"Internal Medicine".26
# Prscrbr_Type_Src:"Claim-Specialty".53
# Brnd_Name:"Dexlansoprazole Dr"
# Gnrc_Name:"Dexlansoprazole"
# Tot_Clms:"13".5
# Tot_30day_Fills:"24"
# Tot_Day_Suply:"720"
# Tot_Drug_Cst:"5600.13"
# Tot_Benes:"".22
# GE65_Sprsn_Flag:"".31
# GE65_Tot_Clms:"13".4
# GE65_Tot_30day_Fills:"24"
# GE65_Tot_Drug_Cst:"5600.13"
# GE65_Tot_Day_Suply:"720"
# GE65_Bene_Sprsn_Flag:"*".31
# GE65_Tot_Benes:""}.43
# {"Prscrbr_NPI":"1003000530".27
# Prscrbr_Last_Org_Name:"Semonche".27
# Prscrbr_First_Name:"Amanda".27
# Prscrbr_City:"Quakertown".27
# Prscrbr_State_Abrvtn:"PA".27
# Prscrbr_State_FIPS:"42".27
# Prscrbr_Type:"Internal Medicine".27
# Prscrbr_Type_Src:"Claim-Specialty".54
# Brnd_Name:"Diazepam"
# Gnrc_Name:"Diazepam"
# Tot_Clms:"16".3
# Tot_30day_Fills:"16".1
# Tot_Day_Suply:"199"
# Tot_Drug_Cst:"41.64"
# Tot_Benes:"".23
# GE65_Sprsn_Flag:"*".7
# GE65_Tot_Clms:"".24
# GE65_Tot_30day_Fills:"".24
# GE65_Tot_Drug_Cst:"".24
# GE65_Tot_Day_Suply:"".24
# GE65_Bene_Sprsn_Flag:"*".32
# GE65_Tot_Benes:""}.44
# {"Prscrbr_NPI":"1003000530".28
# Prscrbr_Last_Org_Name:"Semonche".28
# Prscrbr_First_Name:"Amanda".28
# Prscrbr_City:"Quakertown".28
# Prscrbr_State_Abrvtn:"PA".28
# Prscrbr_State_FIPS:"42".28
# Prscrbr_Type:"Internal Medicine".28
# Prscrbr_Type_Src:"Claim-Specialty".55
# Brnd_Name:"Diclofenac Sodium".1
# Gnrc_Name:"Diclofenac Sodium".1
# Tot_Clms:"14".4
# Tot_30day_Fills:"14".3
# Tot_Day_Suply:"260"
# Tot_Drug_Cst:"307.2"
# Tot_Benes:"".24
# GE65_Sprsn_Flag:"#".17
# GE65_Tot_Clms:"".25
# GE65_Tot_30day_Fills:"".25
# GE65_Tot_Drug_Cst:"".25
# GE65_Tot_Day_Suply:"".25
# GE65_Bene_Sprsn_Flag:"*".33
# GE65_Tot_Benes:""}.45
# {"Prscrbr_NPI":"1003000530".29
# Prscrbr_Last_Org_Name:"Semonche".29
# Prscrbr_First_Name:"Amanda".29
# Prscrbr_City:"Quakertown".29
# Prscrbr_State_Abrvtn:"PA".29
# Prscrbr_State_FIPS:"42".29
# Prscrbr_Type:"Internal Medicine".29
# Prscrbr_Type_Src:"Claim-Specialty".56
# Brnd_Name:"Diltiazem 24hr Er (Cd)"
# Gnrc_Name:"Diltiazem Hcl"
# Tot_Clms:"14".5
# Tot_30day_Fills:"14".4
# Tot_Day_Suply:"420"
# Tot_Drug_Cst:"232.74"
# Tot_Benes:"".25
# GE65_Sprsn_Flag:"".32
# GE65_Tot_Clms:"14".1
# GE65_Tot_30day_Fills:"14"
# GE65_Tot_Drug_Cst:"232.74"
# GE65_Tot_Day_Suply:"420"
# GE65_Bene_Sprsn_Flag:"*".34
# GE65_Tot_Benes:""}.46
# {"Prscrbr_NPI":"1003000530".30
# Prscrbr_Last_Org_Name:"Semonche".30
# Prscrbr_First_Name:"Amanda".30
# Prscrbr_City:"Quakertown".30
# Prscrbr_State_Abrvtn:"PA".30
# Prscrbr_State_FIPS:"42".30
# Prscrbr_Type:"Internal Medicine".30
# Prscrbr_Type_Src:"Claim-Specialty".57
# Brnd_Name:"Dofetilide"
# Gnrc_Name:"Dofetilide"
# Tot_Clms:"14".6
# Tot_30day_Fills:"14".5
# Tot_Day_Suply:"409"
# Tot_Drug_Cst:"312.85"
# Tot_Benes:"".26
# GE65_Sprsn_Flag:"".33
# GE65_Tot_Clms:"14".2
# GE65_Tot_30day_Fills:"14".1
# GE65_Tot_Drug_Cst:"312.85"
# GE65_Tot_Day_Suply:"409"
# GE65_Bene_Sprsn_Flag:"*".35
# GE65_Tot_Benes:""}.47
# {"Prscrbr_NPI":"1003000530".31
# Prscrbr_Last_Org_Name:"Semonche".31
# Prscrbr_First_Name:"Amanda".31
# Prscrbr_City:"Quakertown".31
# Prscrbr_State_Abrvtn:"PA".31
# Prscrbr_State_FIPS:"42".31
# Prscrbr_Type:"Internal Medicine".31
# Prscrbr_Type_Src:"Claim-Specialty".58
# Brnd_Name:"Donepezil Hcl"
# Gnrc_Name:"Donepezil Hcl"
# Tot_Clms:"20".3
# Tot_30day_Fills:"30"
# Tot_Day_Suply:"900"
# Tot_Drug_Cst:"289.85"
# Tot_Benes:"".27
# GE65_Sprsn_Flag:"".34
# GE65_Tot_Clms:"20"
# GE65_Tot_30day_Fills:"30"
# GE65_Tot_Drug_Cst:"289.85"
# GE65_Tot_Day_Suply:"900"
# GE65_Bene_Sprsn_Flag:"*".36
# GE65_Tot_Benes:""}.48
# {"Prscrbr_NPI":"1003000530".32
# Prscrbr_Last_Org_Name:"Semonche".32
# Prscrbr_First_Name:"Amanda".32
# Prscrbr_City:"Quakertown".32
# Prscrbr_State_Abrvtn:"PA".32
# Prscrbr_State_FIPS:"42".32
# Prscrbr_Type:"Internal Medicine".32
# Prscrbr_Type_Src:"Claim-Specialty".59
# Brnd_Name:"Doxazosin Mesylate"
# Gnrc_Name:"Doxazosin Mesylate"
# Tot_Clms:"15"
# Tot_30day_Fills:"35.8"
# Tot_Day_Suply:"1050".2
# Tot_Drug_Cst:"386.22"
# Tot_Benes:"".28
# GE65_Sprsn_Flag:"".35
# GE65_Tot_Clms:"15"
# GE65_Tot_30day_Fills:"35.8"
# GE65_Tot_Drug_Cst:"386.22"
# GE65_Tot_Day_Suply:"1050"
# GE65_Bene_Sprsn_Flag:"*".37
# GE65_Tot_Benes:""}.49
# {"Prscrbr_NPI":"1003000530".33
# Prscrbr_Last_Org_Name:"Semonche".33
# Prscrbr_First_Name:"Amanda".33
# Prscrbr_City:"Quakertown".33
# Prscrbr_State_Abrvtn:"PA".33
# Prscrbr_State_FIPS:"42".33
# Prscrbr_Type:"Internal Medicine".33
# Prscrbr_Type_Src:"Claim-Specialty".60
# Brnd_Name:"Doxycycline Hyclate"
# Gnrc_Name:"Doxycycline Hyclate"
# Tot_Clms:"30"
# Tot_30day_Fills:"30".1
# Tot_Day_Suply:"251"
# Tot_Drug_Cst:"319.64"
# Tot_Benes:"28".1
# GE65_Sprsn_Flag:"".36
# GE65_Tot_Clms:"30"
# GE65_Tot_30day_Fills:"30".1
# GE65_Tot_Drug_Cst:"319.64"
# GE65_Tot_Day_Suply:"251"
# GE65_Bene_Sprsn_Flag:"".12
# GE65_Tot_Benes:"28"}
# {"Prscrbr_NPI":"1003000530".34
# Prscrbr_Last_Org_Name:"Semonche".34
# Prscrbr_First_Name:"Amanda".34
# Prscrbr_City:"Quakertown".34
# Prscrbr_State_Abrvtn:"PA".34
# Prscrbr_State_FIPS:"42".34
# Prscrbr_Type:"Internal Medicine".34
# Prscrbr_Type_Src:"Claim-Specialty".61
# Brnd_Name:"Duloxetine Hcl".1
# Gnrc_Name:"Duloxetine Hcl".1
# Tot_Clms:"69"
# Tot_30day_Fills:"113"
# Tot_Day_Suply:"3382"
# Tot_Drug_Cst:"3664.57"
# Tot_Benes:"11".1
# GE65_Sprsn_Flag:"".37
# GE65_Tot_Clms:"55"
# GE65_Tot_30day_Fills:"89"
# GE65_Tot_Drug_Cst:"3243.56"
# GE65_Tot_Day_Suply:"2662"
# GE65_Bene_Sprsn_Flag:"*".38
# GE65_Tot_Benes:""}.50
# {"Prscrbr_NPI":"1003000530".35
# Prscrbr_Last_Org_Name:"Semonche".35
# Prscrbr_First_Name:"Amanda".35
# Prscrbr_City:"Quakertown".35
# Prscrbr_State_Abrvtn:"PA".35
# Prscrbr_State_FIPS:"42".35
# Prscrbr_Type:"Internal Medicine".35
# Prscrbr_Type_Src:"Claim-Specialty".62
# Brnd_Name:"Eliquis".1
# Gnrc_Name:"Apixaban".1
# Tot_Clms:"113"
# Tot_30day_Fills:"167"
# Tot_Day_Suply:"4999"
# Tot_Drug_Cst:"92087.78"
# Tot_Benes:"20"
# GE65_Sprsn_Flag:"".38
# GE65_Tot_Clms:"113"
# GE65_Tot_30day_Fills:"167"
# GE65_Tot_Drug_Cst:"92087.78"
# GE65_Tot_Day_Suply:"4999"
# GE65_Bene_Sprsn_Flag:"".13
# GE65_Tot_Benes:"20"}
# {"Prscrbr_NPI":"1003000530".36
# Prscrbr_Last_Org_Name:"Semonche".36
# Prscrbr_First_Name:"Amanda".36
# Prscrbr_City:"Quakertown".36
# Prscrbr_State_Abrvtn:"PA".36
# Prscrbr_State_FIPS:"42".36
# Prscrbr_Type:"Internal Medicine".36
# Prscrbr_Type_Src:"Claim-Specialty".63
# Brnd_Name:"Escitalopram Oxalate"
# Gnrc_Name:"Escitalopram Oxalate"
# Tot_Clms:"75"
# Tot_30day_Fills:"168"
# Tot_Day_Suply:"5015"
# Tot_Drug_Cst:"967.02"
# Tot_Benes:"19".2
# GE65_Sprsn_Flag:"#".18
# GE65_Tot_Clms:"".26
# GE65_Tot_30day_Fills:"".26
# GE65_Tot_Drug_Cst:"".26
# GE65_Tot_Day_Suply:"".26
# GE65_Bene_Sprsn_Flag:"#".12
# GE65_Tot_Benes:""}.51
# {"Prscrbr_NPI":"1003000530".37
# Prscrbr_Last_Org_Name:"Semonche".37
# Prscrbr_First_Name:"Amanda".37
# Prscrbr_City:"Quakertown".37
# Prscrbr_State_Abrvtn:"PA".37
# Prscrbr_State_FIPS:"42".37
# Prscrbr_Type:"Internal Medicine".37
# Prscrbr_Type_Src:"Claim-Specialty".64
# Brnd_Name:"Ezetimibe"
# Gnrc_Name:"Ezetimibe"
# Tot_Clms:"13".6
# Tot_30day_Fills:"39"
# Tot_Day_Suply:"1170"
# Tot_Drug_Cst:"272.15"
# Tot_Benes:"".29
# GE65_Sprsn_Flag:"".39
# GE65_Tot_Clms:"13".5
# GE65_Tot_30day_Fills:"39"
# GE65_Tot_Drug_Cst:"272.15"
# GE65_Tot_Day_Suply:"1170"
# GE65_Bene_Sprsn_Flag:"*".39
# GE65_Tot_Benes:""}.52
# {"Prscrbr_NPI":"1003000530".38
# Prscrbr_Last_Org_Name:"Semonche".38
# Prscrbr_First_Name:"Amanda".38
# Prscrbr_City:"Quakertown".38
# Prscrbr_State_Abrvtn:"PA".38
# Prscrbr_State_FIPS:"42".38
# Prscrbr_Type:"Internal Medicine".38
# Prscrbr_Type_Src:"Claim-Specialty".65
# Brnd_Name:"Famotidine"
# Gnrc_Name:"Famotidine"
# Tot_Clms:"143".1
# Tot_30day_Fills:"293.5"
# Tot_Day_Suply:"8770"
# Tot_Drug_Cst:"1813.81"
# Tot_Benes:"42".1
# GE65_Sprsn_Flag:"#".19
# GE65_Tot_Clms:"".27
# GE65_Tot_30day_Fills:"".27
# GE65_Tot_Drug_Cst:"".27
# GE65_Tot_Day_Suply:"".27
# GE65_Bene_Sprsn_Flag:"#".13
# GE65_Tot_Benes:""}.53
# {"Prscrbr_NPI":"1003000530".39
# Prscrbr_Last_Org_Name:"Semonche".39
# Prscrbr_First_Name:"Amanda".39
# Prscrbr_City:"Quakertown".39
# Prscrbr_State_Abrvtn:"PA".39
# Prscrbr_State_FIPS:"42".39
# Prscrbr_Type:"Internal Medicine".39
# Prscrbr_Type_Src:"Claim-Specialty".66
# Brnd_Name:"Febuxostat"
# Gnrc_Name:"Febuxostat"
# Tot_Clms:"12".4
# Tot_30day_Fills:"12".3
# Tot_Day_Suply:"360".1
# Tot_Drug_Cst:"2867.88"
# Tot_Benes:"".30
# GE65_Sprsn_Flag:"".40
# GE65_Tot_Clms:"12".1
# GE65_Tot_30day_Fills:"12".1
# GE65_Tot_Drug_Cst:"2867.88"
# GE65_Tot_Day_Suply:"360".1
# GE65_Bene_Sprsn_Flag:"*".40
# GE65_Tot_Benes:""}.54
# {"Prscrbr_NPI":"1003000530".40
# Prscrbr_Last_Org_Name:"Semonche".40
# Prscrbr_First_Name:"Amanda".40
# Prscrbr_City:"Quakertown".40
# Prscrbr_State_Abrvtn:"PA".40
# Prscrbr_State_FIPS:"42".40
# Prscrbr_Type:"Internal Medicine".40
# Prscrbr_Type_Src:"Claim-Specialty".67
# Brnd_Name:"Fenofibrate"
# Gnrc_Name:"Fenofibrate"
# Tot_Clms:"12".5
# Tot_30day_Fills:"32"
# Tot_Day_Suply:"960"
# Tot_Drug_Cst:"400.88"
# Tot_Benes:"".31
# GE65_Sprsn_Flag:"*".8
# GE65_Tot_Clms:"".28
# GE65_Tot_30day_Fills:"".28
# GE65_Tot_Drug_Cst:"".28
# GE65_Tot_Day_Suply:"".28
# GE65_Bene_Sprsn_Flag:"*".41
# GE65_Tot_Benes:""}.55
# {"Prscrbr_NPI":"1003000530".41
# Prscrbr_Last_Org_Name:"Semonche".41
# Prscrbr_First_Name:"Amanda".41
# Prscrbr_City:"Quakertown".41
# Prscrbr_State_Abrvtn:"PA".41
# Prscrbr_State_FIPS:"42".41
# Prscrbr_Type:"Internal Medicine".41
# Prscrbr_Type_Src:"Claim-Specialty".68
# Brnd_Name:"Finasteride"
# Gnrc_Name:"Finasteride"
# Tot_Clms:"31".1
# Tot_30day_Fills:"79"
# Tot_Day_Suply:"2370"
# Tot_Drug_Cst:"628.74"
# Tot_Benes:"".32
# GE65_Sprsn_Flag:"".41
# GE65_Tot_Clms:"31"
# GE65_Tot_30day_Fills:"79"
# GE65_Tot_Drug_Cst:"628.74"
# GE65_Tot_Day_Suply:"2370"
# GE65_Bene_Sprsn_Flag:"*".42
# GE65_Tot_Benes:""}.56
# {"Prscrbr_NPI":"1003000530".42
# Prscrbr_Last_Org_Name:"Semonche".42
# Prscrbr_First_Name:"Amanda".42
# Prscrbr_City:"Quakertown".42
# Prscrbr_State_Abrvtn:"PA".42
# Prscrbr_State_FIPS:"42".42
# Prscrbr_Type:"Internal Medicine".42
# Prscrbr_Type_Src:"Claim-Specialty".69
# Brnd_Name:"Fluticasone Propionate"
# Gnrc_Name:"Fluticasone Propionate"
# Tot_Clms:"59"
# Tot_30day_Fills:"108"
# Tot_Day_Suply:"3240"
# Tot_Drug_Cst:"709.42"
# Tot_Benes:"23".1
# GE65_Sprsn_Flag:"#".20
# GE65_Tot_Clms:"".29
# GE65_Tot_30day_Fills:"".29
# GE65_Tot_Drug_Cst:"".29
# GE65_Tot_Day_Suply:"".29
# GE65_Bene_Sprsn_Flag:"#".14
# GE65_Tot_Benes:""}.57
# {"Prscrbr_NPI":"1003000530".43
# Prscrbr_Last_Org_Name:"Semonche".43
# Prscrbr_First_Name:"Amanda".43
# Prscrbr_City:"Quakertown".43
# Prscrbr_State_Abrvtn:"PA".43
# Prscrbr_State_FIPS:"42".43
# Prscrbr_Type:"Internal Medicine".43
# Prscrbr_Type_Src:"Claim-Specialty".70
# Brnd_Name:"Fluticasone-Salmeterol"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol".1
# Tot_Clms:"16".4
# Tot_30day_Fills:"24".1
# Tot_Day_Suply:"720".1
# Tot_Drug_Cst:"3464.46"
# Tot_Benes:"".33
# GE65_Sprsn_Flag:"#".21
# GE65_Tot_Clms:"".30
# GE65_Tot_30day_Fills:"".30
# GE65_Tot_Drug_Cst:"".30
# GE65_Tot_Day_Suply:"".30
# GE65_Bene_Sprsn_Flag:"*".43
# GE65_Tot_Benes:""}.58
# {"Prscrbr_NPI":"1003000530".44
# Prscrbr_Last_Org_Name:"Semonche".44
# Prscrbr_First_Name:"Amanda".44
# Prscrbr_City:"Quakertown".44
# Prscrbr_State_Abrvtn:"PA".44
# Prscrbr_State_FIPS:"42".44
# Prscrbr_Type:"Internal Medicine".44
# Prscrbr_Type_Src:"Claim-Specialty".71
# Brnd_Name:"Fosinopril Sodium"
# Gnrc_Name:"Fosinopril Sodium"
# Tot_Clms:"23".1
# Tot_30day_Fills:"33"
# Tot_Day_Suply:"990"
# Tot_Drug_Cst:"487.11"
# Tot_Benes:"".34
# GE65_Sprsn_Flag:"".42
# GE65_Tot_Clms:"23"
# GE65_Tot_30day_Fills:"33"
# GE65_Tot_Drug_Cst:"487.11"
# GE65_Tot_Day_Suply:"990"
# GE65_Bene_Sprsn_Flag:"*".44
# GE65_Tot_Benes:""}.59
# {"Prscrbr_NPI":"1003000530".45
# Prscrbr_Last_Org_Name:"Semonche".45
# Prscrbr_First_Name:"Amanda".45
# Prscrbr_City:"Quakertown".45
# Prscrbr_State_Abrvtn:"PA".45
# Prscrbr_State_FIPS:"42".45
# Prscrbr_Type:"Internal Medicine".45
# Prscrbr_Type_Src:"Claim-Specialty".72
# Brnd_Name:"Furosemide"
# Gnrc_Name:"Furosemide"
# Tot_Clms:"74"
# Tot_30day_Fills:"137"
# Tot_Day_Suply:"4054"
# Tot_Drug_Cst:"516.89"
# Tot_Benes:"23".2
# GE65_Sprsn_Flag:"#".22
# GE65_Tot_Clms:"".31
# GE65_Tot_30day_Fills:"".31
# GE65_Tot_Drug_Cst:"".31
# GE65_Tot_Day_Suply:"".31
# GE65_Bene_Sprsn_Flag:"#".15
# GE65_Tot_Benes:""}.60
# {"Prscrbr_NPI":"1003000530".46
# Prscrbr_Last_Org_Name:"Semonche".46
# Prscrbr_First_Name:"Amanda".46
# Prscrbr_City:"Quakertown".46
# Prscrbr_State_Abrvtn:"PA".46
# Prscrbr_State_FIPS:"42".46
# Prscrbr_Type:"Internal Medicine".46
# Prscrbr_Type_Src:"Claim-Specialty".73
# Brnd_Name:"Gabapentin".1
# Gnrc_Name:"Gabapentin".1
# Tot_Clms:"223"
# Tot_30day_Fills:"382"
# Tot_Day_Suply:"11391"
# Tot_Drug_Cst:"3411.56"
# Tot_Benes:"53"
# GE65_Sprsn_Flag:"".43
# GE65_Tot_Clms:"203"
# GE65_Tot_30day_Fills:"358"
# GE65_Tot_Drug_Cst:"3230.61"
# GE65_Tot_Day_Suply:"10677"
# GE65_Bene_Sprsn_Flag:"#".16
# GE65_Tot_Benes:""}.61
# {"Prscrbr_NPI":"1003000530".47
# Prscrbr_Last_Org_Name:"Semonche".47
# Prscrbr_First_Name:"Amanda".47
# Prscrbr_City:"Quakertown".47
# Prscrbr_State_Abrvtn:"PA".47
# Prscrbr_State_FIPS:"42".47
# Prscrbr_Type:"Internal Medicine".47
# Prscrbr_Type_Src:"Claim-Specialty".74
# Brnd_Name:"Gemfibrozil"
# Gnrc_Name:"Gemfibrozil"
# Tot_Clms:"11".1
# Tot_30day_Fills:"11".1
# Tot_Day_Suply:"330"
# Tot_Drug_Cst:"99"
# Tot_Benes:"".35
# GE65_Sprsn_Flag:"".44
# GE65_Tot_Clms:"11".1
# GE65_Tot_30day_Fills:"11"
# GE65_Tot_Drug_Cst:"99"
# GE65_Tot_Day_Suply:"330"
# GE65_Bene_Sprsn_Flag:"*".45
# GE65_Tot_Benes:""}.62
# {"Prscrbr_NPI":"1003000530".48
# Prscrbr_Last_Org_Name:"Semonche".48
# Prscrbr_First_Name:"Amanda".48
# Prscrbr_City:"Quakertown".48
# Prscrbr_State_Abrvtn:"PA".48
# Prscrbr_State_FIPS:"42".48
# Prscrbr_Type:"Internal Medicine".48
# Prscrbr_Type_Src:"Claim-Specialty".75
# Brnd_Name:"Glipizide"
# Gnrc_Name:"Glipizide"
# Tot_Clms:"82".1
# Tot_30day_Fills:"191.1"
# Tot_Day_Suply:"5694"
# Tot_Drug_Cst:"958.43"
# Tot_Benes:"18".1
# GE65_Sprsn_Flag:"".45
# GE65_Tot_Clms:"82"
# GE65_Tot_30day_Fills:"191.1"
# GE65_Tot_Drug_Cst:"958.43"
# GE65_Tot_Day_Suply:"5694"
# GE65_Bene_Sprsn_Flag:"".14
# GE65_Tot_Benes:"18"}
# {"Prscrbr_NPI":"1003000530".49
# Prscrbr_Last_Org_Name:"Semonche".49
# Prscrbr_First_Name:"Amanda".49
# Prscrbr_City:"Quakertown".49
# Prscrbr_State_Abrvtn:"PA".49
# Prscrbr_State_FIPS:"42".49
# Prscrbr_Type:"Internal Medicine".49
# Prscrbr_Type_Src:"Claim-Specialty".76
# Brnd_Name:"Glycopyrrolate"
# Gnrc_Name:"Glycopyrrolate"
# Tot_Clms:"14".7
# Tot_30day_Fills:"16.2"
# Tot_Day_Suply:"485"
# Tot_Drug_Cst:"908.42"
# Tot_Benes:"".36
# GE65_Sprsn_Flag:"*".9
# GE65_Tot_Clms:"".32
# GE65_Tot_30day_Fills:"".32
# GE65_Tot_Drug_Cst:"".32
# GE65_Tot_Day_Suply:"".32
# GE65_Bene_Sprsn_Flag:"*".46
# GE65_Tot_Benes:""}.63
# {"Prscrbr_NPI":"1003000530".50
# Prscrbr_Last_Org_Name:"Semonche".50
# Prscrbr_First_Name:"Amanda".50
# Prscrbr_City:"Quakertown".50
# Prscrbr_State_Abrvtn:"PA".50
# Prscrbr_State_FIPS:"42".50
# Prscrbr_Type:"Internal Medicine".50
# Prscrbr_Type_Src:"Claim-Specialty".77
# Brnd_Name:"Hydrochlorothiazide"
# Gnrc_Name:"Hydrochlorothiazide"
# Tot_Clms:"188"
# Tot_30day_Fills:"456"
# Tot_Day_Suply:"13668"
# Tot_Drug_Cst:"712.76"
# Tot_Benes:"44"
# GE65_Sprsn_Flag:"#".23
# GE65_Tot_Clms:"".33
# GE65_Tot_30day_Fills:"".33
# GE65_Tot_Drug_Cst:"".33
# GE65_Tot_Day_Suply:"".33
# GE65_Bene_Sprsn_Flag:"#".17
# GE65_Tot_Benes:""}.64
# {"Prscrbr_NPI":"1003000530".51
# Prscrbr_Last_Org_Name:"Semonche".51
# Prscrbr_First_Name:"Amanda".51
# Prscrbr_City:"Quakertown".51
# Prscrbr_State_Abrvtn:"PA".51
# Prscrbr_State_FIPS:"42".51
# Prscrbr_Type:"Internal Medicine".51
# Prscrbr_Type_Src:"Claim-Specialty".78
# Brnd_Name:"Hydrocodone-Acetaminophen".1
# Gnrc_Name:"Hydrocodone\/Acetaminophen".1
# Tot_Clms:"21".1
# Tot_30day_Fills:"21"
# Tot_Day_Suply:"306"
# Tot_Drug_Cst:"463.91"
# Tot_Benes:"".37
# GE65_Sprsn_Flag:"".46
# GE65_Tot_Clms:"21"
# GE65_Tot_30day_Fills:"21".1
# GE65_Tot_Drug_Cst:"463.91"
# GE65_Tot_Day_Suply:"306"
# GE65_Bene_Sprsn_Flag:"*".47
# GE65_Tot_Benes:""}.65
# {"Prscrbr_NPI":"1003000530".52
# Prscrbr_Last_Org_Name:"Semonche".52
# Prscrbr_First_Name:"Amanda".52
# Prscrbr_City:"Quakertown".52
# Prscrbr_State_Abrvtn:"PA".52
# Prscrbr_State_FIPS:"42".52
# Prscrbr_Type:"Internal Medicine".52
# Prscrbr_Type_Src:"Claim-Specialty".79
# Brnd_Name:"Irbesartan"
# Gnrc_Name:"Irbesartan"
# Tot_Clms:"19".1
# Tot_30day_Fills:"33".1
# Tot_Day_Suply:"964"
# Tot_Drug_Cst:"852.51"
# Tot_Benes:"".38
# GE65_Sprsn_Flag:"*".10
# GE65_Tot_Clms:"".34
# GE65_Tot_30day_Fills:"".34
# GE65_Tot_Drug_Cst:"".34
# GE65_Tot_Day_Suply:"".34
# GE65_Bene_Sprsn_Flag:"*".48
# GE65_Tot_Benes:""}.66
# {"Prscrbr_NPI":"1003000530".53
# Prscrbr_Last_Org_Name:"Semonche".53
# Prscrbr_First_Name:"Amanda".53
# Prscrbr_City:"Quakertown".53
# Prscrbr_State_Abrvtn:"PA".53
# Prscrbr_State_FIPS:"42".53
# Prscrbr_Type:"Internal Medicine".53
# Prscrbr_Type_Src:"Claim-Specialty".80
# Brnd_Name:"Isosorbide Mononitrate Er"
# Gnrc_Name:"Isosorbide Mononitrate"
# Tot_Clms:"23".2
# Tot_30day_Fills:"47"
# Tot_Day_Suply:"1410"
# Tot_Drug_Cst:"529.15"
# Tot_Benes:"".39
# GE65_Sprsn_Flag:"#".24
# GE65_Tot_Clms:"".35
# GE65_Tot_30day_Fills:"".35
# GE65_Tot_Drug_Cst:"".35
# GE65_Tot_Day_Suply:"".35
# GE65_Bene_Sprsn_Flag:"*".49
# GE65_Tot_Benes:""}.67
# {"Prscrbr_NPI":"1003000530".54
# Prscrbr_Last_Org_Name:"Semonche".54
# Prscrbr_First_Name:"Amanda".54
# Prscrbr_City:"Quakertown".54
# Prscrbr_State_Abrvtn:"PA".54
# Prscrbr_State_FIPS:"42".54
# Prscrbr_Type:"Internal Medicine".54
# Prscrbr_Type_Src:"Claim-Specialty".81
# Brnd_Name:"Januvia"
# Gnrc_Name:"Sitagliptin Phosphate"
# Tot_Clms:"27".1
# Tot_30day_Fills:"49"
# Tot_Day_Suply:"1470"
# Tot_Drug_Cst:"27971.54"
# Tot_Benes:"".40
# GE65_Sprsn_Flag:"".47
# GE65_Tot_Clms:"27".1
# GE65_Tot_30day_Fills:"49"
# GE65_Tot_Drug_Cst:"27971.54"
# GE65_Tot_Day_Suply:"1470"
# GE65_Bene_Sprsn_Flag:"*".50
# GE65_Tot_Benes:""}.68
# ...
# GE65_Bene_Sprsn_Flag:"".146
# GE65_Tot_Benes:"30"}.1
# {"Prscrbr_NPI":"1003004201".48
# Prscrbr_Last_Org_Name:"Philbrick".48
# Prscrbr_First_Name:"Natalie".48
# Prscrbr_City:"Corpus Christi".48
# Prscrbr_State_Abrvtn:"TX".96
# Prscrbr_State_FIPS:"48".96
# Prscrbr_Type:"Internal Medicine".170
# Prscrbr_Type_Src:"Claim-Specialty".758
# Brnd_Name:"Glimepiride".2
# Gnrc_Name:"Glimepiride".2
# Tot_Clms:"11".54
# Tot_30day_Fills:"31".7
# Tot_Day_Suply:"911"
# Tot_Drug_Cst:"72.72"
# Tot_Benes:"".497
# GE65_Sprsn_Flag:"".554
# GE65_Tot_Clms:"11".26
# GE65_Tot_30day_Fills:"31".3
# GE65_Tot_Drug_Cst:"72.72"
# GE65_Tot_Day_Suply:"911"
# GE65_Bene_Sprsn_Flag:"*".531
# GE65_Tot_Benes:""}.827
# {"Prscrbr_NPI":"1003004201".49
# Prscrbr_Last_Org_Name:"Philbrick".49
# Prscrbr_First_Name:"Natalie".49
# Prscrbr_City:"Corpus Christi".49
# Prscrbr_State_Abrvtn:"TX".97
# Prscrbr_State_FIPS:"48".97
# Prscrbr_Type:"Internal Medicine".171
# Prscrbr_Type_Src:"Claim-Specialty".759
# Brnd_Name:"Glipizide".4
# Gnrc_Name:"Glipizide".8
# Tot_Clms:"12".45
# Tot_30day_Fills:"35".12
# Tot_Day_Suply:"1050".8
# Tot_Drug_Cst:"69.59".1
# Tot_Benes:"".498
# GE65_Sprsn_Flag:"".555
# GE65_Tot_Clms:"12".24
# GE65_Tot_30day_Fills:"35".5
# GE65_Tot_Drug_Cst:"69.59".1
# GE65_Tot_Day_Suply:"1050".5
# GE65_Bene_Sprsn_Flag:"*".532
# GE65_Tot_Benes:""}.828
# {"Prscrbr_NPI":"1003004201".50
# Prscrbr_Last_Org_Name:"Philbrick".50
# Prscrbr_First_Name:"Natalie".50
# Prscrbr_City:"Corpus Christi".50
# Prscrbr_State_Abrvtn:"TX".98
# Prscrbr_State_FIPS:"48".98
# Prscrbr_Type:"Internal Medicine".172
# Prscrbr_Type_Src:"Claim-Specialty".760
# Brnd_Name:"Hydrochlorothiazide".7
# Gnrc_Name:"Hydrochlorothiazide".7
# Tot_Clms:"88".4
# Tot_30day_Fills:"198.7"
# Tot_Day_Suply:"5943"
# Tot_Drug_Cst:"308.78"
# Tot_Benes:"21".17
# GE65_Sprsn_Flag:"".556
# GE65_Tot_Clms:"76".1
# GE65_Tot_30day_Fills:"164"
# GE65_Tot_Drug_Cst:"245.72"
# GE65_Tot_Day_Suply:"4903"
# GE65_Bene_Sprsn_Flag:"#".296
# GE65_Tot_Benes:""}.829
# {"Prscrbr_NPI":"1003004201".51
# Prscrbr_Last_Org_Name:"Philbrick".51
# Prscrbr_First_Name:"Natalie".51
# Prscrbr_City:"Corpus Christi".51
# Prscrbr_State_Abrvtn:"TX".99
# Prscrbr_State_FIPS:"48".99
# Prscrbr_Type:"Internal Medicine".173
# Prscrbr_Type_Src:"Claim-Specialty".761
# Brnd_Name:"Hydrocodone-Acetaminophen".12
# Gnrc_Name:"Hydrocodone\/Acetaminophen".12
# Tot_Clms:"75".2
# Tot_30day_Fills:"75".3
# Tot_Day_Suply:"1902"
# Tot_Drug_Cst:"1984.27"
# Tot_Benes:"24".11
# GE65_Sprsn_Flag:"".557
# GE65_Tot_Clms:"51".2
# GE65_Tot_30day_Fills:"51".5
# GE65_Tot_Drug_Cst:"1443.05"
# GE65_Tot_Day_Suply:"1317"
# GE65_Bene_Sprsn_Flag:"#".297
# GE65_Tot_Benes:""}.830
# {"Prscrbr_NPI":"1003004201".52
# Prscrbr_Last_Org_Name:"Philbrick".52
# Prscrbr_First_Name:"Natalie".52
# Prscrbr_City:"Corpus Christi".52
# Prscrbr_State_Abrvtn:"TX".100
# Prscrbr_State_FIPS:"48".100
# Prscrbr_Type:"Internal Medicine".174
# Prscrbr_Type_Src:"Claim-Specialty".762
# Brnd_Name:"Ibuprofen".5
# Gnrc_Name:"Ibuprofen".5
# Tot_Clms:"23".20
# Tot_30day_Fills:"23".9
# Tot_Day_Suply:"645"
# Tot_Drug_Cst:"239.22"
# Tot_Benes:"".499
# GE65_Sprsn_Flag:"*".100
# GE65_Tot_Clms:"".420
# GE65_Tot_30day_Fills:"".420
# GE65_Tot_Drug_Cst:"".420
# GE65_Tot_Day_Suply:"".420
# GE65_Bene_Sprsn_Flag:"*".533
# GE65_Tot_Benes:""}.831
# {"Prscrbr_NPI":"1003004201".53
# Prscrbr_Last_Org_Name:"Philbrick".53
# Prscrbr_First_Name:"Natalie".53
# Prscrbr_City:"Corpus Christi".53
# Prscrbr_State_Abrvtn:"TX".101
# Prscrbr_State_FIPS:"48".101
# Prscrbr_Type:"Internal Medicine".175
# Prscrbr_Type_Src:"Claim-Specialty".763
# Brnd_Name:"Irbesartan".3
# Gnrc_Name:"Irbesartan".3
# Tot_Clms:"33".12
# Tot_30day_Fills:"81".2
# Tot_Day_Suply:"2409"
# Tot_Drug_Cst:"601.43"
# Tot_Benes:"".500
# GE65_Sprsn_Flag:"".558
# GE65_Tot_Clms:"33".5
# GE65_Tot_30day_Fills:"81".1
# GE65_Tot_Drug_Cst:"601.43"
# GE65_Tot_Day_Suply:"2409"
# GE65_Bene_Sprsn_Flag:"*".534
# GE65_Tot_Benes:""}.832
# {"Prscrbr_NPI":"1003004201".54
# Prscrbr_Last_Org_Name:"Philbrick".54
# Prscrbr_First_Name:"Natalie".54
# Prscrbr_City:"Corpus Christi".54
# Prscrbr_State_Abrvtn:"TX".102
# Prscrbr_State_FIPS:"48".102
# Prscrbr_Type:"Internal Medicine".176
# Prscrbr_Type_Src:"Claim-Specialty".764
# Brnd_Name:"Janumet".2
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".3
# Tot_Clms:"11".55
# Tot_30day_Fills:"34.3".1
# Tot_Day_Suply:"1030"
# Tot_Drug_Cst:"15945.71"
# Tot_Benes:"".501
# GE65_Sprsn_Flag:"*".101
# GE65_Tot_Clms:"".421
# GE65_Tot_30day_Fills:"".421
# GE65_Tot_Drug_Cst:"".421
# GE65_Tot_Day_Suply:"".421
# GE65_Bene_Sprsn_Flag:"*".535
# GE65_Tot_Benes:""}.833
# {"Prscrbr_NPI":"1003004201".55
# Prscrbr_Last_Org_Name:"Philbrick".55
# Prscrbr_First_Name:"Natalie".55
# Prscrbr_City:"Corpus Christi".55
# Prscrbr_State_Abrvtn:"TX".103
# Prscrbr_State_FIPS:"48".103
# Prscrbr_Type:"Internal Medicine".177
# Prscrbr_Type_Src:"Claim-Specialty".765
# Brnd_Name:"Janumet Xr".1
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".4
# Tot_Clms:"16".31
# Tot_30day_Fills:"26".10
# Tot_Day_Suply:"780".4
# Tot_Drug_Cst:"14576.22"
# Tot_Benes:"".502
# GE65_Sprsn_Flag:"".559
# GE65_Tot_Clms:"16".17
# GE65_Tot_30day_Fills:"26".4
# GE65_Tot_Drug_Cst:"14576.22"
# GE65_Tot_Day_Suply:"780".1
# GE65_Bene_Sprsn_Flag:"*".536
# GE65_Tot_Benes:""}.834
# {"Prscrbr_NPI":"1003004201".56
# Prscrbr_Last_Org_Name:"Philbrick".56
# Prscrbr_First_Name:"Natalie".56
# Prscrbr_City:"Corpus Christi".56
# Prscrbr_State_Abrvtn:"TX".104
# Prscrbr_State_FIPS:"48".104
# Prscrbr_Type:"Internal Medicine".178
# Prscrbr_Type_Src:"Claim-Specialty".766
# Brnd_Name:"Januvia".5
# Gnrc_Name:"Sitagliptin Phosphate".5
# Tot_Clms:"47".7
# Tot_30day_Fills:"102.7"
# Tot_Day_Suply:"3080"
# Tot_Drug_Cst:"57151.67"
# Tot_Benes:"".503
# GE65_Sprsn_Flag:"".560
# GE65_Tot_Clms:"33".6
# GE65_Tot_30day_Fills:"61".4
# GE65_Tot_Drug_Cst:"32794.59"
# GE65_Tot_Day_Suply:"1830".3
# GE65_Bene_Sprsn_Flag:"*".537
# GE65_Tot_Benes:""}.835
# {"Prscrbr_NPI":"1003004201".57
# Prscrbr_Last_Org_Name:"Philbrick".57
# Prscrbr_First_Name:"Natalie".57
# Prscrbr_City:"Corpus Christi".57
# Prscrbr_State_Abrvtn:"TX".105
# Prscrbr_State_FIPS:"48".105
# Prscrbr_Type:"Internal Medicine".179
# Prscrbr_Type_Src:"Claim-Specialty".767
# Brnd_Name:"Jardiance".5
# Gnrc_Name:"Empagliflozin".5
# Tot_Clms:"36".10
# Tot_30day_Fills:"48".7
# Tot_Day_Suply:"1440".5
# Tot_Drug_Cst:"30810.62"
# Tot_Benes:"".504
# GE65_Sprsn_Flag:"".561
# GE65_Tot_Clms:"16".18
# GE65_Tot_30day_Fills:"28".4
# GE65_Tot_Drug_Cst:"17814.66"
# GE65_Tot_Day_Suply:"840".4
# GE65_Bene_Sprsn_Flag:"*".538
# GE65_Tot_Benes:""}.836
# {"Prscrbr_NPI":"1003004201".58
# Prscrbr_Last_Org_Name:"Philbrick".58
# Prscrbr_First_Name:"Natalie".58
# Prscrbr_City:"Corpus Christi".58
# Prscrbr_State_Abrvtn:"TX".106
# Prscrbr_State_FIPS:"48".106
# Prscrbr_Type:"Internal Medicine".180
# Prscrbr_Type_Src:"Claim-Specialty".768
# Brnd_Name:"Lantus Solostar".4
# Gnrc_Name:"Insulin Glargine.7
# hum.Rec.Anlog".7
# Tot_Clms:"30".15
# Tot_30day_Fills:"42.6"
# Tot_Day_Suply:"1200".4
# Tot_Drug_Cst:"14025.7"
# Tot_Benes:"".505
# GE65_Sprsn_Flag:"*".102
# GE65_Tot_Clms:"".422
# GE65_Tot_30day_Fills:"".422
# GE65_Tot_Drug_Cst:"".422
# GE65_Tot_Day_Suply:"".422
# GE65_Bene_Sprsn_Flag:"*".539
# GE65_Tot_Benes:""}.837
# {"Prscrbr_NPI":"1003004201".59
# Prscrbr_Last_Org_Name:"Philbrick".59
# Prscrbr_First_Name:"Natalie".59
# Prscrbr_City:"Corpus Christi".59
# Prscrbr_State_Abrvtn:"TX".107
# Prscrbr_State_FIPS:"48".107
# Prscrbr_Type:"Internal Medicine".181
# Prscrbr_Type_Src:"Claim-Specialty".769
# Brnd_Name:"Levemir Flexpen"
# Gnrc_Name:"Insulin Detemir"
# Tot_Clms:"18".24
# Tot_30day_Fills:"40.7".1
# Tot_Day_Suply:"1216"
# Tot_Drug_Cst:"14820.64"
# Tot_Benes:"".506
# GE65_Sprsn_Flag:"#".320
# GE65_Tot_Clms:"".423
# GE65_Tot_30day_Fills:"".423
# GE65_Tot_Drug_Cst:"".423
# GE65_Tot_Day_Suply:"".423
# GE65_Bene_Sprsn_Flag:"*".540
# GE65_Tot_Benes:""}.838
# {"Prscrbr_NPI":"1003004201".60
# Prscrbr_Last_Org_Name:"Philbrick".60
# Prscrbr_First_Name:"Natalie".60
# Prscrbr_City:"Corpus Christi".60
# Prscrbr_State_Abrvtn:"TX".108
# Prscrbr_State_FIPS:"48".108
# Prscrbr_Type:"Internal Medicine".182
# Prscrbr_Type_Src:"Claim-Specialty".770
# Brnd_Name:"Levothyroxine Sodium".7
# Gnrc_Name:"Levothyroxine Sodium".13
# Tot_Clms:"329"
# Tot_30day_Fills:"878.8"
# Tot_Day_Suply:"26336"
# Tot_Drug_Cst:"5172.2"
# Tot_Benes:"87".1
# GE65_Sprsn_Flag:"".562
# GE65_Tot_Clms:"296"
# GE65_Tot_30day_Fills:"792.8"
# GE65_Tot_Drug_Cst:"4565.09"
# GE65_Tot_Day_Suply:"23768"
# GE65_Bene_Sprsn_Flag:"#".298
# GE65_Tot_Benes:""}.839
# {"Prscrbr_NPI":"1003004201".61
# Prscrbr_Last_Org_Name:"Philbrick".61
# Prscrbr_First_Name:"Natalie".61
# Prscrbr_City:"Corpus Christi".61
# Prscrbr_State_Abrvtn:"TX".109
# Prscrbr_State_FIPS:"48".109
# Prscrbr_Type:"Internal Medicine".183
# Prscrbr_Type_Src:"Claim-Specialty".771
# Brnd_Name:"Lisinopril".9
# Gnrc_Name:"Lisinopril".9
# Tot_Clms:"191".1
# Tot_30day_Fills:"567.6"
# Tot_Day_Suply:"17030"
# Tot_Drug_Cst:"1067.95"
# Tot_Benes:"57".1
# GE65_Sprsn_Flag:"".563
# GE65_Tot_Clms:"168".1
# GE65_Tot_30day_Fills:"498.6"
# GE65_Tot_Drug_Cst:"935.82"
# GE65_Tot_Day_Suply:"14960"
# GE65_Bene_Sprsn_Flag:"#".299
# GE65_Tot_Benes:""}.840
# {"Prscrbr_NPI":"1003004201".62
# Prscrbr_Last_Org_Name:"Philbrick".62
# Prscrbr_First_Name:"Natalie".62
# Prscrbr_City:"Corpus Christi".62
# Prscrbr_State_Abrvtn:"TX".110
# Prscrbr_State_FIPS:"48".110
# Prscrbr_Type:"Internal Medicine".184
# Prscrbr_Type_Src:"Claim-Specialty".772
# Brnd_Name:"Lisinopril-Hydrochlorothiazide".3
# Gnrc_Name:"Lisinopril\/Hydrochlorothiazide".3
# Tot_Clms:"31".8
# Tot_30day_Fills:"86.3"
# Tot_Day_Suply:"2556"
# Tot_Drug_Cst:"358.53"
# Tot_Benes:"".507
# GE65_Sprsn_Flag:"#".321
# GE65_Tot_Clms:"".424
# GE65_Tot_30day_Fills:"".424
# GE65_Tot_Drug_Cst:"".424
# GE65_Tot_Day_Suply:"".424
# GE65_Bene_Sprsn_Flag:"*".541
# GE65_Tot_Benes:""}.841
# {"Prscrbr_NPI":"1003004201".63
# Prscrbr_Last_Org_Name:"Philbrick".63
# Prscrbr_First_Name:"Natalie".63
# Prscrbr_City:"Corpus Christi".63
# Prscrbr_State_Abrvtn:"TX".111
# Prscrbr_State_FIPS:"48".111
# Prscrbr_Type:"Internal Medicine".185
# Prscrbr_Type_Src:"Claim-Specialty".773
# Brnd_Name:"Lorazepam".4
# Gnrc_Name:"Lorazepam".4
# Tot_Clms:"17".23
# Tot_30day_Fills:"17".14
# Tot_Day_Suply:"467"
# Tot_Drug_Cst:"68.44"
# Tot_Benes:"".508
# GE65_Sprsn_Flag:"#".322
# GE65_Tot_Clms:"".425
# GE65_Tot_30day_Fills:"".425
# GE65_Tot_Drug_Cst:"".425
# GE65_Tot_Day_Suply:"".425
# GE65_Bene_Sprsn_Flag:"*".542
# GE65_Tot_Benes:""}.842
# {"Prscrbr_NPI":"1003004201".64
# Prscrbr_Last_Org_Name:"Philbrick".64
# Prscrbr_First_Name:"Natalie".64
# Prscrbr_City:"Corpus Christi".64
# Prscrbr_State_Abrvtn:"TX".112
# Prscrbr_State_FIPS:"48".112
# Prscrbr_Type:"Internal Medicine".186
# Prscrbr_Type_Src:"Claim-Specialty".774
# Brnd_Name:"Losartan Potassium".8
# Gnrc_Name:"Losartan Potassium".8
# Tot_Clms:"198"
# Tot_30day_Fills:"489"
# Tot_Day_Suply:"14661"
# Tot_Drug_Cst:"2739.62"
# Tot_Benes:"54".1
# GE65_Sprsn_Flag:"#".323
# GE65_Tot_Clms:"".426
# GE65_Tot_30day_Fills:"".426
# GE65_Tot_Drug_Cst:"".426
# GE65_Tot_Day_Suply:"".426
# GE65_Bene_Sprsn_Flag:"#".300
# GE65_Tot_Benes:""}.843
# {"Prscrbr_NPI":"1003004201".65
# Prscrbr_Last_Org_Name:"Philbrick".65
# Prscrbr_First_Name:"Natalie".65
# Prscrbr_City:"Corpus Christi".65
# Prscrbr_State_Abrvtn:"TX".113
# Prscrbr_State_FIPS:"48".113
# Prscrbr_Type:"Internal Medicine".187
# Prscrbr_Type_Src:"Claim-Specialty".775
# Brnd_Name:"Losartan-Hydrochlorothiazide".3
# Gnrc_Name:"Losartan\/Hydrochlorothiazide".3
# Tot_Clms:"77"
# Tot_30day_Fills:"218.3"
# Tot_Day_Suply:"6550"
# Tot_Drug_Cst:"1248.85"
# Tot_Benes:"23".11
# GE65_Sprsn_Flag:"#".324
# GE65_Tot_Clms:"".427
# GE65_Tot_30day_Fills:"".427
# GE65_Tot_Drug_Cst:"".427
# GE65_Tot_Day_Suply:"".427
# GE65_Bene_Sprsn_Flag:"#".301
# GE65_Tot_Benes:""}.844
# {"Prscrbr_NPI":"1003004201".66
# Prscrbr_Last_Org_Name:"Philbrick".66
# Prscrbr_First_Name:"Natalie".66
# Prscrbr_City:"Corpus Christi".66
# Prscrbr_State_Abrvtn:"TX".114
# Prscrbr_State_FIPS:"48".114
# Prscrbr_Type:"Internal Medicine".188
# Prscrbr_Type_Src:"Claim-Specialty".776
# Brnd_Name:"Meloxicam".10
# Gnrc_Name:"Meloxicam".10
# Tot_Clms:"295".1
# Tot_30day_Fills:"662.6"
# Tot_Day_Suply:"19839"
# Tot_Drug_Cst:"1681.33"
# Tot_Benes:"87".2
# GE65_Sprsn_Flag:"".564
# GE65_Tot_Clms:"250"
# GE65_Tot_30day_Fills:"558"
# GE65_Tot_Drug_Cst:"1493.45"
# GE65_Tot_Day_Suply:"16724"
# GE65_Bene_Sprsn_Flag:"".147
# GE65_Tot_Benes:"72"}
# {"Prscrbr_NPI":"1003004201".67
# Prscrbr_Last_Org_Name:"Philbrick".67
# Prscrbr_First_Name:"Natalie".67
# Prscrbr_City:"Corpus Christi".67
# Prscrbr_State_Abrvtn:"TX".115
# Prscrbr_State_FIPS:"48".115
# Prscrbr_Type:"Internal Medicine".189
# Prscrbr_Type_Src:"Claim-Specialty".777
# Brnd_Name:"Memantine Hcl Er"
# Gnrc_Name:"Memantine Hcl".3
# Tot_Clms:"11".56
# Tot_30day_Fills:"17".15
# Tot_Day_Suply:"510".6
# Tot_Drug_Cst:"685.59"
# Tot_Benes:"".509
# GE65_Sprsn_Flag:"".565
# GE65_Tot_Clms:"11".27
# GE65_Tot_30day_Fills:"17".5
# GE65_Tot_Drug_Cst:"685.59"
# GE65_Tot_Day_Suply:"510".2
# GE65_Bene_Sprsn_Flag:"*".543
# GE65_Tot_Benes:""}.845
# {"Prscrbr_NPI":"1003004201".68
# Prscrbr_Last_Org_Name:"Philbrick".68
# Prscrbr_First_Name:"Natalie".68
# Prscrbr_City:"Corpus Christi".68
# Prscrbr_State_Abrvtn:"TX".116
# Prscrbr_State_FIPS:"48".116
# Prscrbr_Type:"Internal Medicine".190
# Prscrbr_Type_Src:"Claim-Specialty".778
# Brnd_Name:"Metformin Hcl".7
# Gnrc_Name:"Metformin Hcl".12
# Tot_Clms:"172"
# Tot_30day_Fills:"477.7"
# Tot_Day_Suply:"14331"
# Tot_Drug_Cst:"1379.45"
# Tot_Benes:"54".2
# GE65_Sprsn_Flag:"".566
# GE65_Tot_Clms:"134"
# GE65_Tot_30day_Fills:"385"
# GE65_Tot_Drug_Cst:"998.73"
# GE65_Tot_Day_Suply:"11551"
# GE65_Bene_Sprsn_Flag:"".148
# GE65_Tot_Benes:"43"}.1
# {"Prscrbr_NPI":"1003004201".69
# Prscrbr_Last_Org_Name:"Philbrick".69
# Prscrbr_First_Name:"Natalie".69
# Prscrbr_City:"Corpus Christi".69
# Prscrbr_State_Abrvtn:"TX".117
# Prscrbr_State_FIPS:"48".117
# Prscrbr_Type:"Internal Medicine".191
# Prscrbr_Type_Src:"Claim-Specialty".779
# Brnd_Name:"Metformin Hcl Er".5
# Gnrc_Name:"Metformin Hcl".13
# Tot_Clms:"36".11
# Tot_30day_Fills:"94".2
# Tot_Day_Suply:"2819"
# Tot_Drug_Cst:"453.51"
# Tot_Benes:"14".23
# GE65_Sprsn_Flag:"#".325
# GE65_Tot_Clms:"".428
# GE65_Tot_30day_Fills:"".428
# GE65_Tot_Drug_Cst:"".428
# GE65_Tot_Day_Suply:"".428
# GE65_Bene_Sprsn_Flag:"#".302
# GE65_Tot_Benes:""}.846
# {"Prscrbr_NPI":"1003004201".70
# Prscrbr_Last_Org_Name:"Philbrick".70
# Prscrbr_First_Name:"Natalie".70
# Prscrbr_City:"Corpus Christi".70
# Prscrbr_State_Abrvtn:"TX".118
# Prscrbr_State_FIPS:"48".118
# Prscrbr_Type:"Internal Medicine".192
# Prscrbr_Type_Src:"Claim-Specialty".780
# Brnd_Name:"Methocarbamol".2
# Gnrc_Name:"Methocarbamol".2
# Tot_Clms:"16".32
# Tot_30day_Fills:"18".11
# Tot_Day_Suply:"520".1
# Tot_Drug_Cst:"110.37"
# Tot_Benes:"".510
# GE65_Sprsn_Flag:"#".326
# GE65_Tot_Clms:"".429
# GE65_Tot_30day_Fills:"".429
# GE65_Tot_Drug_Cst:"".429
# GE65_Tot_Day_Suply:"".429
# GE65_Bene_Sprsn_Flag:"*".544
# GE65_Tot_Benes:""}.847
# {"Prscrbr_NPI":"1003004201".71
# Prscrbr_Last_Org_Name:"Philbrick".71
# Prscrbr_First_Name:"Natalie".71
# Prscrbr_City:"Corpus Christi".71
# Prscrbr_State_Abrvtn:"TX".119
# Prscrbr_State_FIPS:"48".119
# Prscrbr_Type:"Internal Medicine".193
# Prscrbr_Type_Src:"Claim-Specialty".781
# Brnd_Name:"Metoprolol Succinate".8
# Gnrc_Name:"Metoprolol Succinate".8
# Tot_Clms:"65".3
# Tot_30day_Fills:"192.3"
# Tot_Day_Suply:"5770"
# Tot_Drug_Cst:"1332.13"
# Tot_Benes:"20".12
# GE65_Sprsn_Flag:"#".327
# GE65_Tot_Clms:"".430
# GE65_Tot_30day_Fills:"".430
# GE65_Tot_Drug_Cst:"".430
# GE65_Tot_Day_Suply:"".430
# GE65_Bene_Sprsn_Flag:"#".303
# GE65_Tot_Benes:""}.848
# {"Prscrbr_NPI":"1003004201".72
# Prscrbr_Last_Org_Name:"Philbrick".72
# Prscrbr_First_Name:"Natalie".72
# Prscrbr_City:"Corpus Christi".72
# Prscrbr_State_Abrvtn:"TX".120
# Prscrbr_State_FIPS:"48".120
# Prscrbr_Type:"Internal Medicine".194
# Prscrbr_Type_Src:"Claim-Specialty".782
# Brnd_Name:"Metoprolol Tartrate".6
# Gnrc_Name:"Metoprolol Tartrate".6
# Tot_Clms:"60".3
# Tot_30day_Fills:"150.1"
# Tot_Day_Suply:"4492"
# Tot_Drug_Cst:"305.37"
# Tot_Benes:"21".18
# GE65_Sprsn_Flag:"#".328
# GE65_Tot_Clms:"".431
# GE65_Tot_30day_Fills:"".431
# GE65_Tot_Drug_Cst:"".431
# GE65_Tot_Day_Suply:"".431
# GE65_Bene_Sprsn_Flag:"#".304
# GE65_Tot_Benes:""}.849
# {"Prscrbr_NPI":"1003004201".73
# Prscrbr_Last_Org_Name:"Philbrick".73
# Prscrbr_First_Name:"Natalie".73
# Prscrbr_City:"Corpus Christi".73
# Prscrbr_State_Abrvtn:"TX".121
# Prscrbr_State_FIPS:"48".121
# Prscrbr_Type:"Internal Medicine".195
# Prscrbr_Type_Src:"Claim-Specialty".783
# Brnd_Name:"Mirtazapine".4
# Gnrc_Name:"Mirtazapine".4
# Tot_Clms:"11".57
# Tot_30day_Fills:"21.3"
# Tot_Day_Suply:"640"
# Tot_Drug_Cst:"174.68"
# Tot_Benes:"".511
# GE65_Sprsn_Flag:"".567
# GE65_Tot_Clms:"11".28
# GE65_Tot_30day_Fills:"21.3"
# GE65_Tot_Drug_Cst:"174.68"
# GE65_Tot_Day_Suply:"640"
# GE65_Bene_Sprsn_Flag:"*".545
# GE65_Tot_Benes:""}]
# Drug Name column: [{"Prscrbr_NPI":"1003000126"
# Total Drug Cost column: [{"Prscrbr_NPI":"1003000126"
# Total Claims column: Prscrbr_Last_Org_Name:"Enkeshafi"

# %%
#10
# Fetch full 2020 CMS data and print real column names
df_full = pd.read_csv(f"{BASE_URL_CMS}?year=2020&format=csv")

print("\n Full 2020 CMS Columns:")
for col in df_full.columns:
    print(col)
# Out:
#  Full 2020 CMS Columns:
# [{"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi"
# Prscrbr_First_Name:"Ardalan"
# Prscrbr_City:"Bethesda"
# Prscrbr_State_Abrvtn:"MD"
# Prscrbr_State_FIPS:"24"
# Prscrbr_Type:"Hospitalist"
# Prscrbr_Type_Src:"Claim-Specialty"
# Brnd_Name:"Eliquis"
# Gnrc_Name:"Apixaban"
# Tot_Clms:"13"
# Tot_30day_Fills:"15.3"
# Tot_Day_Suply:"437"
# Tot_Drug_Cst:"8828.74"
# Tot_Benes:""
# GE65_Sprsn_Flag:"#"
# GE65_Tot_Clms:""
# GE65_Tot_30day_Fills:""
# GE65_Tot_Drug_Cst:""
# GE65_Tot_Day_Suply:""
# GE65_Bene_Sprsn_Flag:"*"
# GE65_Tot_Benes:""}
# {"Prscrbr_NPI":"1003000126"
# Prscrbr_Last_Org_Name:"Enkeshafi".1
# Prscrbr_First_Name:"Ardalan".1
# Prscrbr_City:"Bethesda".1
# Prscrbr_State_Abrvtn:"MD".1
# Prscrbr_State_FIPS:"24".1
# Prscrbr_Type:"Hospitalist".1
# Prscrbr_Type_Src:"Claim-Specialty".1
# Brnd_Name:"Prednisone"
# Gnrc_Name:"Prednisone"
# Tot_Clms:"14"
# Tot_30day_Fills:"14"
# Tot_Day_Suply:"153"
# Tot_Drug_Cst:"54.98"
# Tot_Benes:"14"
# GE65_Sprsn_Flag:"#".1
# GE65_Tot_Clms:"".1
# GE65_Tot_30day_Fills:"".1
# GE65_Tot_Drug_Cst:"".1
# GE65_Tot_Day_Suply:"".1
# GE65_Bene_Sprsn_Flag:"#"
# GE65_Tot_Benes:""}.1
# {"Prscrbr_NPI":"1003000142"
# Prscrbr_Last_Org_Name:"Khalil"
# Prscrbr_First_Name:"Rashid"
# Prscrbr_City:"Toledo"
# Prscrbr_State_Abrvtn:"OH"
# Prscrbr_State_FIPS:"39"
# Prscrbr_Type:"Anesthesiology"
# Prscrbr_Type_Src:"Claim-Specialty".2
# Brnd_Name:"Acetaminophen-Codeine"
# Gnrc_Name:"Acetaminophen With Codeine"
# Tot_Clms:"43"
# Tot_30day_Fills:"43"
# Tot_Day_Suply:"1020"
# Tot_Drug_Cst:"491.38"
# Tot_Benes:"12"
# GE65_Sprsn_Flag:"#".2
# GE65_Tot_Clms:"".2
# GE65_Tot_30day_Fills:"".2
# GE65_Tot_Drug_Cst:"".2
# GE65_Tot_Day_Suply:"".2
# GE65_Bene_Sprsn_Flag:"*".1
# GE65_Tot_Benes:""}.2
# {"Prscrbr_NPI":"1003000142".1
# Prscrbr_Last_Org_Name:"Khalil".1
# Prscrbr_First_Name:"Rashid".1
# Prscrbr_City:"Toledo".1
# Prscrbr_State_Abrvtn:"OH".1
# Prscrbr_State_FIPS:"39".1
# Prscrbr_Type:"Anesthesiology".1
# Prscrbr_Type_Src:"Claim-Specialty".3
# Brnd_Name:"Amitriptyline Hcl"
# Gnrc_Name:"Amitriptyline Hcl"
# Tot_Clms:"35"
# Tot_30day_Fills:"35"
# Tot_Day_Suply:"1050"
# Tot_Drug_Cst:"471.01"
# Tot_Benes:"15"
# GE65_Sprsn_Flag:"#".3
# GE65_Tot_Clms:"".3
# GE65_Tot_30day_Fills:"".3
# GE65_Tot_Drug_Cst:"".3
# GE65_Tot_Day_Suply:"".3
# GE65_Bene_Sprsn_Flag:"*".2
# GE65_Tot_Benes:""}.3
# {"Prscrbr_NPI":"1003000142".2
# Prscrbr_Last_Org_Name:"Khalil".2
# Prscrbr_First_Name:"Rashid".2
# Prscrbr_City:"Toledo".2
# Prscrbr_State_Abrvtn:"OH".2
# Prscrbr_State_FIPS:"39".2
# Prscrbr_Type:"Anesthesiology".2
# Prscrbr_Type_Src:"Claim-Specialty".4
# Brnd_Name:"Baclofen"
# Gnrc_Name:"Baclofen"
# Tot_Clms:"55"
# Tot_30day_Fills:"63"
# Tot_Day_Suply:"1890"
# Tot_Drug_Cst:"796.1"
# Tot_Benes:"23"
# GE65_Sprsn_Flag:""
# GE65_Tot_Clms:"27"
# GE65_Tot_30day_Fills:"29"
# GE65_Tot_Drug_Cst:"417.86"
# GE65_Tot_Day_Suply:"870"
# GE65_Bene_Sprsn_Flag:"*".3
# GE65_Tot_Benes:""}.4
# {"Prscrbr_NPI":"1003000142".3
# Prscrbr_Last_Org_Name:"Khalil".3
# Prscrbr_First_Name:"Rashid".3
# Prscrbr_City:"Toledo".3
# Prscrbr_State_Abrvtn:"OH".3
# Prscrbr_State_FIPS:"39".3
# Prscrbr_Type:"Anesthesiology".3
# Prscrbr_Type_Src:"Claim-Specialty".5
# Brnd_Name:"Buprenorphine"
# Gnrc_Name:"Buprenorphine"
# Tot_Clms:"16"
# Tot_30day_Fills:"16"
# Tot_Day_Suply:"448"
# Tot_Drug_Cst:"6229.05"
# Tot_Benes:"".1
# GE65_Sprsn_Flag:"*"
# GE65_Tot_Clms:"".4
# GE65_Tot_30day_Fills:"".4
# GE65_Tot_Drug_Cst:"".4
# GE65_Tot_Day_Suply:"".4
# GE65_Bene_Sprsn_Flag:"*".4
# GE65_Tot_Benes:""}.5
# {"Prscrbr_NPI":"1003000142".4
# Prscrbr_Last_Org_Name:"Khalil".4
# Prscrbr_First_Name:"Rashid".4
# Prscrbr_City:"Toledo".4
# Prscrbr_State_Abrvtn:"OH".4
# Prscrbr_State_FIPS:"39".4
# Prscrbr_Type:"Anesthesiology".4
# Prscrbr_Type_Src:"Claim-Specialty".6
# Brnd_Name:"Cyclobenzaprine Hcl"
# Gnrc_Name:"Cyclobenzaprine Hcl"
# Tot_Clms:"54"
# Tot_30day_Fills:"56"
# Tot_Day_Suply:"1645"
# Tot_Drug_Cst:"572.47"
# Tot_Benes:"30"
# GE65_Sprsn_Flag:"".1
# GE65_Tot_Clms:"16"
# GE65_Tot_30day_Fills:"16"
# GE65_Tot_Drug_Cst:"217.6"
# GE65_Tot_Day_Suply:"455"
# GE65_Bene_Sprsn_Flag:""
# GE65_Tot_Benes:"11"}
# {"Prscrbr_NPI":"1003000142".5
# Prscrbr_Last_Org_Name:"Khalil".5
# Prscrbr_First_Name:"Rashid".5
# Prscrbr_City:"Toledo".5
# Prscrbr_State_Abrvtn:"OH".5
# Prscrbr_State_FIPS:"39".5
# Prscrbr_Type:"Anesthesiology".5
# Prscrbr_Type_Src:"Claim-Specialty".7
# Brnd_Name:"Dantrolene Sodium"
# Gnrc_Name:"Dantrolene Sodium"
# Tot_Clms:"14".1
# Tot_30day_Fills:"14".1
# Tot_Day_Suply:"221"
# Tot_Drug_Cst:"236.09"
# Tot_Benes:"13"
# GE65_Sprsn_Flag:"*".1
# GE65_Tot_Clms:"".5
# GE65_Tot_30day_Fills:"".5
# GE65_Tot_Drug_Cst:"".5
# GE65_Tot_Day_Suply:"".5
# GE65_Bene_Sprsn_Flag:"*".5
# GE65_Tot_Benes:""}.6
# {"Prscrbr_NPI":"1003000142".6
# Prscrbr_Last_Org_Name:"Khalil".6
# Prscrbr_First_Name:"Rashid".6
# Prscrbr_City:"Toledo".6
# Prscrbr_State_Abrvtn:"OH".6
# Prscrbr_State_FIPS:"39".6
# Prscrbr_Type:"Anesthesiology".6
# Prscrbr_Type_Src:"Claim-Specialty".8
# Brnd_Name:"Diclofenac Sodium"
# Gnrc_Name:"Diclofenac Sodium"
# Tot_Clms:"82"
# Tot_30day_Fills:"82"
# Tot_Day_Suply:"1629"
# Tot_Drug_Cst:"2423.34"
# Tot_Benes:"42"
# GE65_Sprsn_Flag:"".2
# GE65_Tot_Clms:"42"
# GE65_Tot_30day_Fills:"42"
# GE65_Tot_Drug_Cst:"1374.84"
# GE65_Tot_Day_Suply:"753"
# GE65_Bene_Sprsn_Flag:"".1
# GE65_Tot_Benes:"24"}
# {"Prscrbr_NPI":"1003000142".7
# Prscrbr_Last_Org_Name:"Khalil".7
# Prscrbr_First_Name:"Rashid".7
# Prscrbr_City:"Toledo".7
# Prscrbr_State_Abrvtn:"OH".7
# Prscrbr_State_FIPS:"39".7
# Prscrbr_Type:"Anesthesiology".7
# Prscrbr_Type_Src:"Claim-Specialty".9
# Brnd_Name:"Duloxetine Hcl"
# Gnrc_Name:"Duloxetine Hcl"
# Tot_Clms:"27"
# Tot_30day_Fills:"31"
# Tot_Day_Suply:"930"
# Tot_Drug_Cst:"337.43"
# Tot_Benes:"14".1
# GE65_Sprsn_Flag:"".3
# GE65_Tot_Clms:"11"
# GE65_Tot_30day_Fills:"13"
# GE65_Tot_Drug_Cst:"159.01"
# GE65_Tot_Day_Suply:"390"
# GE65_Bene_Sprsn_Flag:"*".6
# GE65_Tot_Benes:""}.7
# {"Prscrbr_NPI":"1003000142".8
# Prscrbr_Last_Org_Name:"Khalil".8
# Prscrbr_First_Name:"Rashid".8
# Prscrbr_City:"Toledo".8
# Prscrbr_State_Abrvtn:"OH".8
# Prscrbr_State_FIPS:"39".8
# Prscrbr_Type:"Anesthesiology".8
# Prscrbr_Type_Src:"Claim-Specialty".10
# Brnd_Name:"Gabapentin"
# Gnrc_Name:"Gabapentin"
# Tot_Clms:"281"
# Tot_30day_Fills:"345"
# Tot_Day_Suply:"10315"
# Tot_Drug_Cst:"5713.75"
# Tot_Benes:"125"
# GE65_Sprsn_Flag:"".4
# GE65_Tot_Clms:"167"
# GE65_Tot_30day_Fills:"209"
# GE65_Tot_Drug_Cst:"3585.65"
# GE65_Tot_Day_Suply:"6255"
# GE65_Bene_Sprsn_Flag:"".2
# GE65_Tot_Benes:"73"}
# {"Prscrbr_NPI":"1003000142".9
# Prscrbr_Last_Org_Name:"Khalil".9
# Prscrbr_First_Name:"Rashid".9
# Prscrbr_City:"Toledo".9
# Prscrbr_State_Abrvtn:"OH".9
# Prscrbr_State_FIPS:"39".9
# Prscrbr_Type:"Anesthesiology".9
# Prscrbr_Type_Src:"Claim-Specialty".11
# Brnd_Name:"Hydrocodone-Acetaminophen"
# Gnrc_Name:"Hydrocodone\/Acetaminophen"
# Tot_Clms:"355"
# Tot_30day_Fills:"355.5"
# Tot_Day_Suply:"9511"
# Tot_Drug_Cst:"7202.47"
# Tot_Benes:"171"
# GE65_Sprsn_Flag:"".5
# GE65_Tot_Clms:"214"
# GE65_Tot_30day_Fills:"214"
# GE65_Tot_Drug_Cst:"4543.33"
# GE65_Tot_Day_Suply:"5669"
# GE65_Bene_Sprsn_Flag:"".3
# GE65_Tot_Benes:"110"}
# {"Prscrbr_NPI":"1003000142".10
# Prscrbr_Last_Org_Name:"Khalil".10
# Prscrbr_First_Name:"Rashid".10
# Prscrbr_City:"Toledo".10
# Prscrbr_State_Abrvtn:"OH".10
# Prscrbr_State_FIPS:"39".10
# Prscrbr_Type:"Anesthesiology".10
# Prscrbr_Type_Src:"Claim-Specialty".12
# Brnd_Name:"Lidocaine"
# Gnrc_Name:"Lidocaine"
# Tot_Clms:"20"
# Tot_30day_Fills:"20"
# Tot_Day_Suply:"525"
# Tot_Drug_Cst:"2146.83"
# Tot_Benes:"12".1
# GE65_Sprsn_Flag:"#".4
# GE65_Tot_Clms:"".6
# GE65_Tot_30day_Fills:"".6
# GE65_Tot_Drug_Cst:"".6
# GE65_Tot_Day_Suply:"".6
# GE65_Bene_Sprsn_Flag:"*".7
# GE65_Tot_Benes:""}.8
# {"Prscrbr_NPI":"1003000142".11
# Prscrbr_Last_Org_Name:"Khalil".11
# Prscrbr_First_Name:"Rashid".11
# Prscrbr_City:"Toledo".11
# Prscrbr_State_Abrvtn:"OH".11
# Prscrbr_State_FIPS:"39".11
# Prscrbr_Type:"Anesthesiology".11
# Prscrbr_Type_Src:"Claim-Specialty".13
# Brnd_Name:"Meloxicam"
# Gnrc_Name:"Meloxicam"
# Tot_Clms:"57"
# Tot_30day_Fills:"65"
# Tot_Day_Suply:"1948"
# Tot_Drug_Cst:"230.35"
# Tot_Benes:"25"
# GE65_Sprsn_Flag:"".6
# GE65_Tot_Clms:"19"
# GE65_Tot_30day_Fills:"21"
# GE65_Tot_Drug_Cst:"68.52"
# GE65_Tot_Day_Suply:"630"
# GE65_Bene_Sprsn_Flag:"*".8
# GE65_Tot_Benes:""}.9
# {"Prscrbr_NPI":"1003000142".12
# Prscrbr_Last_Org_Name:"Khalil".12
# Prscrbr_First_Name:"Rashid".12
# Prscrbr_City:"Toledo".12
# Prscrbr_State_Abrvtn:"OH".12
# Prscrbr_State_FIPS:"39".12
# Prscrbr_Type:"Anesthesiology".12
# Prscrbr_Type_Src:"Claim-Specialty".14
# Brnd_Name:"Methocarbamol"
# Gnrc_Name:"Methocarbamol"
# Tot_Clms:"14".2
# Tot_30day_Fills:"14".2
# Tot_Day_Suply:"375"
# Tot_Drug_Cst:"231.58"
# Tot_Benes:"".2
# GE65_Sprsn_Flag:"*".2
# GE65_Tot_Clms:"".7
# GE65_Tot_30day_Fills:"".7
# GE65_Tot_Drug_Cst:"".7
# GE65_Tot_Day_Suply:"".7
# GE65_Bene_Sprsn_Flag:"*".9
# GE65_Tot_Benes:""}.10
# {"Prscrbr_NPI":"1003000142".13
# Prscrbr_Last_Org_Name:"Khalil".13
# Prscrbr_First_Name:"Rashid".13
# Prscrbr_City:"Toledo".13
# Prscrbr_State_Abrvtn:"OH".13
# Prscrbr_State_FIPS:"39".13
# Prscrbr_Type:"Anesthesiology".13
# Prscrbr_Type_Src:"Claim-Specialty".15
# Brnd_Name:"Morphine Sulfate Er"
# Gnrc_Name:"Morphine Sulfate"
# Tot_Clms:"35".1
# Tot_30day_Fills:"35".1
# Tot_Day_Suply:"1050".1
# Tot_Drug_Cst:"633.8"
# Tot_Benes:"13".1
# GE65_Sprsn_Flag:"#".5
# GE65_Tot_Clms:"".8
# GE65_Tot_30day_Fills:"".8
# GE65_Tot_Drug_Cst:"".8
# GE65_Tot_Day_Suply:"".8
# GE65_Bene_Sprsn_Flag:"*".10
# GE65_Tot_Benes:""}.11
# {"Prscrbr_NPI":"1003000142".14
# Prscrbr_Last_Org_Name:"Khalil".14
# Prscrbr_First_Name:"Rashid".14
# Prscrbr_City:"Toledo".14
# Prscrbr_State_Abrvtn:"OH".14
# Prscrbr_State_FIPS:"39".14
# Prscrbr_Type:"Anesthesiology".14
# Prscrbr_Type_Src:"Claim-Specialty".16
# Brnd_Name:"Movantik"
# Gnrc_Name:"Naloxegol Oxalate"
# Tot_Clms:"21"
# Tot_30day_Fills:"29"
# Tot_Day_Suply:"844"
# Tot_Drug_Cst:"11694.14"
# Tot_Benes:"13".2
# GE65_Sprsn_Flag:"#".6
# GE65_Tot_Clms:"".9
# GE65_Tot_30day_Fills:"".9
# GE65_Tot_Drug_Cst:"".9
# GE65_Tot_Day_Suply:"".9
# GE65_Bene_Sprsn_Flag:"*".11
# GE65_Tot_Benes:""}.12
# {"Prscrbr_NPI":"1003000142".15
# Prscrbr_Last_Org_Name:"Khalil".15
# Prscrbr_First_Name:"Rashid".15
# Prscrbr_City:"Toledo".15
# Prscrbr_State_Abrvtn:"OH".15
# Prscrbr_State_FIPS:"39".15
# Prscrbr_Type:"Anesthesiology".15
# Prscrbr_Type_Src:"Claim-Specialty".17
# Brnd_Name:"Oxycodone Hcl"
# Gnrc_Name:"Oxycodone Hcl"
# Tot_Clms:"84"
# Tot_30day_Fills:"84"
# Tot_Day_Suply:"2439"
# Tot_Drug_Cst:"1269.35"
# Tot_Benes:"39"
# GE65_Sprsn_Flag:"".7
# GE65_Tot_Clms:"62"
# GE65_Tot_30day_Fills:"62"
# GE65_Tot_Drug_Cst:"983.14"
# GE65_Tot_Day_Suply:"1795"
# GE65_Bene_Sprsn_Flag:"".4
# GE65_Tot_Benes:"27"}
# {"Prscrbr_NPI":"1003000142".16
# Prscrbr_Last_Org_Name:"Khalil".16
# Prscrbr_First_Name:"Rashid".16
# Prscrbr_City:"Toledo".16
# Prscrbr_State_Abrvtn:"OH".16
# Prscrbr_State_FIPS:"39".16
# Prscrbr_Type:"Anesthesiology".16
# Prscrbr_Type_Src:"Claim-Specialty".18
# Brnd_Name:"Oxycodone-Acetaminophen"
# Gnrc_Name:"Oxycodone Hcl\/Acetaminophen"
# Tot_Clms:"194"
# Tot_30day_Fills:"194"
# Tot_Day_Suply:"5644"
# Tot_Drug_Cst:"5029.88"
# Tot_Benes:"94"
# GE65_Sprsn_Flag:"".8
# GE65_Tot_Clms:"94"
# GE65_Tot_30day_Fills:"94"
# GE65_Tot_Drug_Cst:"2155.06"
# GE65_Tot_Day_Suply:"2727"
# GE65_Bene_Sprsn_Flag:"".5
# GE65_Tot_Benes:"48"}
# {"Prscrbr_NPI":"1003000142".17
# Prscrbr_Last_Org_Name:"Khalil".17
# Prscrbr_First_Name:"Rashid".17
# Prscrbr_City:"Toledo".17
# Prscrbr_State_Abrvtn:"OH".17
# Prscrbr_State_FIPS:"39".17
# Prscrbr_Type:"Anesthesiology".17
# Prscrbr_Type_Src:"Claim-Specialty".19
# Brnd_Name:"Pregabalin"
# Gnrc_Name:"Pregabalin"
# Tot_Clms:"143"
# Tot_30day_Fills:"153"
# Tot_Day_Suply:"4425"
# Tot_Drug_Cst:"6575.8"
# Tot_Benes:"58"
# GE65_Sprsn_Flag:"".9
# GE65_Tot_Clms:"61"
# GE65_Tot_30day_Fills:"65"
# GE65_Tot_Drug_Cst:"2168.07"
# GE65_Tot_Day_Suply:"1819"
# GE65_Bene_Sprsn_Flag:"".6
# GE65_Tot_Benes:"27"}.1
# {"Prscrbr_NPI":"1003000142".18
# Prscrbr_Last_Org_Name:"Khalil".18
# Prscrbr_First_Name:"Rashid".18
# Prscrbr_City:"Toledo".18
# Prscrbr_State_Abrvtn:"OH".18
# Prscrbr_State_FIPS:"39".18
# Prscrbr_Type:"Anesthesiology".18
# Prscrbr_Type_Src:"Claim-Specialty".20
# Brnd_Name:"Tizanidine Hcl"
# Gnrc_Name:"Tizanidine Hcl"
# Tot_Clms:"126"
# Tot_30day_Fills:"140"
# Tot_Day_Suply:"4064"
# Tot_Drug_Cst:"1426.75"
# Tot_Benes:"66"
# GE65_Sprsn_Flag:"".10
# GE65_Tot_Clms:"51"
# GE65_Tot_30day_Fills:"51"
# GE65_Tot_Drug_Cst:"515.26"
# GE65_Tot_Day_Suply:"1449"
# GE65_Bene_Sprsn_Flag:"".7
# GE65_Tot_Benes:"29"}
# {"Prscrbr_NPI":"1003000142".19
# Prscrbr_Last_Org_Name:"Khalil".19
# Prscrbr_First_Name:"Rashid".19
# Prscrbr_City:"Toledo".19
# Prscrbr_State_Abrvtn:"OH".19
# Prscrbr_State_FIPS:"39".19
# Prscrbr_Type:"Anesthesiology".19
# Prscrbr_Type_Src:"Claim-Specialty".21
# Brnd_Name:"Topiramate"
# Gnrc_Name:"Topiramate"
# Tot_Clms:"16".1
# Tot_30day_Fills:"22"
# Tot_Day_Suply:"660"
# Tot_Drug_Cst:"199.68"
# Tot_Benes:"".3
# GE65_Sprsn_Flag:"*".3
# GE65_Tot_Clms:"".10
# GE65_Tot_30day_Fills:"".10
# GE65_Tot_Drug_Cst:"".10
# GE65_Tot_Day_Suply:"".10
# GE65_Bene_Sprsn_Flag:"*".12
# GE65_Tot_Benes:""}.13
# {"Prscrbr_NPI":"1003000142".20
# Prscrbr_Last_Org_Name:"Khalil".20
# Prscrbr_First_Name:"Rashid".20
# Prscrbr_City:"Toledo".20
# Prscrbr_State_Abrvtn:"OH".20
# Prscrbr_State_FIPS:"39".20
# Prscrbr_Type:"Anesthesiology".20
# Prscrbr_Type_Src:"Claim-Specialty".22
# Brnd_Name:"Tramadol Hcl"
# Gnrc_Name:"Tramadol Hcl"
# Tot_Clms:"97"
# Tot_30day_Fills:"97"
# Tot_Day_Suply:"2550"
# Tot_Drug_Cst:"529"
# Tot_Benes:"41"
# GE65_Sprsn_Flag:"".11
# GE65_Tot_Clms:"68"
# GE65_Tot_30day_Fills:"68"
# GE65_Tot_Drug_Cst:"344.88"
# GE65_Tot_Day_Suply:"1756"
# GE65_Bene_Sprsn_Flag:"".8
# GE65_Tot_Benes:"29"}.1
# {"Prscrbr_NPI":"1003000167"
# Prscrbr_Last_Org_Name:"Escobar"
# Prscrbr_First_Name:"Julio"
# Prscrbr_City:"Dayton"
# Prscrbr_State_Abrvtn:"NV"
# Prscrbr_State_FIPS:"32"
# Prscrbr_Type:"Dentist"
# Prscrbr_Type_Src:"NPPES-Specialty"
# Brnd_Name:"Amoxicillin"
# Gnrc_Name:"Amoxicillin"
# Tot_Clms:"51"
# Tot_30day_Fills:"51"
# Tot_Day_Suply:"308"
# Tot_Drug_Cst:"152.04"
# Tot_Benes:"43"
# GE65_Sprsn_Flag:"#".7
# GE65_Tot_Clms:"".11
# GE65_Tot_30day_Fills:"".11
# GE65_Tot_Drug_Cst:"".11
# GE65_Tot_Day_Suply:"".11
# GE65_Bene_Sprsn_Flag:"#".1
# GE65_Tot_Benes:""}.14
# {"Prscrbr_NPI":"1003000167".1
# Prscrbr_Last_Org_Name:"Escobar".1
# Prscrbr_First_Name:"Julio".1
# Prscrbr_City:"Dayton".1
# Prscrbr_State_Abrvtn:"NV".1
# Prscrbr_State_FIPS:"32".1
# Prscrbr_Type:"Dentist".1
# Prscrbr_Type_Src:"NPPES-Specialty".1
# Brnd_Name:"Dexamethasone"
# Gnrc_Name:"Dexamethasone"
# Tot_Clms:"20".1
# Tot_30day_Fills:"20".1
# Tot_Day_Suply:"20"
# Tot_Drug_Cst:"38.04"
# Tot_Benes:"17"
# GE65_Sprsn_Flag:"#".8
# GE65_Tot_Clms:"".12
# GE65_Tot_30day_Fills:"".12
# GE65_Tot_Drug_Cst:"".12
# GE65_Tot_Day_Suply:"".12
# GE65_Bene_Sprsn_Flag:"#".2
# GE65_Tot_Benes:""}.15
# {"Prscrbr_NPI":"1003000423"
# Prscrbr_Last_Org_Name:"Velotta"
# Prscrbr_First_Name:"Jennifer"
# Prscrbr_City:"Cleveland"
# Prscrbr_State_Abrvtn:"OH".21
# Prscrbr_State_FIPS:"39".21
# Prscrbr_Type:"Obstetrics \u0026 Gynecology"
# Prscrbr_Type_Src:"Claim-Specialty".23
# Brnd_Name:"Clotrimazole-Betamethasone"
# Gnrc_Name:"Clotrimazole\/Betamethasone Dip"
# Tot_Clms:"19"
# Tot_30day_Fills:"19"
# Tot_Day_Suply:"249"
# Tot_Drug_Cst:"250.55"
# Tot_Benes:"".4
# GE65_Sprsn_Flag:"#".9
# GE65_Tot_Clms:"".13
# GE65_Tot_30day_Fills:"".13
# GE65_Tot_Drug_Cst:"".13
# GE65_Tot_Day_Suply:"".13
# GE65_Bene_Sprsn_Flag:"*".13
# GE65_Tot_Benes:""}.16
# {"Prscrbr_NPI":"1003000423".1
# Prscrbr_Last_Org_Name:"Velotta".1
# Prscrbr_First_Name:"Jennifer".1
# Prscrbr_City:"Cleveland".1
# Prscrbr_State_Abrvtn:"OH".22
# Prscrbr_State_FIPS:"39".22
# Prscrbr_Type:"Obstetrics \u0026 Gynecology".1
# Prscrbr_Type_Src:"Claim-Specialty".24
# Brnd_Name:"Estradiol"
# Gnrc_Name:"Estradiol"
# Tot_Clms:"39"
# Tot_30day_Fills:"112.4"
# Tot_Day_Suply:"3359"
# Tot_Drug_Cst:"5419.72"
# Tot_Benes:"19"
# GE65_Sprsn_Flag:"#".10
# GE65_Tot_Clms:"".14
# GE65_Tot_30day_Fills:"".14
# GE65_Tot_Drug_Cst:"".14
# GE65_Tot_Day_Suply:"".14
# GE65_Bene_Sprsn_Flag:"#".3
# GE65_Tot_Benes:""}.17
# {"Prscrbr_NPI":"1003000480"
# Prscrbr_Last_Org_Name:"Rothchild"
# Prscrbr_First_Name:"Kevin"
# Prscrbr_City:"Aurora"
# Prscrbr_State_Abrvtn:"CO"
# Prscrbr_State_FIPS:"08"
# Prscrbr_Type:"General Surgery"
# Prscrbr_Type_Src:"Claim-Specialty".25
# Brnd_Name:"Omeprazole"
# Gnrc_Name:"Omeprazole"
# Tot_Clms:"16".2
# Tot_30day_Fills:"18.1"
# Tot_Day_Suply:"543"
# Tot_Drug_Cst:"384.12"
# Tot_Benes:"".5
# GE65_Sprsn_Flag:"*".4
# GE65_Tot_Clms:"".15
# GE65_Tot_30day_Fills:"".15
# GE65_Tot_Drug_Cst:"".15
# GE65_Tot_Day_Suply:"".15
# GE65_Bene_Sprsn_Flag:"*".14
# GE65_Tot_Benes:""}.18
# {"Prscrbr_NPI":"1003000480".1
# Prscrbr_Last_Org_Name:"Rothchild".1
# Prscrbr_First_Name:"Kevin".1
# Prscrbr_City:"Aurora".1
# Prscrbr_State_Abrvtn:"CO".1
# Prscrbr_State_FIPS:"08".1
# Prscrbr_Type:"General Surgery".1
# Prscrbr_Type_Src:"Claim-Specialty".26
# Brnd_Name:"Oxycodone Hcl".1
# Gnrc_Name:"Oxycodone Hcl".1
# Tot_Clms:"12"
# Tot_30day_Fills:"12"
# Tot_Day_Suply:"40"
# Tot_Drug_Cst:"25.58"
# Tot_Benes:"12".2
# GE65_Sprsn_Flag:"*".5
# GE65_Tot_Clms:"".16
# GE65_Tot_30day_Fills:"".16
# GE65_Tot_Drug_Cst:"".16
# GE65_Tot_Day_Suply:"".16
# GE65_Bene_Sprsn_Flag:"*".15
# GE65_Tot_Benes:""}.19
# {"Prscrbr_NPI":"1003000530"
# Prscrbr_Last_Org_Name:"Semonche"
# Prscrbr_First_Name:"Amanda"
# Prscrbr_City:"Quakertown"
# Prscrbr_State_Abrvtn:"PA"
# Prscrbr_State_FIPS:"42"
# Prscrbr_Type:"Internal Medicine"
# Prscrbr_Type_Src:"Claim-Specialty".27
# Brnd_Name:"Advair Diskus"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol"
# Tot_Clms:"18"
# Tot_30day_Fills:"25"
# Tot_Day_Suply:"750"
# Tot_Drug_Cst:"8222.59"
# Tot_Benes:"".6
# GE65_Sprsn_Flag:"".12
# GE65_Tot_Clms:"18"
# GE65_Tot_30day_Fills:"25"
# GE65_Tot_Drug_Cst:"8222.59"
# GE65_Tot_Day_Suply:"750"
# GE65_Bene_Sprsn_Flag:"*".16
# GE65_Tot_Benes:""}.20
# {"Prscrbr_NPI":"1003000530".1
# Prscrbr_Last_Org_Name:"Semonche".1
# Prscrbr_First_Name:"Amanda".1
# Prscrbr_City:"Quakertown".1
# Prscrbr_State_Abrvtn:"PA".1
# Prscrbr_State_FIPS:"42".1
# Prscrbr_Type:"Internal Medicine".1
# Prscrbr_Type_Src:"Claim-Specialty".28
# Brnd_Name:"Albuterol Sulfate Hfa"
# Gnrc_Name:"Albuterol Sulfate"
# Tot_Clms:"54".1
# Tot_30day_Fills:"59.9"
# Tot_Day_Suply:"1385"
# Tot_Drug_Cst:"1900.5"
# Tot_Benes:"24"
# GE65_Sprsn_Flag:"#".11
# GE65_Tot_Clms:"".17
# GE65_Tot_30day_Fills:"".17
# GE65_Tot_Drug_Cst:"".17
# GE65_Tot_Day_Suply:"".17
# GE65_Bene_Sprsn_Flag:"#".4
# GE65_Tot_Benes:""}.21
# {"Prscrbr_NPI":"1003000530".2
# Prscrbr_Last_Org_Name:"Semonche".2
# Prscrbr_First_Name:"Amanda".2
# Prscrbr_City:"Quakertown".2
# Prscrbr_State_Abrvtn:"PA".2
# Prscrbr_State_FIPS:"42".2
# Prscrbr_Type:"Internal Medicine".2
# Prscrbr_Type_Src:"Claim-Specialty".29
# Brnd_Name:"Alendronate Sodium"
# Gnrc_Name:"Alendronate Sodium"
# Tot_Clms:"68"
# Tot_30day_Fills:"155.1"
# Tot_Day_Suply:"4611"
# Tot_Drug_Cst:"876.77"
# Tot_Benes:"17".1
# GE65_Sprsn_Flag:"".13
# GE65_Tot_Clms:"68".1
# GE65_Tot_30day_Fills:"155.1"
# GE65_Tot_Drug_Cst:"876.77"
# GE65_Tot_Day_Suply:"4611"
# GE65_Bene_Sprsn_Flag:"".9
# GE65_Tot_Benes:"17"}
# {"Prscrbr_NPI":"1003000530".3
# Prscrbr_Last_Org_Name:"Semonche".3
# Prscrbr_First_Name:"Amanda".3
# Prscrbr_City:"Quakertown".3
# Prscrbr_State_Abrvtn:"PA".3
# Prscrbr_State_FIPS:"42".3
# Prscrbr_Type:"Internal Medicine".3
# Prscrbr_Type_Src:"Claim-Specialty".30
# Brnd_Name:"Alfuzosin Hcl Er"
# Gnrc_Name:"Alfuzosin Hcl"
# Tot_Clms:"13".1
# Tot_30day_Fills:"13"
# Tot_Day_Suply:"390"
# Tot_Drug_Cst:"121.14"
# Tot_Benes:"".7
# GE65_Sprsn_Flag:"".14
# GE65_Tot_Clms:"13"
# GE65_Tot_30day_Fills:"13".1
# GE65_Tot_Drug_Cst:"121.14"
# GE65_Tot_Day_Suply:"390".1
# GE65_Bene_Sprsn_Flag:"*".17
# GE65_Tot_Benes:""}.22
# {"Prscrbr_NPI":"1003000530".4
# Prscrbr_Last_Org_Name:"Semonche".4
# Prscrbr_First_Name:"Amanda".4
# Prscrbr_City:"Quakertown".4
# Prscrbr_State_Abrvtn:"PA".4
# Prscrbr_State_FIPS:"42".4
# Prscrbr_Type:"Internal Medicine".4
# Prscrbr_Type_Src:"Claim-Specialty".31
# Brnd_Name:"Allopurinol"
# Gnrc_Name:"Allopurinol"
# Tot_Clms:"57".1
# Tot_30day_Fills:"155"
# Tot_Day_Suply:"4650"
# Tot_Drug_Cst:"927.53"
# Tot_Benes:"14".2
# GE65_Sprsn_Flag:"".15
# GE65_Tot_Clms:"57"
# GE65_Tot_30day_Fills:"155"
# GE65_Tot_Drug_Cst:"927.53"
# GE65_Tot_Day_Suply:"4650"
# GE65_Bene_Sprsn_Flag:"".10
# GE65_Tot_Benes:"14"}
# {"Prscrbr_NPI":"1003000530".5
# Prscrbr_Last_Org_Name:"Semonche".5
# Prscrbr_First_Name:"Amanda".5
# Prscrbr_City:"Quakertown".5
# Prscrbr_State_Abrvtn:"PA".5
# Prscrbr_State_FIPS:"42".5
# Prscrbr_Type:"Internal Medicine".5
# Prscrbr_Type_Src:"Claim-Specialty".32
# Brnd_Name:"Alprazolam"
# Gnrc_Name:"Alprazolam"
# Tot_Clms:"31"
# Tot_30day_Fills:"54"
# Tot_Day_Suply:"1590"
# Tot_Drug_Cst:"194.85"
# Tot_Benes:"11"
# GE65_Sprsn_Flag:"#".12
# GE65_Tot_Clms:"".18
# GE65_Tot_30day_Fills:"".18
# GE65_Tot_Drug_Cst:"".18
# GE65_Tot_Day_Suply:"".18
# GE65_Bene_Sprsn_Flag:"*".18
# GE65_Tot_Benes:""}.23
# {"Prscrbr_NPI":"1003000530".6
# Prscrbr_Last_Org_Name:"Semonche".6
# Prscrbr_First_Name:"Amanda".6
# Prscrbr_City:"Quakertown".6
# Prscrbr_State_Abrvtn:"PA".6
# Prscrbr_State_FIPS:"42".6
# Prscrbr_Type:"Internal Medicine".6
# Prscrbr_Type_Src:"Claim-Specialty".33
# Brnd_Name:"Amiodarone Hcl"
# Gnrc_Name:"Amiodarone Hcl"
# Tot_Clms:"12".1
# Tot_30day_Fills:"12".1
# Tot_Day_Suply:"360"
# Tot_Drug_Cst:"122.76"
# Tot_Benes:"".8
# GE65_Sprsn_Flag:"".16
# GE65_Tot_Clms:"12"
# GE65_Tot_30day_Fills:"12"
# GE65_Tot_Drug_Cst:"122.76"
# GE65_Tot_Day_Suply:"360"
# GE65_Bene_Sprsn_Flag:"*".19
# GE65_Tot_Benes:""}.24
# {"Prscrbr_NPI":"1003000530".7
# Prscrbr_Last_Org_Name:"Semonche".7
# Prscrbr_First_Name:"Amanda".7
# Prscrbr_City:"Quakertown".7
# Prscrbr_State_Abrvtn:"PA".7
# Prscrbr_State_FIPS:"42".7
# Prscrbr_Type:"Internal Medicine".7
# Prscrbr_Type_Src:"Claim-Specialty".34
# Brnd_Name:"Amlodipine Besylate"
# Gnrc_Name:"Amlodipine Besylate"
# Tot_Clms:"419"
# Tot_30day_Fills:"976.7"
# Tot_Day_Suply:"29238"
# Tot_Drug_Cst:"3238.1"
# Tot_Benes:"101"
# GE65_Sprsn_Flag:"".17
# GE65_Tot_Clms:"403"
# GE65_Tot_30day_Fills:"956.5"
# GE65_Tot_Drug_Cst:"3171.72"
# GE65_Tot_Day_Suply:"28664"
# GE65_Bene_Sprsn_Flag:"#".5
# GE65_Tot_Benes:""}.25
# {"Prscrbr_NPI":"1003000530".8
# Prscrbr_Last_Org_Name:"Semonche".8
# Prscrbr_First_Name:"Amanda".8
# Prscrbr_City:"Quakertown".8
# Prscrbr_State_Abrvtn:"PA".8
# Prscrbr_State_FIPS:"42".8
# Prscrbr_Type:"Internal Medicine".8
# Prscrbr_Type_Src:"Claim-Specialty".35
# Brnd_Name:"Amoxicillin-Clavulanate Potass"
# Gnrc_Name:"Amoxicillin\/Potassium Clav"
# Tot_Clms:"29"
# Tot_30day_Fills:"29".1
# Tot_Day_Suply:"204"
# Tot_Drug_Cst:"299.35"
# Tot_Benes:"28"
# GE65_Sprsn_Flag:"#".13
# GE65_Tot_Clms:"".19
# GE65_Tot_30day_Fills:"".19
# GE65_Tot_Drug_Cst:"".19
# GE65_Tot_Day_Suply:"".19
# GE65_Bene_Sprsn_Flag:"#".6
# GE65_Tot_Benes:""}.26
# {"Prscrbr_NPI":"1003000530".9
# Prscrbr_Last_Org_Name:"Semonche".9
# Prscrbr_First_Name:"Amanda".9
# Prscrbr_City:"Quakertown".9
# Prscrbr_State_Abrvtn:"PA".9
# Prscrbr_State_FIPS:"42".9
# Prscrbr_Type:"Internal Medicine".9
# Prscrbr_Type_Src:"Claim-Specialty".36
# Brnd_Name:"Aripiprazole"
# Gnrc_Name:"Aripiprazole"
# Tot_Clms:"24"
# Tot_30day_Fills:"36"
# Tot_Day_Suply:"1080"
# Tot_Drug_Cst:"1879.6"
# Tot_Benes:"".9
# GE65_Sprsn_Flag:"#".14
# GE65_Tot_Clms:"".20
# GE65_Tot_30day_Fills:"".20
# GE65_Tot_Drug_Cst:"".20
# GE65_Tot_Day_Suply:"".20
# GE65_Bene_Sprsn_Flag:"*".20
# GE65_Tot_Benes:""}.27
# {"Prscrbr_NPI":"1003000530".10
# Prscrbr_Last_Org_Name:"Semonche".10
# Prscrbr_First_Name:"Amanda".10
# Prscrbr_City:"Quakertown".10
# Prscrbr_State_Abrvtn:"PA".10
# Prscrbr_State_FIPS:"42".10
# Prscrbr_Type:"Internal Medicine".10
# Prscrbr_Type_Src:"Claim-Specialty".37
# Brnd_Name:"Atenolol"
# Gnrc_Name:"Atenolol"
# Tot_Clms:"26"
# Tot_30day_Fills:"78"
# Tot_Day_Suply:"2340"
# Tot_Drug_Cst:"142.77"
# Tot_Benes:"".10
# GE65_Sprsn_Flag:"".18
# GE65_Tot_Clms:"26"
# GE65_Tot_30day_Fills:"78"
# GE65_Tot_Drug_Cst:"142.77"
# GE65_Tot_Day_Suply:"2340"
# GE65_Bene_Sprsn_Flag:"*".21
# GE65_Tot_Benes:""}.28
# {"Prscrbr_NPI":"1003000530".11
# Prscrbr_Last_Org_Name:"Semonche".11
# Prscrbr_First_Name:"Amanda".11
# Prscrbr_City:"Quakertown".11
# Prscrbr_State_Abrvtn:"PA".11
# Prscrbr_State_FIPS:"42".11
# Prscrbr_Type:"Internal Medicine".11
# Prscrbr_Type_Src:"Claim-Specialty".38
# Brnd_Name:"Atorvastatin Calcium"
# Gnrc_Name:"Atorvastatin Calcium"
# Tot_Clms:"470"
# Tot_30day_Fills:"1154.7"
# Tot_Day_Suply:"34590"
# Tot_Drug_Cst:"5690.05"
# Tot_Benes:"112"
# GE65_Sprsn_Flag:"".19
# GE65_Tot_Clms:"453"
# GE65_Tot_30day_Fills:"1117.7"
# GE65_Tot_Drug_Cst:"5225.24"
# GE65_Tot_Day_Suply:"33480"
# GE65_Bene_Sprsn_Flag:"#".7
# GE65_Tot_Benes:""}.29
# {"Prscrbr_NPI":"1003000530".12
# Prscrbr_Last_Org_Name:"Semonche".12
# Prscrbr_First_Name:"Amanda".12
# Prscrbr_City:"Quakertown".12
# Prscrbr_State_Abrvtn:"PA".12
# Prscrbr_State_FIPS:"42".12
# Prscrbr_Type:"Internal Medicine".12
# Prscrbr_Type_Src:"Claim-Specialty".39
# Brnd_Name:"Benazepril Hcl"
# Gnrc_Name:"Benazepril Hcl"
# Tot_Clms:"13".2
# Tot_30day_Fills:"37"
# Tot_Day_Suply:"1110"
# Tot_Drug_Cst:"282.77"
# Tot_Benes:"".11
# GE65_Sprsn_Flag:"".20
# GE65_Tot_Clms:"13".1
# GE65_Tot_30day_Fills:"37"
# GE65_Tot_Drug_Cst:"282.77"
# GE65_Tot_Day_Suply:"1110"
# GE65_Bene_Sprsn_Flag:"*".22
# GE65_Tot_Benes:""}.30
# {"Prscrbr_NPI":"1003000530".13
# Prscrbr_Last_Org_Name:"Semonche".13
# Prscrbr_First_Name:"Amanda".13
# Prscrbr_City:"Quakertown".13
# Prscrbr_State_Abrvtn:"PA".13
# Prscrbr_State_FIPS:"42".13
# Prscrbr_Type:"Internal Medicine".13
# Prscrbr_Type_Src:"Claim-Specialty".40
# Brnd_Name:"Bupropion Hcl Sr"
# Gnrc_Name:"Bupropion Hcl"
# Tot_Clms:"25"
# Tot_30day_Fills:"33.5"
# Tot_Day_Suply:"1005"
# Tot_Drug_Cst:"258.44"
# Tot_Benes:"".12
# GE65_Sprsn_Flag:"".21
# GE65_Tot_Clms:"25"
# GE65_Tot_30day_Fills:"33.5"
# GE65_Tot_Drug_Cst:"258.44"
# GE65_Tot_Day_Suply:"1005"
# GE65_Bene_Sprsn_Flag:"*".23
# GE65_Tot_Benes:""}.31
# {"Prscrbr_NPI":"1003000530".14
# Prscrbr_Last_Org_Name:"Semonche".14
# Prscrbr_First_Name:"Amanda".14
# Prscrbr_City:"Quakertown".14
# Prscrbr_State_Abrvtn:"PA".14
# Prscrbr_State_FIPS:"42".14
# Prscrbr_Type:"Internal Medicine".14
# Prscrbr_Type_Src:"Claim-Specialty".41
# Brnd_Name:"Bupropion Xl"
# Gnrc_Name:"Bupropion Hcl".1
# Tot_Clms:"85"
# Tot_30day_Fills:"191"
# Tot_Day_Suply:"5714"
# Tot_Drug_Cst:"2770.34"
# Tot_Benes:"18"
# GE65_Sprsn_Flag:"".22
# GE65_Tot_Clms:"71"
# GE65_Tot_30day_Fills:"159"
# GE65_Tot_Drug_Cst:"2514.77"
# GE65_Tot_Day_Suply:"4770"
# GE65_Bene_Sprsn_Flag:"#".8
# GE65_Tot_Benes:""}.32
# {"Prscrbr_NPI":"1003000530".15
# Prscrbr_Last_Org_Name:"Semonche".15
# Prscrbr_First_Name:"Amanda".15
# Prscrbr_City:"Quakertown".15
# Prscrbr_State_Abrvtn:"PA".15
# Prscrbr_State_FIPS:"42".15
# Prscrbr_Type:"Internal Medicine".15
# Prscrbr_Type_Src:"Claim-Specialty".42
# Brnd_Name:"Buspirone Hcl"
# Gnrc_Name:"Buspirone Hcl"
# Tot_Clms:"13".3
# Tot_30day_Fills:"31".1
# Tot_Day_Suply:"930".1
# Tot_Drug_Cst:"82.61"
# Tot_Benes:"".13
# GE65_Sprsn_Flag:"".23
# GE65_Tot_Clms:"13".2
# GE65_Tot_30day_Fills:"31"
# GE65_Tot_Drug_Cst:"82.61"
# GE65_Tot_Day_Suply:"930"
# GE65_Bene_Sprsn_Flag:"*".24
# GE65_Tot_Benes:""}.33
# {"Prscrbr_NPI":"1003000530".16
# Prscrbr_Last_Org_Name:"Semonche".16
# Prscrbr_First_Name:"Amanda".16
# Prscrbr_City:"Quakertown".16
# Prscrbr_State_Abrvtn:"PA".16
# Prscrbr_State_FIPS:"42".16
# Prscrbr_Type:"Internal Medicine".16
# Prscrbr_Type_Src:"Claim-Specialty".43
# Brnd_Name:"Butalbital-Acetaminophen-Caffe"
# Gnrc_Name:"Butalb\/Acetaminophen\/Caffeine"
# Tot_Clms:"14".3
# Tot_30day_Fills:"15"
# Tot_Day_Suply:"450"
# Tot_Drug_Cst:"463.9"
# Tot_Benes:"".14
# GE65_Sprsn_Flag:"".24
# GE65_Tot_Clms:"14"
# GE65_Tot_30day_Fills:"15"
# GE65_Tot_Drug_Cst:"463.9"
# GE65_Tot_Day_Suply:"450"
# GE65_Bene_Sprsn_Flag:"*".25
# GE65_Tot_Benes:""}.34
# {"Prscrbr_NPI":"1003000530".17
# Prscrbr_Last_Org_Name:"Semonche".17
# Prscrbr_First_Name:"Amanda".17
# Prscrbr_City:"Quakertown".17
# Prscrbr_State_Abrvtn:"PA".17
# Prscrbr_State_FIPS:"42".17
# Prscrbr_Type:"Internal Medicine".17
# Prscrbr_Type_Src:"Claim-Specialty".44
# Brnd_Name:"Calcitriol"
# Gnrc_Name:"Calcitriol"
# Tot_Clms:"12".2
# Tot_30day_Fills:"12.2"
# Tot_Day_Suply:"365"
# Tot_Drug_Cst:"328.47"
# Tot_Benes:"".15
# GE65_Sprsn_Flag:"".25
# GE65_Tot_Clms:"0"
# GE65_Tot_30day_Fills:"0"
# GE65_Tot_Drug_Cst:"0"
# GE65_Tot_Day_Suply:"0"
# GE65_Bene_Sprsn_Flag:"#".9
# GE65_Tot_Benes:""}.35
# {"Prscrbr_NPI":"1003000530".18
# Prscrbr_Last_Org_Name:"Semonche".18
# Prscrbr_First_Name:"Amanda".18
# Prscrbr_City:"Quakertown".18
# Prscrbr_State_Abrvtn:"PA".18
# Prscrbr_State_FIPS:"42".18
# Prscrbr_Type:"Internal Medicine".18
# Prscrbr_Type_Src:"Claim-Specialty".45
# Brnd_Name:"Carvedilol"
# Gnrc_Name:"Carvedilol"
# Tot_Clms:"23"
# Tot_30day_Fills:"60"
# Tot_Day_Suply:"1800"
# Tot_Drug_Cst:"391.49"
# Tot_Benes:"".16
# GE65_Sprsn_Flag:"#".15
# GE65_Tot_Clms:"".21
# GE65_Tot_30day_Fills:"".21
# GE65_Tot_Drug_Cst:"".21
# GE65_Tot_Day_Suply:"".21
# GE65_Bene_Sprsn_Flag:"*".26
# GE65_Tot_Benes:""}.36
# {"Prscrbr_NPI":"1003000530".19
# Prscrbr_Last_Org_Name:"Semonche".19
# Prscrbr_First_Name:"Amanda".19
# Prscrbr_City:"Quakertown".19
# Prscrbr_State_Abrvtn:"PA".19
# Prscrbr_State_FIPS:"42".19
# Prscrbr_Type:"Internal Medicine".19
# Prscrbr_Type_Src:"Claim-Specialty".46
# Brnd_Name:"Cephalexin"
# Gnrc_Name:"Cephalexin"
# Tot_Clms:"12".3
# Tot_30day_Fills:"12".2
# Tot_Day_Suply:"110"
# Tot_Drug_Cst:"43.42"
# Tot_Benes:"12".3
# GE65_Sprsn_Flag:"#".16
# GE65_Tot_Clms:"".22
# GE65_Tot_30day_Fills:"".22
# GE65_Tot_Drug_Cst:"".22
# GE65_Tot_Day_Suply:"".22
# GE65_Bene_Sprsn_Flag:"#".10
# GE65_Tot_Benes:""}.37
# {"Prscrbr_NPI":"1003000530".20
# Prscrbr_Last_Org_Name:"Semonche".20
# Prscrbr_First_Name:"Amanda".20
# Prscrbr_City:"Quakertown".20
# Prscrbr_State_Abrvtn:"PA".20
# Prscrbr_State_FIPS:"42".20
# Prscrbr_Type:"Internal Medicine".20
# Prscrbr_Type_Src:"Claim-Specialty".47
# Brnd_Name:"Chlorhexidine Gluconate"
# Gnrc_Name:"Chlorhexidine Gluconate"
# Tot_Clms:"20".2
# Tot_30day_Fills:"20".2
# Tot_Day_Suply:"345"
# Tot_Drug_Cst:"116.2"
# Tot_Benes:"".17
# GE65_Sprsn_Flag:"".26
# GE65_Tot_Clms:"0".1
# GE65_Tot_30day_Fills:"0".1
# GE65_Tot_Drug_Cst:"0".1
# GE65_Tot_Day_Suply:"0".1
# GE65_Bene_Sprsn_Flag:"#".11
# GE65_Tot_Benes:""}.38
# {"Prscrbr_NPI":"1003000530".21
# Prscrbr_Last_Org_Name:"Semonche".21
# Prscrbr_First_Name:"Amanda".21
# Prscrbr_City:"Quakertown".21
# Prscrbr_State_Abrvtn:"PA".21
# Prscrbr_State_FIPS:"42".21
# Prscrbr_Type:"Internal Medicine".21
# Prscrbr_Type_Src:"Claim-Specialty".48
# Brnd_Name:"Citalopram Hbr"
# Gnrc_Name:"Citalopram Hydrobromide"
# Tot_Clms:"39".1
# Tot_30day_Fills:"81"
# Tot_Day_Suply:"2430"
# Tot_Drug_Cst:"228.34"
# Tot_Benes:"".18
# GE65_Sprsn_Flag:"".27
# GE65_Tot_Clms:"39"
# GE65_Tot_30day_Fills:"81"
# GE65_Tot_Drug_Cst:"228.34"
# GE65_Tot_Day_Suply:"2430"
# GE65_Bene_Sprsn_Flag:"*".27
# GE65_Tot_Benes:""}.39
# {"Prscrbr_NPI":"1003000530".22
# Prscrbr_Last_Org_Name:"Semonche".22
# Prscrbr_First_Name:"Amanda".22
# Prscrbr_City:"Quakertown".22
# Prscrbr_State_Abrvtn:"PA".22
# Prscrbr_State_FIPS:"42".22
# Prscrbr_Type:"Internal Medicine".22
# Prscrbr_Type_Src:"Claim-Specialty".49
# Brnd_Name:"Clonazepam"
# Gnrc_Name:"Clonazepam"
# Tot_Clms:"35".2
# Tot_30day_Fills:"45"
# Tot_Day_Suply:"1341"
# Tot_Drug_Cst:"386.75"
# Tot_Benes:"".19
# GE65_Sprsn_Flag:"".28
# GE65_Tot_Clms:"22"
# GE65_Tot_30day_Fills:"32"
# GE65_Tot_Drug_Cst:"258.27"
# GE65_Tot_Day_Suply:"951"
# GE65_Bene_Sprsn_Flag:"*".28
# GE65_Tot_Benes:""}.40
# {"Prscrbr_NPI":"1003000530".23
# Prscrbr_Last_Org_Name:"Semonche".23
# Prscrbr_First_Name:"Amanda".23
# Prscrbr_City:"Quakertown".23
# Prscrbr_State_Abrvtn:"PA".23
# Prscrbr_State_FIPS:"42".23
# Prscrbr_Type:"Internal Medicine".23
# Prscrbr_Type_Src:"Claim-Specialty".50
# Brnd_Name:"Clonidine Hcl"
# Gnrc_Name:"Clonidine Hcl"
# Tot_Clms:"13".4
# Tot_30day_Fills:"27.6"
# Tot_Day_Suply:"827"
# Tot_Drug_Cst:"48.65"
# Tot_Benes:"".20
# GE65_Sprsn_Flag:"".29
# GE65_Tot_Clms:"13".3
# GE65_Tot_30day_Fills:"27.6"
# GE65_Tot_Drug_Cst:"48.65"
# GE65_Tot_Day_Suply:"827"
# GE65_Bene_Sprsn_Flag:"*".29
# GE65_Tot_Benes:""}.41
# {"Prscrbr_NPI":"1003000530".24
# Prscrbr_Last_Org_Name:"Semonche".24
# Prscrbr_First_Name:"Amanda".24
# Prscrbr_City:"Quakertown".24
# Prscrbr_State_Abrvtn:"PA".24
# Prscrbr_State_FIPS:"42".24
# Prscrbr_Type:"Internal Medicine".24
# Prscrbr_Type_Src:"Claim-Specialty".51
# Brnd_Name:"Clopidogrel"
# Gnrc_Name:"Clopidogrel Bisulfate"
# Tot_Clms:"85".1
# Tot_30day_Fills:"188"
# Tot_Day_Suply:"5630"
# Tot_Drug_Cst:"1640.22"
# Tot_Benes:"19".1
# GE65_Sprsn_Flag:"".30
# GE65_Tot_Clms:"85"
# GE65_Tot_30day_Fills:"188"
# GE65_Tot_Drug_Cst:"1640.22"
# GE65_Tot_Day_Suply:"5630"
# GE65_Bene_Sprsn_Flag:"".11
# GE65_Tot_Benes:"19"}
# {"Prscrbr_NPI":"1003000530".25
# Prscrbr_Last_Org_Name:"Semonche".25
# Prscrbr_First_Name:"Amanda".25
# Prscrbr_City:"Quakertown".25
# Prscrbr_State_Abrvtn:"PA".25
# Prscrbr_State_FIPS:"42".25
# Prscrbr_Type:"Internal Medicine".25
# Prscrbr_Type_Src:"Claim-Specialty".52
# Brnd_Name:"Cyclobenzaprine Hcl".1
# Gnrc_Name:"Cyclobenzaprine Hcl".1
# Tot_Clms:"11"
# Tot_30day_Fills:"11"
# Tot_Day_Suply:"110".1
# Tot_Drug_Cst:"41.17"
# Tot_Benes:"".21
# GE65_Sprsn_Flag:"*".6
# GE65_Tot_Clms:"".23
# GE65_Tot_30day_Fills:"".23
# GE65_Tot_Drug_Cst:"".23
# GE65_Tot_Day_Suply:"".23
# GE65_Bene_Sprsn_Flag:"*".30
# GE65_Tot_Benes:""}.42
# {"Prscrbr_NPI":"1003000530".26
# Prscrbr_Last_Org_Name:"Semonche".26
# Prscrbr_First_Name:"Amanda".26
# Prscrbr_City:"Quakertown".26
# Prscrbr_State_Abrvtn:"PA".26
# Prscrbr_State_FIPS:"42".26
# Prscrbr_Type:"Internal Medicine".26
# Prscrbr_Type_Src:"Claim-Specialty".53
# Brnd_Name:"Dexlansoprazole Dr"
# Gnrc_Name:"Dexlansoprazole"
# Tot_Clms:"13".5
# Tot_30day_Fills:"24"
# Tot_Day_Suply:"720"
# Tot_Drug_Cst:"5600.13"
# Tot_Benes:"".22
# GE65_Sprsn_Flag:"".31
# GE65_Tot_Clms:"13".4
# GE65_Tot_30day_Fills:"24"
# GE65_Tot_Drug_Cst:"5600.13"
# GE65_Tot_Day_Suply:"720"
# GE65_Bene_Sprsn_Flag:"*".31
# GE65_Tot_Benes:""}.43
# {"Prscrbr_NPI":"1003000530".27
# Prscrbr_Last_Org_Name:"Semonche".27
# Prscrbr_First_Name:"Amanda".27
# Prscrbr_City:"Quakertown".27
# Prscrbr_State_Abrvtn:"PA".27
# Prscrbr_State_FIPS:"42".27
# Prscrbr_Type:"Internal Medicine".27
# Prscrbr_Type_Src:"Claim-Specialty".54
# Brnd_Name:"Diazepam"
# Gnrc_Name:"Diazepam"
# Tot_Clms:"16".3
# Tot_30day_Fills:"16".1
# Tot_Day_Suply:"199"
# Tot_Drug_Cst:"41.64"
# Tot_Benes:"".23
# GE65_Sprsn_Flag:"*".7
# GE65_Tot_Clms:"".24
# GE65_Tot_30day_Fills:"".24
# GE65_Tot_Drug_Cst:"".24
# GE65_Tot_Day_Suply:"".24
# GE65_Bene_Sprsn_Flag:"*".32
# GE65_Tot_Benes:""}.44
# {"Prscrbr_NPI":"1003000530".28
# Prscrbr_Last_Org_Name:"Semonche".28
# Prscrbr_First_Name:"Amanda".28
# Prscrbr_City:"Quakertown".28
# Prscrbr_State_Abrvtn:"PA".28
# Prscrbr_State_FIPS:"42".28
# Prscrbr_Type:"Internal Medicine".28
# Prscrbr_Type_Src:"Claim-Specialty".55
# Brnd_Name:"Diclofenac Sodium".1
# Gnrc_Name:"Diclofenac Sodium".1
# Tot_Clms:"14".4
# Tot_30day_Fills:"14".3
# Tot_Day_Suply:"260"
# Tot_Drug_Cst:"307.2"
# Tot_Benes:"".24
# GE65_Sprsn_Flag:"#".17
# GE65_Tot_Clms:"".25
# GE65_Tot_30day_Fills:"".25
# GE65_Tot_Drug_Cst:"".25
# GE65_Tot_Day_Suply:"".25
# GE65_Bene_Sprsn_Flag:"*".33
# GE65_Tot_Benes:""}.45
# {"Prscrbr_NPI":"1003000530".29
# Prscrbr_Last_Org_Name:"Semonche".29
# Prscrbr_First_Name:"Amanda".29
# Prscrbr_City:"Quakertown".29
# Prscrbr_State_Abrvtn:"PA".29
# Prscrbr_State_FIPS:"42".29
# Prscrbr_Type:"Internal Medicine".29
# Prscrbr_Type_Src:"Claim-Specialty".56
# Brnd_Name:"Diltiazem 24hr Er (Cd)"
# Gnrc_Name:"Diltiazem Hcl"
# Tot_Clms:"14".5
# Tot_30day_Fills:"14".4
# Tot_Day_Suply:"420"
# Tot_Drug_Cst:"232.74"
# Tot_Benes:"".25
# GE65_Sprsn_Flag:"".32
# GE65_Tot_Clms:"14".1
# GE65_Tot_30day_Fills:"14"
# GE65_Tot_Drug_Cst:"232.74"
# GE65_Tot_Day_Suply:"420"
# GE65_Bene_Sprsn_Flag:"*".34
# GE65_Tot_Benes:""}.46
# {"Prscrbr_NPI":"1003000530".30
# Prscrbr_Last_Org_Name:"Semonche".30
# Prscrbr_First_Name:"Amanda".30
# Prscrbr_City:"Quakertown".30
# Prscrbr_State_Abrvtn:"PA".30
# Prscrbr_State_FIPS:"42".30
# Prscrbr_Type:"Internal Medicine".30
# Prscrbr_Type_Src:"Claim-Specialty".57
# Brnd_Name:"Dofetilide"
# Gnrc_Name:"Dofetilide"
# Tot_Clms:"14".6
# Tot_30day_Fills:"14".5
# Tot_Day_Suply:"409"
# Tot_Drug_Cst:"312.85"
# Tot_Benes:"".26
# GE65_Sprsn_Flag:"".33
# GE65_Tot_Clms:"14".2
# GE65_Tot_30day_Fills:"14".1
# GE65_Tot_Drug_Cst:"312.85"
# GE65_Tot_Day_Suply:"409"
# GE65_Bene_Sprsn_Flag:"*".35
# GE65_Tot_Benes:""}.47
# {"Prscrbr_NPI":"1003000530".31
# Prscrbr_Last_Org_Name:"Semonche".31
# Prscrbr_First_Name:"Amanda".31
# Prscrbr_City:"Quakertown".31
# Prscrbr_State_Abrvtn:"PA".31
# Prscrbr_State_FIPS:"42".31
# Prscrbr_Type:"Internal Medicine".31
# Prscrbr_Type_Src:"Claim-Specialty".58
# Brnd_Name:"Donepezil Hcl"
# Gnrc_Name:"Donepezil Hcl"
# Tot_Clms:"20".3
# Tot_30day_Fills:"30"
# Tot_Day_Suply:"900"
# Tot_Drug_Cst:"289.85"
# Tot_Benes:"".27
# GE65_Sprsn_Flag:"".34
# GE65_Tot_Clms:"20"
# GE65_Tot_30day_Fills:"30"
# GE65_Tot_Drug_Cst:"289.85"
# GE65_Tot_Day_Suply:"900"
# GE65_Bene_Sprsn_Flag:"*".36
# GE65_Tot_Benes:""}.48
# {"Prscrbr_NPI":"1003000530".32
# Prscrbr_Last_Org_Name:"Semonche".32
# Prscrbr_First_Name:"Amanda".32
# Prscrbr_City:"Quakertown".32
# Prscrbr_State_Abrvtn:"PA".32
# Prscrbr_State_FIPS:"42".32
# Prscrbr_Type:"Internal Medicine".32
# Prscrbr_Type_Src:"Claim-Specialty".59
# Brnd_Name:"Doxazosin Mesylate"
# Gnrc_Name:"Doxazosin Mesylate"
# Tot_Clms:"15"
# Tot_30day_Fills:"35.8"
# Tot_Day_Suply:"1050".2
# Tot_Drug_Cst:"386.22"
# Tot_Benes:"".28
# GE65_Sprsn_Flag:"".35
# GE65_Tot_Clms:"15"
# GE65_Tot_30day_Fills:"35.8"
# GE65_Tot_Drug_Cst:"386.22"
# GE65_Tot_Day_Suply:"1050"
# GE65_Bene_Sprsn_Flag:"*".37
# GE65_Tot_Benes:""}.49
# {"Prscrbr_NPI":"1003000530".33
# Prscrbr_Last_Org_Name:"Semonche".33
# Prscrbr_First_Name:"Amanda".33
# Prscrbr_City:"Quakertown".33
# Prscrbr_State_Abrvtn:"PA".33
# Prscrbr_State_FIPS:"42".33
# Prscrbr_Type:"Internal Medicine".33
# Prscrbr_Type_Src:"Claim-Specialty".60
# Brnd_Name:"Doxycycline Hyclate"
# Gnrc_Name:"Doxycycline Hyclate"
# Tot_Clms:"30"
# Tot_30day_Fills:"30".1
# Tot_Day_Suply:"251"
# Tot_Drug_Cst:"319.64"
# Tot_Benes:"28".1
# GE65_Sprsn_Flag:"".36
# GE65_Tot_Clms:"30"
# GE65_Tot_30day_Fills:"30".1
# GE65_Tot_Drug_Cst:"319.64"
# GE65_Tot_Day_Suply:"251"
# GE65_Bene_Sprsn_Flag:"".12
# GE65_Tot_Benes:"28"}
# {"Prscrbr_NPI":"1003000530".34
# Prscrbr_Last_Org_Name:"Semonche".34
# Prscrbr_First_Name:"Amanda".34
# Prscrbr_City:"Quakertown".34
# Prscrbr_State_Abrvtn:"PA".34
# Prscrbr_State_FIPS:"42".34
# Prscrbr_Type:"Internal Medicine".34
# Prscrbr_Type_Src:"Claim-Specialty".61
# Brnd_Name:"Duloxetine Hcl".1
# Gnrc_Name:"Duloxetine Hcl".1
# Tot_Clms:"69"
# Tot_30day_Fills:"113"
# Tot_Day_Suply:"3382"
# Tot_Drug_Cst:"3664.57"
# Tot_Benes:"11".1
# GE65_Sprsn_Flag:"".37
# GE65_Tot_Clms:"55"
# GE65_Tot_30day_Fills:"89"
# GE65_Tot_Drug_Cst:"3243.56"
# GE65_Tot_Day_Suply:"2662"
# GE65_Bene_Sprsn_Flag:"*".38
# GE65_Tot_Benes:""}.50
# {"Prscrbr_NPI":"1003000530".35
# Prscrbr_Last_Org_Name:"Semonche".35
# Prscrbr_First_Name:"Amanda".35
# Prscrbr_City:"Quakertown".35
# Prscrbr_State_Abrvtn:"PA".35
# Prscrbr_State_FIPS:"42".35
# Prscrbr_Type:"Internal Medicine".35
# Prscrbr_Type_Src:"Claim-Specialty".62
# Brnd_Name:"Eliquis".1
# Gnrc_Name:"Apixaban".1
# Tot_Clms:"113"
# Tot_30day_Fills:"167"
# Tot_Day_Suply:"4999"
# Tot_Drug_Cst:"92087.78"
# Tot_Benes:"20"
# GE65_Sprsn_Flag:"".38
# GE65_Tot_Clms:"113"
# GE65_Tot_30day_Fills:"167"
# GE65_Tot_Drug_Cst:"92087.78"
# GE65_Tot_Day_Suply:"4999"
# GE65_Bene_Sprsn_Flag:"".13
# GE65_Tot_Benes:"20"}
# {"Prscrbr_NPI":"1003000530".36
# Prscrbr_Last_Org_Name:"Semonche".36
# Prscrbr_First_Name:"Amanda".36
# Prscrbr_City:"Quakertown".36
# Prscrbr_State_Abrvtn:"PA".36
# Prscrbr_State_FIPS:"42".36
# Prscrbr_Type:"Internal Medicine".36
# Prscrbr_Type_Src:"Claim-Specialty".63
# Brnd_Name:"Escitalopram Oxalate"
# Gnrc_Name:"Escitalopram Oxalate"
# Tot_Clms:"75"
# Tot_30day_Fills:"168"
# Tot_Day_Suply:"5015"
# Tot_Drug_Cst:"967.02"
# Tot_Benes:"19".2
# GE65_Sprsn_Flag:"#".18
# GE65_Tot_Clms:"".26
# GE65_Tot_30day_Fills:"".26
# GE65_Tot_Drug_Cst:"".26
# GE65_Tot_Day_Suply:"".26
# GE65_Bene_Sprsn_Flag:"#".12
# GE65_Tot_Benes:""}.51
# {"Prscrbr_NPI":"1003000530".37
# Prscrbr_Last_Org_Name:"Semonche".37
# Prscrbr_First_Name:"Amanda".37
# Prscrbr_City:"Quakertown".37
# Prscrbr_State_Abrvtn:"PA".37
# Prscrbr_State_FIPS:"42".37
# Prscrbr_Type:"Internal Medicine".37
# Prscrbr_Type_Src:"Claim-Specialty".64
# Brnd_Name:"Ezetimibe"
# Gnrc_Name:"Ezetimibe"
# Tot_Clms:"13".6
# Tot_30day_Fills:"39"
# Tot_Day_Suply:"1170"
# Tot_Drug_Cst:"272.15"
# Tot_Benes:"".29
# GE65_Sprsn_Flag:"".39
# GE65_Tot_Clms:"13".5
# GE65_Tot_30day_Fills:"39"
# GE65_Tot_Drug_Cst:"272.15"
# GE65_Tot_Day_Suply:"1170"
# GE65_Bene_Sprsn_Flag:"*".39
# GE65_Tot_Benes:""}.52
# {"Prscrbr_NPI":"1003000530".38
# Prscrbr_Last_Org_Name:"Semonche".38
# Prscrbr_First_Name:"Amanda".38
# Prscrbr_City:"Quakertown".38
# Prscrbr_State_Abrvtn:"PA".38
# Prscrbr_State_FIPS:"42".38
# Prscrbr_Type:"Internal Medicine".38
# Prscrbr_Type_Src:"Claim-Specialty".65
# Brnd_Name:"Famotidine"
# Gnrc_Name:"Famotidine"
# Tot_Clms:"143".1
# Tot_30day_Fills:"293.5"
# Tot_Day_Suply:"8770"
# Tot_Drug_Cst:"1813.81"
# Tot_Benes:"42".1
# GE65_Sprsn_Flag:"#".19
# GE65_Tot_Clms:"".27
# GE65_Tot_30day_Fills:"".27
# GE65_Tot_Drug_Cst:"".27
# GE65_Tot_Day_Suply:"".27
# GE65_Bene_Sprsn_Flag:"#".13
# GE65_Tot_Benes:""}.53
# {"Prscrbr_NPI":"1003000530".39
# Prscrbr_Last_Org_Name:"Semonche".39
# Prscrbr_First_Name:"Amanda".39
# Prscrbr_City:"Quakertown".39
# Prscrbr_State_Abrvtn:"PA".39
# Prscrbr_State_FIPS:"42".39
# Prscrbr_Type:"Internal Medicine".39
# Prscrbr_Type_Src:"Claim-Specialty".66
# Brnd_Name:"Febuxostat"
# Gnrc_Name:"Febuxostat"
# Tot_Clms:"12".4
# Tot_30day_Fills:"12".3
# Tot_Day_Suply:"360".1
# Tot_Drug_Cst:"2867.88"
# Tot_Benes:"".30
# GE65_Sprsn_Flag:"".40
# GE65_Tot_Clms:"12".1
# GE65_Tot_30day_Fills:"12".1
# GE65_Tot_Drug_Cst:"2867.88"
# GE65_Tot_Day_Suply:"360".1
# GE65_Bene_Sprsn_Flag:"*".40
# GE65_Tot_Benes:""}.54
# {"Prscrbr_NPI":"1003000530".40
# Prscrbr_Last_Org_Name:"Semonche".40
# Prscrbr_First_Name:"Amanda".40
# Prscrbr_City:"Quakertown".40
# Prscrbr_State_Abrvtn:"PA".40
# Prscrbr_State_FIPS:"42".40
# Prscrbr_Type:"Internal Medicine".40
# Prscrbr_Type_Src:"Claim-Specialty".67
# Brnd_Name:"Fenofibrate"
# Gnrc_Name:"Fenofibrate"
# Tot_Clms:"12".5
# Tot_30day_Fills:"32"
# Tot_Day_Suply:"960"
# Tot_Drug_Cst:"400.88"
# Tot_Benes:"".31
# GE65_Sprsn_Flag:"*".8
# GE65_Tot_Clms:"".28
# GE65_Tot_30day_Fills:"".28
# GE65_Tot_Drug_Cst:"".28
# GE65_Tot_Day_Suply:"".28
# GE65_Bene_Sprsn_Flag:"*".41
# GE65_Tot_Benes:""}.55
# {"Prscrbr_NPI":"1003000530".41
# Prscrbr_Last_Org_Name:"Semonche".41
# Prscrbr_First_Name:"Amanda".41
# Prscrbr_City:"Quakertown".41
# Prscrbr_State_Abrvtn:"PA".41
# Prscrbr_State_FIPS:"42".41
# Prscrbr_Type:"Internal Medicine".41
# Prscrbr_Type_Src:"Claim-Specialty".68
# Brnd_Name:"Finasteride"
# Gnrc_Name:"Finasteride"
# Tot_Clms:"31".1
# Tot_30day_Fills:"79"
# Tot_Day_Suply:"2370"
# Tot_Drug_Cst:"628.74"
# Tot_Benes:"".32
# GE65_Sprsn_Flag:"".41
# GE65_Tot_Clms:"31"
# GE65_Tot_30day_Fills:"79"
# GE65_Tot_Drug_Cst:"628.74"
# GE65_Tot_Day_Suply:"2370"
# GE65_Bene_Sprsn_Flag:"*".42
# GE65_Tot_Benes:""}.56
# {"Prscrbr_NPI":"1003000530".42
# Prscrbr_Last_Org_Name:"Semonche".42
# Prscrbr_First_Name:"Amanda".42
# Prscrbr_City:"Quakertown".42
# Prscrbr_State_Abrvtn:"PA".42
# Prscrbr_State_FIPS:"42".42
# Prscrbr_Type:"Internal Medicine".42
# Prscrbr_Type_Src:"Claim-Specialty".69
# Brnd_Name:"Fluticasone Propionate"
# Gnrc_Name:"Fluticasone Propionate"
# Tot_Clms:"59"
# Tot_30day_Fills:"108"
# Tot_Day_Suply:"3240"
# Tot_Drug_Cst:"709.42"
# Tot_Benes:"23".1
# GE65_Sprsn_Flag:"#".20
# GE65_Tot_Clms:"".29
# GE65_Tot_30day_Fills:"".29
# GE65_Tot_Drug_Cst:"".29
# GE65_Tot_Day_Suply:"".29
# GE65_Bene_Sprsn_Flag:"#".14
# GE65_Tot_Benes:""}.57
# {"Prscrbr_NPI":"1003000530".43
# Prscrbr_Last_Org_Name:"Semonche".43
# Prscrbr_First_Name:"Amanda".43
# Prscrbr_City:"Quakertown".43
# Prscrbr_State_Abrvtn:"PA".43
# Prscrbr_State_FIPS:"42".43
# Prscrbr_Type:"Internal Medicine".43
# Prscrbr_Type_Src:"Claim-Specialty".70
# Brnd_Name:"Fluticasone-Salmeterol"
# Gnrc_Name:"Fluticasone Propion\/Salmeterol".1
# Tot_Clms:"16".4
# Tot_30day_Fills:"24".1
# Tot_Day_Suply:"720".1
# Tot_Drug_Cst:"3464.46"
# Tot_Benes:"".33
# GE65_Sprsn_Flag:"#".21
# GE65_Tot_Clms:"".30
# GE65_Tot_30day_Fills:"".30
# GE65_Tot_Drug_Cst:"".30
# GE65_Tot_Day_Suply:"".30
# GE65_Bene_Sprsn_Flag:"*".43
# GE65_Tot_Benes:""}.58
# {"Prscrbr_NPI":"1003000530".44
# Prscrbr_Last_Org_Name:"Semonche".44
# Prscrbr_First_Name:"Amanda".44
# Prscrbr_City:"Quakertown".44
# Prscrbr_State_Abrvtn:"PA".44
# Prscrbr_State_FIPS:"42".44
# Prscrbr_Type:"Internal Medicine".44
# Prscrbr_Type_Src:"Claim-Specialty".71
# Brnd_Name:"Fosinopril Sodium"
# Gnrc_Name:"Fosinopril Sodium"
# Tot_Clms:"23".1
# Tot_30day_Fills:"33"
# Tot_Day_Suply:"990"
# Tot_Drug_Cst:"487.11"
# Tot_Benes:"".34
# GE65_Sprsn_Flag:"".42
# GE65_Tot_Clms:"23"
# GE65_Tot_30day_Fills:"33"
# GE65_Tot_Drug_Cst:"487.11"
# GE65_Tot_Day_Suply:"990"
# GE65_Bene_Sprsn_Flag:"*".44
# GE65_Tot_Benes:""}.59
# {"Prscrbr_NPI":"1003000530".45
# Prscrbr_Last_Org_Name:"Semonche".45
# Prscrbr_First_Name:"Amanda".45
# Prscrbr_City:"Quakertown".45
# Prscrbr_State_Abrvtn:"PA".45
# Prscrbr_State_FIPS:"42".45
# Prscrbr_Type:"Internal Medicine".45
# Prscrbr_Type_Src:"Claim-Specialty".72
# Brnd_Name:"Furosemide"
# Gnrc_Name:"Furosemide"
# Tot_Clms:"74"
# Tot_30day_Fills:"137"
# Tot_Day_Suply:"4054"
# Tot_Drug_Cst:"516.89"
# Tot_Benes:"23".2
# GE65_Sprsn_Flag:"#".22
# GE65_Tot_Clms:"".31
# GE65_Tot_30day_Fills:"".31
# GE65_Tot_Drug_Cst:"".31
# GE65_Tot_Day_Suply:"".31
# GE65_Bene_Sprsn_Flag:"#".15
# GE65_Tot_Benes:""}.60
# {"Prscrbr_NPI":"1003000530".46
# Prscrbr_Last_Org_Name:"Semonche".46
# Prscrbr_First_Name:"Amanda".46
# Prscrbr_City:"Quakertown".46
# Prscrbr_State_Abrvtn:"PA".46
# Prscrbr_State_FIPS:"42".46
# Prscrbr_Type:"Internal Medicine".46
# Prscrbr_Type_Src:"Claim-Specialty".73
# Brnd_Name:"Gabapentin".1
# Gnrc_Name:"Gabapentin".1
# Tot_Clms:"223"
# Tot_30day_Fills:"382"
# Tot_Day_Suply:"11391"
# Tot_Drug_Cst:"3411.56"
# Tot_Benes:"53"
# GE65_Sprsn_Flag:"".43
# GE65_Tot_Clms:"203"
# GE65_Tot_30day_Fills:"358"
# GE65_Tot_Drug_Cst:"3230.61"
# GE65_Tot_Day_Suply:"10677"
# GE65_Bene_Sprsn_Flag:"#".16
# GE65_Tot_Benes:""}.61
# {"Prscrbr_NPI":"1003000530".47
# Prscrbr_Last_Org_Name:"Semonche".47
# Prscrbr_First_Name:"Amanda".47
# Prscrbr_City:"Quakertown".47
# Prscrbr_State_Abrvtn:"PA".47
# Prscrbr_State_FIPS:"42".47
# Prscrbr_Type:"Internal Medicine".47
# Prscrbr_Type_Src:"Claim-Specialty".74
# Brnd_Name:"Gemfibrozil"
# Gnrc_Name:"Gemfibrozil"
# Tot_Clms:"11".1
# Tot_30day_Fills:"11".1
# Tot_Day_Suply:"330"
# Tot_Drug_Cst:"99"
# Tot_Benes:"".35
# GE65_Sprsn_Flag:"".44
# GE65_Tot_Clms:"11".1
# GE65_Tot_30day_Fills:"11"
# GE65_Tot_Drug_Cst:"99"
# GE65_Tot_Day_Suply:"330"
# GE65_Bene_Sprsn_Flag:"*".45
# GE65_Tot_Benes:""}.62
# {"Prscrbr_NPI":"1003000530".48
# Prscrbr_Last_Org_Name:"Semonche".48
# Prscrbr_First_Name:"Amanda".48
# Prscrbr_City:"Quakertown".48
# Prscrbr_State_Abrvtn:"PA".48
# Prscrbr_State_FIPS:"42".48
# Prscrbr_Type:"Internal Medicine".48
# Prscrbr_Type_Src:"Claim-Specialty".75
# Brnd_Name:"Glipizide"
# Gnrc_Name:"Glipizide"
# Tot_Clms:"82".1
# Tot_30day_Fills:"191.1"
# Tot_Day_Suply:"5694"
# Tot_Drug_Cst:"958.43"
# Tot_Benes:"18".1
# GE65_Sprsn_Flag:"".45
# GE65_Tot_Clms:"82"
# GE65_Tot_30day_Fills:"191.1"
# GE65_Tot_Drug_Cst:"958.43"
# GE65_Tot_Day_Suply:"5694"
# GE65_Bene_Sprsn_Flag:"".14
# GE65_Tot_Benes:"18"}
# {"Prscrbr_NPI":"1003000530".49
# Prscrbr_Last_Org_Name:"Semonche".49
# Prscrbr_First_Name:"Amanda".49
# Prscrbr_City:"Quakertown".49
# Prscrbr_State_Abrvtn:"PA".49
# Prscrbr_State_FIPS:"42".49
# Prscrbr_Type:"Internal Medicine".49
# Prscrbr_Type_Src:"Claim-Specialty".76
# Brnd_Name:"Glycopyrrolate"
# Gnrc_Name:"Glycopyrrolate"
# Tot_Clms:"14".7
# Tot_30day_Fills:"16.2"
# Tot_Day_Suply:"485"
# Tot_Drug_Cst:"908.42"
# Tot_Benes:"".36
# GE65_Sprsn_Flag:"*".9
# GE65_Tot_Clms:"".32
# GE65_Tot_30day_Fills:"".32
# GE65_Tot_Drug_Cst:"".32
# GE65_Tot_Day_Suply:"".32
# GE65_Bene_Sprsn_Flag:"*".46
# GE65_Tot_Benes:""}.63
# {"Prscrbr_NPI":"1003000530".50
# Prscrbr_Last_Org_Name:"Semonche".50
# Prscrbr_First_Name:"Amanda".50
# Prscrbr_City:"Quakertown".50
# Prscrbr_State_Abrvtn:"PA".50
# Prscrbr_State_FIPS:"42".50
# Prscrbr_Type:"Internal Medicine".50
# Prscrbr_Type_Src:"Claim-Specialty".77
# Brnd_Name:"Hydrochlorothiazide"
# Gnrc_Name:"Hydrochlorothiazide"
# Tot_Clms:"188"
# Tot_30day_Fills:"456"
# Tot_Day_Suply:"13668"
# Tot_Drug_Cst:"712.76"
# Tot_Benes:"44"
# GE65_Sprsn_Flag:"#".23
# GE65_Tot_Clms:"".33
# GE65_Tot_30day_Fills:"".33
# GE65_Tot_Drug_Cst:"".33
# GE65_Tot_Day_Suply:"".33
# GE65_Bene_Sprsn_Flag:"#".17
# GE65_Tot_Benes:""}.64
# {"Prscrbr_NPI":"1003000530".51
# Prscrbr_Last_Org_Name:"Semonche".51
# Prscrbr_First_Name:"Amanda".51
# Prscrbr_City:"Quakertown".51
# Prscrbr_State_Abrvtn:"PA".51
# Prscrbr_State_FIPS:"42".51
# Prscrbr_Type:"Internal Medicine".51
# Prscrbr_Type_Src:"Claim-Specialty".78
# Brnd_Name:"Hydrocodone-Acetaminophen".1
# Gnrc_Name:"Hydrocodone\/Acetaminophen".1
# Tot_Clms:"21".1
# Tot_30day_Fills:"21"
# Tot_Day_Suply:"306"
# Tot_Drug_Cst:"463.91"
# Tot_Benes:"".37
# GE65_Sprsn_Flag:"".46
# GE65_Tot_Clms:"21"
# GE65_Tot_30day_Fills:"21".1
# GE65_Tot_Drug_Cst:"463.91"
# GE65_Tot_Day_Suply:"306"
# GE65_Bene_Sprsn_Flag:"*".47
# GE65_Tot_Benes:""}.65
# {"Prscrbr_NPI":"1003000530".52
# Prscrbr_Last_Org_Name:"Semonche".52
# Prscrbr_First_Name:"Amanda".52
# Prscrbr_City:"Quakertown".52
# Prscrbr_State_Abrvtn:"PA".52
# Prscrbr_State_FIPS:"42".52
# Prscrbr_Type:"Internal Medicine".52
# Prscrbr_Type_Src:"Claim-Specialty".79
# Brnd_Name:"Irbesartan"
# Gnrc_Name:"Irbesartan"
# Tot_Clms:"19".1
# Tot_30day_Fills:"33".1
# Tot_Day_Suply:"964"
# Tot_Drug_Cst:"852.51"
# Tot_Benes:"".38
# GE65_Sprsn_Flag:"*".10
# GE65_Tot_Clms:"".34
# GE65_Tot_30day_Fills:"".34
# GE65_Tot_Drug_Cst:"".34
# GE65_Tot_Day_Suply:"".34
# GE65_Bene_Sprsn_Flag:"*".48
# GE65_Tot_Benes:""}.66
# {"Prscrbr_NPI":"1003000530".53
# Prscrbr_Last_Org_Name:"Semonche".53
# Prscrbr_First_Name:"Amanda".53
# Prscrbr_City:"Quakertown".53
# Prscrbr_State_Abrvtn:"PA".53
# Prscrbr_State_FIPS:"42".53
# Prscrbr_Type:"Internal Medicine".53
# Prscrbr_Type_Src:"Claim-Specialty".80
# Brnd_Name:"Isosorbide Mononitrate Er"
# Gnrc_Name:"Isosorbide Mononitrate"
# Tot_Clms:"23".2
# Tot_30day_Fills:"47"
# Tot_Day_Suply:"1410"
# Tot_Drug_Cst:"529.15"
# Tot_Benes:"".39
# GE65_Sprsn_Flag:"#".24
# GE65_Tot_Clms:"".35
# GE65_Tot_30day_Fills:"".35
# GE65_Tot_Drug_Cst:"".35
# GE65_Tot_Day_Suply:"".35
# GE65_Bene_Sprsn_Flag:"*".49
# GE65_Tot_Benes:""}.67
# {"Prscrbr_NPI":"1003000530".54
# Prscrbr_Last_Org_Name:"Semonche".54
# Prscrbr_First_Name:"Amanda".54
# Prscrbr_City:"Quakertown".54
# Prscrbr_State_Abrvtn:"PA".54
# Prscrbr_State_FIPS:"42".54
# Prscrbr_Type:"Internal Medicine".54
# Prscrbr_Type_Src:"Claim-Specialty".81
# Brnd_Name:"Januvia"
# Gnrc_Name:"Sitagliptin Phosphate"
# Tot_Clms:"27".1
# Tot_30day_Fills:"49"
# Tot_Day_Suply:"1470"
# Tot_Drug_Cst:"27971.54"
# Tot_Benes:"".40
# GE65_Sprsn_Flag:"".47
# GE65_Tot_Clms:"27".1
# GE65_Tot_30day_Fills:"49"
# GE65_Tot_Drug_Cst:"27971.54"
# GE65_Tot_Day_Suply:"1470"
# GE65_Bene_Sprsn_Flag:"*".50
# GE65_Tot_Benes:""}.68
# ...
# Tot_Benes:"41".5
# GE65_Sprsn_Flag:"".553
# GE65_Tot_Clms:"106".2
# GE65_Tot_30day_Fills:"226".1
# GE65_Tot_Drug_Cst:"2465.7"
# GE65_Tot_Day_Suply:"6780"
# GE65_Bene_Sprsn_Flag:"".146
# GE65_Tot_Benes:"30"}.1
# {"Prscrbr_NPI":"1003004201".48
# Prscrbr_Last_Org_Name:"Philbrick".48
# Prscrbr_First_Name:"Natalie".48
# Prscrbr_City:"Corpus Christi".48
# Prscrbr_State_Abrvtn:"TX".96
# Prscrbr_State_FIPS:"48".96
# Prscrbr_Type:"Internal Medicine".170
# Prscrbr_Type_Src:"Claim-Specialty".758
# Brnd_Name:"Glimepiride".2
# Gnrc_Name:"Glimepiride".2
# Tot_Clms:"11".54
# Tot_30day_Fills:"31".7
# Tot_Day_Suply:"911"
# Tot_Drug_Cst:"72.72"
# Tot_Benes:"".497
# GE65_Sprsn_Flag:"".554
# GE65_Tot_Clms:"11".26
# GE65_Tot_30day_Fills:"31".3
# GE65_Tot_Drug_Cst:"72.72"
# GE65_Tot_Day_Suply:"911"
# GE65_Bene_Sprsn_Flag:"*".531
# GE65_Tot_Benes:""}.827
# {"Prscrbr_NPI":"1003004201".49
# Prscrbr_Last_Org_Name:"Philbrick".49
# Prscrbr_First_Name:"Natalie".49
# Prscrbr_City:"Corpus Christi".49
# Prscrbr_State_Abrvtn:"TX".97
# Prscrbr_State_FIPS:"48".97
# Prscrbr_Type:"Internal Medicine".171
# Prscrbr_Type_Src:"Claim-Specialty".759
# Brnd_Name:"Glipizide".4
# Gnrc_Name:"Glipizide".8
# Tot_Clms:"12".45
# Tot_30day_Fills:"35".12
# Tot_Day_Suply:"1050".8
# Tot_Drug_Cst:"69.59".1
# Tot_Benes:"".498
# GE65_Sprsn_Flag:"".555
# GE65_Tot_Clms:"12".24
# GE65_Tot_30day_Fills:"35".5
# GE65_Tot_Drug_Cst:"69.59".1
# GE65_Tot_Day_Suply:"1050".5
# GE65_Bene_Sprsn_Flag:"*".532
# GE65_Tot_Benes:""}.828
# {"Prscrbr_NPI":"1003004201".50
# Prscrbr_Last_Org_Name:"Philbrick".50
# Prscrbr_First_Name:"Natalie".50
# Prscrbr_City:"Corpus Christi".50
# Prscrbr_State_Abrvtn:"TX".98
# Prscrbr_State_FIPS:"48".98
# Prscrbr_Type:"Internal Medicine".172
# Prscrbr_Type_Src:"Claim-Specialty".760
# Brnd_Name:"Hydrochlorothiazide".7
# Gnrc_Name:"Hydrochlorothiazide".7
# Tot_Clms:"88".4
# Tot_30day_Fills:"198.7"
# Tot_Day_Suply:"5943"
# Tot_Drug_Cst:"308.78"
# Tot_Benes:"21".17
# GE65_Sprsn_Flag:"".556
# GE65_Tot_Clms:"76".1
# GE65_Tot_30day_Fills:"164"
# GE65_Tot_Drug_Cst:"245.72"
# GE65_Tot_Day_Suply:"4903"
# GE65_Bene_Sprsn_Flag:"#".296
# GE65_Tot_Benes:""}.829
# {"Prscrbr_NPI":"1003004201".51
# Prscrbr_Last_Org_Name:"Philbrick".51
# Prscrbr_First_Name:"Natalie".51
# Prscrbr_City:"Corpus Christi".51
# Prscrbr_State_Abrvtn:"TX".99
# Prscrbr_State_FIPS:"48".99
# Prscrbr_Type:"Internal Medicine".173
# Prscrbr_Type_Src:"Claim-Specialty".761
# Brnd_Name:"Hydrocodone-Acetaminophen".12
# Gnrc_Name:"Hydrocodone\/Acetaminophen".12
# Tot_Clms:"75".2
# Tot_30day_Fills:"75".3
# Tot_Day_Suply:"1902"
# Tot_Drug_Cst:"1984.27"
# Tot_Benes:"24".11
# GE65_Sprsn_Flag:"".557
# GE65_Tot_Clms:"51".2
# GE65_Tot_30day_Fills:"51".5
# GE65_Tot_Drug_Cst:"1443.05"
# GE65_Tot_Day_Suply:"1317"
# GE65_Bene_Sprsn_Flag:"#".297
# GE65_Tot_Benes:""}.830
# {"Prscrbr_NPI":"1003004201".52
# Prscrbr_Last_Org_Name:"Philbrick".52
# Prscrbr_First_Name:"Natalie".52
# Prscrbr_City:"Corpus Christi".52
# Prscrbr_State_Abrvtn:"TX".100
# Prscrbr_State_FIPS:"48".100
# Prscrbr_Type:"Internal Medicine".174
# Prscrbr_Type_Src:"Claim-Specialty".762
# Brnd_Name:"Ibuprofen".5
# Gnrc_Name:"Ibuprofen".5
# Tot_Clms:"23".20
# Tot_30day_Fills:"23".9
# Tot_Day_Suply:"645"
# Tot_Drug_Cst:"239.22"
# Tot_Benes:"".499
# GE65_Sprsn_Flag:"*".100
# GE65_Tot_Clms:"".420
# GE65_Tot_30day_Fills:"".420
# GE65_Tot_Drug_Cst:"".420
# GE65_Tot_Day_Suply:"".420
# GE65_Bene_Sprsn_Flag:"*".533
# GE65_Tot_Benes:""}.831
# {"Prscrbr_NPI":"1003004201".53
# Prscrbr_Last_Org_Name:"Philbrick".53
# Prscrbr_First_Name:"Natalie".53
# Prscrbr_City:"Corpus Christi".53
# Prscrbr_State_Abrvtn:"TX".101
# Prscrbr_State_FIPS:"48".101
# Prscrbr_Type:"Internal Medicine".175
# Prscrbr_Type_Src:"Claim-Specialty".763
# Brnd_Name:"Irbesartan".3
# Gnrc_Name:"Irbesartan".3
# Tot_Clms:"33".12
# Tot_30day_Fills:"81".2
# Tot_Day_Suply:"2409"
# Tot_Drug_Cst:"601.43"
# Tot_Benes:"".500
# GE65_Sprsn_Flag:"".558
# GE65_Tot_Clms:"33".5
# GE65_Tot_30day_Fills:"81".1
# GE65_Tot_Drug_Cst:"601.43"
# GE65_Tot_Day_Suply:"2409"
# GE65_Bene_Sprsn_Flag:"*".534
# GE65_Tot_Benes:""}.832
# {"Prscrbr_NPI":"1003004201".54
# Prscrbr_Last_Org_Name:"Philbrick".54
# Prscrbr_First_Name:"Natalie".54
# Prscrbr_City:"Corpus Christi".54
# Prscrbr_State_Abrvtn:"TX".102
# Prscrbr_State_FIPS:"48".102
# Prscrbr_Type:"Internal Medicine".176
# Prscrbr_Type_Src:"Claim-Specialty".764
# Brnd_Name:"Janumet".2
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".3
# Tot_Clms:"11".55
# Tot_30day_Fills:"34.3".1
# Tot_Day_Suply:"1030"
# Tot_Drug_Cst:"15945.71"
# Tot_Benes:"".501
# GE65_Sprsn_Flag:"*".101
# GE65_Tot_Clms:"".421
# GE65_Tot_30day_Fills:"".421
# GE65_Tot_Drug_Cst:"".421
# GE65_Tot_Day_Suply:"".421
# GE65_Bene_Sprsn_Flag:"*".535
# GE65_Tot_Benes:""}.833
# {"Prscrbr_NPI":"1003004201".55
# Prscrbr_Last_Org_Name:"Philbrick".55
# Prscrbr_First_Name:"Natalie".55
# Prscrbr_City:"Corpus Christi".55
# Prscrbr_State_Abrvtn:"TX".103
# Prscrbr_State_FIPS:"48".103
# Prscrbr_Type:"Internal Medicine".177
# Prscrbr_Type_Src:"Claim-Specialty".765
# Brnd_Name:"Janumet Xr".1
# Gnrc_Name:"Sitagliptin Phos\/Metformin Hcl".4
# Tot_Clms:"16".31
# Tot_30day_Fills:"26".10
# Tot_Day_Suply:"780".4
# Tot_Drug_Cst:"14576.22"
# Tot_Benes:"".502
# GE65_Sprsn_Flag:"".559
# GE65_Tot_Clms:"16".17
# GE65_Tot_30day_Fills:"26".4
# GE65_Tot_Drug_Cst:"14576.22"
# GE65_Tot_Day_Suply:"780".1
# GE65_Bene_Sprsn_Flag:"*".536
# GE65_Tot_Benes:""}.834
# {"Prscrbr_NPI":"1003004201".56
# Prscrbr_Last_Org_Name:"Philbrick".56
# Prscrbr_First_Name:"Natalie".56
# Prscrbr_City:"Corpus Christi".56
# Prscrbr_State_Abrvtn:"TX".104
# Prscrbr_State_FIPS:"48".104
# Prscrbr_Type:"Internal Medicine".178
# Prscrbr_Type_Src:"Claim-Specialty".766
# Brnd_Name:"Januvia".5
# Gnrc_Name:"Sitagliptin Phosphate".5
# Tot_Clms:"47".7
# Tot_30day_Fills:"102.7"
# Tot_Day_Suply:"3080"
# Tot_Drug_Cst:"57151.67"
# Tot_Benes:"".503
# GE65_Sprsn_Flag:"".560
# GE65_Tot_Clms:"33".6
# GE65_Tot_30day_Fills:"61".4
# GE65_Tot_Drug_Cst:"32794.59"
# GE65_Tot_Day_Suply:"1830".3
# GE65_Bene_Sprsn_Flag:"*".537
# GE65_Tot_Benes:""}.835
# {"Prscrbr_NPI":"1003004201".57
# Prscrbr_Last_Org_Name:"Philbrick".57
# Prscrbr_First_Name:"Natalie".57
# Prscrbr_City:"Corpus Christi".57
# Prscrbr_State_Abrvtn:"TX".105
# Prscrbr_State_FIPS:"48".105
# Prscrbr_Type:"Internal Medicine".179
# Prscrbr_Type_Src:"Claim-Specialty".767
# Brnd_Name:"Jardiance".5
# Gnrc_Name:"Empagliflozin".5
# Tot_Clms:"36".10
# Tot_30day_Fills:"48".7
# Tot_Day_Suply:"1440".5
# Tot_Drug_Cst:"30810.62"
# Tot_Benes:"".504
# GE65_Sprsn_Flag:"".561
# GE65_Tot_Clms:"16".18
# GE65_Tot_30day_Fills:"28".4
# GE65_Tot_Drug_Cst:"17814.66"
# GE65_Tot_Day_Suply:"840".4
# GE65_Bene_Sprsn_Flag:"*".538
# GE65_Tot_Benes:""}.836
# {"Prscrbr_NPI":"1003004201".58
# Prscrbr_Last_Org_Name:"Philbrick".58
# Prscrbr_First_Name:"Natalie".58
# Prscrbr_City:"Corpus Christi".58
# Prscrbr_State_Abrvtn:"TX".106
# Prscrbr_State_FIPS:"48".106
# Prscrbr_Type:"Internal Medicine".180
# Prscrbr_Type_Src:"Claim-Specialty".768
# Brnd_Name:"Lantus Solostar".4
# Gnrc_Name:"Insulin Glargine.7
# hum.Rec.Anlog".7
# Tot_Clms:"30".15
# Tot_30day_Fills:"42.6"
# Tot_Day_Suply:"1200".4
# Tot_Drug_Cst:"14025.7"
# Tot_Benes:"".505
# GE65_Sprsn_Flag:"*".102
# GE65_Tot_Clms:"".422
# GE65_Tot_30day_Fills:"".422
# GE65_Tot_Drug_Cst:"".422
# GE65_Tot_Day_Suply:"".422
# GE65_Bene_Sprsn_Flag:"*".539
# GE65_Tot_Benes:""}.837
# {"Prscrbr_NPI":"1003004201".59
# Prscrbr_Last_Org_Name:"Philbrick".59
# Prscrbr_First_Name:"Natalie".59
# Prscrbr_City:"Corpus Christi".59
# Prscrbr_State_Abrvtn:"TX".107
# Prscrbr_State_FIPS:"48".107
# Prscrbr_Type:"Internal Medicine".181
# Prscrbr_Type_Src:"Claim-Specialty".769
# Brnd_Name:"Levemir Flexpen"
# Gnrc_Name:"Insulin Detemir"
# Tot_Clms:"18".24
# Tot_30day_Fills:"40.7".1
# Tot_Day_Suply:"1216"
# Tot_Drug_Cst:"14820.64"
# Tot_Benes:"".506
# GE65_Sprsn_Flag:"#".320
# GE65_Tot_Clms:"".423
# GE65_Tot_30day_Fills:"".423
# GE65_Tot_Drug_Cst:"".423
# GE65_Tot_Day_Suply:"".423
# GE65_Bene_Sprsn_Flag:"*".540
# GE65_Tot_Benes:""}.838
# {"Prscrbr_NPI":"1003004201".60
# Prscrbr_Last_Org_Name:"Philbrick".60
# Prscrbr_First_Name:"Natalie".60
# Prscrbr_City:"Corpus Christi".60
# Prscrbr_State_Abrvtn:"TX".108
# Prscrbr_State_FIPS:"48".108
# Prscrbr_Type:"Internal Medicine".182
# Prscrbr_Type_Src:"Claim-Specialty".770
# Brnd_Name:"Levothyroxine Sodium".7
# Gnrc_Name:"Levothyroxine Sodium".13
# Tot_Clms:"329"
# Tot_30day_Fills:"878.8"
# Tot_Day_Suply:"26336"
# Tot_Drug_Cst:"5172.2"
# Tot_Benes:"87".1
# GE65_Sprsn_Flag:"".562
# GE65_Tot_Clms:"296"
# GE65_Tot_30day_Fills:"792.8"
# GE65_Tot_Drug_Cst:"4565.09"
# GE65_Tot_Day_Suply:"23768"
# GE65_Bene_Sprsn_Flag:"#".298
# GE65_Tot_Benes:""}.839
# {"Prscrbr_NPI":"1003004201".61
# Prscrbr_Last_Org_Name:"Philbrick".61
# Prscrbr_First_Name:"Natalie".61
# Prscrbr_City:"Corpus Christi".61
# Prscrbr_State_Abrvtn:"TX".109
# Prscrbr_State_FIPS:"48".109
# Prscrbr_Type:"Internal Medicine".183
# Prscrbr_Type_Src:"Claim-Specialty".771
# Brnd_Name:"Lisinopril".9
# Gnrc_Name:"Lisinopril".9
# Tot_Clms:"191".1
# Tot_30day_Fills:"567.6"
# Tot_Day_Suply:"17030"
# Tot_Drug_Cst:"1067.95"
# Tot_Benes:"57".1
# GE65_Sprsn_Flag:"".563
# GE65_Tot_Clms:"168".1
# GE65_Tot_30day_Fills:"498.6"
# GE65_Tot_Drug_Cst:"935.82"
# GE65_Tot_Day_Suply:"14960"
# GE65_Bene_Sprsn_Flag:"#".299
# GE65_Tot_Benes:""}.840
# {"Prscrbr_NPI":"1003004201".62
# Prscrbr_Last_Org_Name:"Philbrick".62
# Prscrbr_First_Name:"Natalie".62
# Prscrbr_City:"Corpus Christi".62
# Prscrbr_State_Abrvtn:"TX".110
# Prscrbr_State_FIPS:"48".110
# Prscrbr_Type:"Internal Medicine".184
# Prscrbr_Type_Src:"Claim-Specialty".772
# Brnd_Name:"Lisinopril-Hydrochlorothiazide".3
# Gnrc_Name:"Lisinopril\/Hydrochlorothiazide".3
# Tot_Clms:"31".8
# Tot_30day_Fills:"86.3"
# Tot_Day_Suply:"2556"
# Tot_Drug_Cst:"358.53"
# Tot_Benes:"".507
# GE65_Sprsn_Flag:"#".321
# GE65_Tot_Clms:"".424
# GE65_Tot_30day_Fills:"".424
# GE65_Tot_Drug_Cst:"".424
# GE65_Tot_Day_Suply:"".424
# GE65_Bene_Sprsn_Flag:"*".541
# GE65_Tot_Benes:""}.841
# {"Prscrbr_NPI":"1003004201".63
# Prscrbr_Last_Org_Name:"Philbrick".63
# Prscrbr_First_Name:"Natalie".63
# Prscrbr_City:"Corpus Christi".63
# Prscrbr_State_Abrvtn:"TX".111
# Prscrbr_State_FIPS:"48".111
# Prscrbr_Type:"Internal Medicine".185
# Prscrbr_Type_Src:"Claim-Specialty".773
# Brnd_Name:"Lorazepam".4
# Gnrc_Name:"Lorazepam".4
# Tot_Clms:"17".23
# Tot_30day_Fills:"17".14
# Tot_Day_Suply:"467"
# Tot_Drug_Cst:"68.44"
# Tot_Benes:"".508
# GE65_Sprsn_Flag:"#".322
# GE65_Tot_Clms:"".425
# GE65_Tot_30day_Fills:"".425
# GE65_Tot_Drug_Cst:"".425
# GE65_Tot_Day_Suply:"".425
# GE65_Bene_Sprsn_Flag:"*".542
# GE65_Tot_Benes:""}.842
# {"Prscrbr_NPI":"1003004201".64
# Prscrbr_Last_Org_Name:"Philbrick".64
# Prscrbr_First_Name:"Natalie".64
# Prscrbr_City:"Corpus Christi".64
# Prscrbr_State_Abrvtn:"TX".112
# Prscrbr_State_FIPS:"48".112
# Prscrbr_Type:"Internal Medicine".186
# Prscrbr_Type_Src:"Claim-Specialty".774
# Brnd_Name:"Losartan Potassium".8
# Gnrc_Name:"Losartan Potassium".8
# Tot_Clms:"198"
# Tot_30day_Fills:"489"
# Tot_Day_Suply:"14661"
# Tot_Drug_Cst:"2739.62"
# Tot_Benes:"54".1
# GE65_Sprsn_Flag:"#".323
# GE65_Tot_Clms:"".426
# GE65_Tot_30day_Fills:"".426
# GE65_Tot_Drug_Cst:"".426
# GE65_Tot_Day_Suply:"".426
# GE65_Bene_Sprsn_Flag:"#".300
# GE65_Tot_Benes:""}.843
# {"Prscrbr_NPI":"1003004201".65
# Prscrbr_Last_Org_Name:"Philbrick".65
# Prscrbr_First_Name:"Natalie".65
# Prscrbr_City:"Corpus Christi".65
# Prscrbr_State_Abrvtn:"TX".113
# Prscrbr_State_FIPS:"48".113
# Prscrbr_Type:"Internal Medicine".187
# Prscrbr_Type_Src:"Claim-Specialty".775
# Brnd_Name:"Losartan-Hydrochlorothiazide".3
# Gnrc_Name:"Losartan\/Hydrochlorothiazide".3
# Tot_Clms:"77"
# Tot_30day_Fills:"218.3"
# Tot_Day_Suply:"6550"
# Tot_Drug_Cst:"1248.85"
# Tot_Benes:"23".11
# GE65_Sprsn_Flag:"#".324
# GE65_Tot_Clms:"".427
# GE65_Tot_30day_Fills:"".427
# GE65_Tot_Drug_Cst:"".427
# GE65_Tot_Day_Suply:"".427
# GE65_Bene_Sprsn_Flag:"#".301
# GE65_Tot_Benes:""}.844
# {"Prscrbr_NPI":"1003004201".66
# Prscrbr_Last_Org_Name:"Philbrick".66
# Prscrbr_First_Name:"Natalie".66
# Prscrbr_City:"Corpus Christi".66
# Prscrbr_State_Abrvtn:"TX".114
# Prscrbr_State_FIPS:"48".114
# Prscrbr_Type:"Internal Medicine".188
# Prscrbr_Type_Src:"Claim-Specialty".776
# Brnd_Name:"Meloxicam".10
# Gnrc_Name:"Meloxicam".10
# Tot_Clms:"295".1
# Tot_30day_Fills:"662.6"
# Tot_Day_Suply:"19839"
# Tot_Drug_Cst:"1681.33"
# Tot_Benes:"87".2
# GE65_Sprsn_Flag:"".564
# GE65_Tot_Clms:"250"
# GE65_Tot_30day_Fills:"558"
# GE65_Tot_Drug_Cst:"1493.45"
# GE65_Tot_Day_Suply:"16724"
# GE65_Bene_Sprsn_Flag:"".147
# GE65_Tot_Benes:"72"}
# {"Prscrbr_NPI":"1003004201".67
# Prscrbr_Last_Org_Name:"Philbrick".67
# Prscrbr_First_Name:"Natalie".67
# Prscrbr_City:"Corpus Christi".67
# Prscrbr_State_Abrvtn:"TX".115
# Prscrbr_State_FIPS:"48".115
# Prscrbr_Type:"Internal Medicine".189
# Prscrbr_Type_Src:"Claim-Specialty".777
# Brnd_Name:"Memantine Hcl Er"
# Gnrc_Name:"Memantine Hcl".3
# Tot_Clms:"11".56
# Tot_30day_Fills:"17".15
# Tot_Day_Suply:"510".6
# Tot_Drug_Cst:"685.59"
# Tot_Benes:"".509
# GE65_Sprsn_Flag:"".565
# GE65_Tot_Clms:"11".27
# GE65_Tot_30day_Fills:"17".5
# GE65_Tot_Drug_Cst:"685.59"
# GE65_Tot_Day_Suply:"510".2
# GE65_Bene_Sprsn_Flag:"*".543
# GE65_Tot_Benes:""}.845
# {"Prscrbr_NPI":"1003004201".68
# Prscrbr_Last_Org_Name:"Philbrick".68
# Prscrbr_First_Name:"Natalie".68
# Prscrbr_City:"Corpus Christi".68
# Prscrbr_State_Abrvtn:"TX".116
# Prscrbr_State_FIPS:"48".116
# Prscrbr_Type:"Internal Medicine".190
# Prscrbr_Type_Src:"Claim-Specialty".778
# Brnd_Name:"Metformin Hcl".7
# Gnrc_Name:"Metformin Hcl".12
# Tot_Clms:"172"
# Tot_30day_Fills:"477.7"
# Tot_Day_Suply:"14331"
# Tot_Drug_Cst:"1379.45"
# Tot_Benes:"54".2
# GE65_Sprsn_Flag:"".566
# GE65_Tot_Clms:"134"
# GE65_Tot_30day_Fills:"385"
# GE65_Tot_Drug_Cst:"998.73"
# GE65_Tot_Day_Suply:"11551"
# GE65_Bene_Sprsn_Flag:"".148
# GE65_Tot_Benes:"43"}.1
# {"Prscrbr_NPI":"1003004201".69
# Prscrbr_Last_Org_Name:"Philbrick".69
# Prscrbr_First_Name:"Natalie".69
# Prscrbr_City:"Corpus Christi".69
# Prscrbr_State_Abrvtn:"TX".117
# Prscrbr_State_FIPS:"48".117
# Prscrbr_Type:"Internal Medicine".191
# Prscrbr_Type_Src:"Claim-Specialty".779
# Brnd_Name:"Metformin Hcl Er".5
# Gnrc_Name:"Metformin Hcl".13
# Tot_Clms:"36".11
# Tot_30day_Fills:"94".2
# Tot_Day_Suply:"2819"
# Tot_Drug_Cst:"453.51"
# Tot_Benes:"14".23
# GE65_Sprsn_Flag:"#".325
# GE65_Tot_Clms:"".428
# GE65_Tot_30day_Fills:"".428
# GE65_Tot_Drug_Cst:"".428
# GE65_Tot_Day_Suply:"".428
# GE65_Bene_Sprsn_Flag:"#".302
# GE65_Tot_Benes:""}.846
# {"Prscrbr_NPI":"1003004201".70
# Prscrbr_Last_Org_Name:"Philbrick".70
# Prscrbr_First_Name:"Natalie".70
# Prscrbr_City:"Corpus Christi".70
# Prscrbr_State_Abrvtn:"TX".118
# Prscrbr_State_FIPS:"48".118
# Prscrbr_Type:"Internal Medicine".192
# Prscrbr_Type_Src:"Claim-Specialty".780
# Brnd_Name:"Methocarbamol".2
# Gnrc_Name:"Methocarbamol".2
# Tot_Clms:"16".32
# Tot_30day_Fills:"18".11
# Tot_Day_Suply:"520".1
# Tot_Drug_Cst:"110.37"
# Tot_Benes:"".510
# GE65_Sprsn_Flag:"#".326
# GE65_Tot_Clms:"".429
# GE65_Tot_30day_Fills:"".429
# GE65_Tot_Drug_Cst:"".429
# GE65_Tot_Day_Suply:"".429
# GE65_Bene_Sprsn_Flag:"*".544
# GE65_Tot_Benes:""}.847
# {"Prscrbr_NPI":"1003004201".71
# Prscrbr_Last_Org_Name:"Philbrick".71
# Prscrbr_First_Name:"Natalie".71
# Prscrbr_City:"Corpus Christi".71
# Prscrbr_State_Abrvtn:"TX".119
# Prscrbr_State_FIPS:"48".119
# Prscrbr_Type:"Internal Medicine".193
# Prscrbr_Type_Src:"Claim-Specialty".781
# Brnd_Name:"Metoprolol Succinate".8
# Gnrc_Name:"Metoprolol Succinate".8
# Tot_Clms:"65".3
# Tot_30day_Fills:"192.3"
# Tot_Day_Suply:"5770"
# Tot_Drug_Cst:"1332.13"
# Tot_Benes:"20".12
# GE65_Sprsn_Flag:"#".327
# GE65_Tot_Clms:"".430
# GE65_Tot_30day_Fills:"".430
# GE65_Tot_Drug_Cst:"".430
# GE65_Tot_Day_Suply:"".430
# GE65_Bene_Sprsn_Flag:"#".303
# GE65_Tot_Benes:""}.848
# {"Prscrbr_NPI":"1003004201".72
# Prscrbr_Last_Org_Name:"Philbrick".72
# Prscrbr_First_Name:"Natalie".72
# Prscrbr_City:"Corpus Christi".72
# Prscrbr_State_Abrvtn:"TX".120
# Prscrbr_State_FIPS:"48".120
# Prscrbr_Type:"Internal Medicine".194
# Prscrbr_Type_Src:"Claim-Specialty".782
# Brnd_Name:"Metoprolol Tartrate".6
# Gnrc_Name:"Metoprolol Tartrate".6
# Tot_Clms:"60".3
# Tot_30day_Fills:"150.1"
# Tot_Day_Suply:"4492"
# Tot_Drug_Cst:"305.37"
# Tot_Benes:"21".18
# GE65_Sprsn_Flag:"#".328
# GE65_Tot_Clms:"".431
# GE65_Tot_30day_Fills:"".431
# GE65_Tot_Drug_Cst:"".431
# GE65_Tot_Day_Suply:"".431
# GE65_Bene_Sprsn_Flag:"#".304
# GE65_Tot_Benes:""}.849
# {"Prscrbr_NPI":"1003004201".73
# Prscrbr_Last_Org_Name:"Philbrick".73
# Prscrbr_First_Name:"Natalie".73
# Prscrbr_City:"Corpus Christi".73
# Prscrbr_State_Abrvtn:"TX".121
# Prscrbr_State_FIPS:"48".121
# Prscrbr_Type:"Internal Medicine".195
# Prscrbr_Type_Src:"Claim-Specialty".783
# Brnd_Name:"Mirtazapine".4
# Gnrc_Name:"Mirtazapine".4
# Tot_Clms:"11".57
# Tot_30day_Fills:"21.3"
# Tot_Day_Suply:"640"
# Tot_Drug_Cst:"174.68"
# Tot_Benes:"".511
# GE65_Sprsn_Flag:"".567
# GE65_Tot_Clms:"11".28
# GE65_Tot_30day_Fills:"21.3"
# GE65_Tot_Drug_Cst:"174.68"
# GE65_Tot_Day_Suply:"640"
# GE65_Bene_Sprsn_Flag:"*".545
# GE65_Tot_Benes:""}]

# %% [markdown]
# **Auto-Detector**

# %%
#11
import pandas as pd

# === SMART FIELD DETECTOR ===
def auto_detect_columns(df, role_mapping):
    """
    Automatically detects the correct columns in CMS datasets based on role_mapping.

    Parameters:
    - df: the dataframe
    - role_mapping: dictionary, { 'role': [list of possible substrings to match] }

    Returns:
    - field_mapping: dictionary, { 'role': 'actual_column_name' }
    """
    detected = {}
    # Convert all column names to lowercase for case-insensitive matching
    all_cols = [c.lower() for c in df.columns]

    for role, candidates in role_mapping.items():
        match_found = False
        for keyword in candidates:
            # Iterate through actual column names (case-sensitive)
            for actual_col in df.columns:
                # Check if keyword is in lowercase column name
                if keyword in actual_col.lower():
                    detected[role] = actual_col
                    match_found = True
                    break
            if match_found:
                break
        if not match_found:
            raise ValueError(f"❌ No match found for '{role}' field. Tried keywords: {candidates}")

    return detected

# === CMS Data Pull ===
df = pd.read_csv(f"https://data.cms.gov/data-api/v1/dataset/9552739e-3d05-4c1b-8eff-ecabf391e2e5/data?year=2020&format=csv")

# === Auto-Detect Columns ===
role_mapping = {
    "generic_col": ["gnrc_name", "generic", "drug_name", "product", "description"], # Added "gnrc_name"
    "cost_col": ["tot_drug_cst", "cost"],
    "claims_col": ["tot_clms", "claim"]
}

detected_cols = auto_detect_columns(df, role_mapping)

generic_col = detected_cols["generic_col"]
cost_col = detected_cols["cost_col"]
claims_col = detected_cols["claims_col"]

print(f"\n🛰️ Auto-Detected Columns -> Generic: {generic_col} | Cost: {cost_col} | Claims: {claims_col}")
# Out:
# 🛰️ Auto-Detected Columns -> Generic: Gnrc_Name:"Apixaban" | Cost: Tot_Drug_Cst:"8828.74" | Claims: Tot_Clms:"13"

# %% [markdown]
# **Projection**

# %% [markdown]
# **Sensitivity Analysis**

# %%
#12
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

def run_sensitivity_analysis(df_norm, summary):
    """
    Performs sensitivity analysis on Semaglutide utilization projections.

    Args:
        df_norm (pd.DataFrame): DataFrame containing normalized Semaglutide fill rates.
        summary (pd.DataFrame): DataFrame containing Semaglutide cost data.

    Returns:
        None (Prints sensitivity analysis tables and visualizations)
    """
    # === STEP 1: Prevalence Sensitivity (±5%) ===
    print("\n🩺 Running Prevalence Sensitivity Analysis (±5%)...")

    # --- Merge the original 'df_norm' with the 'prev_df' to include 'Prevalence' ---
    # Assuming prev_df is defined and available in your environment
    # Replace this with the actual dataframe containing your prevalence data
    prev_df = pd.DataFrame({
        "Year": [2020, 2021, 2022],
        "Prevalence": [10.5, 10.7, 10.8]  # Example realistic values (you can adjust if needed)
    })
    # Merge df_norm with prev_df and summary to include 'Prevalence' and 'Total Fills'
    df_norm = pd.merge(df_norm, prev_df[['Year', 'Prevalence']], on='Year', how='inner')
    df_norm = pd.merge(df_norm, summary[['Year', 'Total Fills']], on='Year', how='inner') # Added this line to merge 'Total Fills'

    # --- End of Merge ---

    prevalence_shocks = [0.95, 1.00, 1.05]  # -5%, base, +5%

    prevalence_records = []
    for shock in prevalence_shocks:
        adj_df = df_norm.copy()
        adj_df["Adjusted Prevalence"] = adj_df["Prevalence"] * shock
        adj_df["Fills per 1,000 Patients (Adjusted)"] = adj_df["Total Fills"] / (adj_df["Adjusted Prevalence"] * 1000)
        adj_df["Shock"] = f"{(shock - 1) * 100:+.0f}%"
        prevalence_records.append(adj_df[["Year", "Shock", "Fills per 1,000 Patients (Adjusted)"]])

    prevalence_sens_df = pd.concat(prevalence_records, ignore_index=True)

    print("\n📊 Prevalence Sensitivity Table:")
    display(prevalence_sens_df.pivot(index="Year", columns="Shock", values="Fills per 1,000 Patients (Adjusted)"))

    # === STEP 2: Cost Sensitivity (-10%) ===
    print("\n💵 Running Cost Sensitivity Analysis (-10%)...")

    cost_shocks = [1.00, 0.90]  # Base, -10%

    cost_records = []
    for shock in cost_shocks:
        adj_df = df_norm.copy()
        adj_df["Avg Cost per Fill (Adjusted)"] = summary["Avg Cost per Fill"] * shock
        adj_df["Shock"] = f"{(shock - 1) * 100:+.0f}%"
        cost_records.append(adj_df[["Year", "Shock", "Avg Cost per Fill (Adjusted)"]])

    cost_sens_df = pd.concat(cost_records, ignore_index=True)

    print("\n📊 Cost Sensitivity Table:")
    display(cost_sens_df.pivot(index="Year", columns="Shock", values="Avg Cost per Fill (Adjusted)"))

# %%
#13
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

def run_sensitivity_analysis(df_norm, summary):
    """
    Performs sensitivity analysis on Semaglutide utilization projections,
    including data visualizations.

    Args:
        df_norm (pd.DataFrame): DataFrame containing normalized Semaglutide fill rates.
        summary (pd.DataFrame): DataFrame containing Semaglutide cost data.

    Returns:
        None (Prints tables and shows plots)
    """
    # === STEP 1: Prevalence Sensitivity (±5%) ===
    print("\n🩺 Running Prevalence Sensitivity Analysis (±5%)...")

    # Mocked prevalence data if not already included
    prev_df = pd.DataFrame({
        "Year": [2020, 2021, 2022],
        "Prevalence": [10.5, 10.7, 10.8]
    })
    df_norm = pd.merge(df_norm, prev_df[['Year', 'Prevalence']], on='Year', how='inner')

    prevalence_shocks = [0.95, 1.00, 1.05]  # -5%, base, +5%

    prevalence_records = []
    for shock in prevalence_shocks:
        adj_df = df_norm.copy()
        adj_df["Adjusted Prevalence"] = adj_df["Prevalence"] * shock
        adj_df["Fills per 1,000 Patients (Adjusted)"] = adj_df["Total Fills"] / (adj_df["Adjusted Prevalence"] * 1000)
        adj_df["Shock"] = f"{(shock - 1) * 100:+.0f}%"
        prevalence_records.append(adj_df[["Year", "Shock", "Fills per 1,000 Patients (Adjusted)"]])

    prevalence_sens_df = pd.concat(prevalence_records, ignore_index=True)

    print("\n📊 Prevalence Sensitivity Table:")
    display(prevalence_sens_df.pivot(index="Year", columns="Shock", values="Fills per 1,000 Patients (Adjusted)"))

    # === STEP 2: Prevalence Sensitivity Plot ===
    plt.figure(figsize=(10,6))
    for shock_level, group in prevalence_sens_df.groupby("Shock"):
        plt.plot(group["Year"], group["Fills per 1,000 Patients (Adjusted)"], marker="o", label=f"Shock {shock_level}")
    plt.title("Semaglutide Fills per 1,000 Patients - Prevalence Sensitivity (±5%)")
    plt.xlabel("Year")
    plt.ylabel("Fills per 1,000 Patients")
    plt.grid(True)
    plt.legend()
    plt.show()

    # === STEP 3: Cost Sensitivity (-10%) ===
    print("\n💵 Running Cost Sensitivity Analysis (-10%)...")

    cost_shocks = [1.00, 0.90]  # Base, -10%

    cost_records = []
    for shock in cost_shocks:
        adj_df = df_norm.copy()
        adj_df["Avg Cost per Fill (Adjusted)"] = summary["Avg Cost per Fill"] * shock
        adj_df["Shock"] = f"{(shock - 1) * 100:+.0f}%"
        cost_records.append(adj_df[["Year", "Shock", "Avg Cost per Fill (Adjusted)"]])

    cost_sens_df = pd.concat(cost_records, ignore_index=True)

    print("\n📊 Cost Sensitivity Table:")
    display(cost_sens_df.pivot(index="Year", columns="Shock", values="Avg Cost per Fill (Adjusted)"))

    # === STEP 4: Cost Sensitivity Plot (Bar Plot) ===
    pivot_cost = cost_sens_df.pivot(index="Year", columns="Shock", values="Avg Cost per Fill (Adjusted)")

    pivot_cost.plot(kind="bar", figsize=(10,6))
    plt.title("Semaglutide Avg Cost per Fill - Cost Sensitivity (-10%)")
    plt.xlabel("Year")
    plt.ylabel("Avg Cost per Fill ($)")
    plt.grid(axis='y')
    plt.legend(title="Shock Level")
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Dashboard**

# %%
#14
# !pip install dash dash-core-components dash-html-components plotly
# Out:
# Collecting dash
#   Downloading dash-3.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting dash-core-components
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash) (2.32.4)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2025.8.3)
# Downloading dash-3.2.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 32.8 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: dash-html-components, dash-core-components, retrying, dash
# Successfully installed dash-3.2.0 dash-core-components-2.0.0 dash-html-components-2.0.0 retrying-1.4.2

# %%
#15
# final_dash_app.py

import pandas as pd
import numpy as np
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objs as go
from sklearn.linear_model import LinearRegression  # Ensure you import LinearRegression
from IPython.display import IFrame  # Import IFrame for displaying the app in the notebook

def run_semaglutide_dashboard():
    """
    Creates and runs the Semaglutide Sensitivity Analysis Dashboard using Dash and Plotly.

    Includes data loading/mock data generation, app layout, callbacks, and app execution.
    """

    # === STEP 1: Prepare Real Data (or use mock data if necessary) ===
    # ... (Your data loading or mock data generation code) ...
    years = [2020, 2021, 2022]
    df_norm = pd.DataFrame({
        "Year": years,
        "Fills per 1,000 Patients": [10, 12, 15],  # Example values, replace with your data
        "Total Fills": [10000, 12000, 15000],  # Example values, replace with your data
        "Avg Cost per Fill": [800, 820, 840],  # placeholder values
        "Prevalence": [10.5, 10.7, 10.8]  # Example realistic values (you can adjust if needed)
    })
    summary = pd.DataFrame({
        "Year": years,
        "Avg Cost per Fill": [800, 820, 840],  # placeholder values
        "Total Fills": [10000, 12000, 15000]  # placeholder values
    })

    # --- Fit Linear Model ---
    X = df_norm[["Year"]]  # independent variable (year)
    y = df_norm["Fills per 1,000 Patients"]  # dependent variable

    model = LinearRegression()
    model.fit(X, y)

    # --- Predict 2023–2025 ---
    future_years = pd.DataFrame({"Year": [2023, 2024, 2025]})
    future_preds = model.predict(future_years)

    future_df = pd.DataFrame({
        "Year": future_years["Year"],
        "Fills per 1,000 Patients (Projected)": future_preds
    })

    # Merge actual and projected fills
    actual_fills = df_norm[["Year", "Fills per 1,000 Patients"]].copy()
    projected_fills = future_df.rename(columns={"Fills per 1,000 Patients (Projected)": "Fills per 1,000 Patients"}).copy()
    projected_fills["Year"] = projected_fills["Year"].astype(int)

    fills_all_years = pd.concat([actual_fills, projected_fills], ignore_index=True).sort_values("Year")

    # Merge actual and projected cost
    costs = summary[["Year", "Avg Cost per Fill"]].copy()

    # Assume simple 2% cost growth per year from 2022 forward
    latest_cost = costs["Avg Cost per Fill"].iloc[-1]
    future_costs = pd.DataFrame({
        "Year": [2023, 2024, 2025],
        "Avg Cost per Fill": [
            latest_cost * (1.02 ** 1),  # 2023
            latest_cost * (1.02 ** 2),  # 2024
            latest_cost * (1.02 ** 3)   # 2025
        ]
    })

    costs_all_years = pd.concat([costs, future_costs], ignore_index=True).sort_values("Year")

    # Merge fills and costs
    final_df = pd.merge(fills_all_years, costs_all_years, on="Year", how="inner")

    # === STEP 2: Dash App Setup ===
    app = Dash(__name__)

    app.layout = html.Div([
        html.H1("Semaglutide Sensitivity Analysis Dashboard (Dash-Plotly)", style={'textAlign': 'center'}),

        html.Div([
            html.Label('Prevalence Shock (% Change):'),
            dcc.Dropdown(
                id='prevalence-shock',
                options=[
                    {'label': '-5%', 'value': 0.95},
                    {'label': '0%', 'value': 1.00},
                    {'label': '+5%', 'value': 1.05}
                ],
                value=1.00,
                clearable=False
            ),
        ], style={'width': '48%', 'display': 'inline-block'}),

        html.Div([
            html.Label('Cost Shock (% Change):'),
            dcc.Dropdown(
                id='cost-shock',
                options=[
                    {'label': '0%', 'value': 1.00},
                    {'label': '-10%', 'value': 0.90}
                ],
                value=1.00,
                clearable=False
            ),
        ], style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),

        dcc.Graph(id='fills-line-chart'),

        html.H2("Adjusted Summary Table", style={'textAlign': 'center'}),
        dcc.Graph(id='summary-table')
    ])

    # === STEP 3: Dash App Callbacks ===
    @app.callback(
        [Output('fills-line-chart', 'figure'),
         Output('summary-table', 'figure')],
        [Input('prevalence-shock', 'value'),
         Input('cost-shock', 'value')]
    )
    def update_graphs(prevalence_factor, cost_factor):
        # Adjust based on dropdown selections
        df = final_df.copy()
        df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
        df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor

        # Line Chart for Adjusted Fills
        line_fig = go.Figure()
        line_fig.add_trace(go.Scatter(
            x=df["Year"],
            y=df["Adjusted Fills per 1,000 Patients"],
            mode='lines+markers',
            name='Adjusted Fills per 1,000 Patients'
        ))
        line_fig.update_layout(
            title="Adjusted Fills per 1,000 Diabetic Patients Over Time",
            xaxis_title="Year",
            yaxis_title="Fills per 1,000 Patients",
            template="plotly_white"
        )

        # Table for Adjusted Summary
        table_fig = go.Figure(data=[go.Table(
            header=dict(values=list(["Year", "Adjusted Fills per 1,000 Patients", "Adjusted Cost per Fill"]),
                        fill_color='paleturquoise',
                        align='center'),
            cells=dict(values=[
                df["Year"],
                np.round(df["Adjusted Fills per 1,000 Patients"], 2),
                np.round(df["Adjusted Cost per Fill"], 2)
            ],
            fill_color='lavender',
            align='center'))
        ])
        table_fig.update_layout(height=400)

        return line_fig, table_fig

    # === STEP 4: Run App ===
    # ... (app.run)
    # app.run_server(debug=True, port=8051)  # commented out this for local execution
    return app

# --- Run the App ---
# Start the Dash app and display it in an IFrame within the notebook
app = run_semaglutide_dashboard()
# Use a unique port to avoid conflicts if running multiple Dash apps
port = 8051
app.run(port=port)
#IFrame(src=f"http://127.0.0.1:{port}/", width="100%", height=800)

# %% [markdown]
# **Budget Impact calculation**

# %%
#16
# final_dash_app.py

import pandas as pd
import numpy as np
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objs as go
from sklearn.linear_model import LinearRegression  # Ensure you import LinearRegression
from IPython.display import IFrame  # Import IFrame for displaying the app in the notebook


def run_semaglutide_dashboard():
    """
    Creates and runs the Semaglutide Sensitivity Analysis Dashboard using Dash and Plotly.

    Includes data loading/mock data generation, app layout, callbacks, and app execution.
    """

    # === STEP 1: Prepare Real Data (or use mock data if necessary) ===
    # ... (Your data loading or mock data generation code) ...
    years = [2020, 2021, 2022]
    df_norm = pd.DataFrame(
        {
            "Year": years,
            "Fills per 1,000 Patients": [10, 12, 15],  # Example values, replace with your data
            "Total Fills": [10000, 12000, 15000],  # Example values, replace with your data
            "Avg Cost per Fill": [800, 820, 840],  # placeholder values
            "Prevalence": [10.5, 10.7, 10.8],  # Example realistic values (you can adjust if needed)
        }
    )
    summary = pd.DataFrame(
        {
            "Year": years,
            "Avg Cost per Fill": [800, 820, 840],  # placeholder values
            "Total Fills": [10000, 12000, 15000],  # placeholder values
        }
    )

    # --- Fit Linear Model ---
    X = df_norm[["Year"]]  # independent variable (year)
    y = df_norm["Fills per 1,000 Patients"]  # dependent variable

    model = LinearRegression()
    model.fit(X, y)

    # --- Predict 2023–2025 ---
    future_years = pd.DataFrame({"Year": [2023, 2024, 2025]})
    future_preds = model.predict(future_years)

    future_df = pd.DataFrame(
        {"Year": future_years["Year"], "Fills per 1,000 Patients (Projected)": future_preds}
    )

    # Merge actual and projected fills
    actual_fills = df_norm[["Year", "Fills per 1,000 Patients"]].copy()
    projected_fills = future_df.rename(
        columns={"Fills per 1,000 Patients (Projected)": "Fills per 1,000 Patients"}
    ).copy()
    projected_fills["Year"] = projected_fills["Year"].astype(int)

    fills_all_years = pd.concat([actual_fills, projected_fills], ignore_index=True).sort_values(
        "Year"
    )

    # Merge actual and projected cost
    costs = summary[["Year", "Avg Cost per Fill"]].copy()

    # Assume simple 2% cost growth per year from 2022 forward
    latest_cost = costs["Avg Cost per Fill"].iloc[-1]
    future_costs = pd.DataFrame(
        {
            "Year": [2023, 2024, 2025],
            "Avg Cost per Fill": [
                latest_cost * (1.02**1),  # 2023
                latest_cost * (1.02**2),  # 2024
                latest_cost * (1.02**3),  # 2025
            ],
        }
    )

    costs_all_years = pd.concat([costs, future_costs], ignore_index=True).sort_values("Year")

    # Merge fills and costs
    final_df = pd.merge(fills_all_years, costs_all_years, on="Year", how="inner")

    # === STEP 2: Dash App Setup ===
    app = Dash(__name__)

    app.layout = html.Div(
        [
            html.H1(
                "Semaglutide Sensitivity Analysis Dashboard (Dash-Plotly)",
                style={"textAlign": "center"},
            ),
            html.Div(
                [
                    html.Label("Prevalence Shock (% Change):"),
                    dcc.Dropdown(
                        id="prevalence-shock",
                        options=[
                            {"label": "-5%", "value": 0.95},
                            {"label": "0%", "value": 1.00},
                            {"label": "+5%", "value": 1.05},
                        ],
                        value=1.00,
                        clearable=False,
                    ),
                ],
                style={"width": "48%", "display": "inline-block"},
            ),
            html.Div(
                [
                    html.Label("Cost Shock (% Change):"),
                    dcc.Dropdown(
                        id="cost-shock",
                        options=[{"label": "0%", "value": 1.00}, {"label": "-10%", "value": 0.90}],
                        value=1.00,
                        clearable=False,
                    ),
                ],
                style={"width": "48%", "float": "right", "display": "inline-block"},
            ),
            dcc.Graph(id="fills-line-chart"),
            html.H2("Adjusted Summary Table", style={"textAlign": "center"}),
            dcc.Graph(id="summary-table"),
        ]
    )

    # === STEP 3: Dash App Callbacks ===

    @app.callback(
        [Output("fills-line-chart", "figure"), Output("summary-table", "figure")],
        [Input("prevalence-shock", "value"), Input("cost-shock", "value")],
    )
    def update_graphs(prevalence_factor, cost_factor):
        # Adjust based on dropdown selections
        df = final_df.copy()
        df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
        df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor

        # Line Chart for Adjusted Fills
        line_fig = go.Figure()
        line_fig.add_trace(
            go.Scatter(
                x=df["Year"],
                y=df["Adjusted Fills per 1,000 Patients"],
                mode="lines+markers",
                name="Adjusted Fills per 1,000 Patients",
            )
        )
        line_fig.update_layout(
            title="Adjusted Fills per 1,000 Diabetic Patients Over Time",
            xaxis_title="Year",
            yaxis_title="Fills per 1,000 Patients",
            template="plotly_white",
        )

        # Table for Adjusted Summary
        table_fig = go.Figure(
            data=[
                go.Table(
                    header=dict(
                        values=list(
                            ["Year", "Adjusted Fills per 1,000 Patients", "Adjusted Cost per Fill"]
                        ),
                        fill_color="paleturquoise",
                        align="center",
                    ),
                    cells=dict(
                        values=[
                            df["Year"],
                            np.round(df["Adjusted Fills per 1,000 Patients"], 2),
                            np.round(df["Adjusted Cost per Fill"], 2),
                        ],
                        fill_color="lavender",
                        align="center",
                    ),
                )
            ]
        )
        table_fig.update_layout(height=400)

        return line_fig, table_fig

    # === STEP 4: Run App ===
    # ... (app.run)
    # app.run_server(debug=True, port=8051)  # commented out this for local execution
    return app


# --- Run the App ---
# Start the Dash app and display it in an IFrame within the notebook
app = run_semaglutide_dashboard()
# Use a unique port to avoid conflicts if running multiple Dash apps
port = 8051
# Changed from app.run_server to app.run
app.run(port=port, debug=True)
# IFrame(src=f"http://127.0.0.1:{port}/", width="100%", height=800)

# %% [markdown]
# **SUMMARY REPORT**

# %% [markdown]
# **Modeling: Projections and Sensitivity Analysis**

# %%
#17
import pandas as pd
import matplotlib.pyplot as plt

# ==== Replace this mock summary with your actual 'summary' DataFrame ====
summary = pd.DataFrame({
    "Year": [2020, 2021, 2022],
    "Avg Cost per Fill": [800, 820, 840],  # placeholder values
    "Total Fills": [100000, 110000, 120000] # placeholder values
})

# 1) Compute Annual Cost and Cost per QALY
fills_per_year = 12    # assumed fills per patient per year
qaly_gain = 0.25       # assumed QALY gain per year

summary["Annual Cost"] = summary["Avg Cost per Fill"] * fills_per_year
summary["Cost per QALY"] = summary["Annual Cost"] / qaly_gain

# Display the cost-per-QALY summary
print("Cost per QALY Summary:")
display(summary[["Year", "Cost per QALY"]])

# 2) One-way sensitivity analysis (±20% QALY gain)
sens_qaly = [qaly_gain * 0.8, qaly_gain, qaly_gain * 1.2]
sens_records = []
for q in sens_qaly:
    for _, row in summary.iterrows():
        sens_records.append({
            "Year": row["Year"],
            "QALY Gain": f"{q:.2f}",
            "Cost per QALY": row["Annual Cost"] / q
        })
sens_df = pd.DataFrame(sens_records)

# Display sensitivity table
print("\nSensitivity Analysis Table:")
display(sens_df.pivot(index="Year", columns="QALY Gain", values="Cost per QALY"))

# 3) Static Plots

# a) Base Cost per QALY
plt.figure(figsize=(8, 5))
plt.plot(summary["Year"], summary["Cost per QALY"], marker="o")
plt.title("Estimated Cost per QALY for Semaglutide (2020–2022)")
plt.xlabel("Year")
plt.ylabel("Cost per QALY ($)")
plt.grid(True)
plt.show()

# b) Sensitivity Analysis
plt.figure(figsize=(8, 5))
for label, grp in sens_df.groupby("QALY Gain"):
    plt.plot(grp["Year"], grp["Cost per QALY"], marker="o", label=f"QALY Gain = {label}")
plt.title("One-Way Sensitivity: Cost per QALY vs. QALY Gain")
plt.xlabel("Year")
plt.ylabel("Cost per QALY ($)")
plt.legend(title="QALY Gain")
plt.grid(True)
plt.show()
# Out:
# Cost per QALY Summary:
#    Year  Cost per QALY
# 0  2020        38400.0
# 1  2021        39360.0
# 2  2022        40320.0
# Sensitivity Analysis Table:
# QALY Gain     0.20     0.25     0.30
# Year
# 2020.0     48000.0  38400.0  32000.0
# 2021.0     49200.0  39360.0  32800.0
# 2022.0     50400.0  40320.0  33600.0

# %%
#18
# === STEP 2: Patch real-world diabetes prevalence (Mocked Data) ===
print("\n⚠️ WHO API Unavailable. Using Mocked Diabetes Prevalence Data (for USA)...")
prev_df = pd.DataFrame({
    "Year": [2020, 2021, 2022],
    "Prevalence": [10.5, 10.7, 10.8]  # Example realistic values (you can adjust if needed)
})
display(prev_df)
# Out:
# ⚠️ WHO API Unavailable. Using Mocked Diabetes Prevalence Data (for USA)...
#    Year  Prevalence
# 0  2020        10.5
# 1  2021        10.7
# 2  2022        10.8

# %%
#19
Drug_Name
Tot_Drug_Cst
Tot_Clms
...
# Out:
# Ellipsis

# %%
#20
generic_col = "Drug_Name"
cost_col    = "Tot_Drug_Cst"
claims_col  = "Tot_Clms"

# %%
#21
# === SMART FIELD DETECTOR ===
def auto_detect_columns(df, role_mapping):
    """
    Automatically detects the correct columns in CMS datasets based on role_mapping.

    Parameters:
    - df: the dataframe
    - role_mapping: dictionary, { 'role': [list of possible substrings to match] }

    Returns:
    - field_mapping: dictionary, { 'role': 'actual_column_name' }
    """
    detected = {}
    all_cols = [c.lower() for c in df.columns]

    for role, candidates in role_mapping.items():
        match_found = False
        for keyword in candidates:
            for actual_col in df.columns:
                if keyword in actual_col.lower():
                    detected[role] = actual_col
                    match_found = True
                    break
            if match_found:
                break
        if not match_found:
            raise ValueError(f"❌ No match found for '{role}' field. Tried keywords: {candidates}")

    return detected

# %%
#22
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# === Mock Data for df_norm (Replace with your actual data source) ===
df_norm = pd.DataFrame({
    "Year": [2020, 2021, 2022],
    "Fills per 1,000 Patients": [10, 12, 15]  # Example values, replace with your data
})
# === END of Mock Data ===


# === STEP 1: Fit Linear Model ===
X = df_norm[["Year"]]  # independent variable (year)
y = df_norm["Fills per 1,000 Patients"]  # dependent variable

model = LinearRegression()
model.fit(X, y)

print("\n📈 Model Coefficients:")
print(f"Slope: {model.coef_[0]:.4f}")
print(f"Intercept: {model.intercept_:.2f}")

# === STEP 2: Predict 2023–2025 ===
future_years = pd.DataFrame({"Year": [2023, 2024, 2025]})
future_preds = model.predict(future_years)

future_df = pd.DataFrame({
    "Year": future_years["Year"],
    "Fills per 1,000 Patients (Projected)": future_preds
})

print("\n🔮 Future Projections:")
display(future_df)

# === STEP 3: Combine Actual + Projected for Plotting ===
actual_plot = df_norm[["Year", "Fills per 1,000 Patients"]].copy()
actual_plot["Type"] = "Actual"

proj_plot = future_df.rename(columns={"Fills per 1,000 Patients (Projected)": "Fills per 1,000 Patients"})
proj_plot["Type"] = "Projected"

plot_df = pd.concat([actual_plot, proj_plot], ignore_index=True)

# === STEP 4: Plot ===
plt.figure(figsize=(10,6))

for label, group in plot_df.groupby("Type"):
    linestyle = "-" if label == "Actual" else "--"
    plt.plot(group["Year"], group["Fills per 1,000 Patients"], linestyle=linestyle, marker="o", label=label)

plt.title("Semaglutide Fills per 1,000 Diabetic Patients (USA, 2020–2025)")
plt.xlabel("Year")
plt.ylabel("Fills per 1,000 Patients")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 📈 Model Coefficients:
# Slope: 2.5000
# Intercept: -5040.17
#
# 🔮 Future Projections:
#    Year  Fills per 1,000 Patients (Projected)
# 0  2023                             17.333333
# 1  2024                             19.833333
# 2  2025                             22.333333

# %%
#23
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

def run_sensitivity_analysis(df_norm, summary):
    """
    Performs sensitivity analysis on Semaglutide utilization projections.

    Args:
        df_norm (pd.DataFrame): DataFrame containing normalized Semaglutide fill rates.
        summary (pd.DataFrame): DataFrame containing Semaglutide cost data.

    Returns:
        None (Prints sensitivity analysis tables and visualizations)
    """
    # === STEP 1: Prevalence Sensitivity (±5%) ===
    print("\n🩺 Running Prevalence Sensitivity Analysis (±5%)...")

    # --- Merge the original 'df_norm' with the 'prev_df' to include 'Prevalence' ---
    # Assuming prev_df is defined and available in your environment
    # Replace this with the actual dataframe containing your prevalence data
    prev_df = pd.DataFrame({
        "Year": [2020, 2021, 2022],
        "Prevalence": [10.5, 10.7, 10.8]  # Example realistic values (you can adjust if needed)
    })
    # Merge df_norm with prev_df and summary to include 'Prevalence' and 'Total Fills'
    df_norm = pd.merge(df_norm, prev_df[['Year', 'Prevalence']], on='Year', how='inner')
    df_norm = pd.merge(df_norm, summary[['Year', 'Total Fills']], on='Year', how='inner') # Added this line to merge 'Total Fills'

    # --- End of Merge ---

    prevalence_shocks = [0.95, 1.00, 1.05]  # -5%, base, +5%

    prevalence_records = []
    for shock in prevalence_shocks:
        adj_df = df_norm.copy()
        adj_df["Adjusted Prevalence"] = adj_df["Prevalence"] * shock
        adj_df["Fills per 1,000 Patients (Adjusted)"] = adj_df["Total Fills"] / (adj_df["Adjusted Prevalence"] * 1000)
        adj_df["Shock"] = f"{(shock - 1) * 100:+.0f}%"
        prevalence_records.append(adj_df[["Year", "Shock", "Fills per 1,000 Patients (Adjusted)"]])

    prevalence_sens_df = pd.concat(prevalence_records, ignore_index=True)

    print("\n📊 Prevalence Sensitivity Table:")
    display(prevalence_sens_df.pivot(index="Year", columns="Shock", values="Fills per 1,000 Patients (Adjusted)"))

    # === STEP 2: Cost Sensitivity (-10%) ===
    print("\n💵 Running Cost Sensitivity Analysis (-10%)...")

    cost_shocks = [1.00, 0.90]  # Base, -10%

    cost_records = []
    for shock in cost_shocks:
        adj_df = df_norm.copy()
        adj_df["Avg Cost per Fill (Adjusted)"] = summary["Avg Cost per Fill"] * shock
        adj_df["Shock"] = f"{(shock - 1) * 100:+.0f}%"
        cost_records.append(adj_df[["Year", "Shock", "Avg Cost per Fill (Adjusted)"]])

    cost_sens_df = pd.concat(cost_records, ignore_index=True)

    print("\n📊 Cost Sensitivity Table:")
    display(cost_sens_df.pivot(index="Year", columns="Shock", values="Avg Cost per Fill (Adjusted)"))

# %%
#24
run_sensitivity_analysis(df_norm, summary)
# Out:
# 🩺 Running Prevalence Sensitivity Analysis (±5%)...
#
# 📊 Prevalence Sensitivity Table:
# Shock        +0%        +5%        -5%
# Year
# 2020    9.523810   9.070295  10.025063
# 2021   10.280374   9.790832  10.821446
# 2022   11.111111  10.582011  11.695906
# 💵 Running Cost Sensitivity Analysis (-10%)...
#
# 📊 Cost Sensitivity Table:
# Shock    +0%   -10%
# Year
# 2020   800.0  720.0
# 2021   820.0  738.0
# 2022   840.0  756.0

# %%
#25
# === STEP 4 (Fixed): Cost Sensitivity Plot (Bar Plot for better visibility) ===
# Ensure cost_sens_df is defined by running the sensitivity analysis first

# Call the sensitivity analysis function here, if it hasn't been called before
# run_sensitivity_analysis(df_norm, summary)  # Assuming you have df_norm and summary defined

# This creates the DataFrame cost_sens_df from the analysis results
import pandas as pd
# === STEP 4 (Fixed): Cost Sensitivity Plot (Bar Plot for better visibility) ===
# Ensure cost_sens_df is defined by running the sensitivity analysis first

# Call the sensitivity analysis function here, if it hasn't been called before
# run_sensitivity_analysis(df_norm, summary)  # Assuming you have df_norm and summary defined

# This creates the DataFrame cost_sens_df from the analysis results
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression # Added missing import

# %%
#26
# !pip install dash
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash) (2.32.4)
# Requirement already satisfied: retrying in /usr/local/lib/python3.12/dist-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2025.8.3)

# %%
#27
# !pip install dash dash-core-components dash-html-components
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: dash-core-components in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: dash-html-components in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash) (2.32.4)
# Requirement already satisfied: retrying in /usr/local/lib/python3.12/dist-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash) (2025.8.3)

# %%
#28
# dash_app.py

import pandas as pd
import numpy as np
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objs as go

# === Mock Data Preparation (replace with your real df_norm + future projections later) ===
years = [2020, 2021, 2022, 2023, 2024, 2025]
base_fills_per_1000 = [120, 135, 150, 165, 180, 195]  # Example only
avg_cost_per_fill = [850, 870, 890, 910, 930, 950]    # Example only

df_base = pd.DataFrame({
    "Year": years,
    "Fills per 1,000 Patients": base_fills_per_1000,
    "Avg Cost per Fill": avg_cost_per_fill
})

# === Dash App Setup ===
app = Dash(__name__)

app.layout = html.Div([
    html.H1("Semaglutide Sensitivity Analysis Dashboard (Dash-Plotly)", style={'textAlign': 'center'}),

    html.Div([
        html.Label('Prevalence Shock (% Change):'),
        dcc.Dropdown(
            id='prevalence-shock',
            options=[
                {'label': '-5%', 'value': 0.95},
                {'label': '0%', 'value': 1.00},
                {'label': '+5%', 'value': 1.05}
            ],
            value=1.00,
            clearable=False
        ),
    ], style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
        html.Label('Cost Shock (% Change):'),
        dcc.Dropdown(
            id='cost-shock',
            options=[
                {'label': '0%', 'value': 1.00},
                {'label': '-10%', 'value': 0.90}
            ],
            value=1.00,
            clearable=False
        ),
    ], style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),

    dcc.Graph(id='fills-line-chart'),

    html.H2("Adjusted Summary Table", style={'textAlign': 'center'}),
    dcc.Graph(id='summary-table')
])

# === Dash App Callbacks ===
@app.callback(
    [Output('fills-line-chart', 'figure'),
     Output('summary-table', 'figure')],
    [Input('prevalence-shock', 'value'),
     Input('cost-shock', 'value')]
)
def update_graphs(prevalence_factor, cost_factor):
    # Adjusted calculations
    df = df_base.copy()
    df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
    df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor

    # Line Plot
    line_fig = go.Figure()
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Adjusted Fills per 1,000 Patients"],
        mode='lines+markers',
        name='Fills per 1,000 Patients'
    ))
    line_fig.update_layout(
        title="Adjusted Fills per 1,000 Patients Over Time",
        xaxis_title="Year",
        yaxis_title="Fills per 1,000 Patients",
        template="plotly_white"
    )

    # Table
    table_fig = go.Figure(data=[go.Table(
        header=dict(values=list(df[["Year", "Adjusted Fills per 1,000 Patients", "Adjusted Cost per Fill"]].columns),
                    fill_color='paleturquoise',
                    align='center'),
        cells=dict(values=[
            df["Year"],
            np.round(df["Adjusted Fills per 1,000 Patients"], 2),
            np.round(df["Adjusted Cost per Fill"], 2)
        ],
        fill_color='lavender',
        align='center'))
    ])
    table_fig.update_layout(height=400)

    return line_fig, table_fig

# === Run the App ===
#if __name__ == '__main__':
   # app.run_server(debug=True, port=8051)


if __name__ == '__main__':
    app.run(debug=True, port=8051) # Changed from app.run_server to app.run

# %%
#29
# final_dash_app.py

import pandas as pd
import numpy as np
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objs as go
from sklearn.linear_model import LinearRegression  # Ensure you import LinearRegression

def run_semaglutide_dashboard():
    """
    Creates and runs the Semaglutide Sensitivity Analysis Dashboard using Dash and Plotly.

    Includes data loading/mock data generation, app layout, callbacks, and app execution.
    """

    # === STEP 1: Prepare Real Data (or use mock data if necessary) ===
    years = [2020, 2021, 2022]
    df_norm = pd.DataFrame({
        "Year": years,
        "Fills per 1,000 Patients": [10, 12, 15],  # Example values, replace with your data
        "Total Fills": [10000, 12000, 15000],  # Example values, replace with your data
        "Avg Cost per Fill": [800, 820, 840],  # placeholder values
        "Prevalence": [10.5, 10.7, 10.8]  # Example realistic values (you can adjust if needed)
    })
    summary = pd.DataFrame({
        "Year": years,
        "Avg Cost per Fill": [800, 820, 840],  # placeholder values
        "Total Fills": [10000, 12000, 15000]  # placeholder values
    })

    # --- Fit Linear Model ---
    X = df_norm[["Year"]]  # independent variable (year)
    y = df_norm["Fills per 1,000 Patients"]  # dependent variable

    model = LinearRegression()
    model.fit(X, y)

# %%
#30
@app.callback(
    [Output('fills-line-chart', 'figure'),
     Output('summary-table', 'figure')],
    [Input('prevalence-shock', 'value'),
     Input('cost-shock', 'value')]
)
def update_graphs(prevalence_factor, cost_factor):
    # Adjust data based on dropdown selections
    df = final_df.copy()
    df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
    df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor

    # === NEW: Calculate Budget Impact ===
    df["Total Budget Impact (USD)"] = df["Adjusted Fills per 1,000 Patients"] * 1000 * df["Adjusted Cost per Fill"]

    # Line Chart for Adjusted Fills
    line_fig = go.Figure()
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Adjusted Fills per 1,000 Patients"],
        mode='lines+markers',
        name='Adjusted Fills per 1,000 Patients'
    ))
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Total Budget Impact (USD)"]/1e6,  # Show in millions
        mode='lines+markers',
        name='Total Budget Impact (in Millions USD)',
        yaxis='y2'
    ))
    line_fig.update_layout(
        title="Semaglutide Sensitivity Analysis Over Time",
        xaxis_title="Year",
        yaxis=dict(
            title="Fills per 1,000 Patients",
            titlefont=dict(color="#1f77b4"),
            tickfont=dict(color="#1f77b4")
        ),
        yaxis2=dict(
            title="Budget Impact (Millions USD)",
            overlaying='y',
            side='right',
            titlefont=dict(color="#ff7f0e"),
            tickfont=dict(color="#ff7f0e")
        ),
        legend=dict(x=0, y=1.15, orientation="h"),
        template="plotly_white"
    )

    # Updated Table with Budget Impact
    table_fig = go.Figure(data=[go.Table(
        header=dict(values=[
            "Year",
            "Adjusted Fills per 1,000 Patients",
            "Adjusted Cost per Fill",
            "Total Budget Impact (USD)"
        ],
        fill_color='paleturquoise',
        align='center'),
        cells=dict(values=[
            df["Year"],
            np.round(df["Adjusted Fills per 1,000 Patients"], 2),
            np.round(df["Adjusted Cost per Fill"], 2),
            np.round(df["Total Budget Impact (USD)"], 2)
        ],
        fill_color='lavender',
        align='center'))
    ])
    table_fig.update_layout(height=600)

    return line_fig, table_fig

# %%
#31
@app.callback(
    [Output('fills-line-chart', 'figure'),
     Output('summary-table', 'figure')],
    [Input('prevalence-shock', 'value'),
     Input('cost-shock', 'value')]
)
def update_graphs(prevalence_factor, cost_factor):
    # Adjust data based on dropdown selections
    df = final_df.copy()
    df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
    df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor

    # === Calculate Budget Impact ===
    df["Total Budget Impact (USD)"] = df["Adjusted Fills per 1,000 Patients"] * 1000 * df["Adjusted Cost per Fill"]

    # === Plot: Line Chart for Adjusted Fills + Budget Impact ===
    line_fig = go.Figure()

    # Line for Adjusted Fills
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Adjusted Fills per 1,000 Patients"],
        mode='lines+markers',
        name='Adjusted Fills per 1,000 Patients'
    ))

    # Line for Budget Impact (in Millions)
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Total Budget Impact (USD)"]/1e6,
        mode='lines+markers',
        name='Total Budget Impact (Millions USD)',
        yaxis='y2'
    ))

    # Update layout with 2 y-axes
    line_fig.update_layout(
        title="Semaglutide Sensitivity Analysis Over Time",
        xaxis_title="Year",
        yaxis=dict(
            title="Fills per 1,000 Patients",
            titlefont=dict(color="#1f77b4"),
            tickfont=dict(color="#1f77b4")
        ),
        yaxis2=dict(
            title="Budget Impact (Millions USD)",
            overlaying='y',
            side='right',
            titlefont=dict(color="#ff7f0e"),
            tickfont=dict(color="#ff7f0e")
        ),
        legend=dict(x=0, y=1.15, orientation="h"),
        template="plotly_white"
    )

    # === Plot: Correlation Plot (Budget Impact vs Fills per 1,000 Patients) ===
    corr_fig = go.Figure()

    corr_fig.add_trace(go.Scatter(
        x=df["Adjusted Fills per 1,000 Patients"],
        y=df["Total Budget Impact (USD)"]/1e6,
        mode='markers+text',
        text=df["Year"],
        textposition="top center",
        marker=dict(size=10, color='blue'),
        name="Data Points"
    ))

    # Add Linear Regression Line
    slope, intercept = np.polyfit(df["Adjusted Fills per 1,000 Patients"], df["Total Budget Impact (USD)"]/1e6, 1)
    reg_line = slope * df["Adjusted Fills per 1,000 Patients"] + intercept

    corr_fig.add_trace(go.Scatter(
        x=df["Adjusted Fills per 1,000 Patients"],
        y=reg_line,
        mode='lines',
        name=f"Fit: y = {slope:.2f}x + {intercept:.2f}",
        line=dict(color='red', dash='dash')
    ))

    corr_fig.update_layout(
        title="Correlation: Fills vs Budget Impact",
        xaxis_title="Adjusted Fills per 1,000 Patients",
        yaxis_title="Total Budget Impact (Millions USD)",
        template="plotly_white",
        height=500
    )

    # === Update Table: Now Include Budget Impact ===
    table_fig = go.Figure(data=[go.Table(
        header=dict(values=[
            "Year",
            "Adjusted Fills per 1,000 Patients",
            "Adjusted Cost per Fill",
            "Total Budget Impact (USD)"
        ],
        fill_color='paleturquoise',
        align='center'),
        cells=dict(values=[
            df["Year"],
            np.round(df["Adjusted Fills per 1,000 Patients"], 2),
            np.round(df["Adjusted Cost per Fill"], 2),
            np.round(df["Total Budget Impact (USD)"], 2)
        ],
        fill_color='lavender',
        align='center'))
    ])
    table_fig.update_layout(height=600)

    # === Return Both Main Graph + Table ===
    return [dcc.Graph(figure=line_fig), dcc.Graph(figure=corr_fig)], table_fig

# %%
#32
app.layout = html.Div([
    html.H1("Semaglutide Sensitivity Analysis Dashboard (Dash-Plotly)", style={'textAlign': 'center'}),

    html.Div([
        html.Label('Prevalence Shock (% Change):'),
        dcc.Dropdown(
            id='prevalence-shock',
            options=[
                {'label': '-5%', 'value': 0.95},
                {'label': '0%', 'value': 1.00},
                {'label': '+5%', 'value': 1.05}
            ],
            value=1.00,
            clearable=False
        ),
    ], style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
        html.Label('Cost Shock (% Change):'),
        dcc.Dropdown(
            id='cost-shock',
            options=[
                {'label': '0%', 'value': 1.00},
                {'label': '-10%', 'value': 0.90}
            ],
            value=1.00,
            clearable=False
        ),
    ], style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),

    dcc.Graph(id='fills-line-chart'),
    dcc.Graph(id='correlation-plot'),

    html.H2("Adjusted Summary Table", style={'textAlign': 'center'}),
    dcc.Graph(id='summary-table')
])

# %%
#33
@app.callback(
    [Output('fills-line-chart', 'figure'),
     Output('correlation-plot', 'figure'),
     Output('summary-table', 'figure')],
    [Input('prevalence-shock', 'value'),
     Input('cost-shock', 'value')]
)
def update_graphs(prevalence_factor, cost_factor):
    # Adjust data
    df = final_df.copy()
    df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
    df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor
    df["Total Budget Impact (USD)"] = df["Adjusted Fills per 1,000 Patients"] * 1000 * df["Adjusted Cost per Fill"]

    # === Line Chart: Time Trend ===
    line_fig = go.Figure()

    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Adjusted Fills per 1,000 Patients"],
        mode='lines+markers',
        name='Adjusted Fills per 1,000 Patients'
    ))

    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Total Budget Impact (USD)"]/1e6,
        mode='lines+markers',
        name='Total Budget Impact (Millions USD)',
        yaxis='y2'
    ))

    line_fig.update_layout(
        title="Semaglutide Sensitivity Analysis Over Time",
        xaxis_title="Year",
        yaxis=dict(
            title="Fills per 1,000 Patients",
            titlefont=dict(color="#1f77b4"),
            tickfont=dict(color="#1f77b4")
        ),
        yaxis2=dict(
            title="Budget Impact (Millions USD)",
            overlaying='y',
            side='right',
            titlefont=dict(color="#ff7f0e"),
            tickfont=dict(color="#ff7f0e")
        ),
        legend=dict(x=0, y=1.15, orientation="h"),
        template="plotly_white"
    )

    # === Scatter Plot: Correlation ===
    corr_fig = go.Figure()

    corr_fig.add_trace(go.Scatter(
        x=df["Adjusted Fills per 1,000 Patients"],
        y=df["Total Budget Impact (USD)"]/1e6,
        mode='markers+text',
        text=df["Year"],
        textposition="top center",
        marker=dict(size=10, color='blue'),
        name="Data Points"
    ))

    slope, intercept = np.polyfit(df["Adjusted Fills per 1,000 Patients"], df["Total Budget Impact (USD)"]/1e6, 1)
    reg_line = slope * df["Adjusted Fills per 1,000 Patients"] + intercept

    corr_fig.add_trace(go.Scatter(
        x=df["Adjusted Fills per 1,000 Patients"],
        y=reg_line,
        mode='lines',
        name=f"Fit: y = {slope:.2f}x + {intercept:.2f}",
        line=dict(color='red', dash='dash')
    ))

    corr_fig.update_layout(
        title="Correlation: Fills vs Budget Impact",
        xaxis_title="Adjusted Fills per 1,000 Patients",
        yaxis_title="Total Budget Impact (Millions USD)",
        template="plotly_white",
        height=500
    )

    # === Summary Table ===
    table_fig = go.Figure(data=[go.Table(
        header=dict(values=[
            "Year",
            "Adjusted Fills per 1,000 Patients",
            "Adjusted Cost per Fill",
            "Total Budget Impact (USD)"
        ],
        fill_color='paleturquoise',
        align='center'),
        cells=dict(values=[
            df["Year"],
            np.round(df["Adjusted Fills per 1,000 Patients"], 2),
            np.round(df["Adjusted Cost per Fill"], 2),
            np.round(df["Total Budget Impact (USD)"], 2)
        ],
        fill_color='lavender',
        align='center'))
    ])
    table_fig.update_layout(height=600)

    return line_fig, corr_fig, table_fig

# %%
#34
import pandas as pd
import numpy as np
from dash import Dash, dcc, html, Input, Output
import plotly.graph_objs as go

# === Mock some data (replace later with your real final_df) ===
years = [2020, 2021, 2022, 2023, 2024, 2025]
fills = [120, 135, 150, 165, 180, 195]
costs = [850, 870, 890, 910, 930, 950]

final_df = pd.DataFrame({
    "Year": years,
    "Fills per 1,000 Patients": fills,
    "Avg Cost per Fill": costs
})

# === Start Dash App ===
app = Dash(__name__)

app.layout = html.Div([
    html.H1("Semaglutide Sensitivity Analysis Dashboard (Dash-Plotly)", style={'textAlign': 'center'}),

    html.Div([
        html.Label('Prevalence Shock (% Change):'),
        dcc.Dropdown(
            id='prevalence-shock',
            options=[
                {'label': '-5%', 'value': 0.95},
                {'label': '0%', 'value': 1.00},
                {'label': '+5%', 'value': 1.05}
            ],
            value=1.00,
            clearable=False
        ),
    ], style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
        html.Label('Cost Shock (% Change):'),
        dcc.Dropdown(
            id='cost-shock',
            options=[
                {'label': '0%', 'value': 1.00},
                {'label': '-10%', 'value': 0.90}
            ],
            value=1.00,
            clearable=False
        ),
    ], style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),

    html.Br(),

    dcc.Graph(id='fills-line-chart'),
    dcc.Graph(id='correlation-plot'),
    dcc.Graph(id='summary-table')
])

@app.callback(
    [Output('fills-line-chart', 'figure'),
     Output('correlation-plot', 'figure'),
     Output('summary-table', 'figure')],
    [Input('prevalence-shock', 'value'),
     Input('cost-shock', 'value')]
)
def update_graphs(prevalence_factor, cost_factor):
    df = final_df.copy()
    df["Adjusted Fills per 1,000 Patients"] = df["Fills per 1,000 Patients"] / prevalence_factor
    df["Adjusted Cost per Fill"] = df["Avg Cost per Fill"] * cost_factor
    df["Total Budget Impact (USD)"] = df["Adjusted Fills per 1,000 Patients"] * 1000 * df["Adjusted Cost per Fill"]

    # Line Chart
    line_fig = go.Figure()
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Adjusted Fills per 1,000 Patients"],
        mode='lines+markers',
        name='Fills'
    ))
    line_fig.add_trace(go.Scatter(
        x=df["Year"],
        y=df["Total Budget Impact (USD)"]/1e6,
        mode='lines+markers',
        name='Budget Impact (Million USD)',
        yaxis='y2'
    ))
    line_fig.update_layout(
        title="Adjusted Fills and Budget Impact Over Time",
        xaxis_title="Year",
        yaxis=dict(title="Fills per 1,000 Patients"),
        yaxis2=dict(title="Budget (Millions USD)", overlaying='y', side='right'),
        template="plotly_white"
    )

    # Correlation Plot
    corr_fig = go.Figure()
    corr_fig.add_trace(go.Scatter(
        x=df["Adjusted Fills per 1,000 Patients"],
        y=df["Total Budget Impact (USD)"]/1e6,
        mode='markers+text',
        text=df["Year"],
        textposition="top center"
    ))
    slope, intercept = np.polyfit(df["Adjusted Fills per 1,000 Patients"], df["Total Budget Impact (USD)"]/1e6, 1)
    fit_line = slope * df["Adjusted Fills per 1,000 Patients"] + intercept
    corr_fig.add_trace(go.Scatter(
        x=df["Adjusted Fills per 1,000 Patients"],
        y=fit_line,
        mode='lines',
        name=f"Fit: y = {slope:.2f}x + {intercept:.2f}"
    ))
    corr_fig.update_layout(
        title="Correlation: Fills vs Budget Impact",
        xaxis_title="Adjusted Fills per 1,000 Patients",
        yaxis_title="Budget Impact (Million USD)",
        template="plotly_white"
    )

    # Table
    table_fig = go.Figure(data=[go.Table(
        header=dict(values=["Year", "Adjusted Fills", "Adjusted Cost", "Total Budget Impact (USD)"]),
        cells=dict(values=[
            df["Year"],
            np.round(df["Adjusted Fills per 1,000 Patients"], 2),
            np.round(df["Adjusted Cost per Fill"], 2),
            np.round(df["Total Budget Impact (USD)"], 2)
        ])
    )])

    return line_fig, corr_fig, table_fig

# %%
#35
# Run App
if __name__ == '__main__':
    app.run(debug=True, port=8051)  # Changed from app.run_server to app.run

# %% [markdown]
# ## Dashboard App Setup (Dash Plotly)

# %% [markdown]
# ### 🖥️ Interactive Sensitivity Dashboard
#
# The following code launches an interactive dashboard.
# 👉 Access it locally via: **http://localhost:8051**

# %%
#36
# !python dash_app.py
# Out:
# python3: can't open file '/content/dash_app.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Summary Report Generation

# %% [markdown]
# ### 📝 Generate Summary Report
#
# This section generates a clean textual summary of base case findings and sensitivity insights.

# %%
#37
def generate_summary_report(final_df):
    """
    Generate a clean textual summary report based on final adjusted data.

    Args:
        final_df (pd.DataFrame): Final dataframe with adjusted fills and costs.

    Returns:
        report_text (str): Text report.
    """

    base_years = final_df["Year"].tolist()
    base_fills = np.round(final_df["Fills per 1,000 Patients"], 2).tolist()
    base_costs = np.round(final_df["Avg Cost per Fill"], 2).tolist()

    report = []
    report.append("# Semaglutide Sensitivity and Budget Impact Analysis Report")
    report.append("")
    report.append("## 1. Base Case Findings")
    report.append("")
    report.append("| Year | Fills per 1,000 Patients | Avg Cost per Fill (USD) |")
    report.append("|:----|:-------------------------|:------------------------|")

    for y, f, c in zip(base_years, base_fills, base_costs):
        report.append(f"| {y} | {f} | ${c} |")

    report.append("")
    report.append("## 2. Projected Budget Impact (Base Scenario)")
    report.append("")
    report.append("Assuming 1000 diabetic patients per 1,000 fills:")
    report.append("")

    for y, f, c in zip(base_years, base_fills, base_costs):
        impact = f * 1000 * c
        impact_million = impact / 1e6
        report.append(f"- **{y}** ➔ Estimated Total Spending: **${impact_million:.2f}M USD**")

    report.append("")
    report.append("## 3. Sensitivity Scenarios Overview")
    report.append("")
    report.append("**Prevalence Shock:**")
    report.append("- +5% Prevalence ➔ Slightly lower fills per patient but higher total burden.")
    report.append("- -5% Prevalence ➔ Slightly higher fills per patient, reduced system strain.")

    report.append("")
    report.append("**Cost Shock:**")
    report.append("- -10% Cost Shock ➔ Significant reduction in total budget impact (~10%).")
    report.append("")
    report.append("## 4. Key Insights")
    report.append("")
    report.append("- Semaglutide utilization shows steady growth from 2020 to 2025.")
    report.append("- Budget Impact expected to rise linearly with fills unless cost savings (biosimilars, price negotiations) intervene.")
    report.append("- Cost shocks have stronger leverage over total budget than prevalence changes.")

    return "\n".join(report)


report_text = generate_summary_report(final_df)

# Print preview
print(report_text)
# Out:
# # Semaglutide Sensitivity and Budget Impact Analysis Report
#
# ## 1. Base Case Findings
#
# | Year | Fills per 1,000 Patients | Avg Cost per Fill (USD) |
# |:----|:-------------------------|:------------------------|
# | 2020 | 120 | $850 |
# | 2021 | 135 | $870 |
# | 2022 | 150 | $890 |
# | 2023 | 165 | $910 |
# | 2024 | 180 | $930 |
# | 2025 | 195 | $950 |
#
# ## 2. Projected Budget Impact (Base Scenario)
#
# Assuming 1000 diabetic patients per 1,000 fills:
#
# - **2020** ➔ Estimated Total Spending: **$102.00M USD**
# - **2021** ➔ Estimated Total Spending: **$117.45M USD**
# - **2022** ➔ Estimated Total Spending: **$133.50M USD**
# - **2023** ➔ Estimated Total Spending: **$150.15M USD**
# - **2024** ➔ Estimated Total Spending: **$167.40M USD**
# - **2025** ➔ Estimated Total Spending: **$185.25M USD**
#
# ## 3. Sensitivity Scenarios Overview
#
# **Prevalence Shock:**
# - +5% Prevalence ➔ Slightly lower fills per patient but higher total burden.
# - -5% Prevalence ➔ Slightly higher fills per patient, reduced system strain.
#
# **Cost Shock:**
# - -10% Cost Shock ➔ Significant reduction in total budget impact (~10%).
#
# ## 4. Key Insights
#
# - Semaglutide utilization shows steady growth from 2020 to 2025.
# - Budget Impact expected to rise linearly with fills unless cost savings (biosimilars, price negotiations) intervene.
# - Cost shocks have stronger leverage over total budget than prevalence changes.

# %% [markdown]
# ## 📋 Conclusion
#
# - Semaglutide utilization is expected to increase steadily through 2025.
# - Budget impact scales almost linearly with patient fills.
# - Pricing shocks (e.g., biosimilars) have a large moderating effect on national expenditures.
# - Sensitivity analyses confirm model robustness under small perturbations.
#
# Next steps could involve adding multi-drug comparisons or real-world claims validation.
